# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

DATASET_CSV_PATH = DATASET_ROOTDIR_PATH + "_with_labels.csv"
print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring']

num_classes = len(class_names)
print(f"\n👁️ {num_classes} fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training_with_labels.csv
#
# 👁️ 4 fingerprints classes : ['thumb', 'index', 'middle', 'ring']
# Fingerprint model name : MobileNetV2_FingerPrint_Model_4_classes

# %% [markdown]
# ## Dataset Exploration

# %%
# load csv containing image file information for all classes regardless
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         23931 non-null  int64
#  1   ImagePath  23931 non-null  str
#  2   Finger     23931 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 561.0 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.98%
# Percentage of Little fingers: 20.01%

# %% [markdown]
# ## Build a dataframe with image file information only for the classes to be considered in this notebook

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19143 entries, 0 to 19142
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    19143 non-null  str
#  1   ImageFormat  19143 non-null  str
#  2   ImageSize    19143 non-null  object
#  3   ImageMode    19143 non-null  str
#  4   Finger       19143 non-null  str
# dtypes: object(1), str(4)
# memory usage: 747.9+ KB

# %%
# show distribution of columns
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    19143
# Name: count, dtype: int64
# ImageSize
# (96, 96)    19143
# Name: count, dtype: int64
# ImageMode
# RGB    19143
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 25.00%
# Percentage of Index fingers: 25.01%
# Percentage of Middle fingers: 25.01%
# Percentage of Ring fingers: 24.98%
# Percentage of Little fingers: 0.00%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Split dataset for training / validation / test

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)


TRAIN_VS_VALIDATION_TEST_SPLIT = 0.2
SPLIT_DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=TRAIN_VS_VALIDATION_TEST_SPLIT,
    subset="training",
    seed=SPLIT_DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_test_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=TRAIN_VS_VALIDATION_TEST_SPLIT,
    subset="validation",
    seed=SPLIT_DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names
)

# split validation dataset into 2 
val_batches = tf.data.experimental.cardinality(val_test_ds)

test_ds = val_test_ds.take(val_batches // 2)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(val_batches // 2)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 19143 files belonging to 4 classes.
# Using 15315 files for training.
# Found 19143 files belonging to 4 classes.
# Using 3828 files for validation.
# 2026-03-25 20:34:27.722441: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-25 20:34:27.722477: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-25 20:34:27.722492: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-25 20:34:27.722508: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-25 20:34:27.722526: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle', 'ring']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle', 'ring']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle', 'ring']
#   - ✅ Number of correct classes : 4
#
#   - Training batches    : 240
#   - Validation batches  : 30
#   - Test batches        : 30
#   - Batch size          : 64
#   - Training samples    : ~15360
#   - Validation samples  : ~1920
#   - Test samples        : ~1920

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("  - Test dataset       : Normalisation")

print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#   - Test dataset       : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

MobileNet_basename = MobileNet_version + "_FingerPrint_BaseModel"
if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x3028ba0c0>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x3028ba0c0>) → Dropout(0.3) → Dense(4,softmax)
#
#   - Trainable parameters     : 344,644
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,628
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_4_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,628 (9.93 MB)
#  Trainable params: 344,644 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 15
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 15 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-25 20:34:30.339285: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4445 - loss: 4.0532 - top2_accuracy: 0.6980
# Epoch 1: val_accuracy improved from None to 0.61688, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.5020 - loss: 2.7951 - top2_accuracy: 0.7541 - val_accuracy: 0.6169 - val_loss: 1.5205 - val_top2_accuracy: 0.8464 - learning_rate: 0.0010
# Epoch 2/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5665 - loss: 1.4436 - top2_accuracy: 0.8098
# Epoch 2: val_accuracy improved from 0.61688 to 0.62998, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.5667 - loss: 1.3555 - top2_accuracy: 0.8121 - val_accuracy: 0.6300 - val_loss: 1.1419 - val_top2_accuracy: 0.8548 - learning_rate: 0.0010
# Epoch 3/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5881 - loss: 1.1688 - top2_accuracy: 0.8221
# Epoch 3: val_accuracy improved from 0.62998 to 0.63470, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - accuracy: 0.5837 - loss: 1.1449 - top2_accuracy: 0.8264 - val_accuracy: 0.6347 - val_loss: 1.0540 - val_top2_accuracy: 0.8470 - learning_rate: 0.0010
# Epoch 4/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5959 - loss: 1.0840 - top2_accuracy: 0.8296
# Epoch 4: val_accuracy did not improve from 0.63470
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 16s 68ms/step - accuracy: 0.5899 - loss: 1.0857 - top2_accuracy: 0.8270 - val_accuracy: 0.6336 - val_loss: 1.0062 - val_top2_accuracy: 0.8601 - learning_rate: 0.0010
# Epoch 5/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5972 - loss: 1.0527 - top2_accuracy: 0.8260
# Epoch 5: val_accuracy improved from 0.63470 to 0.64570, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.5887 - loss: 1.0576 - top2_accuracy: 0.8253 - val_accuracy: 0.6457 - val_loss: 0.9766 - val_top2_accuracy: 0.8595 - learning_rate: 0.0010
# Epoch 6/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5984 - loss: 1.0406 - top2_accuracy: 0.8333
# Epoch 6: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - accuracy: 0.5922 - loss: 1.0461 - top2_accuracy: 0.8306 - val_accuracy: 0.6399 - val_loss: 0.9811 - val_top2_accuracy: 0.8517 - learning_rate: 0.0010
# Epoch 7/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5966 - loss: 1.0276 - top2_accuracy: 0.8330
# Epoch 7: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.5937 - loss: 1.0324 - top2_accuracy: 0.8315 - val_accuracy: 0.6436 - val_loss: 0.9611 - val_top2_accuracy: 0.8580 - learning_rate: 0.0010
# Epoch 8/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5965 - loss: 1.0236 - top2_accuracy: 0.8383
# Epoch 8: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.5935 - loss: 1.0278 - top2_accuracy: 0.8340 - val_accuracy: 0.6420 - val_loss: 0.9615 - val_top2_accuracy: 0.8606 - learning_rate: 0.0010
# Epoch 9/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6068 - loss: 1.0194 - top2_accuracy: 0.8329
# Epoch 9: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 31s 131ms/step - accuracy: 0.5995 - loss: 1.0253 - top2_accuracy: 0.8326 - val_accuracy: 0.6284 - val_loss: 0.9962 - val_top2_accuracy: 0.8590 - learning_rate: 0.0010
# Epoch 10/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6032 - loss: 1.0161 - top2_accuracy: 0.8341
# Epoch 10: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 33s 137ms/step - accuracy: 0.5969 - loss: 1.0246 - top2_accuracy: 0.8321 - val_accuracy: 0.6426 - val_loss: 0.9614 - val_top2_accuracy: 0.8669 - learning_rate: 0.0010
# Epoch 11/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6074 - loss: 1.0129 - top2_accuracy: 0.8407
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.64570
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 33s 136ms/step - accuracy: 0.5966 - loss: 1.0231 - top2_accuracy: 0.8345 - val_accuracy: 0.6368 - val_loss: 0.9699 - val_top2_accuracy: 0.8574 - learning_rate: 0.0010
# Epoch 12/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6128 - loss: 0.9905 - top2_accuracy: 0.8425
# Epoch 12: val_accuracy improved from 0.64570 to 0.66038, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 30s 124ms/step - accuracy: 0.6117 - loss: 0.9861 - top2_accuracy: 0.8427 - val_accuracy: 0.6604 - val_loss: 0.9124 - val_top2_accuracy: 0.8800 - learning_rate: 5.0000e-04
# Epoch 13/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6247 - loss: 0.9680 - top2_accuracy: 0.8523
# Epoch 13: val_accuracy improved from 0.66038 to 0.66352, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 13: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 25s 105ms/step - accuracy: 0.6199 - loss: 0.9723 - top2_accuracy: 0.8520 - val_accuracy: 0.6635 - val_loss: 0.9065 - val_top2_accuracy: 0.8716 - learning_rate: 5.0000e-04
# Epoch 14/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6180 - loss: 0.9711 - top2_accuracy: 0.8486
# Epoch 14: val_accuracy improved from 0.66352 to 0.66614, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 14: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 24s 98ms/step - accuracy: 0.6159 - loss: 0.9691 - top2_accuracy: 0.8503 - val_accuracy: 0.6661 - val_loss: 0.9079 - val_top2_accuracy: 0.8795 - learning_rate: 5.0000e-04
# Epoch 15/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6209 - loss: 0.9602 - top2_accuracy: 0.8471
# Epoch 15: val_accuracy improved from 0.66614 to 0.67086, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 25s 103ms/step - accuracy: 0.6185 - loss: 0.9608 - top2_accuracy: 0.8496 - val_accuracy: 0.6709 - val_loss: 0.9119 - val_top2_accuracy: 0.8763 - learning_rate: 5.0000e-04
# Epoch 16/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6259 - loss: 0.9604 - top2_accuracy: 0.8546
# Epoch 16: val_accuracy improved from 0.67086 to 0.67715, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 26s 107ms/step - accuracy: 0.6195 - loss: 0.9595 - top2_accuracy: 0.8557 - val_accuracy: 0.6771 - val_loss: 0.8942 - val_top2_accuracy: 0.8894 - learning_rate: 5.0000e-04
# Epoch 17/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6208 - loss: 0.9564 - top2_accuracy: 0.8539
# Epoch 17: val_accuracy did not improve from 0.67715
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 26s 110ms/step - accuracy: 0.6173 - loss: 0.9618 - top2_accuracy: 0.8507 - val_accuracy: 0.6656 - val_loss: 0.8916 - val_top2_accuracy: 0.8831 - learning_rate: 5.0000e-04
# Epoch 18/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6343 - loss: 0.9453 - top2_accuracy: 0.8570
# Epoch 18: val_accuracy improved from 0.67715 to 0.68501, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 18: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 24s 99ms/step - accuracy: 0.6276 - loss: 0.9524 - top2_accuracy: 0.8545 - val_accuracy: 0.6850 - val_loss: 0.8958 - val_top2_accuracy: 0.8847 - learning_rate: 5.0000e-04
# Epoch 19/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6274 - loss: 0.9515 - top2_accuracy: 0.8564
# Epoch 19: val_accuracy did not improve from 0.68501
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.6260 - loss: 0.9502 - top2_accuracy: 0.8542 - val_accuracy: 0.6766 - val_loss: 0.8873 - val_top2_accuracy: 0.8857 - learning_rate: 5.0000e-04
# Epoch 20/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6384 - loss: 0.9414 - top2_accuracy: 0.8548
# Epoch 20: val_accuracy did not improve from 0.68501
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.6277 - loss: 0.9520 - top2_accuracy: 0.8522 - val_accuracy: 0.6787 - val_loss: 0.8912 - val_top2_accuracy: 0.8795 - learning_rate: 5.0000e-04
# Epoch 21/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6336 - loss: 0.9502 - top2_accuracy: 0.8542
# Epoch 21: val_accuracy did not improve from 0.68501
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.6255 - loss: 0.9538 - top2_accuracy: 0.8537 - val_accuracy: 0.6771 - val_loss: 0.8874 - val_top2_accuracy: 0.8789 - learning_rate: 5.0000e-04
# Epoch 22/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6385 - loss: 0.9448 - top2_accuracy: 0.8629
# Epoch 22: val_accuracy did not improve from 0.68501
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 81ms/step - accuracy: 0.6357 - loss: 0.9424 - top2_accuracy: 0.8612 - val_accuracy: 0.6834 - val_loss: 0.8785 - val_top2_accuracy: 0.8863 - learning_rate: 5.0000e-04
# Epoch 23/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6313 - loss: 0.9420 - top2_accuracy: 0.8595
# Epoch 23: val_accuracy did not improve from 0.68501
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 85ms/step - accuracy: 0.6268 - loss: 0.9463 - top2_accuracy: 0.8549 - val_accuracy: 0.6766 - val_loss: 0.8864 - val_top2_accuracy: 0.8789 - learning_rate: 5.0000e-04
# Epoch 24/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6344 - loss: 0.9437 - top2_accuracy: 0.8619
# Epoch 24: val_accuracy improved from 0.68501 to 0.69078, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.6289 - loss: 0.9473 - top2_accuracy: 0.8565 - val_accuracy: 0.6908 - val_loss: 0.8771 - val_top2_accuracy: 0.8936 - learning_rate: 5.0000e-04
# Epoch 25/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6370 - loss: 0.9353 - top2_accuracy: 0.8662
# Epoch 25: val_accuracy did not improve from 0.69078
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - accuracy: 0.6285 - loss: 0.9417 - top2_accuracy: 0.8618 - val_accuracy: 0.6845 - val_loss: 0.8860 - val_top2_accuracy: 0.8842 - learning_rate: 5.0000e-04
# Epoch 26/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6371 - loss: 0.9473 - top2_accuracy: 0.8589
# Epoch 26: val_accuracy did not improve from 0.69078
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.6325 - loss: 0.9421 - top2_accuracy: 0.8591 - val_accuracy: 0.6798 - val_loss: 0.8863 - val_top2_accuracy: 0.8842 - learning_rate: 5.0000e-04
# Epoch 27/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6317 - loss: 0.9387 - top2_accuracy: 0.8621
# Epoch 27: val_accuracy did not improve from 0.69078
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 87ms/step - accuracy: 0.6310 - loss: 0.9448 - top2_accuracy: 0.8601 - val_accuracy: 0.6787 - val_loss: 0.8786 - val_top2_accuracy: 0.8915 - learning_rate: 5.0000e-04
# Epoch 28/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6272 - loss: 0.9456 - top2_accuracy: 0.8557
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 28: val_accuracy did not improve from 0.69078
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 25s 105ms/step - accuracy: 0.6291 - loss: 0.9412 - top2_accuracy: 0.8584 - val_accuracy: 0.6819 - val_loss: 0.8797 - val_top2_accuracy: 0.8905 - learning_rate: 5.0000e-04
# Epoch 29/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6374 - loss: 0.9320 - top2_accuracy: 0.8594
# Epoch 29: val_accuracy did not improve from 0.69078
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 22s 92ms/step - accuracy: 0.6361 - loss: 0.9246 - top2_accuracy: 0.8633 - val_accuracy: 0.6908 - val_loss: 0.8538 - val_top2_accuracy: 0.8926 - learning_rate: 2.5000e-04
# Epoch 30/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6559 - loss: 0.9031 - top2_accuracy: 0.8661
# Epoch 30: val_accuracy improved from 0.69078 to 0.69602, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 22s 91ms/step - accuracy: 0.6522 - loss: 0.9019 - top2_accuracy: 0.8659 - val_accuracy: 0.6960 - val_loss: 0.8487 - val_top2_accuracy: 0.8994 - learning_rate: 2.5000e-04
# Epoch 31/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6555 - loss: 0.8961 - top2_accuracy: 0.8724
# Epoch 31: val_accuracy did not improve from 0.69602
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 87ms/step - accuracy: 0.6518 - loss: 0.8987 - top2_accuracy: 0.8742 - val_accuracy: 0.6850 - val_loss: 0.8561 - val_top2_accuracy: 0.8847 - learning_rate: 2.5000e-04
# Epoch 32/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6555 - loss: 0.9043 - top2_accuracy: 0.8662
# Epoch 32: val_accuracy did not improve from 0.69602
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 25s 105ms/step - accuracy: 0.6464 - loss: 0.9075 - top2_accuracy: 0.8665 - val_accuracy: 0.6960 - val_loss: 0.8457 - val_top2_accuracy: 0.8910 - learning_rate: 2.5000e-04
# Epoch 33/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6516 - loss: 0.9000 - top2_accuracy: 0.8693
# Epoch 33: val_accuracy did not improve from 0.69602
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.6482 - loss: 0.9006 - top2_accuracy: 0.8697 - val_accuracy: 0.6939 - val_loss: 0.8326 - val_top2_accuracy: 0.9046 - learning_rate: 2.5000e-04
# Epoch 34/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6507 - loss: 0.8954 - top2_accuracy: 0.8673
# Epoch 34: val_accuracy improved from 0.69602 to 0.70283, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 34: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 81ms/step - accuracy: 0.6470 - loss: 0.8980 - top2_accuracy: 0.8686 - val_accuracy: 0.7028 - val_loss: 0.8345 - val_top2_accuracy: 0.8994 - learning_rate: 2.5000e-04
# Epoch 35/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6478 - loss: 0.8954 - top2_accuracy: 0.8693
# Epoch 35: val_accuracy improved from 0.70283 to 0.70388, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 35: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 79ms/step - accuracy: 0.6463 - loss: 0.8946 - top2_accuracy: 0.8710 - val_accuracy: 0.7039 - val_loss: 0.8385 - val_top2_accuracy: 0.8978 - learning_rate: 2.5000e-04
# Epoch 36/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6530 - loss: 0.8924 - top2_accuracy: 0.8712
# Epoch 36: val_accuracy did not improve from 0.70388
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - accuracy: 0.6482 - loss: 0.8971 - top2_accuracy: 0.8698 - val_accuracy: 0.6965 - val_loss: 0.8343 - val_top2_accuracy: 0.8978 - learning_rate: 2.5000e-04
# Epoch 37/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6614 - loss: 0.8849 - top2_accuracy: 0.8708
# Epoch 37: val_accuracy improved from 0.70388 to 0.70597, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 37: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.6556 - loss: 0.8921 - top2_accuracy: 0.8712 - val_accuracy: 0.7060 - val_loss: 0.8296 - val_top2_accuracy: 0.9051 - learning_rate: 2.5000e-04
# Epoch 38/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6521 - loss: 0.8885 - top2_accuracy: 0.8725
# Epoch 38: val_accuracy did not improve from 0.70597
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 85ms/step - accuracy: 0.6496 - loss: 0.8911 - top2_accuracy: 0.8743 - val_accuracy: 0.7028 - val_loss: 0.8306 - val_top2_accuracy: 0.8983 - learning_rate: 2.5000e-04
# Epoch 39/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6510 - loss: 0.8868 - top2_accuracy: 0.8721
# Epoch 39: val_accuracy did not improve from 0.70597
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.6497 - loss: 0.8920 - top2_accuracy: 0.8712 - val_accuracy: 0.7007 - val_loss: 0.8342 - val_top2_accuracy: 0.8968 - learning_rate: 2.5000e-04
# Epoch 40/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6561 - loss: 0.8824 - top2_accuracy: 0.8785
# Epoch 40: val_accuracy did not improve from 0.70597
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.6558 - loss: 0.8825 - top2_accuracy: 0.8774 - val_accuracy: 0.6971 - val_loss: 0.8372 - val_top2_accuracy: 0.8936 - learning_rate: 2.5000e-04
# Epoch 41/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6560 - loss: 0.8843 - top2_accuracy: 0.8736
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 41: val_accuracy did not improve from 0.70597
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.6541 - loss: 0.8867 - top2_accuracy: 0.8746 - val_accuracy: 0.6923 - val_loss: 0.8446 - val_top2_accuracy: 0.9046 - learning_rate: 2.5000e-04
# Epoch 42/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6527 - loss: 0.8778 - top2_accuracy: 0.8749
# Epoch 42: val_accuracy improved from 0.70597 to 0.71069, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 42: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.6577 - loss: 0.8725 - top2_accuracy: 0.8778 - val_accuracy: 0.7107 - val_loss: 0.8141 - val_top2_accuracy: 0.9057 - learning_rate: 1.2500e-04
# Epoch 43/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6686 - loss: 0.8658 - top2_accuracy: 0.8834
# Epoch 43: val_accuracy improved from 0.71069 to 0.71331, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 43: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 85ms/step - accuracy: 0.6664 - loss: 0.8651 - top2_accuracy: 0.8829 - val_accuracy: 0.7133 - val_loss: 0.8144 - val_top2_accuracy: 0.9067 - learning_rate: 1.2500e-04
# Epoch 44/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6699 - loss: 0.8555 - top2_accuracy: 0.8856
# Epoch 44: val_accuracy did not improve from 0.71331
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 79ms/step - accuracy: 0.6652 - loss: 0.8592 - top2_accuracy: 0.8851 - val_accuracy: 0.7102 - val_loss: 0.8031 - val_top2_accuracy: 0.9083 - learning_rate: 1.2500e-04
# Epoch 45/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6626 - loss: 0.8599 - top2_accuracy: 0.8826
# Epoch 45: val_accuracy improved from 0.71331 to 0.71384, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 45: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - accuracy: 0.6669 - loss: 0.8564 - top2_accuracy: 0.8825 - val_accuracy: 0.7138 - val_loss: 0.8089 - val_top2_accuracy: 0.9072 - learning_rate: 1.2500e-04
# Epoch 46/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6707 - loss: 0.8503 - top2_accuracy: 0.8890
# Epoch 46: val_accuracy did not improve from 0.71384
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.6677 - loss: 0.8546 - top2_accuracy: 0.8870 - val_accuracy: 0.7102 - val_loss: 0.8112 - val_top2_accuracy: 0.9020 - learning_rate: 1.2500e-04
# Epoch 47/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6648 - loss: 0.8532 - top2_accuracy: 0.8813
# Epoch 47: val_accuracy improved from 0.71384 to 0.71646, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 47: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.6650 - loss: 0.8528 - top2_accuracy: 0.8810 - val_accuracy: 0.7165 - val_loss: 0.8015 - val_top2_accuracy: 0.9067 - learning_rate: 1.2500e-04
# Epoch 48/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6621 - loss: 0.8569 - top2_accuracy: 0.8822
# Epoch 48: val_accuracy did not improve from 0.71646
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 80ms/step - accuracy: 0.6599 - loss: 0.8608 - top2_accuracy: 0.8841 - val_accuracy: 0.7128 - val_loss: 0.8079 - val_top2_accuracy: 0.9099 - learning_rate: 1.2500e-04
# Epoch 49/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6704 - loss: 0.8537 - top2_accuracy: 0.8819
# Epoch 49: val_accuracy improved from 0.71646 to 0.72117, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 49: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.6641 - loss: 0.8575 - top2_accuracy: 0.8813 - val_accuracy: 0.7212 - val_loss: 0.8027 - val_top2_accuracy: 0.9036 - learning_rate: 1.2500e-04
# Epoch 50/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6700 - loss: 0.8535 - top2_accuracy: 0.8853
# Epoch 50: val_accuracy improved from 0.72117 to 0.72170, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 50: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 77ms/step - accuracy: 0.6697 - loss: 0.8521 - top2_accuracy: 0.8850 - val_accuracy: 0.7217 - val_loss: 0.8034 - val_top2_accuracy: 0.9067 - learning_rate: 1.2500e-04
# Epoch 51/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6658 - loss: 0.8537 - top2_accuracy: 0.8853
# Epoch 51: val_accuracy did not improve from 0.72170
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.6635 - loss: 0.8544 - top2_accuracy: 0.8840 - val_accuracy: 0.7217 - val_loss: 0.7960 - val_top2_accuracy: 0.9062 - learning_rate: 1.2500e-04
# Epoch 52/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6745 - loss: 0.8454 - top2_accuracy: 0.8901
# Epoch 52: val_accuracy did not improve from 0.72170
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.6726 - loss: 0.8468 - top2_accuracy: 0.8874 - val_accuracy: 0.7138 - val_loss: 0.7944 - val_top2_accuracy: 0.9020 - learning_rate: 1.2500e-04
# Epoch 53/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6757 - loss: 0.8469 - top2_accuracy: 0.8839
# Epoch 53: val_accuracy did not improve from 0.72170
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - accuracy: 0.6736 - loss: 0.8469 - top2_accuracy: 0.8863 - val_accuracy: 0.7212 - val_loss: 0.7926 - val_top2_accuracy: 0.9093 - learning_rate: 1.2500e-04
# Epoch 54/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6636 - loss: 0.8552 - top2_accuracy: 0.8855
# Epoch 54: val_accuracy improved from 0.72170 to 0.72327, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 54: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 79ms/step - accuracy: 0.6654 - loss: 0.8561 - top2_accuracy: 0.8831 - val_accuracy: 0.7233 - val_loss: 0.7916 - val_top2_accuracy: 0.9104 - learning_rate: 1.2500e-04
# Epoch 55/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6702 - loss: 0.8430 - top2_accuracy: 0.8824
# Epoch 55: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.6682 - loss: 0.8452 - top2_accuracy: 0.8835 - val_accuracy: 0.7217 - val_loss: 0.7942 - val_top2_accuracy: 0.9109 - learning_rate: 1.2500e-04
# Epoch 56/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6751 - loss: 0.8403 - top2_accuracy: 0.8840
# Epoch 56: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6714 - loss: 0.8432 - top2_accuracy: 0.8875 - val_accuracy: 0.7138 - val_loss: 0.7949 - val_top2_accuracy: 0.9093 - learning_rate: 1.2500e-04
# Epoch 57/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6746 - loss: 0.8441 - top2_accuracy: 0.8906
# Epoch 57: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6728 - loss: 0.8460 - top2_accuracy: 0.8884 - val_accuracy: 0.7175 - val_loss: 0.7885 - val_top2_accuracy: 0.9083 - learning_rate: 1.2500e-04
# Epoch 58/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6707 - loss: 0.8584 - top2_accuracy: 0.8865
# Epoch 58: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6666 - loss: 0.8546 - top2_accuracy: 0.8866 - val_accuracy: 0.7227 - val_loss: 0.7910 - val_top2_accuracy: 0.9099 - learning_rate: 1.2500e-04
# Epoch 59/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6731 - loss: 0.8359 - top2_accuracy: 0.8890
# Epoch 59: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 79ms/step - accuracy: 0.6712 - loss: 0.8385 - top2_accuracy: 0.8881 - val_accuracy: 0.7222 - val_loss: 0.7913 - val_top2_accuracy: 0.9104 - learning_rate: 1.2500e-04
# Epoch 60/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6743 - loss: 0.8419 - top2_accuracy: 0.8868
# Epoch 60: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 80ms/step - accuracy: 0.6735 - loss: 0.8398 - top2_accuracy: 0.8906 - val_accuracy: 0.7165 - val_loss: 0.7940 - val_top2_accuracy: 0.9114 - learning_rate: 1.2500e-04
# Epoch 61/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6770 - loss: 0.8398 - top2_accuracy: 0.8903
# Epoch 61: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.6746 - loss: 0.8377 - top2_accuracy: 0.8896 - val_accuracy: 0.7191 - val_loss: 0.7839 - val_top2_accuracy: 0.9140 - learning_rate: 1.2500e-04
# Epoch 62/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6775 - loss: 0.8372 - top2_accuracy: 0.8952
# Epoch 62: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.6778 - loss: 0.8369 - top2_accuracy: 0.8949 - val_accuracy: 0.7175 - val_loss: 0.7856 - val_top2_accuracy: 0.9135 - learning_rate: 1.2500e-04
# Epoch 63/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6711 - loss: 0.8394 - top2_accuracy: 0.8882
# Epoch 63: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.6716 - loss: 0.8389 - top2_accuracy: 0.8873 - val_accuracy: 0.7201 - val_loss: 0.7857 - val_top2_accuracy: 0.9119 - learning_rate: 1.2500e-04
# Epoch 64/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6743 - loss: 0.8346 - top2_accuracy: 0.8904
# Epoch 64: val_accuracy did not improve from 0.72327
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6737 - loss: 0.8312 - top2_accuracy: 0.8935 - val_accuracy: 0.7175 - val_loss: 0.7905 - val_top2_accuracy: 0.9130 - learning_rate: 1.2500e-04
# Epoch 65/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6754 - loss: 0.8419 - top2_accuracy: 0.8886
# Epoch 65: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 65: val_accuracy improved from 0.72327 to 0.72642, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 65: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 73ms/step - accuracy: 0.6724 - loss: 0.8419 - top2_accuracy: 0.8883 - val_accuracy: 0.7264 - val_loss: 0.7923 - val_top2_accuracy: 0.9119 - learning_rate: 1.2500e-04
# Epoch 66/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6812 - loss: 0.8297 - top2_accuracy: 0.8849
# Epoch 66: val_accuracy did not improve from 0.72642
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6819 - loss: 0.8251 - top2_accuracy: 0.8901 - val_accuracy: 0.7212 - val_loss: 0.7815 - val_top2_accuracy: 0.9151 - learning_rate: 6.2500e-05
# Epoch 67/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6820 - loss: 0.8316 - top2_accuracy: 0.8925
# Epoch 67: val_accuracy did not improve from 0.72642
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.6804 - loss: 0.8278 - top2_accuracy: 0.8935 - val_accuracy: 0.7227 - val_loss: 0.7784 - val_top2_accuracy: 0.9182 - learning_rate: 6.2500e-05
# Epoch 68/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6802 - loss: 0.8288 - top2_accuracy: 0.8919
# Epoch 68: val_accuracy did not improve from 0.72642
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6796 - loss: 0.8265 - top2_accuracy: 0.8932 - val_accuracy: 0.7264 - val_loss: 0.7819 - val_top2_accuracy: 0.9146 - learning_rate: 6.2500e-05
# Epoch 69/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6851 - loss: 0.8141 - top2_accuracy: 0.8956
# Epoch 69: val_accuracy did not improve from 0.72642
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.6824 - loss: 0.8157 - top2_accuracy: 0.8981 - val_accuracy: 0.7254 - val_loss: 0.7767 - val_top2_accuracy: 0.9182 - learning_rate: 6.2500e-05
# Epoch 70/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6839 - loss: 0.8225 - top2_accuracy: 0.8955
# Epoch 70: val_accuracy did not improve from 0.72642
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6807 - loss: 0.8196 - top2_accuracy: 0.8977 - val_accuracy: 0.7254 - val_loss: 0.7732 - val_top2_accuracy: 0.9188 - learning_rate: 6.2500e-05
# Epoch 71/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6831 - loss: 0.8166 - top2_accuracy: 0.8932
# Epoch 71: val_accuracy improved from 0.72642 to 0.73218, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 71: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 73ms/step - accuracy: 0.6818 - loss: 0.8239 - top2_accuracy: 0.8925 - val_accuracy: 0.7322 - val_loss: 0.7717 - val_top2_accuracy: 0.9214 - learning_rate: 6.2500e-05
# Epoch 72/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6829 - loss: 0.8186 - top2_accuracy: 0.8975
# Epoch 72: val_accuracy did not improve from 0.73218
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 81ms/step - accuracy: 0.6838 - loss: 0.8177 - top2_accuracy: 0.8966 - val_accuracy: 0.7269 - val_loss: 0.7774 - val_top2_accuracy: 0.9167 - learning_rate: 6.2500e-05
# Epoch 73/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6889 - loss: 0.8178 - top2_accuracy: 0.8944
# Epoch 73: val_accuracy did not improve from 0.73218
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.6860 - loss: 0.8168 - top2_accuracy: 0.8940 - val_accuracy: 0.7290 - val_loss: 0.7699 - val_top2_accuracy: 0.9209 - learning_rate: 6.2500e-05
# Epoch 74/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6889 - loss: 0.8176 - top2_accuracy: 0.8946
# Epoch 74: val_accuracy did not improve from 0.73218
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 77ms/step - accuracy: 0.6861 - loss: 0.8176 - top2_accuracy: 0.8951 - val_accuracy: 0.7311 - val_loss: 0.7719 - val_top2_accuracy: 0.9156 - learning_rate: 6.2500e-05
# Epoch 75/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6950 - loss: 0.8112 - top2_accuracy: 0.8963
# Epoch 75: val_accuracy did not improve from 0.73218
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.6910 - loss: 0.8093 - top2_accuracy: 0.8985 - val_accuracy: 0.7285 - val_loss: 0.7681 - val_top2_accuracy: 0.9114 - learning_rate: 6.2500e-05
# Epoch 76/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6868 - loss: 0.8200 - top2_accuracy: 0.8923
# Epoch 76: val_accuracy did not improve from 0.73218
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 77ms/step - accuracy: 0.6846 - loss: 0.8222 - top2_accuracy: 0.8938 - val_accuracy: 0.7248 - val_loss: 0.7753 - val_top2_accuracy: 0.9119 - learning_rate: 6.2500e-05
# Epoch 77/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6853 - loss: 0.8156 - top2_accuracy: 0.8923
# Epoch 77: val_accuracy improved from 0.73218 to 0.73375, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 77: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.6868 - loss: 0.8147 - top2_accuracy: 0.8959 - val_accuracy: 0.7338 - val_loss: 0.7729 - val_top2_accuracy: 0.9177 - learning_rate: 6.2500e-05
# Epoch 78/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6893 - loss: 0.8203 - top2_accuracy: 0.8938
# Epoch 78: val_accuracy did not improve from 0.73375
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.6919 - loss: 0.8188 - top2_accuracy: 0.8949 - val_accuracy: 0.7269 - val_loss: 0.7725 - val_top2_accuracy: 0.9172 - learning_rate: 6.2500e-05
# Epoch 79/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6866 - loss: 0.8133 - top2_accuracy: 0.8925
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 79: val_accuracy did not improve from 0.73375
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 16s 68ms/step - accuracy: 0.6853 - loss: 0.8139 - top2_accuracy: 0.8932 - val_accuracy: 0.7285 - val_loss: 0.7691 - val_top2_accuracy: 0.9177 - learning_rate: 6.2500e-05
# Epoch 80/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6936 - loss: 0.8112 - top2_accuracy: 0.8968
# Epoch 80: val_accuracy did not improve from 0.73375
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - accuracy: 0.6907 - loss: 0.8105 - top2_accuracy: 0.8972 - val_accuracy: 0.7322 - val_loss: 0.7662 - val_top2_accuracy: 0.9214 - learning_rate: 3.1250e-05
# Epoch 81/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6840 - loss: 0.8074 - top2_accuracy: 0.8997
# Epoch 81: val_accuracy did not improve from 0.73375
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - accuracy: 0.6848 - loss: 0.8086 - top2_accuracy: 0.8982 - val_accuracy: 0.7338 - val_loss: 0.7667 - val_top2_accuracy: 0.9214 - learning_rate: 3.1250e-05
# Epoch 82/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6907 - loss: 0.8088 - top2_accuracy: 0.8985
# Epoch 82: val_accuracy improved from 0.73375 to 0.73428, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 82: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.6878 - loss: 0.8096 - top2_accuracy: 0.8962 - val_accuracy: 0.7343 - val_loss: 0.7639 - val_top2_accuracy: 0.9198 - learning_rate: 3.1250e-05
# Epoch 83/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6901 - loss: 0.8026 - top2_accuracy: 0.8978
# Epoch 83: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - accuracy: 0.6900 - loss: 0.8056 - top2_accuracy: 0.8989 - val_accuracy: 0.7327 - val_loss: 0.7662 - val_top2_accuracy: 0.9230 - learning_rate: 3.1250e-05
# Epoch 84/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6880 - loss: 0.8090 - top2_accuracy: 0.8960
# Epoch 84: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - accuracy: 0.6855 - loss: 0.8105 - top2_accuracy: 0.8984 - val_accuracy: 0.7322 - val_loss: 0.7668 - val_top2_accuracy: 0.9203 - learning_rate: 3.1250e-05
# Epoch 85/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6944 - loss: 0.7994 - top2_accuracy: 0.9003
# Epoch 85: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 19s 79ms/step - accuracy: 0.6898 - loss: 0.8030 - top2_accuracy: 0.8993 - val_accuracy: 0.7306 - val_loss: 0.7651 - val_top2_accuracy: 0.9219 - learning_rate: 3.1250e-05
# Epoch 86/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6914 - loss: 0.8074 - top2_accuracy: 0.8948
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 86: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.6930 - loss: 0.8022 - top2_accuracy: 0.9001 - val_accuracy: 0.7296 - val_loss: 0.7640 - val_top2_accuracy: 0.9188 - learning_rate: 3.1250e-05
# Epoch 87/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6852 - loss: 0.8064 - top2_accuracy: 0.8990
# Epoch 87: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - accuracy: 0.6867 - loss: 0.8071 - top2_accuracy: 0.8987 - val_accuracy: 0.7311 - val_loss: 0.7638 - val_top2_accuracy: 0.9224 - learning_rate: 1.5625e-05
# Epoch 88/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6927 - loss: 0.8019 - top2_accuracy: 0.8999
# Epoch 88: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.6904 - loss: 0.7996 - top2_accuracy: 0.9009 - val_accuracy: 0.7343 - val_loss: 0.7655 - val_top2_accuracy: 0.9214 - learning_rate: 1.5625e-05
# Epoch 89/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6903 - loss: 0.8052 - top2_accuracy: 0.9000
# Epoch 89: val_accuracy did not improve from 0.73428
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.6893 - loss: 0.8043 - top2_accuracy: 0.8997 - val_accuracy: 0.7327 - val_loss: 0.7634 - val_top2_accuracy: 0.9230 - learning_rate: 1.5625e-05
# Epoch 90/90
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6957 - loss: 0.7989 - top2_accuracy: 0.9019
# Epoch 90: val_accuracy improved from 0.73428 to 0.73585, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 90: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - accuracy: 0.6960 - loss: 0.7964 - top2_accuracy: 0.9026 - val_accuracy: 0.7358 - val_loss: 0.7618 - val_top2_accuracy: 0.9219 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 90.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 90
#    Best val_accuracy : 73.58% (epoch 90)
#
# ✅ Good result : 73.6%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
# 2026-03-25 21:04:23.450539: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=ring         | Prediction=ring         | Confidence= 57.8% | 2nd Prediction=middle       | 2nd Confidence= 27.0%
# ✅ Image 2: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 3: Label=index        | Prediction=index        | Confidence= 79.5% | 2nd Prediction=middle       | 2nd Confidence= 12.8%
# ✅ Image 4: Label=index        | Prediction=index        | Confidence= 75.8% | 2nd Prediction=middle       | 2nd Confidence= 14.3%
# ❌ Image 5: Label=ring         | Prediction=middle       | Confidence= 54.7% | 2nd Prediction=ring         | 2nd Confidence= 41.3%
# ✅ Image 6: Label=index        | Prediction=index        | Confidence= 42.5% | 2nd Prediction=ring         | 2nd Confidence= 33.1%
# ✅ Image 7: Label=ring         | Prediction=ring         | Confidence= 52.0% | 2nd Prediction=middle       | 2nd Confidence= 39.2%
# ✅ Image 8: Label=ring         | Prediction=ring         | Confidence= 48.8% | 2nd Prediction=middle       | 2nd Confidence= 29.9%
# ❌ Image 9: Label=middle       | Prediction=index        | Confidence= 46.7% | 2nd Prediction=middle       | 2nd Confidence= 33.0%
# ❌ Image 10: Label=middle       | Prediction=ring         | Confidence= 78.9% | 2nd Prediction=middle       | 2nd Confidence= 20.4%
# ✅ Image 11: Label=middle       | Prediction=middle       | Confidence= 56.1% | 2nd Prediction=index        | 2nd Confidence= 29.5%
# ✅ Image 12: Label=index        | Prediction=index        | Confidence= 47.2% | 2nd Prediction=middle       | 2nd Confidence= 38.5%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence= 67.4% | 2nd Prediction=ring         | 2nd Confidence= 16.9%
# ✅ Image 14: Label=index        | Prediction=index        | Confidence= 61.7% | 2nd Prediction=middle       | 2nd Confidence= 18.8%
# ✅ Image 15: Label=thumb        | Prediction=thumb        | Confidence= 88.7% | 2nd Prediction=ring         | 2nd Confidence=  4.2%
# ✅ Image 16: Label=thumb        | Prediction=thumb        | Confidence= 99.3% | 2nd Prediction=index        | 2nd Confidence=  0.4%
# ❌ Image 17: Label=index        | Prediction=ring         | Confidence= 61.3% | 2nd Prediction=middle       | 2nd Confidence= 19.6%
# ✅ Image 18: Label=ring         | Prediction=ring         | Confidence= 46.9% | 2nd Prediction=middle       | 2nd Confidence= 33.9%
# ❌ Image 19: Label=thumb        | Prediction=middle       | Confidence= 52.9% | 2nd Prediction=index        | 2nd Confidence= 24.2%
# ❌ Image 20: Label=index        | Prediction=thumb        | Confidence= 56.2% | 2nd Prediction=index        | 2nd Confidence= 32.0%
#
# ======================================================================================================================================================
# 2026-03-25 21:04:25.811256: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of frozen model using test dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using test dataset...
#
# Results :
#   - Loss                : 0.7527
#   - Accuracy            : 73.02%
#   - Top-2 Accuracy      : 92.19%
