# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
#
# 👁️ fingerprints classes : ['thumb', 'index']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_2_classes

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_test_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation/Test Dataset Classes      : {val_test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset!")
    print(f"   Classes found: {train_ds.class_names}\n")
    exit(0)
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation/test dataset!")
    print(f"   Classes found : {val_test_ds.class_names}")
    exit(0)
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

# split validation dataset into 2 
val_batches = tf.data.experimental.cardinality(val_test_ds)

test_ds = val_test_ds.take(val_batches // 2)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(val_batches // 2)
val_ds.class_names = class_names

print(f"  - Training batches      : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Test batches          : {len(test_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples          : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 9573 files belonging to 2 classes.
# Using 7659 files for training.
# Found 9573 files belonging to 2 classes.
# Using 1914 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index']
#   - Validation/Test Dataset Classes      : ['thumb', 'index']
#   - ✅ Number of correct classes : 2
#
#   - Training batches      : 120
#   - Validation batches    : 15
#   - Test batches          : 15
#   - Batch size            : 64
#   - Training samples      : ~7680
#   - Validation samples    : ~960
#   - Test samples          : ~960
# 2026-03-25 17:21:44.394631: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-25 17:21:44.394658: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-25 17:21:44.394666: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-25 17:21:44.394684: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-25 17:21:44.394695: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset             : normalisation + shuffle")
print("  - Validation and test dataset  : normalisation only")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset             : normalisation + shuffle
#   - Validation and test dataset  : normalisation only
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 2)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,498
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 2)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_2_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,291,528 (12.56 MB)
#  Trainable params: 344,514 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,030 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-25 17:21:46.109658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 92.92%
#   - Loss     : 0.2229

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants

# Number of layers in the model 
NUM_BASE_MODEL_LAYERS = len(frozen_fingerprint_basemodel.layers)

# keep ratio of 1/3 unfrozen layers vs. 2/3 frozen layers
UNFROZEN_FROZEN_LAYERS_RATIO = 0.33
NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS = int(NUM_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_LAYERS_RATIO)

# Keep ratio of 1/3 unfrozen first layers vs. 2/3 unfrozen last layers
UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO = 0.33
FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO)
FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS - FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS)

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")
print(f"Number of layers in the base model                      : {NUM_BASE_MODEL_LAYERS}")
print(f"Number of the first unfrozen layers in the base model   : {FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS}")
print(f"Number of the last unfrozen layers in the base model   : {FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS}")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Unfreeze the first FINE_TUNING_UNFREEZE_INPUT_BASE_MODEL_LAYERS-th layers
# Unfreeze the last FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS-th layers

for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS:
        layer.trainable = True
    elif i < (NUM_BASE_MODEL_LAYERS - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS):
        layer.trainable = False
    else:
        layer.trainable = True


print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# Number of layers in the base model                      : 155
# Number of the first unfrozen layers in the base model   : 16
# Number of the last unfrozen layers in the base model   : 35
# 📊 Unfreeze configuration :
#   - Frozen layers   : 51
#   - Unfrozen layers : 104
#   - Trainable params : 1,629,504 (72.2%)
#   - Frozen params    : 628,480
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_2_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS + 2]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[- FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS -2:], start=len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS - 2):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: True
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: True
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: True
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: True
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: True
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: True
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: True
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: True
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: True
#    11. block_1_expand_BN                        | Output: (None, 48, 48, 96)             | Trainable: True
#    12. block_1_expand_relu                      | Output: (None, 48, 48, 96)             | Trainable: True
#    13. block_1_pad                              | Output: (None, 49, 49, 96)             | Trainable: True
#    14. block_1_depthwise                        | Output: (None, 24, 24, 96)             | Trainable: True
#    15. block_1_depthwise_BN                     | Output: (None, 24, 24, 96)             | Trainable: True
#    16. block_1_depthwise_relu                   | Output: (None, 24, 24, 96)             | Trainable: True
#    17. block_1_project                          | Output: (None, 24, 24, 24)             | Trainable: False
#    18. block_1_project_BN                       | Output: (None, 24, 24, 24)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   119. block_13_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: False
#   120. block_13_pad                             | Output: (None, 7, 7, 576)              | Trainable: False
#   121. block_13_depthwise                       | Output: (None, 3, 3, 576)              | Trainable: True
#   122. block_13_depthwise_BN                    | Output: (None, 3, 3, 576)              | Trainable: True
#   123. block_13_depthwise_relu                  | Output: (None, 3, 3, 576)              | Trainable: True
#   124. block_13_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   125. block_13_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   126. block_14_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   127. block_14_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   128. block_14_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   129. block_14_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   130. block_14_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   131. block_14_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   132. block_14_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   133. block_14_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   134. block_14_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   135. block_15_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   136. block_15_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   137. block_15_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   138. block_15_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   139. block_15_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   140. block_15_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   141. block_15_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   142. block_15_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   143. block_15_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   144. block_16_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   145. block_16_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_2_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,498 (9.93 MB)
#  Trainable params: 1,974,018 (7.53 MB)
#  Non-trainable params: 628,480 (2.40 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_after_compile[1]*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 92.92%
#   - Loss     : 0.2229
#
#   ✅ Transfer-learning weigths have been preserved (92.9%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
# These values are taken from transfer learning n-class models training
accuracies = [0.944, 0.818, 0.725, 0.672]

frozen_best = accuracies[num_classes - 2]
improvement = (best_val_acc - frozen_best) * 100

print(f"\n📊 Improvement vs Frozen  : {improvement:+.1f} %")
print(f"   - Frozen                 : {frozen_best*100:.1f}%")
print(f"   - Fine-tuned             : {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7276 - loss: 0.8485 - top2_accuracy: 1.0000
# Epoch 1: val_accuracy improved from None to 0.90042, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 263ms/step - accuracy: 0.7885 - loss: 0.6480 - top2_accuracy: 1.0000 - val_accuracy: 0.9004 - val_loss: 0.3425 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8631 - loss: 0.3986 - top2_accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 28s 233ms/step - accuracy: 0.8731 - loss: 0.3707 - top2_accuracy: 1.0000 - val_accuracy: 0.8826 - val_loss: 0.3973 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 3/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8974 - loss: 0.3213 - top2_accuracy: 1.0000
# Epoch 3: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 28s 230ms/step - accuracy: 0.9034 - loss: 0.3041 - top2_accuracy: 1.0000 - val_accuracy: 0.8826 - val_loss: 0.3965 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 4/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9168 - loss: 0.2616 - top2_accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 28s 233ms/step - accuracy: 0.9214 - loss: 0.2513 - top2_accuracy: 1.0000 - val_accuracy: 0.8795 - val_loss: 0.4123 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 5/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9314 - loss: 0.2226 - top2_accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step - accuracy: 0.9309 - loss: 0.2233 - top2_accuracy: 1.0000 - val_accuracy: 0.8816 - val_loss: 0.4105 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 6/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9394 - loss: 0.2025 - top2_accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 29s 238ms/step - accuracy: 0.9420 - loss: 0.1985 - top2_accuracy: 1.0000 - val_accuracy: 0.8826 - val_loss: 0.4115 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 7/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9525 - loss: 0.1794 - top2_accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 35s 294ms/step - accuracy: 0.9550 - loss: 0.1741 - top2_accuracy: 1.0000 - val_accuracy: 0.8742 - val_loss: 0.4276 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 8/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9660 - loss: 0.1552 - top2_accuracy: 1.0000
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 8: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 523ms/step - accuracy: 0.9638 - loss: 0.1551 - top2_accuracy: 1.0000 - val_accuracy: 0.8753 - val_loss: 0.4161 - val_top2_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 9/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9689 - loss: 0.1402 - top2_accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.9685 - loss: 0.1377 - top2_accuracy: 1.0000 - val_accuracy: 0.8753 - val_loss: 0.4138 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 10/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9702 - loss: 0.1322 - top2_accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 342ms/step - accuracy: 0.9721 - loss: 0.1294 - top2_accuracy: 1.0000 - val_accuracy: 0.8742 - val_loss: 0.4105 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 11/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9784 - loss: 0.1213 - top2_accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 42s 354ms/step - accuracy: 0.9786 - loss: 0.1187 - top2_accuracy: 1.0000 - val_accuracy: 0.8753 - val_loss: 0.4111 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 12/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9811 - loss: 0.1131 - top2_accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 316ms/step - accuracy: 0.9804 - loss: 0.1120 - top2_accuracy: 1.0000 - val_accuracy: 0.8816 - val_loss: 0.4084 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 13/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9829 - loss: 0.1061 - top2_accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 35s 291ms/step - accuracy: 0.9824 - loss: 0.1063 - top2_accuracy: 1.0000 - val_accuracy: 0.8836 - val_loss: 0.4009 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 14/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9854 - loss: 0.0988 - top2_accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 35s 295ms/step - accuracy: 0.9847 - loss: 0.0993 - top2_accuracy: 1.0000 - val_accuracy: 0.8889 - val_loss: 0.3966 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 15/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9883 - loss: 0.0965 - top2_accuracy: 1.0000
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 15: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 297ms/step - accuracy: 0.9873 - loss: 0.0943 - top2_accuracy: 1.0000 - val_accuracy: 0.8920 - val_loss: 0.3980 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-06
# Epoch 16/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9877 - loss: 0.0916 - top2_accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 298ms/step - accuracy: 0.9892 - loss: 0.0891 - top2_accuracy: 1.0000 - val_accuracy: 0.8899 - val_loss: 0.3929 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 17/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9905 - loss: 0.0861 - top2_accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 296ms/step - accuracy: 0.9905 - loss: 0.0862 - top2_accuracy: 1.0000 - val_accuracy: 0.8952 - val_loss: 0.3891 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 18/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9910 - loss: 0.0856 - top2_accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 316ms/step - accuracy: 0.9916 - loss: 0.0857 - top2_accuracy: 1.0000 - val_accuracy: 0.8931 - val_loss: 0.3875 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 19/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9915 - loss: 0.0831 - top2_accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 317ms/step - accuracy: 0.9922 - loss: 0.0817 - top2_accuracy: 1.0000 - val_accuracy: 0.8910 - val_loss: 0.3828 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 20/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9909 - loss: 0.0830 - top2_accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 43s 363ms/step - accuracy: 0.9915 - loss: 0.0809 - top2_accuracy: 1.0000 - val_accuracy: 0.8941 - val_loss: 0.3795 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 21/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9944 - loss: 0.0795 - top2_accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 60s 494ms/step - accuracy: 0.9952 - loss: 0.0764 - top2_accuracy: 1.0000 - val_accuracy: 0.8962 - val_loss: 0.3765 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 22/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9945 - loss: 0.0768 - top2_accuracy: 1.0000
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 22: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 58s 479ms/step - accuracy: 0.9935 - loss: 0.0777 - top2_accuracy: 1.0000 - val_accuracy: 0.8952 - val_loss: 0.3718 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-06
# Epoch 23/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9940 - loss: 0.0748 - top2_accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 56s 466ms/step - accuracy: 0.9948 - loss: 0.0731 - top2_accuracy: 1.0000 - val_accuracy: 0.8973 - val_loss: 0.3649 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 24/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9963 - loss: 0.0725 - top2_accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.90042
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 56s 465ms/step - accuracy: 0.9954 - loss: 0.0724 - top2_accuracy: 1.0000 - val_accuracy: 0.9004 - val_loss: 0.3583 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 25/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.9945 - loss: 0.0726 - top2_accuracy: 1.0000
# Epoch 25: val_accuracy improved from 0.90042 to 0.90671, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 25: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 65s 536ms/step - accuracy: 0.9948 - loss: 0.0721 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.3518 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 26/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9940 - loss: 0.0735 - top2_accuracy: 1.0000
# Epoch 26: val_accuracy improved from 0.90671 to 0.90881, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 26: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 58s 481ms/step - accuracy: 0.9950 - loss: 0.0725 - top2_accuracy: 1.0000 - val_accuracy: 0.9088 - val_loss: 0.3460 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 27/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9955 - loss: 0.0712 - top2_accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 55s 455ms/step - accuracy: 0.9953 - loss: 0.0710 - top2_accuracy: 1.0000 - val_accuracy: 0.9088 - val_loss: 0.3422 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 28/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9972 - loss: 0.0681 - top2_accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 50s 412ms/step - accuracy: 0.9963 - loss: 0.0691 - top2_accuracy: 1.0000 - val_accuracy: 0.9046 - val_loss: 0.3391 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 29/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9931 - loss: 0.0739 - top2_accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 39s 321ms/step - accuracy: 0.9940 - loss: 0.0722 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.3328 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 30/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9959 - loss: 0.0689 - top2_accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 313ms/step - accuracy: 0.9960 - loss: 0.0681 - top2_accuracy: 1.0000 - val_accuracy: 0.9057 - val_loss: 0.3284 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 31/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9958 - loss: 0.0701 - top2_accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 310ms/step - accuracy: 0.9969 - loss: 0.0673 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.3238 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 32/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9956 - loss: 0.0681 - top2_accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.90881
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 312ms/step - accuracy: 0.9962 - loss: 0.0674 - top2_accuracy: 1.0000 - val_accuracy: 0.9088 - val_loss: 0.3168 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 33/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9951 - loss: 0.0677 - top2_accuracy: 1.0000
# Epoch 33: val_accuracy improved from 0.90881 to 0.91090, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 33: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 315ms/step - accuracy: 0.9958 - loss: 0.0672 - top2_accuracy: 1.0000 - val_accuracy: 0.9109 - val_loss: 0.3142 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 34/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9963 - loss: 0.0664 - top2_accuracy: 1.0000
# Epoch 34: val_accuracy improved from 0.91090 to 0.91719, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 34: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 318ms/step - accuracy: 0.9965 - loss: 0.0656 - top2_accuracy: 1.0000 - val_accuracy: 0.9172 - val_loss: 0.3065 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 35/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9951 - loss: 0.0661 - top2_accuracy: 1.0000
# Epoch 35: val_accuracy improved from 0.91719 to 0.92243, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 35: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 314ms/step - accuracy: 0.9953 - loss: 0.0672 - top2_accuracy: 1.0000 - val_accuracy: 0.9224 - val_loss: 0.2931 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 36/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9976 - loss: 0.0640 - top2_accuracy: 1.0000
# Epoch 36: val_accuracy improved from 0.92243 to 0.92453, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 36: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 314ms/step - accuracy: 0.9969 - loss: 0.0651 - top2_accuracy: 1.0000 - val_accuracy: 0.9245 - val_loss: 0.2816 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 37/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9963 - loss: 0.0651 - top2_accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.92453
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 370ms/step - accuracy: 0.9973 - loss: 0.0643 - top2_accuracy: 1.0000 - val_accuracy: 0.9224 - val_loss: 0.2751 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 38/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9969 - loss: 0.0637 - top2_accuracy: 1.0000
# Epoch 38: val_accuracy improved from 0.92453 to 0.92767, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 38: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 54s 452ms/step - accuracy: 0.9971 - loss: 0.0632 - top2_accuracy: 1.0000 - val_accuracy: 0.9277 - val_loss: 0.2674 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 39/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9986 - loss: 0.0616 - top2_accuracy: 1.0000
# Epoch 39: val_accuracy improved from 0.92767 to 0.92977, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 39: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.9986 - loss: 0.0613 - top2_accuracy: 1.0000 - val_accuracy: 0.9298 - val_loss: 0.2605 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 40/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9968 - loss: 0.0635 - top2_accuracy: 1.0000
# Epoch 40: val_accuracy improved from 0.92977 to 0.93396, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 40: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 43s 360ms/step - accuracy: 0.9969 - loss: 0.0637 - top2_accuracy: 1.0000 - val_accuracy: 0.9340 - val_loss: 0.2541 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 41/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9964 - loss: 0.0630 - top2_accuracy: 1.0000
# Epoch 41: val_accuracy improved from 0.93396 to 0.93501, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 309ms/step - accuracy: 0.9969 - loss: 0.0624 - top2_accuracy: 1.0000 - val_accuracy: 0.9350 - val_loss: 0.2490 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 42/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9968 - loss: 0.0629 - top2_accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.93501
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 296ms/step - accuracy: 0.9973 - loss: 0.0624 - top2_accuracy: 1.0000 - val_accuracy: 0.9340 - val_loss: 0.2454 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 43/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9975 - loss: 0.0613 - top2_accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.93501
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 35s 296ms/step - accuracy: 0.9976 - loss: 0.0607 - top2_accuracy: 1.0000 - val_accuracy: 0.9329 - val_loss: 0.2428 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 44/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9974 - loss: 0.0609 - top2_accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.93501
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 296ms/step - accuracy: 0.9978 - loss: 0.0606 - top2_accuracy: 1.0000 - val_accuracy: 0.9350 - val_loss: 0.2413 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 45/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9983 - loss: 0.0594 - top2_accuracy: 1.0000
# Epoch 45: val_accuracy improved from 0.93501 to 0.93920, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 45: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 304ms/step - accuracy: 0.9984 - loss: 0.0593 - top2_accuracy: 1.0000 - val_accuracy: 0.9392 - val_loss: 0.2398 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 46/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9983 - loss: 0.0601 - top2_accuracy: 1.0000
# Epoch 46: val_accuracy improved from 0.93920 to 0.94235, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 46: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 307ms/step - accuracy: 0.9983 - loss: 0.0600 - top2_accuracy: 1.0000 - val_accuracy: 0.9423 - val_loss: 0.2399 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 47/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9990 - loss: 0.0594 - top2_accuracy: 1.0000
# Epoch 47: val_accuracy improved from 0.94235 to 0.94444, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 47: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 305ms/step - accuracy: 0.9984 - loss: 0.0599 - top2_accuracy: 1.0000 - val_accuracy: 0.9444 - val_loss: 0.2387 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 48/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9989 - loss: 0.0584 - top2_accuracy: 1.0000
# Epoch 48: val_accuracy improved from 0.94444 to 0.94654, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 48: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 308ms/step - accuracy: 0.9988 - loss: 0.0588 - top2_accuracy: 1.0000 - val_accuracy: 0.9465 - val_loss: 0.2319 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 49/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9990 - loss: 0.0569 - top2_accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.94654
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 302ms/step - accuracy: 0.9990 - loss: 0.0575 - top2_accuracy: 1.0000 - val_accuracy: 0.9455 - val_loss: 0.2274 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 50/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9981 - loss: 0.0582 - top2_accuracy: 1.0000
# Epoch 50: val_accuracy improved from 0.94654 to 0.94969, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 50: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 40s 333ms/step - accuracy: 0.9991 - loss: 0.0572 - top2_accuracy: 1.0000 - val_accuracy: 0.9497 - val_loss: 0.2213 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 51/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9979 - loss: 0.0584 - top2_accuracy: 1.0000
# Epoch 51: val_accuracy improved from 0.94969 to 0.95283, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 51: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 342ms/step - accuracy: 0.9980 - loss: 0.0584 - top2_accuracy: 1.0000 - val_accuracy: 0.9528 - val_loss: 0.2130 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 52/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9978 - loss: 0.0590 - top2_accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.95283
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 304ms/step - accuracy: 0.9983 - loss: 0.0579 - top2_accuracy: 1.0000 - val_accuracy: 0.9528 - val_loss: 0.2126 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 53/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9991 - loss: 0.0564 - top2_accuracy: 1.0000
# Epoch 53: val_accuracy improved from 0.95283 to 0.95388, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 53: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9984 - loss: 0.0571 - top2_accuracy: 1.0000 - val_accuracy: 0.9539 - val_loss: 0.2077 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 54/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9984 - loss: 0.0571 - top2_accuracy: 1.0000
# Epoch 54: val_accuracy improved from 0.95388 to 0.95597, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 54: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 382ms/step - accuracy: 0.9987 - loss: 0.0567 - top2_accuracy: 1.0000 - val_accuracy: 0.9560 - val_loss: 0.2028 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 55/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9988 - loss: 0.0564 - top2_accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.95597
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 39s 325ms/step - accuracy: 0.9987 - loss: 0.0566 - top2_accuracy: 1.0000 - val_accuracy: 0.9560 - val_loss: 0.2001 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 56/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9988 - loss: 0.0568 - top2_accuracy: 1.0000
# Epoch 56: val_accuracy improved from 0.95597 to 0.95807, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 56: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 305ms/step - accuracy: 0.9991 - loss: 0.0563 - top2_accuracy: 1.0000 - val_accuracy: 0.9581 - val_loss: 0.1978 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 57/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9988 - loss: 0.0563 - top2_accuracy: 1.0000
# Epoch 57: val_accuracy improved from 0.95807 to 0.96017, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 57: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 307ms/step - accuracy: 0.9990 - loss: 0.0563 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1932 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 58/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9997 - loss: 0.0544 - top2_accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.96017
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 306ms/step - accuracy: 0.9996 - loss: 0.0544 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1912 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 59/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9991 - loss: 0.0547 - top2_accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.96017
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 306ms/step - accuracy: 0.9992 - loss: 0.0548 - top2_accuracy: 1.0000 - val_accuracy: 0.9591 - val_loss: 0.1914 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 60/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9991 - loss: 0.0549 - top2_accuracy: 1.0000
# Epoch 60: val_accuracy improved from 0.96017 to 0.96226, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
#
# Epoch 60: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Fine_Tuning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 309ms/step - accuracy: 0.9990 - loss: 0.0549 - top2_accuracy: 1.0000 - val_accuracy: 0.9623 - val_loss: 0.1896 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 61/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9988 - loss: 0.0551 - top2_accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 305ms/step - accuracy: 0.9990 - loss: 0.0547 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1872 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 62/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9986 - loss: 0.0546 - top2_accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 53s 442ms/step - accuracy: 0.9988 - loss: 0.0545 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1880 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 63/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9993 - loss: 0.0541 - top2_accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 42s 350ms/step - accuracy: 0.9996 - loss: 0.0537 - top2_accuracy: 1.0000 - val_accuracy: 0.9591 - val_loss: 0.1882 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 64/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9989 - loss: 0.0551 - top2_accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 39s 323ms/step - accuracy: 0.9992 - loss: 0.0537 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1869 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 65/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9994 - loss: 0.0533 - top2_accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 312ms/step - accuracy: 0.9991 - loss: 0.0536 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1870 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 66/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9997 - loss: 0.0529 - top2_accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 39s 327ms/step - accuracy: 0.9995 - loss: 0.0534 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1890 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 67/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9986 - loss: 0.0529 - top2_accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 307ms/step - accuracy: 0.9988 - loss: 0.0530 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1888 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 68/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9999 - loss: 0.0521 - top2_accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 310ms/step - accuracy: 0.9997 - loss: 0.0524 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1899 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 69/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9996 - loss: 0.0522 - top2_accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 310ms/step - accuracy: 0.9996 - loss: 0.0519 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1897 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 70/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9982 - loss: 0.0536 - top2_accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 307ms/step - accuracy: 0.9990 - loss: 0.0528 - top2_accuracy: 1.0000 - val_accuracy: 0.9623 - val_loss: 0.1916 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 71/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9981 - loss: 0.0537 - top2_accuracy: 1.0000
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 71: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 306ms/step - accuracy: 0.9991 - loss: 0.0527 - top2_accuracy: 1.0000 - val_accuracy: 0.9623 - val_loss: 0.1916 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-06
# Epoch 72/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9993 - loss: 0.0520 - top2_accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 306ms/step - accuracy: 0.9991 - loss: 0.0529 - top2_accuracy: 1.0000 - val_accuracy: 0.9623 - val_loss: 0.1916 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 73/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9996 - loss: 0.0516 - top2_accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 308ms/step - accuracy: 0.9995 - loss: 0.0522 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1922 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 74/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9992 - loss: 0.0522 - top2_accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 303ms/step - accuracy: 0.9991 - loss: 0.0522 - top2_accuracy: 1.0000 - val_accuracy: 0.9591 - val_loss: 0.1926 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 75/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9997 - loss: 0.0515 - top2_accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 38s 318ms/step - accuracy: 0.9996 - loss: 0.0512 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1938 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 76/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9986 - loss: 0.0526 - top2_accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 37s 308ms/step - accuracy: 0.9991 - loss: 0.0519 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1943 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 77/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9995 - loss: 0.0528 - top2_accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 303ms/step - accuracy: 0.9997 - loss: 0.0515 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1946 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 78/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9993 - loss: 0.0514 - top2_accuracy: 1.0000
# Epoch 78: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 78: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 303ms/step - accuracy: 0.9995 - loss: 0.0511 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1944 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-07
# Epoch 79/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9991 - loss: 0.0510 - top2_accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 346ms/step - accuracy: 0.9992 - loss: 0.0512 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1948 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 80/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9999 - loss: 0.0514 - top2_accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 339ms/step - accuracy: 0.9999 - loss: 0.0512 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1951 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 81/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9990 - loss: 0.0516 - top2_accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 339ms/step - accuracy: 0.9992 - loss: 0.0510 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1960 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 82/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9997 - loss: 0.0507 - top2_accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 43s 359ms/step - accuracy: 0.9995 - loss: 0.0510 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1967 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 83/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9996 - loss: 0.0502 - top2_accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 42s 349ms/step - accuracy: 0.9995 - loss: 0.0505 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1971 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 84/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9999 - loss: 0.0508 - top2_accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 52s 434ms/step - accuracy: 0.9999 - loss: 0.0506 - top2_accuracy: 1.0000 - val_accuracy: 0.9602 - val_loss: 0.1975 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 85/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9998 - loss: 0.0502 - top2_accuracy: 1.0000
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 85: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.9996 - loss: 0.0505 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1977 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-07
# Epoch 86/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9997 - loss: 0.0499 - top2_accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 299ms/step - accuracy: 0.9997 - loss: 0.0501 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1979 - val_top2_accuracy: 1.0000 - learning_rate: 1.5625e-07
# Epoch 87/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9997 - loss: 0.0501 - top2_accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 298ms/step - accuracy: 0.9996 - loss: 0.0504 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1982 - val_top2_accuracy: 1.0000 - learning_rate: 1.5625e-07
# Epoch 88/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9994 - loss: 0.0505 - top2_accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 298ms/step - accuracy: 0.9996 - loss: 0.0505 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1984 - val_top2_accuracy: 1.0000 - learning_rate: 1.5625e-07
# Epoch 89/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9992 - loss: 0.0512 - top2_accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 298ms/step - accuracy: 0.9993 - loss: 0.0508 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1986 - val_top2_accuracy: 1.0000 - learning_rate: 1.5625e-07
# Epoch 90/120
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9997 - loss: 0.0509 - top2_accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.96226
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 36s 299ms/step - accuracy: 0.9996 - loss: 0.0509 - top2_accuracy: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.1987 - val_top2_accuracy: 1.0000 - learning_rate: 1.5625e-07
# Epoch 90: early stopping
# Restoring model weights from the end of the best epoch: 60.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 90
#    Meilleure val_accuracy : 96.23% (epoch 60)
#
# 📊 Improvement vs Frozen  : +1.8 %
#    - Frozen                 : 94.4%
#    - Fine-tuned             : 96.2%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few predictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 96.1% | 2nd Prediction=index        | 2nd Confidence=  2.5%
# ✅ Image 2: Label=index        | Prediction=index        | Confidence= 99.1% | 2nd Prediction=thumb        | 2nd Confidence=  0.8%
# ✅ Image 3: Label=index        | Prediction=index        | Confidence= 99.9% | 2nd Prediction=thumb        | 2nd Confidence=  0.0%
# ✅ Image 4: Label=thumb        | Prediction=thumb        | Confidence= 98.6% | 2nd Prediction=index        | 2nd Confidence=  0.8%
# ✅ Image 5: Label=index        | Prediction=index        | Confidence= 97.4% | 2nd Prediction=thumb        | 2nd Confidence=  2.2%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 7: Label=index        | Prediction=index        | Confidence= 95.7% | 2nd Prediction=thumb        | 2nd Confidence=  3.6%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 76.3% | 2nd Prediction=thumb        | 2nd Confidence= 21.2%
# ✅ Image 9: Label=index        | Prediction=index        | Confidence= 99.4% | 2nd Prediction=thumb        | 2nd Confidence=  0.5%
# ✅ Image 10: Label=index        | Prediction=index        | Confidence= 99.4% | 2nd Prediction=thumb        | 2nd Confidence=  0.5%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence= 93.1% | 2nd Prediction=thumb        | 2nd Confidence=  6.1%
# ✅ Image 12: Label=thumb        | Prediction=thumb        | Confidence= 88.6% | 2nd Prediction=index        | 2nd Confidence=  8.5%
# ✅ Image 13: Label=thumb        | Prediction=thumb        | Confidence= 84.9% | 2nd Prediction=index        | 2nd Confidence= 11.9%
# ✅ Image 14: Label=index        | Prediction=index        | Confidence= 99.9% | 2nd Prediction=thumb        | 2nd Confidence=  0.1%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 89.8% | 2nd Prediction=thumb        | 2nd Confidence=  9.2%
# ✅ Image 16: Label=index        | Prediction=index        | Confidence= 98.5% | 2nd Prediction=thumb        | 2nd Confidence=  1.3%
# ✅ Image 17: Label=index        | Prediction=index        | Confidence= 97.9% | 2nd Prediction=thumb        | 2nd Confidence=  1.8%
# ✅ Image 18: Label=index        | Prediction=index        | Confidence= 96.9% | 2nd Prediction=thumb        | 2nd Confidence=  2.7%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 97.9% | 2nd Prediction=index        | 2nd Confidence=  1.2%
# ✅ Image 20: Label=thumb        | Prediction=thumb        | Confidence= 84.5% | 2nd Prediction=index        | 2nd Confidence= 12.2%
#
# ======================================================================================================================================================
# 2026-03-25 18:22:02.743804: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of fine-tuned model using test dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using test dataset...
#
# Results :
#   - Loss                : 0.1755
#   - Accuracy            : 96.15%
#   - Top-2 Accuracy      : 100.00%
