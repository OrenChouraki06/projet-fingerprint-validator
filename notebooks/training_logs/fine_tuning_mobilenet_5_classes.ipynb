# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index',  'middle', 'ring', 'little']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_5_classes

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 15954 files belonging to 5 classes.
# Found 2000 files belonging to 5 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 250
#   - Validation batches  : 22
#   - Test batches        : 10
#   - Batch size          : 64
#   - Training samples    : ~16000
#   - Validation samples  : ~1408
#   - Test samples        : ~640
# 2026-03-26 15:00:11.177098: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-26 15:00:11.177138: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-26 15:00:11.177149: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-26 15:00:11.177171: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-26 15:00:11.177189: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset             : normalisation + shuffle")
print("  - Validation and test dataset  : normalisation only")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset             : normalisation + shuffle
#   - Validation and test dataset  : normalisation only
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 5)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,693
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 5)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,292,113 (12.56 MB)
#  Trainable params: 344,709 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,420 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-26 15:00:12.868379: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 58.59%
#   - Loss     : 1.0705

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants

# Number of layers in the model 
NUM_BASE_MODEL_LAYERS = len(frozen_fingerprint_basemodel.layers)

# keep ratio of 1/3 unfrozen layers vs. 2/3 frozen layers
UNFROZEN_FROZEN_LAYERS_RATIO = 0.33
NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS = int(NUM_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_LAYERS_RATIO)

#  ratio of unfrozen first layers vs. unfrozen last layers
UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO = 0
FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO)
FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS - FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS)

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")
print(f"Number of layers in the base model                      : {NUM_BASE_MODEL_LAYERS}")
print(f"Number of the first unfrozen layers in the base model   : {FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS}")
print(f"Number of the last unfrozen layers in the base model   : {FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS}")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Unfreeze the first FINE_TUNING_UNFREEZE_INPUT_BASE_MODEL_LAYERS-th layers
# Unfreeze the last FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS-th layers

for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS:
        layer.trainable = True
    elif i < (NUM_BASE_MODEL_LAYERS - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS):
        layer.trainable = False
    else:
        layer.trainable = True


print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# Number of layers in the base model                      : 155
# Number of the first unfrozen layers in the base model   : 0
# Number of the last unfrozen layers in the base model   : 51
# 📊 Unfreeze configuration :
#   - Frozen layers   : 51
#   - Unfrozen layers : 104
#   - Trainable params : 1,855,104 (82.2%)
#   - Frozen params    : 402,880
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_5_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS + 2]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[- FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS -2:], start=len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS - 2):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   103. block_11_depthwise_BN                    | Output: (None, 6, 6, 576)              | Trainable: False
#   104. block_11_depthwise_relu                  | Output: (None, 6, 6, 576)              | Trainable: False
#   105. block_11_project                         | Output: (None, 6, 6, 96)               | Trainable: True
#   106. block_11_project_BN                      | Output: (None, 6, 6, 96)               | Trainable: True
#   107. block_11_add                             | Output: (None, 6, 6, 96)               | Trainable: True
#   108. block_12_expand                          | Output: (None, 6, 6, 576)              | Trainable: True
#   109. block_12_expand_BN                       | Output: (None, 6, 6, 576)              | Trainable: True
#   110. block_12_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: True
#   111. block_12_depthwise                       | Output: (None, 6, 6, 576)              | Trainable: True
#   112. block_12_depthwise_BN                    | Output: (None, 6, 6, 576)              | Trainable: True
#   113. block_12_depthwise_relu                  | Output: (None, 6, 6, 576)              | Trainable: True
#   114. block_12_project                         | Output: (None, 6, 6, 96)               | Trainable: True
#   115. block_12_project_BN                      | Output: (None, 6, 6, 96)               | Trainable: True
#   116. block_12_add                             | Output: (None, 6, 6, 96)               | Trainable: True
#   117. block_13_expand                          | Output: (None, 6, 6, 576)              | Trainable: True
#   118. block_13_expand_BN                       | Output: (None, 6, 6, 576)              | Trainable: True
#   119. block_13_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: True
#   120. block_13_pad                             | Output: (None, 7, 7, 576)              | Trainable: True
#   121. block_13_depthwise                       | Output: (None, 3, 3, 576)              | Trainable: True
#   122. block_13_depthwise_BN                    | Output: (None, 3, 3, 576)              | Trainable: True
#   123. block_13_depthwise_relu                  | Output: (None, 3, 3, 576)              | Trainable: True
#   124. block_13_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   125. block_13_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   126. block_14_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   127. block_14_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   128. block_14_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   129. block_14_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   130. block_14_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   131. block_14_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   132. block_14_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   133. block_14_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   134. block_14_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   135. block_15_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   136. block_15_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   137. block_15_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   138. block_15_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   139. block_15_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   140. block_15_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   141. block_15_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   142. block_15_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   143. block_15_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   144. block_16_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   145. block_16_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,693 (9.93 MB)
#  Trainable params: 2,199,813 (8.39 MB)
#  Non-trainable params: 402,880 (1.54 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

frozen_accuracy = results_after_compile[1]
print(f"  - Accuracy : {frozen_accuracy*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 58.59%
#   - Loss     : 1.0705
#
#   ✅ Transfer-learning weigths have been preserved (58.6%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
improvement = (best_val_acc - frozen_accuracy) * 100

print(f"\n📊 Improvement vs Frozen  : {improvement:+.1f} %")
print(f"   - Frozen                 : {frozen_accuracy*100:.1f}%")
print(f"   - Fine-tuned             : {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4463 - loss: 1.5731 - top2_accuracy: 0.6842
# Epoch 1: val_accuracy improved from None to 0.52941, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 196ms/step - accuracy: 0.4929 - loss: 1.3854 - top2_accuracy: 0.7253 - val_accuracy: 0.5294 - val_loss: 1.3244 - val_top2_accuracy: 0.7750 - learning_rate: 1.0000e-05
# Epoch 2/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5618 - loss: 1.1643 - top2_accuracy: 0.7872
# Epoch 2: val_accuracy did not improve from 0.52941
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.5770 - loss: 1.1313 - top2_accuracy: 0.7967 - val_accuracy: 0.5103 - val_loss: 1.3520 - val_top2_accuracy: 0.7757 - learning_rate: 1.0000e-05
# Epoch 3/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.6146 - loss: 1.0435 - top2_accuracy: 0.8301
# Epoch 3: val_accuracy improved from 0.52941 to 0.55074, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.6264 - loss: 1.0222 - top2_accuracy: 0.8394 - val_accuracy: 0.5507 - val_loss: 1.2938 - val_top2_accuracy: 0.7897 - learning_rate: 1.0000e-05
# Epoch 4/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6580 - loss: 0.9457 - top2_accuracy: 0.8554
# Epoch 4: val_accuracy improved from 0.55074 to 0.57647, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 162ms/step - accuracy: 0.6638 - loss: 0.9330 - top2_accuracy: 0.8602 - val_accuracy: 0.5765 - val_loss: 1.2492 - val_top2_accuracy: 0.7985 - learning_rate: 1.0000e-05
# Epoch 5/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6891 - loss: 0.8701 - top2_accuracy: 0.8840
# Epoch 5: val_accuracy improved from 0.57647 to 0.60662, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 172ms/step - accuracy: 0.6983 - loss: 0.8519 - top2_accuracy: 0.8881 - val_accuracy: 0.6066 - val_loss: 1.1916 - val_top2_accuracy: 0.8110 - learning_rate: 1.0000e-05
# Epoch 6/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7255 - loss: 0.7981 - top2_accuracy: 0.9069
# Epoch 6: val_accuracy improved from 0.60662 to 0.61618, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.7287 - loss: 0.7812 - top2_accuracy: 0.9099 - val_accuracy: 0.6162 - val_loss: 1.1597 - val_top2_accuracy: 0.8257 - learning_rate: 1.0000e-05
# Epoch 7/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7524 - loss: 0.7292 - top2_accuracy: 0.9207
# Epoch 7: val_accuracy improved from 0.61618 to 0.62574, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 7: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.7579 - loss: 0.7116 - top2_accuracy: 0.9257 - val_accuracy: 0.6257 - val_loss: 1.1510 - val_top2_accuracy: 0.8265 - learning_rate: 1.0000e-05
# Epoch 8/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7816 - loss: 0.6622 - top2_accuracy: 0.9351
# Epoch 8: val_accuracy improved from 0.62574 to 0.65074, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.7875 - loss: 0.6489 - top2_accuracy: 0.9384 - val_accuracy: 0.6507 - val_loss: 1.1112 - val_top2_accuracy: 0.8419 - learning_rate: 1.0000e-05
# Epoch 9/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8098 - loss: 0.5984 - top2_accuracy: 0.9476
# Epoch 9: val_accuracy improved from 0.65074 to 0.65441, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 170ms/step - accuracy: 0.8162 - loss: 0.5820 - top2_accuracy: 0.9515 - val_accuracy: 0.6544 - val_loss: 1.1078 - val_top2_accuracy: 0.8471 - learning_rate: 1.0000e-05
# Epoch 10/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8294 - loss: 0.5448 - top2_accuracy: 0.9575
# Epoch 10: val_accuracy improved from 0.65441 to 0.65735, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.8323 - loss: 0.5308 - top2_accuracy: 0.9599 - val_accuracy: 0.6574 - val_loss: 1.1330 - val_top2_accuracy: 0.8456 - learning_rate: 1.0000e-05
# Epoch 11/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8509 - loss: 0.4963 - top2_accuracy: 0.9679
# Epoch 11: val_accuracy did not improve from 0.65735
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8554 - loss: 0.4831 - top2_accuracy: 0.9701 - val_accuracy: 0.6544 - val_loss: 1.1414 - val_top2_accuracy: 0.8507 - learning_rate: 1.0000e-05
# Epoch 12/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8776 - loss: 0.4426 - top2_accuracy: 0.9750
# Epoch 12: val_accuracy did not improve from 0.65735
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8813 - loss: 0.4298 - top2_accuracy: 0.9777 - val_accuracy: 0.6515 - val_loss: 1.1822 - val_top2_accuracy: 0.8529 - learning_rate: 1.0000e-05
# Epoch 13/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8866 - loss: 0.4058 - top2_accuracy: 0.9810
# Epoch 13: val_accuracy did not improve from 0.65735
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8956 - loss: 0.3868 - top2_accuracy: 0.9841 - val_accuracy: 0.6515 - val_loss: 1.2285 - val_top2_accuracy: 0.8581 - learning_rate: 1.0000e-05
# Epoch 14/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9020 - loss: 0.3705 - top2_accuracy: 0.9852
# Epoch 14: val_accuracy did not improve from 0.65735
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.9102 - loss: 0.3555 - top2_accuracy: 0.9872 - val_accuracy: 0.6559 - val_loss: 1.2586 - val_top2_accuracy: 0.8551 - learning_rate: 1.0000e-05
# Epoch 15/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9191 - loss: 0.3322 - top2_accuracy: 0.9882
# Epoch 15: val_accuracy improved from 0.65735 to 0.66250, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Fine_Tuning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 185ms/step - accuracy: 0.9252 - loss: 0.3164 - top2_accuracy: 0.9910 - val_accuracy: 0.6625 - val_loss: 1.3003 - val_top2_accuracy: 0.8537 - learning_rate: 1.0000e-05
# Epoch 16/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9368 - loss: 0.2890 - top2_accuracy: 0.9937
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 16: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.9401 - loss: 0.2807 - top2_accuracy: 0.9936 - val_accuracy: 0.6581 - val_loss: 1.3603 - val_top2_accuracy: 0.8500 - learning_rate: 1.0000e-05
# Epoch 17/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9427 - loss: 0.2715 - top2_accuracy: 0.9934
# Epoch 17: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.9477 - loss: 0.2608 - top2_accuracy: 0.9951 - val_accuracy: 0.6581 - val_loss: 1.3754 - val_top2_accuracy: 0.8551 - learning_rate: 5.0000e-06
# Epoch 18/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9494 - loss: 0.2562 - top2_accuracy: 0.9956
# Epoch 18: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - accuracy: 0.9532 - loss: 0.2475 - top2_accuracy: 0.9963 - val_accuracy: 0.6551 - val_loss: 1.4008 - val_top2_accuracy: 0.8529 - learning_rate: 5.0000e-06
# Epoch 19/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9558 - loss: 0.2425 - top2_accuracy: 0.9955
# Epoch 19: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.9609 - loss: 0.2327 - top2_accuracy: 0.9967 - val_accuracy: 0.6551 - val_loss: 1.4289 - val_top2_accuracy: 0.8544 - learning_rate: 5.0000e-06
# Epoch 20/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.9611 - loss: 0.2282 - top2_accuracy: 0.9970
# Epoch 20: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 248s 994ms/step - accuracy: 0.9631 - loss: 0.2224 - top2_accuracy: 0.9976 - val_accuracy: 0.6515 - val_loss: 1.4544 - val_top2_accuracy: 0.8544 - learning_rate: 5.0000e-06
# Epoch 21/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9660 - loss: 0.2147 - top2_accuracy: 0.9989
# Epoch 21: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.9687 - loss: 0.2104 - top2_accuracy: 0.9984 - val_accuracy: 0.6544 - val_loss: 1.4645 - val_top2_accuracy: 0.8574 - learning_rate: 5.0000e-06
# Epoch 22/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9712 - loss: 0.2054 - top2_accuracy: 0.9977
# Epoch 22: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9724 - loss: 0.2012 - top2_accuracy: 0.9977 - val_accuracy: 0.6551 - val_loss: 1.4928 - val_top2_accuracy: 0.8610 - learning_rate: 5.0000e-06
# Epoch 23/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9732 - loss: 0.2004 - top2_accuracy: 0.9987
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 23: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 180ms/step - accuracy: 0.9750 - loss: 0.1957 - top2_accuracy: 0.9988 - val_accuracy: 0.6610 - val_loss: 1.5160 - val_top2_accuracy: 0.8566 - learning_rate: 5.0000e-06
# Epoch 24/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9798 - loss: 0.1869 - top2_accuracy: 0.9990
# Epoch 24: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9798 - loss: 0.1849 - top2_accuracy: 0.9989 - val_accuracy: 0.6596 - val_loss: 1.5328 - val_top2_accuracy: 0.8559 - learning_rate: 2.5000e-06
# Epoch 25/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9792 - loss: 0.1834 - top2_accuracy: 0.9985
# Epoch 25: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 177ms/step - accuracy: 0.9816 - loss: 0.1797 - top2_accuracy: 0.9987 - val_accuracy: 0.6537 - val_loss: 1.5566 - val_top2_accuracy: 0.8515 - learning_rate: 2.5000e-06
# Epoch 26/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9810 - loss: 0.1792 - top2_accuracy: 0.9993
# Epoch 26: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.9823 - loss: 0.1768 - top2_accuracy: 0.9994 - val_accuracy: 0.6529 - val_loss: 1.5706 - val_top2_accuracy: 0.8500 - learning_rate: 2.5000e-06
# Epoch 27/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9821 - loss: 0.1779 - top2_accuracy: 0.9995
# Epoch 27: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 178ms/step - accuracy: 0.9822 - loss: 0.1745 - top2_accuracy: 0.9995 - val_accuracy: 0.6551 - val_loss: 1.5864 - val_top2_accuracy: 0.8522 - learning_rate: 2.5000e-06
# Epoch 28/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9840 - loss: 0.1700 - top2_accuracy: 0.9994
# Epoch 28: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 178ms/step - accuracy: 0.9842 - loss: 0.1701 - top2_accuracy: 0.9996 - val_accuracy: 0.6551 - val_loss: 1.6006 - val_top2_accuracy: 0.8493 - learning_rate: 2.5000e-06
# Epoch 29/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9835 - loss: 0.1697 - top2_accuracy: 0.9994
# Epoch 29: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.9851 - loss: 0.1666 - top2_accuracy: 0.9994 - val_accuracy: 0.6522 - val_loss: 1.6121 - val_top2_accuracy: 0.8551 - learning_rate: 2.5000e-06
# Epoch 30/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9840 - loss: 0.1694 - top2_accuracy: 0.9993
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 30: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.9856 - loss: 0.1638 - top2_accuracy: 0.9995 - val_accuracy: 0.6551 - val_loss: 1.6288 - val_top2_accuracy: 0.8515 - learning_rate: 2.5000e-06
# Epoch 31/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9878 - loss: 0.1593 - top2_accuracy: 0.9995
# Epoch 31: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.9876 - loss: 0.1596 - top2_accuracy: 0.9995 - val_accuracy: 0.6574 - val_loss: 1.6316 - val_top2_accuracy: 0.8515 - learning_rate: 1.2500e-06
# Epoch 32/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9878 - loss: 0.1599 - top2_accuracy: 0.9994
# Epoch 32: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 182ms/step - accuracy: 0.9882 - loss: 0.1585 - top2_accuracy: 0.9994 - val_accuracy: 0.6551 - val_loss: 1.6445 - val_top2_accuracy: 0.8529 - learning_rate: 1.2500e-06
# Epoch 33/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9879 - loss: 0.1573 - top2_accuracy: 0.9991
# Epoch 33: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9883 - loss: 0.1561 - top2_accuracy: 0.9994 - val_accuracy: 0.6566 - val_loss: 1.6499 - val_top2_accuracy: 0.8507 - learning_rate: 1.2500e-06
# Epoch 34/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9875 - loss: 0.1551 - top2_accuracy: 0.9998
# Epoch 34: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9885 - loss: 0.1543 - top2_accuracy: 0.9997 - val_accuracy: 0.6566 - val_loss: 1.6579 - val_top2_accuracy: 0.8507 - learning_rate: 1.2500e-06
# Epoch 35/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9885 - loss: 0.1550 - top2_accuracy: 0.9987
# Epoch 35: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 180ms/step - accuracy: 0.9905 - loss: 0.1533 - top2_accuracy: 0.9990 - val_accuracy: 0.6551 - val_loss: 1.6685 - val_top2_accuracy: 0.8515 - learning_rate: 1.2500e-06
# Epoch 36/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9903 - loss: 0.1518 - top2_accuracy: 0.9996
# Epoch 36: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.9915 - loss: 0.1501 - top2_accuracy: 0.9997 - val_accuracy: 0.6566 - val_loss: 1.6712 - val_top2_accuracy: 0.8493 - learning_rate: 1.2500e-06
# Epoch 37/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9886 - loss: 0.1517 - top2_accuracy: 0.9995
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 37: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 179ms/step - accuracy: 0.9903 - loss: 0.1492 - top2_accuracy: 0.9995 - val_accuracy: 0.6574 - val_loss: 1.6745 - val_top2_accuracy: 0.8500 - learning_rate: 1.2500e-06
# Epoch 38/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9922 - loss: 0.1487 - top2_accuracy: 0.9998
# Epoch 38: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 178ms/step - accuracy: 0.9914 - loss: 0.1483 - top2_accuracy: 0.9998 - val_accuracy: 0.6581 - val_loss: 1.6802 - val_top2_accuracy: 0.8507 - learning_rate: 6.2500e-07
# Epoch 39/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9903 - loss: 0.1495 - top2_accuracy: 0.9997
# Epoch 39: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 177ms/step - accuracy: 0.9906 - loss: 0.1484 - top2_accuracy: 0.9997 - val_accuracy: 0.6566 - val_loss: 1.6854 - val_top2_accuracy: 0.8507 - learning_rate: 6.2500e-07
# Epoch 40/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9915 - loss: 0.1489 - top2_accuracy: 0.9996
# Epoch 40: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 54s 215ms/step - accuracy: 0.9914 - loss: 0.1472 - top2_accuracy: 0.9997 - val_accuracy: 0.6588 - val_loss: 1.6877 - val_top2_accuracy: 0.8507 - learning_rate: 6.2500e-07
# Epoch 41/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9901 - loss: 0.1482 - top2_accuracy: 0.9998
# Epoch 41: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9912 - loss: 0.1467 - top2_accuracy: 0.9997 - val_accuracy: 0.6574 - val_loss: 1.6898 - val_top2_accuracy: 0.8493 - learning_rate: 6.2500e-07
# Epoch 42/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9893 - loss: 0.1497 - top2_accuracy: 0.9996
# Epoch 42: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 333ms/step - accuracy: 0.9902 - loss: 0.1484 - top2_accuracy: 0.9997 - val_accuracy: 0.6596 - val_loss: 1.6956 - val_top2_accuracy: 0.8507 - learning_rate: 6.2500e-07
# Epoch 43/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9913 - loss: 0.1479 - top2_accuracy: 0.9997
# Epoch 43: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 47s 185ms/step - accuracy: 0.9908 - loss: 0.1481 - top2_accuracy: 0.9996 - val_accuracy: 0.6581 - val_loss: 1.6968 - val_top2_accuracy: 0.8522 - learning_rate: 6.2500e-07
# Epoch 44/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9921 - loss: 0.1456 - top2_accuracy: 0.9995
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 44: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.9922 - loss: 0.1445 - top2_accuracy: 0.9996 - val_accuracy: 0.6581 - val_loss: 1.7031 - val_top2_accuracy: 0.8507 - learning_rate: 6.2500e-07
# Epoch 45/120
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9907 - loss: 0.1451 - top2_accuracy: 0.9997
# Epoch 45: val_accuracy did not improve from 0.66250
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 181ms/step - accuracy: 0.9906 - loss: 0.1448 - top2_accuracy: 0.9996 - val_accuracy: 0.6596 - val_loss: 1.7051 - val_top2_accuracy: 0.8507 - learning_rate: 3.1250e-07
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 45
#    Meilleure val_accuracy : 66.25% (epoch 15)
#
# 📊 Improvement vs Frozen  : +7.7 %
#    - Frozen                 : 58.6%
#    - Fine-tuned             : 66.3%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few predictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=ring         | Prediction=ring         | Confidence= 81.3% | 2nd Prediction=middle       | 2nd Confidence= 15.7%
# ✅ Image 2: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ❌ Image 3: Label=index        | Prediction=middle       | Confidence= 83.2% | 2nd Prediction=ring         | 2nd Confidence= 16.2%
# ✅ Image 4: Label=ring         | Prediction=ring         | Confidence= 83.8% | 2nd Prediction=middle       | 2nd Confidence= 15.3%
# ✅ Image 5: Label=little       | Prediction=little       | Confidence= 86.2% | 2nd Prediction=ring         | 2nd Confidence= 13.3%
# ✅ Image 6: Label=index        | Prediction=index        | Confidence= 63.5% | 2nd Prediction=little       | 2nd Confidence= 32.0%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 99.8% | 2nd Prediction=index        | 2nd Confidence=  0.2%
# ✅ Image 8: Label=ring         | Prediction=ring         | Confidence= 98.5% | 2nd Prediction=middle       | 2nd Confidence=  1.5%
# ❌ Image 9: Label=middle       | Prediction=ring         | Confidence= 79.4% | 2nd Prediction=middle       | 2nd Confidence= 20.6%
# ❌ Image 10: Label=middle       | Prediction=little       | Confidence= 79.5% | 2nd Prediction=ring         | 2nd Confidence= 17.3%
# ❌ Image 11: Label=middle       | Prediction=index        | Confidence= 89.2% | 2nd Prediction=middle       | 2nd Confidence=  9.9%
# ✅ Image 12: Label=middle       | Prediction=middle       | Confidence= 98.1% | 2nd Prediction=ring         | 2nd Confidence=  1.4%
# ❌ Image 13: Label=little       | Prediction=ring         | Confidence= 43.3% | 2nd Prediction=little       | 2nd Confidence= 36.6%
# ✅ Image 14: Label=ring         | Prediction=ring         | Confidence= 96.6% | 2nd Prediction=middle       | 2nd Confidence=  3.4%
# ✅ Image 15: Label=little       | Prediction=little       | Confidence= 99.7% | 2nd Prediction=ring         | 2nd Confidence=  0.3%
# ❌ Image 16: Label=index        | Prediction=little       | Confidence= 32.7% | 2nd Prediction=middle       | 2nd Confidence= 32.6%
# ❌ Image 17: Label=ring         | Prediction=little       | Confidence= 95.3% | 2nd Prediction=ring         | 2nd Confidence=  4.3%
# ✅ Image 18: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 19: Label=ring         | Prediction=ring         | Confidence= 89.7% | 2nd Prediction=middle       | 2nd Confidence= 10.1%
# ✅ Image 20: Label=middle       | Prediction=middle       | Confidence= 73.8% | 2nd Prediction=ring         | 2nd Confidence= 23.2%
#
# ======================================================================================================================================================
# 2026-03-26 15:37:59.024108: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of fine-tuned model using test dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using test dataset...
#
# Results :
#   - Loss                : 1.4043
#   - Accuracy            : 63.75%
#   - Top-2 Accuracy      : 85.47%
