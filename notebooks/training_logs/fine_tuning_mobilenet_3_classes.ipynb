# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index',  'middle']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 9575 files belonging to 3 classes.
# Found 1200 files belonging to 3 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 150
#   - Validation batches  : 13
#   - Test batches        : 6
#   - Batch size          : 64
#   - Training samples    : ~9600
#   - Validation samples  : ~832
#   - Test samples        : ~384
# 2026-03-26 08:41:20.951322: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-26 08:41:20.951355: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-26 08:41:20.951364: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-26 08:41:20.951383: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-26 08:41:20.951405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset             : normalisation + shuffle")
print("  - Validation and test dataset  : normalisation only")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset             : normalisation + shuffle
#   - Validation and test dataset  : normalisation only
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 3)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,563
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 3)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,291,723 (12.56 MB)
#  Trainable params: 344,579 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,160 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-26 08:41:22.515186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 78.65%
#   - Loss     : 0.5796

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants

# Number of layers in the model 
NUM_BASE_MODEL_LAYERS = len(frozen_fingerprint_basemodel.layers)

# keep ratio of 1/3 unfrozen layers vs. 2/3 frozen layers
UNFROZEN_FROZEN_LAYERS_RATIO = 0.33
NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS = int(NUM_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_LAYERS_RATIO)

#  ratio of unfrozen first layers vs. unfrozen last layers
UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO = 0
FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO)
FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS - FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS)

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")
print(f"Number of layers in the base model                      : {NUM_BASE_MODEL_LAYERS}")
print(f"Number of the first unfrozen layers in the base model   : {FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS}")
print(f"Number of the last unfrozen layers in the base model   : {FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS}")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Unfreeze the first FINE_TUNING_UNFREEZE_INPUT_BASE_MODEL_LAYERS-th layers
# Unfreeze the last FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS-th layers

for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS:
        layer.trainable = True
    elif i < (NUM_BASE_MODEL_LAYERS - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS):
        layer.trainable = False
    else:
        layer.trainable = True


print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# Number of layers in the base model                      : 155
# Number of the first unfrozen layers in the base model   : 0
# Number of the last unfrozen layers in the base model   : 51
# 📊 Unfreeze configuration :
#   - Frozen layers   : 51
#   - Unfrozen layers : 104
#   - Trainable params : 1,855,104 (82.2%)
#   - Frozen params    : 402,880
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_3_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS + 2]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[- FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS -2:], start=len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS - 2):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   103. block_11_depthwise_BN                    | Output: (None, 6, 6, 576)              | Trainable: False
#   104. block_11_depthwise_relu                  | Output: (None, 6, 6, 576)              | Trainable: False
#   105. block_11_project                         | Output: (None, 6, 6, 96)               | Trainable: True
#   106. block_11_project_BN                      | Output: (None, 6, 6, 96)               | Trainable: True
#   107. block_11_add                             | Output: (None, 6, 6, 96)               | Trainable: True
#   108. block_12_expand                          | Output: (None, 6, 6, 576)              | Trainable: True
#   109. block_12_expand_BN                       | Output: (None, 6, 6, 576)              | Trainable: True
#   110. block_12_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: True
#   111. block_12_depthwise                       | Output: (None, 6, 6, 576)              | Trainable: True
#   112. block_12_depthwise_BN                    | Output: (None, 6, 6, 576)              | Trainable: True
#   113. block_12_depthwise_relu                  | Output: (None, 6, 6, 576)              | Trainable: True
#   114. block_12_project                         | Output: (None, 6, 6, 96)               | Trainable: True
#   115. block_12_project_BN                      | Output: (None, 6, 6, 96)               | Trainable: True
#   116. block_12_add                             | Output: (None, 6, 6, 96)               | Trainable: True
#   117. block_13_expand                          | Output: (None, 6, 6, 576)              | Trainable: True
#   118. block_13_expand_BN                       | Output: (None, 6, 6, 576)              | Trainable: True
#   119. block_13_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: True
#   120. block_13_pad                             | Output: (None, 7, 7, 576)              | Trainable: True
#   121. block_13_depthwise                       | Output: (None, 3, 3, 576)              | Trainable: True
#   122. block_13_depthwise_BN                    | Output: (None, 3, 3, 576)              | Trainable: True
#   123. block_13_depthwise_relu                  | Output: (None, 3, 3, 576)              | Trainable: True
#   124. block_13_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   125. block_13_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   126. block_14_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   127. block_14_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   128. block_14_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   129. block_14_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   130. block_14_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   131. block_14_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   132. block_14_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   133. block_14_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   134. block_14_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   135. block_15_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   136. block_15_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   137. block_15_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   138. block_15_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   139. block_15_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   140. block_15_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   141. block_15_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   142. block_15_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   143. block_15_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   144. block_16_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   145. block_16_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,563 (9.93 MB)
#  Trainable params: 2,199,683 (8.39 MB)
#  Non-trainable params: 402,880 (1.54 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

frozen_accuracy = results_after_compile[1]
print(f"  - Accuracy : {frozen_accuracy*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 78.65%
#   - Loss     : 0.5796
#
#   ✅ Transfer-learning weigths have been preserved (78.6%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
improvement = (best_val_acc - frozen_accuracy) * 100

print(f"\n📊 Improvement vs Frozen  : {improvement:+.1f} %")
print(f"   - Frozen                 : {frozen_accuracy*100:.1f}%")
print(f"   - Fine-tuned             : {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.5988 - loss: 1.0454 - top2_accuracy: 0.8697
# Epoch 1: val_accuracy improved from None to 0.75735, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 42s 216ms/step - accuracy: 0.6367 - loss: 0.9149 - top2_accuracy: 0.8969 - val_accuracy: 0.7574 - val_loss: 0.6916 - val_top2_accuracy: 0.9412 - learning_rate: 1.0000e-05
# Epoch 2/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7172 - loss: 0.7210 - top2_accuracy: 0.9359
# Epoch 2: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 29s 194ms/step - accuracy: 0.7233 - loss: 0.7056 - top2_accuracy: 0.9421 - val_accuracy: 0.7574 - val_loss: 0.7154 - val_top2_accuracy: 0.9314 - learning_rate: 1.0000e-05
# Epoch 3/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7695 - loss: 0.6161 - top2_accuracy: 0.9555
# Epoch 3: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 29s 190ms/step - accuracy: 0.7737 - loss: 0.6062 - top2_accuracy: 0.9608 - val_accuracy: 0.7488 - val_loss: 0.7385 - val_top2_accuracy: 0.9326 - learning_rate: 1.0000e-05
# Epoch 4/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8057 - loss: 0.5466 - top2_accuracy: 0.9688
# Epoch 4: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.8030 - loss: 0.5428 - top2_accuracy: 0.9710 - val_accuracy: 0.7353 - val_loss: 0.7628 - val_top2_accuracy: 0.9326 - learning_rate: 1.0000e-05
# Epoch 5/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8365 - loss: 0.4826 - top2_accuracy: 0.9787
# Epoch 5: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.8369 - loss: 0.4802 - top2_accuracy: 0.9789 - val_accuracy: 0.7451 - val_loss: 0.7496 - val_top2_accuracy: 0.9387 - learning_rate: 1.0000e-05
# Epoch 6/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8630 - loss: 0.4260 - top2_accuracy: 0.9826
# Epoch 6: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 198ms/step - accuracy: 0.8653 - loss: 0.4243 - top2_accuracy: 0.9841 - val_accuracy: 0.7292 - val_loss: 0.7604 - val_top2_accuracy: 0.9449 - learning_rate: 1.0000e-05
# Epoch 7/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8880 - loss: 0.3816 - top2_accuracy: 0.9886
# Epoch 7: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.8904 - loss: 0.3741 - top2_accuracy: 0.9897 - val_accuracy: 0.7267 - val_loss: 0.7610 - val_top2_accuracy: 0.9510 - learning_rate: 1.0000e-05
# Epoch 8/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9034 - loss: 0.3373 - top2_accuracy: 0.9911
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 8: val_accuracy did not improve from 0.75735
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9085 - loss: 0.3303 - top2_accuracy: 0.9926 - val_accuracy: 0.7426 - val_loss: 0.7510 - val_top2_accuracy: 0.9583 - learning_rate: 1.0000e-05
# Epoch 9/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9268 - loss: 0.2895 - top2_accuracy: 0.9940
# Epoch 9: val_accuracy improved from 0.75735 to 0.76103, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 187ms/step - accuracy: 0.9272 - loss: 0.2895 - top2_accuracy: 0.9946 - val_accuracy: 0.7610 - val_loss: 0.7220 - val_top2_accuracy: 0.9571 - learning_rate: 5.0000e-06
# Epoch 10/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9341 - loss: 0.2727 - top2_accuracy: 0.9945
# Epoch 10: val_accuracy improved from 0.76103 to 0.77941, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9364 - loss: 0.2677 - top2_accuracy: 0.9953 - val_accuracy: 0.7794 - val_loss: 0.6991 - val_top2_accuracy: 0.9583 - learning_rate: 5.0000e-06
# Epoch 11/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9432 - loss: 0.2520 - top2_accuracy: 0.9959
# Epoch 11: val_accuracy improved from 0.77941 to 0.78064, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 11: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.9429 - loss: 0.2516 - top2_accuracy: 0.9963 - val_accuracy: 0.7806 - val_loss: 0.6867 - val_top2_accuracy: 0.9583 - learning_rate: 5.0000e-06
# Epoch 12/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9528 - loss: 0.2353 - top2_accuracy: 0.9969
# Epoch 12: val_accuracy did not improve from 0.78064
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9527 - loss: 0.2341 - top2_accuracy: 0.9973 - val_accuracy: 0.7806 - val_loss: 0.6956 - val_top2_accuracy: 0.9596 - learning_rate: 5.0000e-06
# Epoch 13/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9565 - loss: 0.2218 - top2_accuracy: 0.9964
# Epoch 13: val_accuracy improved from 0.78064 to 0.78922, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 13: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9559 - loss: 0.2215 - top2_accuracy: 0.9970 - val_accuracy: 0.7892 - val_loss: 0.6859 - val_top2_accuracy: 0.9608 - learning_rate: 5.0000e-06
# Epoch 14/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9599 - loss: 0.2074 - top2_accuracy: 0.9976
# Epoch 14: val_accuracy improved from 0.78922 to 0.79779, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 14: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 33s 220ms/step - accuracy: 0.9616 - loss: 0.2059 - top2_accuracy: 0.9982 - val_accuracy: 0.7978 - val_loss: 0.6749 - val_top2_accuracy: 0.9632 - learning_rate: 5.0000e-06
# Epoch 15/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9643 - loss: 0.1967 - top2_accuracy: 0.9972
# Epoch 15: val_accuracy did not improve from 0.79779
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 34s 225ms/step - accuracy: 0.9677 - loss: 0.1915 - top2_accuracy: 0.9981 - val_accuracy: 0.7953 - val_loss: 0.6746 - val_top2_accuracy: 0.9632 - learning_rate: 5.0000e-06
# Epoch 16/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9731 - loss: 0.1791 - top2_accuracy: 0.9982
# Epoch 16: val_accuracy improved from 0.79779 to 0.80147, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 34s 226ms/step - accuracy: 0.9732 - loss: 0.1798 - top2_accuracy: 0.9983 - val_accuracy: 0.8015 - val_loss: 0.6850 - val_top2_accuracy: 0.9645 - learning_rate: 5.0000e-06
# Epoch 17/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9786 - loss: 0.1651 - top2_accuracy: 0.9988
# Epoch 17: val_accuracy did not improve from 0.80147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 32s 210ms/step - accuracy: 0.9775 - loss: 0.1676 - top2_accuracy: 0.9990 - val_accuracy: 0.7990 - val_loss: 0.6860 - val_top2_accuracy: 0.9694 - learning_rate: 5.0000e-06
# Epoch 18/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9790 - loss: 0.1568 - top2_accuracy: 0.9991
# Epoch 18: val_accuracy improved from 0.80147 to 0.80270, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 18: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 189ms/step - accuracy: 0.9807 - loss: 0.1550 - top2_accuracy: 0.9994 - val_accuracy: 0.8027 - val_loss: 0.6968 - val_top2_accuracy: 0.9669 - learning_rate: 5.0000e-06
# Epoch 19/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9860 - loss: 0.1476 - top2_accuracy: 0.9994
# Epoch 19: val_accuracy improved from 0.80270 to 0.80515, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 188ms/step - accuracy: 0.9852 - loss: 0.1490 - top2_accuracy: 0.9995 - val_accuracy: 0.8051 - val_loss: 0.7053 - val_top2_accuracy: 0.9669 - learning_rate: 5.0000e-06
# Epoch 20/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9861 - loss: 0.1431 - top2_accuracy: 0.9996
# Epoch 20: val_accuracy improved from 0.80515 to 0.81250, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 20: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9854 - loss: 0.1434 - top2_accuracy: 0.9997 - val_accuracy: 0.8125 - val_loss: 0.7004 - val_top2_accuracy: 0.9669 - learning_rate: 5.0000e-06
# Epoch 21/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9872 - loss: 0.1372 - top2_accuracy: 0.9994
# Epoch 21: val_accuracy improved from 0.81250 to 0.81495, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 21: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 186ms/step - accuracy: 0.9883 - loss: 0.1368 - top2_accuracy: 0.9995 - val_accuracy: 0.8150 - val_loss: 0.7102 - val_top2_accuracy: 0.9681 - learning_rate: 5.0000e-06
# Epoch 22/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9905 - loss: 0.1313 - top2_accuracy: 0.9992
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 22: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9900 - loss: 0.1307 - top2_accuracy: 0.9993 - val_accuracy: 0.8088 - val_loss: 0.7078 - val_top2_accuracy: 0.9669 - learning_rate: 5.0000e-06
# Epoch 23/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9919 - loss: 0.1225 - top2_accuracy: 0.9998
# Epoch 23: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9920 - loss: 0.1241 - top2_accuracy: 0.9998 - val_accuracy: 0.8137 - val_loss: 0.7148 - val_top2_accuracy: 0.9669 - learning_rate: 2.5000e-06
# Epoch 24/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9930 - loss: 0.1202 - top2_accuracy: 0.9999
# Epoch 24: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9933 - loss: 0.1212 - top2_accuracy: 0.9999 - val_accuracy: 0.8088 - val_loss: 0.7146 - val_top2_accuracy: 0.9657 - learning_rate: 2.5000e-06
# Epoch 25/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9947 - loss: 0.1155 - top2_accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 180ms/step - accuracy: 0.9951 - loss: 0.1159 - top2_accuracy: 1.0000 - val_accuracy: 0.8150 - val_loss: 0.7233 - val_top2_accuracy: 0.9657 - learning_rate: 2.5000e-06
# Epoch 26/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9917 - loss: 0.1194 - top2_accuracy: 0.9998
# Epoch 26: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9931 - loss: 0.1176 - top2_accuracy: 0.9999 - val_accuracy: 0.8125 - val_loss: 0.7299 - val_top2_accuracy: 0.9657 - learning_rate: 2.5000e-06
# Epoch 27/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9938 - loss: 0.1158 - top2_accuracy: 0.9998
# Epoch 27: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9944 - loss: 0.1157 - top2_accuracy: 0.9999 - val_accuracy: 0.8113 - val_loss: 0.7345 - val_top2_accuracy: 0.9669 - learning_rate: 2.5000e-06
# Epoch 28/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9938 - loss: 0.1139 - top2_accuracy: 0.9999
# Epoch 28: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 180ms/step - accuracy: 0.9947 - loss: 0.1139 - top2_accuracy: 0.9998 - val_accuracy: 0.8088 - val_loss: 0.7366 - val_top2_accuracy: 0.9669 - learning_rate: 2.5000e-06
# Epoch 29/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9957 - loss: 0.1108 - top2_accuracy: 1.0000
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 29: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 183ms/step - accuracy: 0.9949 - loss: 0.1106 - top2_accuracy: 1.0000 - val_accuracy: 0.8113 - val_loss: 0.7435 - val_top2_accuracy: 0.9657 - learning_rate: 2.5000e-06
# Epoch 30/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9954 - loss: 0.1105 - top2_accuracy: 0.9998
# Epoch 30: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9961 - loss: 0.1090 - top2_accuracy: 0.9999 - val_accuracy: 0.8076 - val_loss: 0.7497 - val_top2_accuracy: 0.9657 - learning_rate: 1.2500e-06
# Epoch 31/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9964 - loss: 0.1078 - top2_accuracy: 0.9997
# Epoch 31: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9969 - loss: 0.1071 - top2_accuracy: 0.9998 - val_accuracy: 0.8100 - val_loss: 0.7506 - val_top2_accuracy: 0.9620 - learning_rate: 1.2500e-06
# Epoch 32/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9940 - loss: 0.1102 - top2_accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9948 - loss: 0.1090 - top2_accuracy: 1.0000 - val_accuracy: 0.8100 - val_loss: 0.7525 - val_top2_accuracy: 0.9632 - learning_rate: 1.2500e-06
# Epoch 33/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9975 - loss: 0.1034 - top2_accuracy: 0.9999
# Epoch 33: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9972 - loss: 0.1052 - top2_accuracy: 0.9999 - val_accuracy: 0.8100 - val_loss: 0.7557 - val_top2_accuracy: 0.9632 - learning_rate: 1.2500e-06
# Epoch 34/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9974 - loss: 0.1035 - top2_accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9969 - loss: 0.1042 - top2_accuracy: 1.0000 - val_accuracy: 0.8076 - val_loss: 0.7605 - val_top2_accuracy: 0.9620 - learning_rate: 1.2500e-06
# Epoch 35/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9972 - loss: 0.1035 - top2_accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9975 - loss: 0.1034 - top2_accuracy: 1.0000 - val_accuracy: 0.8100 - val_loss: 0.7629 - val_top2_accuracy: 0.9608 - learning_rate: 1.2500e-06
# Epoch 36/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9965 - loss: 0.1035 - top2_accuracy: 1.0000
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 36: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 183ms/step - accuracy: 0.9972 - loss: 0.1027 - top2_accuracy: 1.0000 - val_accuracy: 0.8088 - val_loss: 0.7662 - val_top2_accuracy: 0.9620 - learning_rate: 1.2500e-06
# Epoch 37/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9981 - loss: 0.1012 - top2_accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9976 - loss: 0.1025 - top2_accuracy: 1.0000 - val_accuracy: 0.8088 - val_loss: 0.7672 - val_top2_accuracy: 0.9620 - learning_rate: 6.2500e-07
# Epoch 38/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9967 - loss: 0.1028 - top2_accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 183ms/step - accuracy: 0.9972 - loss: 0.1024 - top2_accuracy: 1.0000 - val_accuracy: 0.8088 - val_loss: 0.7700 - val_top2_accuracy: 0.9632 - learning_rate: 6.2500e-07
# Epoch 39/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9963 - loss: 0.1023 - top2_accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9970 - loss: 0.1020 - top2_accuracy: 1.0000 - val_accuracy: 0.8088 - val_loss: 0.7702 - val_top2_accuracy: 0.9632 - learning_rate: 6.2500e-07
# Epoch 40/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9971 - loss: 0.1015 - top2_accuracy: 0.9999
# Epoch 40: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9969 - loss: 0.1019 - top2_accuracy: 0.9999 - val_accuracy: 0.8100 - val_loss: 0.7701 - val_top2_accuracy: 0.9632 - learning_rate: 6.2500e-07
# Epoch 41/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9981 - loss: 0.0985 - top2_accuracy: 0.9999
# Epoch 41: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9976 - loss: 0.1003 - top2_accuracy: 0.9998 - val_accuracy: 0.8125 - val_loss: 0.7713 - val_top2_accuracy: 0.9645 - learning_rate: 6.2500e-07
# Epoch 42/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9972 - loss: 0.1012 - top2_accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 187ms/step - accuracy: 0.9972 - loss: 0.1007 - top2_accuracy: 1.0000 - val_accuracy: 0.8100 - val_loss: 0.7732 - val_top2_accuracy: 0.9620 - learning_rate: 6.2500e-07
# Epoch 43/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9980 - loss: 0.0987 - top2_accuracy: 1.0000
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 43: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 189ms/step - accuracy: 0.9977 - loss: 0.0996 - top2_accuracy: 1.0000 - val_accuracy: 0.8076 - val_loss: 0.7751 - val_top2_accuracy: 0.9620 - learning_rate: 6.2500e-07
# Epoch 44/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9981 - loss: 0.0992 - top2_accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9979 - loss: 0.0996 - top2_accuracy: 1.0000 - val_accuracy: 0.8076 - val_loss: 0.7759 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 45/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9986 - loss: 0.0993 - top2_accuracy: 0.9998
# Epoch 45: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9981 - loss: 0.1000 - top2_accuracy: 0.9999 - val_accuracy: 0.8076 - val_loss: 0.7771 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 46/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9981 - loss: 0.0998 - top2_accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9980 - loss: 0.0993 - top2_accuracy: 1.0000 - val_accuracy: 0.8088 - val_loss: 0.7786 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 47/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9958 - loss: 0.1006 - top2_accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9967 - loss: 0.0997 - top2_accuracy: 0.9999 - val_accuracy: 0.8076 - val_loss: 0.7792 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 48/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9984 - loss: 0.0990 - top2_accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 183ms/step - accuracy: 0.9979 - loss: 0.0992 - top2_accuracy: 1.0000 - val_accuracy: 0.8076 - val_loss: 0.7815 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 49/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9976 - loss: 0.0991 - top2_accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 29s 190ms/step - accuracy: 0.9972 - loss: 0.0998 - top2_accuracy: 1.0000 - val_accuracy: 0.8076 - val_loss: 0.7825 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 50/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9985 - loss: 0.0979 - top2_accuracy: 0.9998
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 50: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 29s 190ms/step - accuracy: 0.9980 - loss: 0.0987 - top2_accuracy: 0.9999 - val_accuracy: 0.8088 - val_loss: 0.7840 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 51/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9982 - loss: 0.0975 - top2_accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.81495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 186ms/step - accuracy: 0.9978 - loss: 0.0983 - top2_accuracy: 0.9999 - val_accuracy: 0.8088 - val_loss: 0.7840 - val_top2_accuracy: 0.9608 - learning_rate: 1.5625e-07
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 51
#    Meilleure val_accuracy : 81.50% (epoch 21)
#
# 📊 Improvement vs Frozen  : +2.8 %
#    - Frozen                 : 78.6%
#    - Fine-tuned             : 81.5%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few predictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ❌ Image 1: Label=thumb        | Prediction=index        | Confidence= 97.2% | 2nd Prediction=middle       | 2nd Confidence=  2.4%
# ✅ Image 2: Label=middle       | Prediction=middle       | Confidence= 91.9% | 2nd Prediction=index        | 2nd Confidence=  7.9%
# ✅ Image 3: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ❌ Image 6: Label=index        | Prediction=middle       | Confidence= 97.7% | 2nd Prediction=index        | 2nd Confidence=  2.3%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 90.2% | 2nd Prediction=index        | 2nd Confidence=  9.0%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 98.6% | 2nd Prediction=thumb        | 2nd Confidence=  1.0%
# ❌ Image 9: Label=index        | Prediction=middle       | Confidence= 99.9% | 2nd Prediction=index        | 2nd Confidence=  0.1%
# ✅ Image 10: Label=index        | Prediction=index        | Confidence= 98.0% | 2nd Prediction=middle       | 2nd Confidence=  1.9%
# ✅ Image 11: Label=middle       | Prediction=middle       | Confidence= 99.0% | 2nd Prediction=index        | 2nd Confidence=  1.0%
# ✅ Image 12: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence= 99.2% | 2nd Prediction=index        | 2nd Confidence=  0.8%
# ❌ Image 14: Label=middle       | Prediction=index        | Confidence= 95.6% | 2nd Prediction=middle       | 2nd Confidence=  4.1%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 95.6% | 2nd Prediction=middle       | 2nd Confidence=  4.4%
# ✅ Image 16: Label=index        | Prediction=index        | Confidence= 98.7% | 2nd Prediction=thumb        | 2nd Confidence=  1.1%
# ❌ Image 17: Label=middle       | Prediction=index        | Confidence= 86.9% | 2nd Prediction=middle       | 2nd Confidence= 13.0%
# ✅ Image 18: Label=middle       | Prediction=middle       | Confidence= 98.7% | 2nd Prediction=index        | 2nd Confidence=  1.3%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 99.9% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 20: Label=index        | Prediction=index        | Confidence= 96.1% | 2nd Prediction=middle       | 2nd Confidence=  3.8%
#
# ======================================================================================================================================================
# 2026-03-26 09:05:53.849705: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of fine-tuned model using test dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using test dataset...
#
# Results :
#   - Loss                : 0.7192
#   - Accuracy            : 81.25%
#   - Top-2 Accuracy      : 97.14%
