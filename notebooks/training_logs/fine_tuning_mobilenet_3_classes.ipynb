# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 9575 files belonging to 3 classes.
# 2026-03-26 07:04:05.551672: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-26 07:04:05.551880: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-26 07:04:05.551905: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-26 07:04:05.552259: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-26 07:04:05.552287: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Found 1200 files belonging to 3 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 150
#   - Validation batches  : 13
#   - Test batches        : 6
#   - Batch size          : 64
#   - Training samples    : ~9600
#   - Validation samples  : ~832
#   - Test samples        : ~384

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset             : normalisation + shuffle")
print("  - Validation and test dataset  : normalisation only")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset             : normalisation + shuffle
#   - Validation and test dataset  : normalisation only
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 3)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,563
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 3)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,291,723 (12.56 MB)
#  Trainable params: 344,579 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,160 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-26 07:04:08.590948: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 78.65%
#   - Loss     : 0.5796

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants

# Number of layers in the model 
NUM_BASE_MODEL_LAYERS = len(frozen_fingerprint_basemodel.layers)

# keep ratio of 1/3 unfrozen layers vs. 2/3 frozen layers
UNFROZEN_FROZEN_LAYERS_RATIO = 0.33
NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS = int(NUM_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_LAYERS_RATIO)

# Keep ratio of 1/3 unfrozen first layers vs. 2/3 unfrozen last layers
UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO = 0.33
FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS * UNFROZEN_FROZEN_INPUT_OUTPUT_LAYERS_RATIO)
FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS = int(NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS - FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS)

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")
print(f"Number of layers in the base model                      : {NUM_BASE_MODEL_LAYERS}")
print(f"Number of the first unfrozen layers in the base model   : {FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS}")
print(f"Number of the last unfrozen layers in the base model   : {FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS}")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Unfreeze the first FINE_TUNING_UNFREEZE_INPUT_BASE_MODEL_LAYERS-th layers
# Unfreeze the last FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS-th layers

for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS:
        layer.trainable = True
    elif i < (NUM_BASE_MODEL_LAYERS - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS):
        layer.trainable = False
    else:
        layer.trainable = True


print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - NUM_MODEL_UNFROZEN_BASE_MODEL_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# Number of layers in the base model                      : 155
# Number of the first unfrozen layers in the base model   : 16
# Number of the last unfrozen layers in the base model   : 35
# 📊 Unfreeze configuration :
#   - Frozen layers   : 51
#   - Unfrozen layers : 104
#   - Trainable params : 1,629,504 (72.2%)
#   - Frozen params    : 628,480
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_3_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:FINE_TUNING_UNFROZEN_INPUT_BASE_MODEL_LAYERS + 2]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[- FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS -2:], start=len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_OUTPUT_BASE_MODEL_LAYERS - 2):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: True
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: True
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: True
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: True
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: True
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: True
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: True
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: True
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: True
#    11. block_1_expand_BN                        | Output: (None, 48, 48, 96)             | Trainable: True
#    12. block_1_expand_relu                      | Output: (None, 48, 48, 96)             | Trainable: True
#    13. block_1_pad                              | Output: (None, 49, 49, 96)             | Trainable: True
#    14. block_1_depthwise                        | Output: (None, 24, 24, 96)             | Trainable: True
#    15. block_1_depthwise_BN                     | Output: (None, 24, 24, 96)             | Trainable: True
#    16. block_1_depthwise_relu                   | Output: (None, 24, 24, 96)             | Trainable: True
#    17. block_1_project                          | Output: (None, 24, 24, 24)             | Trainable: False
#    18. block_1_project_BN                       | Output: (None, 24, 24, 24)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   119. block_13_expand_relu                     | Output: (None, 6, 6, 576)              | Trainable: False
#   120. block_13_pad                             | Output: (None, 7, 7, 576)              | Trainable: False
#   121. block_13_depthwise                       | Output: (None, 3, 3, 576)              | Trainable: True
#   122. block_13_depthwise_BN                    | Output: (None, 3, 3, 576)              | Trainable: True
#   123. block_13_depthwise_relu                  | Output: (None, 3, 3, 576)              | Trainable: True
#   124. block_13_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   125. block_13_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   126. block_14_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   127. block_14_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   128. block_14_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   129. block_14_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   130. block_14_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   131. block_14_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   132. block_14_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   133. block_14_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   134. block_14_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   135. block_15_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   136. block_15_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   137. block_15_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   138. block_15_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   139. block_15_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   140. block_15_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   141. block_15_project                         | Output: (None, 3, 3, 160)              | Trainable: True
#   142. block_15_project_BN                      | Output: (None, 3, 3, 160)              | Trainable: True
#   143. block_15_add                             | Output: (None, 3, 3, 160)              | Trainable: True
#   144. block_16_expand                          | Output: (None, 3, 3, 960)              | Trainable: True
#   145. block_16_expand_BN                       | Output: (None, 3, 3, 960)              | Trainable: True
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,563 (9.93 MB)
#  Trainable params: 1,974,083 (7.53 MB)
#  Non-trainable params: 628,480 (2.40 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

frozen_accuracy = results_after_compile[1]
print(f"  - Accuracy : {frozen_accuracy*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 78.65%
#   - Loss     : 0.5796
#
#   ✅ Transfer-learning weigths have been preserved (78.6%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
improvement = (best_val_acc - frozen_accuracy) * 100

print(f"\n📊 Improvement vs Frozen  : {improvement:+.1f} %")
print(f"   - Frozen                 : {frozen_accuracy*100:.1f}%")
print(f"   - Fine-tuned             : {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.5645 - loss: 1.1052 - top2_accuracy: 0.8530
# Epoch 1: val_accuracy improved from None to 0.71078, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 274ms/step - accuracy: 0.6017 - loss: 0.9784 - top2_accuracy: 0.8824 - val_accuracy: 0.7108 - val_loss: 0.7757 - val_top2_accuracy: 0.9216 - learning_rate: 1.0000e-05
# Epoch 2/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6961 - loss: 0.7648 - top2_accuracy: 0.9290
# Epoch 2: val_accuracy improved from 0.71078 to 0.72917, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - accuracy: 0.6961 - loss: 0.7546 - top2_accuracy: 0.9297 - val_accuracy: 0.7292 - val_loss: 0.7615 - val_top2_accuracy: 0.9167 - learning_rate: 1.0000e-05
# Epoch 3/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.7466 - loss: 0.6682 - top2_accuracy: 0.9472
# Epoch 3: val_accuracy improved from 0.72917 to 0.73407, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.7461 - loss: 0.6636 - top2_accuracy: 0.9489 - val_accuracy: 0.7341 - val_loss: 0.7678 - val_top2_accuracy: 0.9093 - learning_rate: 1.0000e-05
# Epoch 4/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7835 - loss: 0.5968 - top2_accuracy: 0.9612
# Epoch 4: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.7799 - loss: 0.5963 - top2_accuracy: 0.9607 - val_accuracy: 0.6985 - val_loss: 0.7763 - val_top2_accuracy: 0.9056 - learning_rate: 1.0000e-05
# Epoch 5/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8075 - loss: 0.5479 - top2_accuracy: 0.9687
# Epoch 5: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 243ms/step - accuracy: 0.8081 - loss: 0.5444 - top2_accuracy: 0.9690 - val_accuracy: 0.6924 - val_loss: 0.7760 - val_top2_accuracy: 0.9240 - learning_rate: 1.0000e-05
# Epoch 6/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8302 - loss: 0.4867 - top2_accuracy: 0.9777
# Epoch 6: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.8307 - loss: 0.4891 - top2_accuracy: 0.9770 - val_accuracy: 0.6642 - val_loss: 0.8310 - val_top2_accuracy: 0.9216 - learning_rate: 1.0000e-05
# Epoch 7/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8583 - loss: 0.4418 - top2_accuracy: 0.9831
# Epoch 7: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 244ms/step - accuracy: 0.8581 - loss: 0.4384 - top2_accuracy: 0.9830 - val_accuracy: 0.6483 - val_loss: 0.8828 - val_top2_accuracy: 0.9203 - learning_rate: 1.0000e-05
# Epoch 8/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8779 - loss: 0.3976 - top2_accuracy: 0.9852
# Epoch 8: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 236ms/step - accuracy: 0.8802 - loss: 0.3930 - top2_accuracy: 0.9863 - val_accuracy: 0.6422 - val_loss: 0.8921 - val_top2_accuracy: 0.9252 - learning_rate: 1.0000e-05
# Epoch 9/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8963 - loss: 0.3573 - top2_accuracy: 0.9892
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 9: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 233ms/step - accuracy: 0.8942 - loss: 0.3563 - top2_accuracy: 0.9884 - val_accuracy: 0.6336 - val_loss: 0.9237 - val_top2_accuracy: 0.9277 - learning_rate: 1.0000e-05
# Epoch 10/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9130 - loss: 0.3144 - top2_accuracy: 0.9928
# Epoch 10: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 233ms/step - accuracy: 0.9132 - loss: 0.3141 - top2_accuracy: 0.9930 - val_accuracy: 0.6446 - val_loss: 0.9205 - val_top2_accuracy: 0.9314 - learning_rate: 5.0000e-06
# Epoch 11/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9204 - loss: 0.2964 - top2_accuracy: 0.9918
# Epoch 11: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 235ms/step - accuracy: 0.9194 - loss: 0.2994 - top2_accuracy: 0.9928 - val_accuracy: 0.6556 - val_loss: 0.9097 - val_top2_accuracy: 0.9424 - learning_rate: 5.0000e-06
# Epoch 12/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9284 - loss: 0.2849 - top2_accuracy: 0.9931
# Epoch 12: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9276 - loss: 0.2827 - top2_accuracy: 0.9933 - val_accuracy: 0.6642 - val_loss: 0.8981 - val_top2_accuracy: 0.9412 - learning_rate: 5.0000e-06
# Epoch 13/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9407 - loss: 0.2628 - top2_accuracy: 0.9945
# Epoch 13: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9383 - loss: 0.2622 - top2_accuracy: 0.9947 - val_accuracy: 0.6728 - val_loss: 0.9025 - val_top2_accuracy: 0.9424 - learning_rate: 5.0000e-06
# Epoch 14/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9433 - loss: 0.2476 - top2_accuracy: 0.9968
# Epoch 14: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 233ms/step - accuracy: 0.9446 - loss: 0.2465 - top2_accuracy: 0.9961 - val_accuracy: 0.6838 - val_loss: 0.8930 - val_top2_accuracy: 0.9436 - learning_rate: 5.0000e-06
# Epoch 15/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9530 - loss: 0.2331 - top2_accuracy: 0.9965
# Epoch 15: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 233ms/step - accuracy: 0.9508 - loss: 0.2358 - top2_accuracy: 0.9963 - val_accuracy: 0.6814 - val_loss: 0.8877 - val_top2_accuracy: 0.9449 - learning_rate: 5.0000e-06
# Epoch 16/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9582 - loss: 0.2152 - top2_accuracy: 0.9978
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 16: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9581 - loss: 0.2154 - top2_accuracy: 0.9973 - val_accuracy: 0.6924 - val_loss: 0.8845 - val_top2_accuracy: 0.9449 - learning_rate: 5.0000e-06
# Epoch 17/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9642 - loss: 0.2047 - top2_accuracy: 0.9978
# Epoch 17: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9641 - loss: 0.2044 - top2_accuracy: 0.9980 - val_accuracy: 0.6936 - val_loss: 0.8586 - val_top2_accuracy: 0.9485 - learning_rate: 2.5000e-06
# Epoch 18/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9633 - loss: 0.1998 - top2_accuracy: 0.9967
# Epoch 18: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9634 - loss: 0.2010 - top2_accuracy: 0.9977 - val_accuracy: 0.6998 - val_loss: 0.8468 - val_top2_accuracy: 0.9510 - learning_rate: 2.5000e-06
# Epoch 19/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9635 - loss: 0.1970 - top2_accuracy: 0.9971
# Epoch 19: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 232ms/step - accuracy: 0.9644 - loss: 0.1971 - top2_accuracy: 0.9976 - val_accuracy: 0.7034 - val_loss: 0.8455 - val_top2_accuracy: 0.9522 - learning_rate: 2.5000e-06
# Epoch 20/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9709 - loss: 0.1880 - top2_accuracy: 0.9984
# Epoch 20: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9692 - loss: 0.1878 - top2_accuracy: 0.9981 - val_accuracy: 0.7071 - val_loss: 0.8395 - val_top2_accuracy: 0.9522 - learning_rate: 2.5000e-06
# Epoch 21/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9690 - loss: 0.1839 - top2_accuracy: 0.9978
# Epoch 21: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 234ms/step - accuracy: 0.9707 - loss: 0.1846 - top2_accuracy: 0.9986 - val_accuracy: 0.7169 - val_loss: 0.8318 - val_top2_accuracy: 0.9522 - learning_rate: 2.5000e-06
# Epoch 22/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9738 - loss: 0.1771 - top2_accuracy: 0.9974
# Epoch 22: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 235ms/step - accuracy: 0.9722 - loss: 0.1791 - top2_accuracy: 0.9981 - val_accuracy: 0.7157 - val_loss: 0.8418 - val_top2_accuracy: 0.9473 - learning_rate: 2.5000e-06
# Epoch 23/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9753 - loss: 0.1742 - top2_accuracy: 0.9988
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 23: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 235ms/step - accuracy: 0.9725 - loss: 0.1779 - top2_accuracy: 0.9984 - val_accuracy: 0.7194 - val_loss: 0.8335 - val_top2_accuracy: 0.9473 - learning_rate: 2.5000e-06
# Epoch 24/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9783 - loss: 0.1696 - top2_accuracy: 0.9994
# Epoch 24: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 236ms/step - accuracy: 0.9763 - loss: 0.1712 - top2_accuracy: 0.9994 - val_accuracy: 0.7243 - val_loss: 0.8179 - val_top2_accuracy: 0.9485 - learning_rate: 1.2500e-06
# Epoch 25/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9763 - loss: 0.1684 - top2_accuracy: 0.9985
# Epoch 25: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 236ms/step - accuracy: 0.9756 - loss: 0.1703 - top2_accuracy: 0.9986 - val_accuracy: 0.7292 - val_loss: 0.8057 - val_top2_accuracy: 0.9559 - learning_rate: 1.2500e-06
# Epoch 26/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9767 - loss: 0.1642 - top2_accuracy: 0.9981
# Epoch 26: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 236ms/step - accuracy: 0.9772 - loss: 0.1654 - top2_accuracy: 0.9985 - val_accuracy: 0.7255 - val_loss: 0.8040 - val_top2_accuracy: 0.9559 - learning_rate: 1.2500e-06
# Epoch 27/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9788 - loss: 0.1619 - top2_accuracy: 0.9985
# Epoch 27: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 35s 236ms/step - accuracy: 0.9796 - loss: 0.1628 - top2_accuracy: 0.9986 - val_accuracy: 0.7243 - val_loss: 0.8099 - val_top2_accuracy: 0.9522 - learning_rate: 1.2500e-06
# Epoch 28/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9804 - loss: 0.1576 - top2_accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 251ms/step - accuracy: 0.9786 - loss: 0.1598 - top2_accuracy: 0.9994 - val_accuracy: 0.7341 - val_loss: 0.8153 - val_top2_accuracy: 0.9534 - learning_rate: 1.2500e-06
# Epoch 29/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9833 - loss: 0.1555 - top2_accuracy: 0.9992
# Epoch 29: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 252ms/step - accuracy: 0.9816 - loss: 0.1593 - top2_accuracy: 0.9994 - val_accuracy: 0.7341 - val_loss: 0.8148 - val_top2_accuracy: 0.9571 - learning_rate: 1.2500e-06
# Epoch 30/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9797 - loss: 0.1591 - top2_accuracy: 0.9993
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 30: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9797 - loss: 0.1581 - top2_accuracy: 0.9995 - val_accuracy: 0.7341 - val_loss: 0.8184 - val_top2_accuracy: 0.9596 - learning_rate: 1.2500e-06
# Epoch 31/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9807 - loss: 0.1571 - top2_accuracy: 0.9988
# Epoch 31: val_accuracy did not improve from 0.73407
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 237ms/step - accuracy: 0.9807 - loss: 0.1568 - top2_accuracy: 0.9991 - val_accuracy: 0.7328 - val_loss: 0.8231 - val_top2_accuracy: 0.9571 - learning_rate: 6.2500e-07
# Epoch 32/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9803 - loss: 0.1568 - top2_accuracy: 0.9992
# Epoch 32: val_accuracy improved from 0.73407 to 0.74020, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 32: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9791 - loss: 0.1575 - top2_accuracy: 0.9994 - val_accuracy: 0.7402 - val_loss: 0.8250 - val_top2_accuracy: 0.9583 - learning_rate: 6.2500e-07
# Epoch 33/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9876 - loss: 0.1473 - top2_accuracy: 0.9998
# Epoch 33: val_accuracy improved from 0.74020 to 0.75368, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 33: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9858 - loss: 0.1491 - top2_accuracy: 0.9997 - val_accuracy: 0.7537 - val_loss: 0.8270 - val_top2_accuracy: 0.9596 - learning_rate: 6.2500e-07
# Epoch 34/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9835 - loss: 0.1503 - top2_accuracy: 0.9988
# Epoch 34: val_accuracy did not improve from 0.75368
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 237ms/step - accuracy: 0.9833 - loss: 0.1519 - top2_accuracy: 0.9992 - val_accuracy: 0.7537 - val_loss: 0.8234 - val_top2_accuracy: 0.9571 - learning_rate: 6.2500e-07
# Epoch 35/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9852 - loss: 0.1480 - top2_accuracy: 0.9989
# Epoch 35: val_accuracy improved from 0.75368 to 0.75735, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 35: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9845 - loss: 0.1491 - top2_accuracy: 0.9992 - val_accuracy: 0.7574 - val_loss: 0.8213 - val_top2_accuracy: 0.9473 - learning_rate: 6.2500e-07
# Epoch 36/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9859 - loss: 0.1477 - top2_accuracy: 0.9982
# Epoch 36: val_accuracy improved from 0.75735 to 0.76103, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 36: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9854 - loss: 0.1485 - top2_accuracy: 0.9989 - val_accuracy: 0.7610 - val_loss: 0.8186 - val_top2_accuracy: 0.9510 - learning_rate: 6.2500e-07
# Epoch 37/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9830 - loss: 0.1471 - top2_accuracy: 0.9993
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 37: val_accuracy improved from 0.76103 to 0.76471, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 37: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9829 - loss: 0.1490 - top2_accuracy: 0.9994 - val_accuracy: 0.7647 - val_loss: 0.8170 - val_top2_accuracy: 0.9522 - learning_rate: 6.2500e-07
# Epoch 38/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9841 - loss: 0.1464 - top2_accuracy: 0.9992
# Epoch 38: val_accuracy improved from 0.76471 to 0.76838, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 38: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 242ms/step - accuracy: 0.9835 - loss: 0.1476 - top2_accuracy: 0.9994 - val_accuracy: 0.7684 - val_loss: 0.8136 - val_top2_accuracy: 0.9547 - learning_rate: 3.1250e-07
# Epoch 39/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9842 - loss: 0.1469 - top2_accuracy: 0.9992
# Epoch 39: val_accuracy improved from 0.76838 to 0.77328, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 39: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9860 - loss: 0.1444 - top2_accuracy: 0.9994 - val_accuracy: 0.7733 - val_loss: 0.8055 - val_top2_accuracy: 0.9583 - learning_rate: 3.1250e-07
# Epoch 40/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9850 - loss: 0.1459 - top2_accuracy: 0.9992
# Epoch 40: val_accuracy improved from 0.77328 to 0.77819, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 40: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9844 - loss: 0.1466 - top2_accuracy: 0.9993 - val_accuracy: 0.7782 - val_loss: 0.7950 - val_top2_accuracy: 0.9608 - learning_rate: 3.1250e-07
# Epoch 41/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9841 - loss: 0.1497 - top2_accuracy: 0.9994
# Epoch 41: val_accuracy did not improve from 0.77819
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 238ms/step - accuracy: 0.9844 - loss: 0.1483 - top2_accuracy: 0.9994 - val_accuracy: 0.7733 - val_loss: 0.7880 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 42/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9856 - loss: 0.1420 - top2_accuracy: 0.9995
# Epoch 42: val_accuracy did not improve from 0.77819
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 238ms/step - accuracy: 0.9843 - loss: 0.1451 - top2_accuracy: 0.9994 - val_accuracy: 0.7770 - val_loss: 0.7798 - val_top2_accuracy: 0.9620 - learning_rate: 3.1250e-07
# Epoch 43/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9867 - loss: 0.1430 - top2_accuracy: 0.9995
# Epoch 43: val_accuracy improved from 0.77819 to 0.78922, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 43: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9865 - loss: 0.1442 - top2_accuracy: 0.9995 - val_accuracy: 0.7892 - val_loss: 0.7708 - val_top2_accuracy: 0.9645 - learning_rate: 3.1250e-07
# Epoch 44/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9831 - loss: 0.1449 - top2_accuracy: 0.9995
# Epoch 44: val_accuracy improved from 0.78922 to 0.79044, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 44: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 242ms/step - accuracy: 0.9842 - loss: 0.1443 - top2_accuracy: 0.9995 - val_accuracy: 0.7904 - val_loss: 0.7613 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 45/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9857 - loss: 0.1424 - top2_accuracy: 0.9997
# Epoch 45: val_accuracy did not improve from 0.79044
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9856 - loss: 0.1432 - top2_accuracy: 0.9997 - val_accuracy: 0.7904 - val_loss: 0.7521 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 46/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9838 - loss: 0.1469 - top2_accuracy: 0.9996
# Epoch 46: val_accuracy improved from 0.79044 to 0.79534, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 46: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9841 - loss: 0.1451 - top2_accuracy: 0.9993 - val_accuracy: 0.7953 - val_loss: 0.7442 - val_top2_accuracy: 0.9718 - learning_rate: 3.1250e-07
# Epoch 47/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9842 - loss: 0.1431 - top2_accuracy: 0.9998
# Epoch 47: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9836 - loss: 0.1443 - top2_accuracy: 0.9998 - val_accuracy: 0.7941 - val_loss: 0.7376 - val_top2_accuracy: 0.9718 - learning_rate: 3.1250e-07
# Epoch 48/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9858 - loss: 0.1430 - top2_accuracy: 0.9990
# Epoch 48: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 244ms/step - accuracy: 0.9855 - loss: 0.1432 - top2_accuracy: 0.9993 - val_accuracy: 0.7868 - val_loss: 0.7307 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 49/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9868 - loss: 0.1411 - top2_accuracy: 0.9997
# Epoch 49: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9865 - loss: 0.1419 - top2_accuracy: 0.9995 - val_accuracy: 0.7868 - val_loss: 0.7265 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 50/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9830 - loss: 0.1475 - top2_accuracy: 0.9984
# Epoch 50: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 238ms/step - accuracy: 0.9839 - loss: 0.1460 - top2_accuracy: 0.9990 - val_accuracy: 0.7917 - val_loss: 0.7233 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 51/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9853 - loss: 0.1421 - top2_accuracy: 0.9979
# Epoch 51: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9855 - loss: 0.1414 - top2_accuracy: 0.9990 - val_accuracy: 0.7880 - val_loss: 0.7212 - val_top2_accuracy: 0.9694 - learning_rate: 3.1250e-07
# Epoch 52/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9866 - loss: 0.1406 - top2_accuracy: 0.9994
# Epoch 52: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 238ms/step - accuracy: 0.9861 - loss: 0.1421 - top2_accuracy: 0.9993 - val_accuracy: 0.7917 - val_loss: 0.7191 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 53/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9857 - loss: 0.1408 - top2_accuracy: 0.9993
# Epoch 53: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 242ms/step - accuracy: 0.9867 - loss: 0.1395 - top2_accuracy: 0.9992 - val_accuracy: 0.7953 - val_loss: 0.7189 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 54/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9854 - loss: 0.1423 - top2_accuracy: 0.9993
# Epoch 54: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9853 - loss: 0.1438 - top2_accuracy: 0.9994 - val_accuracy: 0.7953 - val_loss: 0.7174 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 55/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9883 - loss: 0.1405 - top2_accuracy: 0.9994
# Epoch 55: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 245ms/step - accuracy: 0.9867 - loss: 0.1411 - top2_accuracy: 0.9995 - val_accuracy: 0.7929 - val_loss: 0.7159 - val_top2_accuracy: 0.9694 - learning_rate: 3.1250e-07
# Epoch 56/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9883 - loss: 0.1348 - top2_accuracy: 0.9997
# Epoch 56: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9867 - loss: 0.1376 - top2_accuracy: 0.9996 - val_accuracy: 0.7941 - val_loss: 0.7156 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 57/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9869 - loss: 0.1370 - top2_accuracy: 0.9993
# Epoch 57: val_accuracy did not improve from 0.79534
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - accuracy: 0.9867 - loss: 0.1373 - top2_accuracy: 0.9993 - val_accuracy: 0.7941 - val_loss: 0.7145 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 58/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9875 - loss: 0.1383 - top2_accuracy: 0.9995
# Epoch 58: val_accuracy improved from 0.79534 to 0.79657, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 58: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 242ms/step - accuracy: 0.9874 - loss: 0.1387 - top2_accuracy: 0.9998 - val_accuracy: 0.7966 - val_loss: 0.7140 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 59/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9869 - loss: 0.1365 - top2_accuracy: 0.9993
# Epoch 59: val_accuracy did not improve from 0.79657
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9865 - loss: 0.1382 - top2_accuracy: 0.9995 - val_accuracy: 0.7953 - val_loss: 0.7136 - val_top2_accuracy: 0.9718 - learning_rate: 3.1250e-07
# Epoch 60/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9861 - loss: 0.1372 - top2_accuracy: 0.9996
# Epoch 60: val_accuracy did not improve from 0.79657
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9870 - loss: 0.1375 - top2_accuracy: 0.9996 - val_accuracy: 0.7941 - val_loss: 0.7132 - val_top2_accuracy: 0.9718 - learning_rate: 3.1250e-07
# Epoch 61/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9895 - loss: 0.1363 - top2_accuracy: 0.9997
# Epoch 61: val_accuracy did not improve from 0.79657
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9882 - loss: 0.1373 - top2_accuracy: 0.9997 - val_accuracy: 0.7966 - val_loss: 0.7129 - val_top2_accuracy: 0.9718 - learning_rate: 3.1250e-07
# Epoch 62/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9859 - loss: 0.1399 - top2_accuracy: 0.9991
# Epoch 62: val_accuracy did not improve from 0.79657
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.9868 - loss: 0.1379 - top2_accuracy: 0.9994 - val_accuracy: 0.7953 - val_loss: 0.7130 - val_top2_accuracy: 0.9706 - learning_rate: 3.1250e-07
# Epoch 63/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9875 - loss: 0.1384 - top2_accuracy: 0.9988
# Epoch 63: val_accuracy did not improve from 0.79657
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 242ms/step - accuracy: 0.9875 - loss: 0.1384 - top2_accuracy: 0.9992 - val_accuracy: 0.7953 - val_loss: 0.7132 - val_top2_accuracy: 0.9694 - learning_rate: 3.1250e-07
# Epoch 64/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9876 - loss: 0.1376 - top2_accuracy: 0.9995
# Epoch 64: val_accuracy improved from 0.79657 to 0.79779, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 64: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 245ms/step - accuracy: 0.9869 - loss: 0.1389 - top2_accuracy: 0.9994 - val_accuracy: 0.7978 - val_loss: 0.7130 - val_top2_accuracy: 0.9694 - learning_rate: 3.1250e-07
# Epoch 65/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9889 - loss: 0.1339 - top2_accuracy: 0.9994
# Epoch 65: val_accuracy did not improve from 0.79779
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 243ms/step - accuracy: 0.9879 - loss: 0.1350 - top2_accuracy: 0.9996 - val_accuracy: 0.7978 - val_loss: 0.7139 - val_top2_accuracy: 0.9694 - learning_rate: 3.1250e-07
# Epoch 66/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9895 - loss: 0.1325 - top2_accuracy: 0.9999
# Epoch 66: val_accuracy did not improve from 0.79779
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 243ms/step - accuracy: 0.9883 - loss: 0.1343 - top2_accuracy: 0.9996 - val_accuracy: 0.7978 - val_loss: 0.7133 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 67/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9865 - loss: 0.1369 - top2_accuracy: 0.9993
# Epoch 67: val_accuracy did not improve from 0.79779
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step - accuracy: 0.9876 - loss: 0.1356 - top2_accuracy: 0.9993 - val_accuracy: 0.7966 - val_loss: 0.7140 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 68/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9884 - loss: 0.1349 - top2_accuracy: 0.9996
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 68: val_accuracy did not improve from 0.79779
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - accuracy: 0.9883 - loss: 0.1353 - top2_accuracy: 0.9995 - val_accuracy: 0.7978 - val_loss: 0.7146 - val_top2_accuracy: 0.9681 - learning_rate: 3.1250e-07
# Epoch 69/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9887 - loss: 0.1334 - top2_accuracy: 0.9997
# Epoch 69: val_accuracy improved from 0.79779 to 0.79902, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 69: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 39s 261ms/step - accuracy: 0.9877 - loss: 0.1343 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7143 - val_top2_accuracy: 0.9681 - learning_rate: 1.5625e-07
# Epoch 70/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9878 - loss: 0.1318 - top2_accuracy: 0.9996
# Epoch 70: val_accuracy did not improve from 0.79902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 45s 301ms/step - accuracy: 0.9884 - loss: 0.1315 - top2_accuracy: 0.9995 - val_accuracy: 0.7990 - val_loss: 0.7140 - val_top2_accuracy: 0.9681 - learning_rate: 1.5625e-07
# Epoch 71/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9904 - loss: 0.1298 - top2_accuracy: 0.9998
# Epoch 71: val_accuracy did not improve from 0.79902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 44s 291ms/step - accuracy: 0.9902 - loss: 0.1301 - top2_accuracy: 0.9999 - val_accuracy: 0.7990 - val_loss: 0.7142 - val_top2_accuracy: 0.9681 - learning_rate: 1.5625e-07
# Epoch 72/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9916 - loss: 0.1314 - top2_accuracy: 0.9997
# Epoch 72: val_accuracy did not improve from 0.79902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 46s 307ms/step - accuracy: 0.9897 - loss: 0.1343 - top2_accuracy: 0.9995 - val_accuracy: 0.7990 - val_loss: 0.7145 - val_top2_accuracy: 0.9681 - learning_rate: 1.5625e-07
# Epoch 73/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9888 - loss: 0.1341 - top2_accuracy: 0.9998
# Epoch 73: val_accuracy improved from 0.79902 to 0.80025, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 73: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 45s 298ms/step - accuracy: 0.9897 - loss: 0.1322 - top2_accuracy: 0.9998 - val_accuracy: 0.8002 - val_loss: 0.7149 - val_top2_accuracy: 0.9669 - learning_rate: 1.5625e-07
# Epoch 74/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9866 - loss: 0.1364 - top2_accuracy: 0.9990
# Epoch 74: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 44s 294ms/step - accuracy: 0.9868 - loss: 0.1354 - top2_accuracy: 0.9992 - val_accuracy: 0.7990 - val_loss: 0.7149 - val_top2_accuracy: 0.9669 - learning_rate: 1.5625e-07
# Epoch 75/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9888 - loss: 0.1324 - top2_accuracy: 0.9994
# Epoch 75: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 75: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 44s 291ms/step - accuracy: 0.9899 - loss: 0.1322 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7152 - val_top2_accuracy: 0.9681 - learning_rate: 1.5625e-07
# Epoch 76/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9875 - loss: 0.1312 - top2_accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 254ms/step - accuracy: 0.9880 - loss: 0.1321 - top2_accuracy: 0.9999 - val_accuracy: 0.7990 - val_loss: 0.7153 - val_top2_accuracy: 0.9681 - learning_rate: 7.8125e-08
# Epoch 77/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9884 - loss: 0.1312 - top2_accuracy: 0.9994
# Epoch 77: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 244ms/step - accuracy: 0.9870 - loss: 0.1340 - top2_accuracy: 0.9995 - val_accuracy: 0.7990 - val_loss: 0.7155 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 78/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9903 - loss: 0.1318 - top2_accuracy: 0.9997
# Epoch 78: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - accuracy: 0.9897 - loss: 0.1326 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7158 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 79/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9894 - loss: 0.1307 - top2_accuracy: 0.9995
# Epoch 79: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 245ms/step - accuracy: 0.9890 - loss: 0.1311 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7159 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 80/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9902 - loss: 0.1293 - top2_accuracy: 0.9995
# Epoch 80: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - accuracy: 0.9890 - loss: 0.1317 - top2_accuracy: 0.9994 - val_accuracy: 0.7978 - val_loss: 0.7160 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 81/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9887 - loss: 0.1320 - top2_accuracy: 0.9998
# Epoch 81: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - accuracy: 0.9896 - loss: 0.1308 - top2_accuracy: 0.9998 - val_accuracy: 0.7978 - val_loss: 0.7162 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 82/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9900 - loss: 0.1317 - top2_accuracy: 0.9997
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 82: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step - accuracy: 0.9908 - loss: 0.1321 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7164 - val_top2_accuracy: 0.9669 - learning_rate: 7.8125e-08
# Epoch 83/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9872 - loss: 0.1342 - top2_accuracy: 0.9996
# Epoch 83: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - accuracy: 0.9879 - loss: 0.1324 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7166 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 84/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9886 - loss: 0.1342 - top2_accuracy: 0.9997
# Epoch 84: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step - accuracy: 0.9883 - loss: 0.1337 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7167 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 85/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9904 - loss: 0.1320 - top2_accuracy: 0.9997
# Epoch 85: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 248ms/step - accuracy: 0.9904 - loss: 0.1317 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7167 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 86/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9913 - loss: 0.1273 - top2_accuracy: 0.9995
# Epoch 86: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - accuracy: 0.9904 - loss: 0.1299 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7168 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 87/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9897 - loss: 0.1313 - top2_accuracy: 0.9993
# Epoch 87: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 248ms/step - accuracy: 0.9889 - loss: 0.1316 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7169 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 88/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9895 - loss: 0.1321 - top2_accuracy: 0.9997
# Epoch 88: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step - accuracy: 0.9887 - loss: 0.1315 - top2_accuracy: 0.9998 - val_accuracy: 0.7990 - val_loss: 0.7170 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 89/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9871 - loss: 0.1348 - top2_accuracy: 0.9997
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-08.
#
# Epoch 89: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 247ms/step - accuracy: 0.9866 - loss: 0.1344 - top2_accuracy: 0.9995 - val_accuracy: 0.7990 - val_loss: 0.7171 - val_top2_accuracy: 0.9669 - learning_rate: 3.9062e-08
# Epoch 90/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9886 - loss: 0.1303 - top2_accuracy: 0.9998
# Epoch 90: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 249ms/step - accuracy: 0.9891 - loss: 0.1307 - top2_accuracy: 0.9999 - val_accuracy: 0.7990 - val_loss: 0.7171 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 91/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9896 - loss: 0.1297 - top2_accuracy: 0.9997
# Epoch 91: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 249ms/step - accuracy: 0.9896 - loss: 0.1309 - top2_accuracy: 0.9994 - val_accuracy: 0.7990 - val_loss: 0.7171 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 92/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9885 - loss: 0.1333 - top2_accuracy: 0.9997
# Epoch 92: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 249ms/step - accuracy: 0.9890 - loss: 0.1327 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7171 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 93/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9896 - loss: 0.1326 - top2_accuracy: 0.9996
# Epoch 93: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 251ms/step - accuracy: 0.9893 - loss: 0.1319 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7172 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 94/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9891 - loss: 0.1312 - top2_accuracy: 0.9999
# Epoch 94: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 251ms/step - accuracy: 0.9887 - loss: 0.1310 - top2_accuracy: 0.9998 - val_accuracy: 0.7990 - val_loss: 0.7172 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 95/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9890 - loss: 0.1301 - top2_accuracy: 0.9997
# Epoch 95: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - accuracy: 0.9890 - loss: 0.1314 - top2_accuracy: 0.9995 - val_accuracy: 0.7990 - val_loss: 0.7173 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 96/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9914 - loss: 0.1297 - top2_accuracy: 0.9997
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1e-08.
#
# Epoch 96: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 250ms/step - accuracy: 0.9901 - loss: 0.1307 - top2_accuracy: 0.9998 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.9531e-08
# Epoch 97/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9902 - loss: 0.1295 - top2_accuracy: 0.9997
# Epoch 97: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 249ms/step - accuracy: 0.9893 - loss: 0.1306 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 98/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9885 - loss: 0.1298 - top2_accuracy: 0.9997
# Epoch 98: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - accuracy: 0.9892 - loss: 0.1293 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 99/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9891 - loss: 0.1307 - top2_accuracy: 0.9998
# Epoch 99: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 249ms/step - accuracy: 0.9900 - loss: 0.1306 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 100/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9893 - loss: 0.1318 - top2_accuracy: 0.9997
# Epoch 100: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 248ms/step - accuracy: 0.9893 - loss: 0.1319 - top2_accuracy: 0.9997 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 101/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9922 - loss: 0.1261 - top2_accuracy: 1.0000
# Epoch 101: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 37s 250ms/step - accuracy: 0.9909 - loss: 0.1295 - top2_accuracy: 0.9999 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 102/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9911 - loss: 0.1300 - top2_accuracy: 0.9999
# Epoch 102: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 38s 253ms/step - accuracy: 0.9907 - loss: 0.1315 - top2_accuracy: 0.9996 - val_accuracy: 0.7990 - val_loss: 0.7174 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 103/120
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9882 - loss: 0.1357 - top2_accuracy: 0.9990
# Epoch 103: val_accuracy did not improve from 0.80025
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - accuracy: 0.9890 - loss: 0.1345 - top2_accuracy: 0.9994 - val_accuracy: 0.7990 - val_loss: 0.7175 - val_top2_accuracy: 0.9669 - learning_rate: 1.0000e-08
# Epoch 103: early stopping
# Restoring model weights from the end of the best epoch: 73.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 103
#    Meilleure val_accuracy : 80.02% (epoch 73)
#
# 📊 Improvement vs Frozen  : +1.4 %
#    - Frozen                 : 78.6%
#    - Fine-tuned             : 80.0%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few predictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 92.5% | 2nd Prediction=index        | 2nd Confidence=  6.4%
# ✅ Image 2: Label=middle       | Prediction=middle       | Confidence= 96.3% | 2nd Prediction=index        | 2nd Confidence=  3.0%
# ✅ Image 3: Label=middle       | Prediction=middle       | Confidence= 75.7% | 2nd Prediction=index        | 2nd Confidence= 20.2%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence= 99.7% | 2nd Prediction=middle       | 2nd Confidence=  0.3%
# ❌ Image 6: Label=index        | Prediction=middle       | Confidence= 99.5% | 2nd Prediction=index        | 2nd Confidence=  0.5%
# ❌ Image 7: Label=thumb        | Prediction=index        | Confidence= 95.9% | 2nd Prediction=middle       | 2nd Confidence=  2.2%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 63.5% | 2nd Prediction=middle       | 2nd Confidence= 30.6%
# ❌ Image 9: Label=index        | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ❌ Image 10: Label=index        | Prediction=middle       | Confidence= 83.5% | 2nd Prediction=index        | 2nd Confidence= 16.4%
# ✅ Image 11: Label=middle       | Prediction=middle       | Confidence= 98.0% | 2nd Prediction=index        | 2nd Confidence=  2.0%
# ✅ Image 12: Label=thumb        | Prediction=thumb        | Confidence= 99.8% | 2nd Prediction=index        | 2nd Confidence=  0.1%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence= 98.8% | 2nd Prediction=index        | 2nd Confidence=  1.1%
# ❌ Image 14: Label=middle       | Prediction=index        | Confidence= 54.9% | 2nd Prediction=middle       | 2nd Confidence= 44.7%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 99.4% | 2nd Prediction=middle       | 2nd Confidence=  0.5%
# ✅ Image 16: Label=index        | Prediction=index        | Confidence= 86.3% | 2nd Prediction=thumb        | 2nd Confidence=  9.2%
# ❌ Image 17: Label=middle       | Prediction=index        | Confidence= 85.1% | 2nd Prediction=middle       | 2nd Confidence= 14.5%
# ❌ Image 18: Label=middle       | Prediction=index        | Confidence= 92.5% | 2nd Prediction=middle       | 2nd Confidence=  7.5%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 20: Label=index        | Prediction=index        | Confidence= 99.7% | 2nd Prediction=middle       | 2nd Confidence=  0.3%
#
# ======================================================================================================================================================
# 2026-03-26 08:07:56.195528: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of fine-tuned model using test dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using test dataset...
#
# Results :
#   - Loss                : 0.7311
#   - Accuracy            : 79.69%
#   - Top-2 Accuracy      : 95.83%
