# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring']

num_classes = len(class_names)
print(f"\n👁️ {num_classes} fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ 4 fingerprints classes : ['thumb', 'index', 'middle', 'ring']
# Fingerprint model name : MobileNetV2_FingerPrint_Model_4_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def traverse_dataset_dir(dataset_dir, class_names):

    # List to store file information
    imgdata = []

    # Traverse the input directory to get all image files
    for dirname, _, filenames in os.walk(dataset_dir):

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        for filename in filenames:
         
            if filename == ".DS_Store":  # Skip macOS system files
                continue

            if filename.find("Zcut") != -1:
                feature = 'zcut'
            elif filename.find('CR') != -1:
                feature = 'cr'
            elif filename.find('Obl') != -1:
                feature = 'obl'
            else:
                feature = 'unaltered'

            if filename.find("thumb") != -1:
                finger = "thumb"
            elif filename.find("index") != -1:
                finger = "index"
            elif filename.find("middle") != -1:
                finger = "middle"
            elif filename.find("ring") != -1:
                finger = "ring"
            elif filename.find("little") != -1:
                finger = "little"
            else:
                finger = None

            # image is to be considered given the current class names 
            file_path = os.path.join(dirname, filename)

            # extract the image features
            img = Image.open(file_path)
    
            try:
                img.verify()  # Verify that the file is a valid image
            except:
                print(f"Invalid image file: {file_path}")
                continue

            imgdata.append([file_path, img.format, img.size, img.mode, feature, finger])

    # Create a DataFrame
    imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Feature", "Finger"])

    # Add an index column
    imgdf.index.name = "ID"

    return imgdf

# %%
# train dataset
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
imgdf = traverse_dataset_dir(dataset_train_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12766 entries, 0 to 12765
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    12766 non-null  str
#  1   ImageFormat  12766 non-null  str
#  2   ImageSize    12766 non-null  object
#  3   ImageMode    12766 non-null  str
#  4   Feature      12766 non-null  str
#  5   Finger       12766 non-null  str
# dtypes: object(1), str(5)
# memory usage: 598.5+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    3200
# obl          3193
# zcut         3191
# cr           3182
# Name: count, dtype: int64
# Finger
# middle    3193
# index     3192
# ring      3191
# thumb     3190
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 24.99%
# Percentage of Index fingers: 25.00%
# Percentage of Middle fingers: 25.01%
# Percentage of Ring fingers: 25.00%
# Percentage of Little fingers: 0.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 25.07%
# Percentage of Zcut: 25.00%
# Percentage of CR: 24.93%
# Percentage of Obl: 25.01%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/train/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/train/

# %%
# validation/test dataset
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
imgdf = traverse_dataset_dir(dataset_val_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    1600 non-null   str
#  1   ImageFormat  1600 non-null   str
#  2   ImageSize    1600 non-null   object
#  3   ImageMode    1600 non-null   str
#  4   Feature      1600 non-null   str
#  5   Finger       1600 non-null   str
# dtypes: object(1), str(5)
# memory usage: 75.1+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    1600
# Name: count, dtype: int64
# Finger
# middle    400
# thumb     400
# index     400
# ring      400
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 25.00%
# Percentage of Index fingers: 25.00%
# Percentage of Middle fingers: 25.00%
# Percentage of Ring fingers: 25.00%
# Percentage of Little fingers: 0.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 100.00%
# Percentage of Zcut: 0.00%
# Percentage of CR: 0.00%
# Percentage of Obl: 0.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/validation/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/validation/

# %% [markdown]
# ## Split dataset for training / validation / test

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 12766 files belonging to 4 classes.
# Found 1600 files belonging to 4 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle', 'ring']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle', 'ring']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle', 'ring']
#   - ✅ Number of correct classes : 4
#
#   - Training batches    : 200
#   - Validation batches  : 17
#   - Test batches        : 8
#   - Batch size          : 64
#   - Training samples    : ~12800
#   - Validation samples  : ~1088
#   - Test samples        : ~512
# 2026-03-25 22:12:24.697092: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-25 22:12:24.697122: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-25 22:12:24.697131: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-25 22:12:24.697148: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-25 22:12:24.697158: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("  - Test dataset       : Normalisation")

print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#   - Test dataset       : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

MobileNet_basename = MobileNet_version + "_FingerPrint_BaseModel"
if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x306170c20>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x306170c20>) → Dropout(0.3) → Dense(4,softmax)
#
#   - Trainable parameters     : 344,644
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,628
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_4_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,628 (9.93 MB)
#  Trainable params: 344,644 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 15
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 15 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-25 22:12:27.236975: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4311 - loss: 4.2658 - top2_accuracy: 0.6926
# Epoch 1: val_accuracy improved from None to 0.60018, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.4902 - loss: 3.0049 - top2_accuracy: 0.7484 - val_accuracy: 0.6002 - val_loss: 1.6238 - val_top2_accuracy: 0.8226 - learning_rate: 0.0010
# Epoch 2/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5610 - loss: 1.5598 - top2_accuracy: 0.8016
# Epoch 2: val_accuracy improved from 0.60018 to 0.60294, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.5681 - loss: 1.4463 - top2_accuracy: 0.8082 - val_accuracy: 0.6029 - val_loss: 1.1938 - val_top2_accuracy: 0.8438 - learning_rate: 0.0010
# Epoch 3/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5792 - loss: 1.2277 - top2_accuracy: 0.8197
# Epoch 3: val_accuracy improved from 0.60294 to 0.60570, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.5850 - loss: 1.1916 - top2_accuracy: 0.8228 - val_accuracy: 0.6057 - val_loss: 1.0739 - val_top2_accuracy: 0.8410 - learning_rate: 0.0010
# Epoch 4/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5901 - loss: 1.1150 - top2_accuracy: 0.8332
# Epoch 4: val_accuracy did not improve from 0.60570
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.5910 - loss: 1.1074 - top2_accuracy: 0.8275 - val_accuracy: 0.6057 - val_loss: 1.0631 - val_top2_accuracy: 0.8364 - learning_rate: 0.0010
# Epoch 5/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5911 - loss: 1.0835 - top2_accuracy: 0.8324
# Epoch 5: val_accuracy improved from 0.60570 to 0.61121, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.5942 - loss: 1.0728 - top2_accuracy: 0.8346 - val_accuracy: 0.6112 - val_loss: 0.9874 - val_top2_accuracy: 0.8511 - learning_rate: 0.0010
# Epoch 6/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6001 - loss: 1.0421 - top2_accuracy: 0.8421
# Epoch 6: val_accuracy improved from 0.61121 to 0.61765, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.5950 - loss: 1.0548 - top2_accuracy: 0.8357 - val_accuracy: 0.6176 - val_loss: 0.9799 - val_top2_accuracy: 0.8511 - learning_rate: 0.0010
# Epoch 7/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6024 - loss: 1.0287 - top2_accuracy: 0.8383
# Epoch 7: val_accuracy did not improve from 0.61765
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step - accuracy: 0.6026 - loss: 1.0312 - top2_accuracy: 0.8382 - val_accuracy: 0.6176 - val_loss: 0.9736 - val_top2_accuracy: 0.8557 - learning_rate: 0.0010
# Epoch 8/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6012 - loss: 1.0293 - top2_accuracy: 0.8402
# Epoch 8: val_accuracy improved from 0.61765 to 0.61857, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.6010 - loss: 1.0323 - top2_accuracy: 0.8381 - val_accuracy: 0.6186 - val_loss: 0.9750 - val_top2_accuracy: 0.8511 - learning_rate: 0.0010
# Epoch 9/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6096 - loss: 1.0193 - top2_accuracy: 0.8499
# Epoch 9: val_accuracy improved from 0.61857 to 0.62592, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.6072 - loss: 1.0200 - top2_accuracy: 0.8444 - val_accuracy: 0.6259 - val_loss: 0.9907 - val_top2_accuracy: 0.8483 - learning_rate: 0.0010
# Epoch 10/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6107 - loss: 1.0146 - top2_accuracy: 0.8466
# Epoch 10: val_accuracy improved from 0.62592 to 0.62684, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.6095 - loss: 1.0202 - top2_accuracy: 0.8420 - val_accuracy: 0.6268 - val_loss: 0.9693 - val_top2_accuracy: 0.8529 - learning_rate: 0.0010
# Epoch 11/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6106 - loss: 1.0136 - top2_accuracy: 0.8392
# Epoch 11: val_accuracy improved from 0.62684 to 0.63511, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 11: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.6068 - loss: 1.0251 - top2_accuracy: 0.8385 - val_accuracy: 0.6351 - val_loss: 0.9661 - val_top2_accuracy: 0.8392 - learning_rate: 0.0010
# Epoch 12/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6062 - loss: 1.0184 - top2_accuracy: 0.8397
# Epoch 12: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step - accuracy: 0.6061 - loss: 1.0235 - top2_accuracy: 0.8379 - val_accuracy: 0.6259 - val_loss: 0.9734 - val_top2_accuracy: 0.8493 - learning_rate: 0.0010
# Epoch 13/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6132 - loss: 1.0150 - top2_accuracy: 0.8338
# Epoch 13: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - accuracy: 0.6113 - loss: 1.0165 - top2_accuracy: 0.8348 - val_accuracy: 0.6085 - val_loss: 0.9721 - val_top2_accuracy: 0.8438 - learning_rate: 0.0010
# Epoch 14/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6080 - loss: 1.0074 - top2_accuracy: 0.8471
# Epoch 14: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.6060 - loss: 1.0149 - top2_accuracy: 0.8424 - val_accuracy: 0.6259 - val_loss: 0.9640 - val_top2_accuracy: 0.8456 - learning_rate: 0.0010
# Epoch 15/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6109 - loss: 1.0121 - top2_accuracy: 0.8400
# Epoch 15: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.6119 - loss: 1.0156 - top2_accuracy: 0.8407 - val_accuracy: 0.6222 - val_loss: 0.9648 - val_top2_accuracy: 0.8566 - learning_rate: 0.0010
# Epoch 16/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6120 - loss: 1.0058 - top2_accuracy: 0.8434
# Epoch 16: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.6083 - loss: 1.0090 - top2_accuracy: 0.8417 - val_accuracy: 0.6278 - val_loss: 0.9492 - val_top2_accuracy: 0.8520 - learning_rate: 0.0010
# Epoch 17/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6072 - loss: 1.0126 - top2_accuracy: 0.8415
# Epoch 17: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.6123 - loss: 1.0126 - top2_accuracy: 0.8397 - val_accuracy: 0.6222 - val_loss: 0.9694 - val_top2_accuracy: 0.8447 - learning_rate: 0.0010
# Epoch 18/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6143 - loss: 1.0087 - top2_accuracy: 0.8465
# Epoch 18: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - accuracy: 0.6097 - loss: 1.0095 - top2_accuracy: 0.8438 - val_accuracy: 0.6259 - val_loss: 0.9818 - val_top2_accuracy: 0.8428 - learning_rate: 0.0010
# Epoch 19/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6158 - loss: 1.0061 - top2_accuracy: 0.8475
# Epoch 19: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.6129 - loss: 1.0089 - top2_accuracy: 0.8466 - val_accuracy: 0.6287 - val_loss: 0.9598 - val_top2_accuracy: 0.8603 - learning_rate: 0.0010
# Epoch 20/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6262 - loss: 0.9802 - top2_accuracy: 0.8547
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.6175 - loss: 0.9970 - top2_accuracy: 0.8460 - val_accuracy: 0.6278 - val_loss: 0.9803 - val_top2_accuracy: 0.8438 - learning_rate: 0.0010
# Epoch 21/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6255 - loss: 0.9767 - top2_accuracy: 0.8553
# Epoch 21: val_accuracy did not improve from 0.63511
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.6318 - loss: 0.9632 - top2_accuracy: 0.8572 - val_accuracy: 0.6333 - val_loss: 0.9421 - val_top2_accuracy: 0.8520 - learning_rate: 5.0000e-04
# Epoch 22/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6314 - loss: 0.9486 - top2_accuracy: 0.8589
# Epoch 22: val_accuracy improved from 0.63511 to 0.64890, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6310 - loss: 0.9543 - top2_accuracy: 0.8561 - val_accuracy: 0.6489 - val_loss: 0.9161 - val_top2_accuracy: 0.8667 - learning_rate: 5.0000e-04
# Epoch 23/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6395 - loss: 0.9361 - top2_accuracy: 0.8623
# Epoch 23: val_accuracy did not improve from 0.64890
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.6380 - loss: 0.9439 - top2_accuracy: 0.8611 - val_accuracy: 0.6379 - val_loss: 0.9256 - val_top2_accuracy: 0.8548 - learning_rate: 5.0000e-04
# Epoch 24/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6329 - loss: 0.9421 - top2_accuracy: 0.8627
# Epoch 24: val_accuracy improved from 0.64890 to 0.65625, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.6377 - loss: 0.9407 - top2_accuracy: 0.8628 - val_accuracy: 0.6562 - val_loss: 0.9092 - val_top2_accuracy: 0.8667 - learning_rate: 5.0000e-04
# Epoch 25/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6359 - loss: 0.9336 - top2_accuracy: 0.8615
# Epoch 25: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.6383 - loss: 0.9335 - top2_accuracy: 0.8613 - val_accuracy: 0.6461 - val_loss: 0.9149 - val_top2_accuracy: 0.8667 - learning_rate: 5.0000e-04
# Epoch 26/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6357 - loss: 0.9397 - top2_accuracy: 0.8628
# Epoch 26: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.6415 - loss: 0.9398 - top2_accuracy: 0.8610 - val_accuracy: 0.6425 - val_loss: 0.9212 - val_top2_accuracy: 0.8631 - learning_rate: 5.0000e-04
# Epoch 27/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6479 - loss: 0.9210 - top2_accuracy: 0.8673
# Epoch 27: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.6446 - loss: 0.9276 - top2_accuracy: 0.8672 - val_accuracy: 0.6434 - val_loss: 0.9276 - val_top2_accuracy: 0.8631 - learning_rate: 5.0000e-04
# Epoch 28/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6406 - loss: 0.9326 - top2_accuracy: 0.8688
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 28: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step - accuracy: 0.6396 - loss: 0.9374 - top2_accuracy: 0.8661 - val_accuracy: 0.6471 - val_loss: 0.9422 - val_top2_accuracy: 0.8474 - learning_rate: 5.0000e-04
# Epoch 29/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6536 - loss: 0.9108 - top2_accuracy: 0.8700
# Epoch 29: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6583 - loss: 0.9093 - top2_accuracy: 0.8730 - val_accuracy: 0.6526 - val_loss: 0.9041 - val_top2_accuracy: 0.8686 - learning_rate: 2.5000e-04
# Epoch 30/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6614 - loss: 0.8866 - top2_accuracy: 0.8785
# Epoch 30: val_accuracy improved from 0.65625 to 0.65809, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6612 - loss: 0.8906 - top2_accuracy: 0.8791 - val_accuracy: 0.6581 - val_loss: 0.9014 - val_top2_accuracy: 0.8676 - learning_rate: 2.5000e-04
# Epoch 31/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6552 - loss: 0.8920 - top2_accuracy: 0.8734
# Epoch 31: val_accuracy improved from 0.65809 to 0.66452, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 31: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6589 - loss: 0.8955 - top2_accuracy: 0.8744 - val_accuracy: 0.6645 - val_loss: 0.8982 - val_top2_accuracy: 0.8713 - learning_rate: 2.5000e-04
# Epoch 32/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6632 - loss: 0.8818 - top2_accuracy: 0.8825
# Epoch 32: val_accuracy did not improve from 0.66452
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.6596 - loss: 0.8879 - top2_accuracy: 0.8818 - val_accuracy: 0.6553 - val_loss: 0.9002 - val_top2_accuracy: 0.8649 - learning_rate: 2.5000e-04
# Epoch 33/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6632 - loss: 0.8865 - top2_accuracy: 0.8807
# Epoch 33: val_accuracy did not improve from 0.66452
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.6658 - loss: 0.8851 - top2_accuracy: 0.8799 - val_accuracy: 0.6608 - val_loss: 0.9079 - val_top2_accuracy: 0.8575 - learning_rate: 2.5000e-04
# Epoch 34/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6687 - loss: 0.8809 - top2_accuracy: 0.8841
# Epoch 34: val_accuracy did not improve from 0.66452
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.6671 - loss: 0.8799 - top2_accuracy: 0.8809 - val_accuracy: 0.6627 - val_loss: 0.8893 - val_top2_accuracy: 0.8686 - learning_rate: 2.5000e-04
# Epoch 35/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6648 - loss: 0.8756 - top2_accuracy: 0.8782
# Epoch 35: val_accuracy did not improve from 0.66452
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6639 - loss: 0.8776 - top2_accuracy: 0.8786 - val_accuracy: 0.6599 - val_loss: 0.8970 - val_top2_accuracy: 0.8667 - learning_rate: 2.5000e-04
# Epoch 36/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6610 - loss: 0.8758 - top2_accuracy: 0.8822
# Epoch 36: val_accuracy did not improve from 0.66452
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.6626 - loss: 0.8818 - top2_accuracy: 0.8809 - val_accuracy: 0.6553 - val_loss: 0.9019 - val_top2_accuracy: 0.8621 - learning_rate: 2.5000e-04
# Epoch 37/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6667 - loss: 0.8691 - top2_accuracy: 0.8837
# Epoch 37: val_accuracy improved from 0.66452 to 0.66636, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 37: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.6640 - loss: 0.8761 - top2_accuracy: 0.8801 - val_accuracy: 0.6664 - val_loss: 0.8962 - val_top2_accuracy: 0.8667 - learning_rate: 2.5000e-04
# Epoch 38/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6640 - loss: 0.8780 - top2_accuracy: 0.8879
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 38: val_accuracy did not improve from 0.66636
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.6663 - loss: 0.8768 - top2_accuracy: 0.8862 - val_accuracy: 0.6590 - val_loss: 0.8960 - val_top2_accuracy: 0.8676 - learning_rate: 2.5000e-04
# Epoch 39/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6774 - loss: 0.8494 - top2_accuracy: 0.8889
# Epoch 39: val_accuracy did not improve from 0.66636
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6760 - loss: 0.8572 - top2_accuracy: 0.8885 - val_accuracy: 0.6590 - val_loss: 0.8902 - val_top2_accuracy: 0.8759 - learning_rate: 1.2500e-04
# Epoch 40/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6757 - loss: 0.8526 - top2_accuracy: 0.8878
# Epoch 40: val_accuracy improved from 0.66636 to 0.66912, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 40: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6756 - loss: 0.8502 - top2_accuracy: 0.8887 - val_accuracy: 0.6691 - val_loss: 0.8814 - val_top2_accuracy: 0.8722 - learning_rate: 1.2500e-04
# Epoch 41/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6785 - loss: 0.8474 - top2_accuracy: 0.8910
# Epoch 41: val_accuracy improved from 0.66912 to 0.67188, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6750 - loss: 0.8538 - top2_accuracy: 0.8898 - val_accuracy: 0.6719 - val_loss: 0.8848 - val_top2_accuracy: 0.8667 - learning_rate: 1.2500e-04
# Epoch 42/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6800 - loss: 0.8437 - top2_accuracy: 0.8937
# Epoch 42: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6796 - loss: 0.8474 - top2_accuracy: 0.8928 - val_accuracy: 0.6654 - val_loss: 0.8868 - val_top2_accuracy: 0.8704 - learning_rate: 1.2500e-04
# Epoch 43/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6866 - loss: 0.8406 - top2_accuracy: 0.8956
# Epoch 43: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6817 - loss: 0.8449 - top2_accuracy: 0.8954 - val_accuracy: 0.6710 - val_loss: 0.8851 - val_top2_accuracy: 0.8732 - learning_rate: 1.2500e-04
# Epoch 44/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6858 - loss: 0.8276 - top2_accuracy: 0.8977
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 44: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6823 - loss: 0.8355 - top2_accuracy: 0.8941 - val_accuracy: 0.6710 - val_loss: 0.8845 - val_top2_accuracy: 0.8686 - learning_rate: 1.2500e-04
# Epoch 45/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6828 - loss: 0.8398 - top2_accuracy: 0.8912
# Epoch 45: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6875 - loss: 0.8360 - top2_accuracy: 0.8953 - val_accuracy: 0.6636 - val_loss: 0.8779 - val_top2_accuracy: 0.8686 - learning_rate: 6.2500e-05
# Epoch 46/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6863 - loss: 0.8248 - top2_accuracy: 0.8928
# Epoch 46: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6879 - loss: 0.8306 - top2_accuracy: 0.8953 - val_accuracy: 0.6608 - val_loss: 0.8815 - val_top2_accuracy: 0.8658 - learning_rate: 6.2500e-05
# Epoch 47/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6886 - loss: 0.8204 - top2_accuracy: 0.8984
# Epoch 47: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6855 - loss: 0.8259 - top2_accuracy: 0.8945 - val_accuracy: 0.6654 - val_loss: 0.8774 - val_top2_accuracy: 0.8676 - learning_rate: 6.2500e-05
# Epoch 48/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6841 - loss: 0.8389 - top2_accuracy: 0.8948
# Epoch 48: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6899 - loss: 0.8304 - top2_accuracy: 0.8979 - val_accuracy: 0.6627 - val_loss: 0.8818 - val_top2_accuracy: 0.8631 - learning_rate: 6.2500e-05
# Epoch 49/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7017 - loss: 0.8081 - top2_accuracy: 0.8996
# Epoch 49: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6954 - loss: 0.8204 - top2_accuracy: 0.8979 - val_accuracy: 0.6636 - val_loss: 0.8814 - val_top2_accuracy: 0.8658 - learning_rate: 6.2500e-05
# Epoch 50/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6923 - loss: 0.8205 - top2_accuracy: 0.8995
# Epoch 50: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6917 - loss: 0.8223 - top2_accuracy: 0.8985 - val_accuracy: 0.6654 - val_loss: 0.8785 - val_top2_accuracy: 0.8695 - learning_rate: 6.2500e-05
# Epoch 51/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6962 - loss: 0.8122 - top2_accuracy: 0.8955
# Epoch 51: val_accuracy did not improve from 0.67188
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.6927 - loss: 0.8211 - top2_accuracy: 0.8956 - val_accuracy: 0.6636 - val_loss: 0.8772 - val_top2_accuracy: 0.8741 - learning_rate: 6.2500e-05
# Epoch 52/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6938 - loss: 0.8219 - top2_accuracy: 0.8997
# Epoch 52: val_accuracy improved from 0.67188 to 0.67279, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 52: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.6898 - loss: 0.8226 - top2_accuracy: 0.8967 - val_accuracy: 0.6728 - val_loss: 0.8802 - val_top2_accuracy: 0.8649 - learning_rate: 6.2500e-05
# Epoch 53/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6975 - loss: 0.8151 - top2_accuracy: 0.8962
# Epoch 53: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6915 - loss: 0.8204 - top2_accuracy: 0.8950 - val_accuracy: 0.6700 - val_loss: 0.8771 - val_top2_accuracy: 0.8695 - learning_rate: 6.2500e-05
# Epoch 54/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6935 - loss: 0.8145 - top2_accuracy: 0.9032
# Epoch 54: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6872 - loss: 0.8253 - top2_accuracy: 0.8957 - val_accuracy: 0.6728 - val_loss: 0.8736 - val_top2_accuracy: 0.8603 - learning_rate: 6.2500e-05
# Epoch 55/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6912 - loss: 0.8255 - top2_accuracy: 0.8920
# Epoch 55: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6932 - loss: 0.8228 - top2_accuracy: 0.8950 - val_accuracy: 0.6664 - val_loss: 0.8751 - val_top2_accuracy: 0.8704 - learning_rate: 6.2500e-05
# Epoch 56/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6929 - loss: 0.8196 - top2_accuracy: 0.9004
# Epoch 56: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6963 - loss: 0.8180 - top2_accuracy: 0.9005 - val_accuracy: 0.6691 - val_loss: 0.8777 - val_top2_accuracy: 0.8676 - learning_rate: 6.2500e-05
# Epoch 57/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6969 - loss: 0.8095 - top2_accuracy: 0.9004
# Epoch 57: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6951 - loss: 0.8117 - top2_accuracy: 0.9000 - val_accuracy: 0.6682 - val_loss: 0.8791 - val_top2_accuracy: 0.8676 - learning_rate: 6.2500e-05
# Epoch 58/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6897 - loss: 0.8168 - top2_accuracy: 0.8997
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 58: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6926 - loss: 0.8156 - top2_accuracy: 0.8992 - val_accuracy: 0.6664 - val_loss: 0.8777 - val_top2_accuracy: 0.8732 - learning_rate: 6.2500e-05
# Epoch 59/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6977 - loss: 0.8078 - top2_accuracy: 0.9001
# Epoch 59: val_accuracy did not improve from 0.67279
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.6982 - loss: 0.8097 - top2_accuracy: 0.9010 - val_accuracy: 0.6710 - val_loss: 0.8742 - val_top2_accuracy: 0.8741 - learning_rate: 3.1250e-05
# Epoch 60/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6959 - loss: 0.8117 - top2_accuracy: 0.9068
# Epoch 60: val_accuracy improved from 0.67279 to 0.67647, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
#
# Epoch 60: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.7021 - loss: 0.8061 - top2_accuracy: 0.9045 - val_accuracy: 0.6765 - val_loss: 0.8742 - val_top2_accuracy: 0.8741 - learning_rate: 3.1250e-05
# Epoch 61/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6995 - loss: 0.8094 - top2_accuracy: 0.8993
# Epoch 61: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6984 - loss: 0.8129 - top2_accuracy: 0.9002 - val_accuracy: 0.6710 - val_loss: 0.8756 - val_top2_accuracy: 0.8713 - learning_rate: 3.1250e-05
# Epoch 62/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6970 - loss: 0.8048 - top2_accuracy: 0.9023
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 62: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6991 - loss: 0.8025 - top2_accuracy: 0.9055 - val_accuracy: 0.6682 - val_loss: 0.8764 - val_top2_accuracy: 0.8713 - learning_rate: 3.1250e-05
# Epoch 63/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7053 - loss: 0.7944 - top2_accuracy: 0.9015
# Epoch 63: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.7060 - loss: 0.8012 - top2_accuracy: 0.8993 - val_accuracy: 0.6682 - val_loss: 0.8749 - val_top2_accuracy: 0.8704 - learning_rate: 1.5625e-05
# Epoch 64/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7021 - loss: 0.8057 - top2_accuracy: 0.9025
# Epoch 64: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.7023 - loss: 0.8062 - top2_accuracy: 0.9027 - val_accuracy: 0.6627 - val_loss: 0.8765 - val_top2_accuracy: 0.8686 - learning_rate: 1.5625e-05
# Epoch 65/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7007 - loss: 0.7948 - top2_accuracy: 0.9055
# Epoch 65: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.6981 - loss: 0.8060 - top2_accuracy: 0.9022 - val_accuracy: 0.6673 - val_loss: 0.8750 - val_top2_accuracy: 0.8695 - learning_rate: 1.5625e-05
# Epoch 66/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7047 - loss: 0.7965 - top2_accuracy: 0.9093
# Epoch 66: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 66: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7013 - loss: 0.8044 - top2_accuracy: 0.9054 - val_accuracy: 0.6691 - val_loss: 0.8749 - val_top2_accuracy: 0.8704 - learning_rate: 1.5625e-05
# Epoch 67/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6985 - loss: 0.8043 - top2_accuracy: 0.9055
# Epoch 67: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7015 - loss: 0.8049 - top2_accuracy: 0.9033 - val_accuracy: 0.6664 - val_loss: 0.8754 - val_top2_accuracy: 0.8676 - learning_rate: 7.8125e-06
# Epoch 68/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7014 - loss: 0.8005 - top2_accuracy: 0.9044
# Epoch 68: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7030 - loss: 0.8027 - top2_accuracy: 0.9031 - val_accuracy: 0.6654 - val_loss: 0.8752 - val_top2_accuracy: 0.8686 - learning_rate: 7.8125e-06
# Epoch 69/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7001 - loss: 0.7952 - top2_accuracy: 0.9068
# Epoch 69: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6959 - loss: 0.8063 - top2_accuracy: 0.9044 - val_accuracy: 0.6700 - val_loss: 0.8750 - val_top2_accuracy: 0.8704 - learning_rate: 7.8125e-06
# Epoch 70/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7097 - loss: 0.7876 - top2_accuracy: 0.9065
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 70: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7067 - loss: 0.7986 - top2_accuracy: 0.9035 - val_accuracy: 0.6654 - val_loss: 0.8773 - val_top2_accuracy: 0.8649 - learning_rate: 7.8125e-06
# Epoch 71/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7087 - loss: 0.7932 - top2_accuracy: 0.9043
# Epoch 71: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7047 - loss: 0.7986 - top2_accuracy: 0.9051 - val_accuracy: 0.6673 - val_loss: 0.8759 - val_top2_accuracy: 0.8676 - learning_rate: 3.9063e-06
# Epoch 72/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7013 - loss: 0.7988 - top2_accuracy: 0.9025
# Epoch 72: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7000 - loss: 0.8045 - top2_accuracy: 0.9035 - val_accuracy: 0.6664 - val_loss: 0.8756 - val_top2_accuracy: 0.8686 - learning_rate: 3.9063e-06
# Epoch 73/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7052 - loss: 0.7986 - top2_accuracy: 0.9061
# Epoch 73: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7038 - loss: 0.8012 - top2_accuracy: 0.9047 - val_accuracy: 0.6682 - val_loss: 0.8755 - val_top2_accuracy: 0.8667 - learning_rate: 3.9063e-06
# Epoch 74/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7082 - loss: 0.7955 - top2_accuracy: 0.9054
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 74: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.7038 - loss: 0.7986 - top2_accuracy: 0.9069 - val_accuracy: 0.6682 - val_loss: 0.8751 - val_top2_accuracy: 0.8658 - learning_rate: 3.9063e-06
# Epoch 75/90
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6978 - loss: 0.7996 - top2_accuracy: 0.9036
# Epoch 75: val_accuracy did not improve from 0.67647
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.7012 - loss: 0.7980 - top2_accuracy: 0.9044 - val_accuracy: 0.6682 - val_loss: 0.8751 - val_top2_accuracy: 0.8667 - learning_rate: 1.9531e-06
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 60.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 75
#    Best val_accuracy : 67.65% (epoch 60)
#
# ⚠️  Accuracy of 67.6% is below 70%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
# 2026-03-25 22:29:24.322978: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=index        | Prediction=index        | Confidence= 54.0% | 2nd Prediction=middle       | 2nd Confidence= 40.1%
# ✅ Image 2: Label=thumb        | Prediction=thumb        | Confidence= 97.9% | 2nd Prediction=middle       | 2nd Confidence=  1.0%
# ❌ Image 3: Label=ring         | Prediction=middle       | Confidence= 55.5% | 2nd Prediction=ring         | 2nd Confidence= 35.9%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence= 74.6% | 2nd Prediction=index        | 2nd Confidence= 12.9%
# ❌ Image 5: Label=ring         | Prediction=index        | Confidence= 36.8% | 2nd Prediction=ring         | 2nd Confidence= 32.7%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 7: Label=index        | Prediction=index        | Confidence= 69.8% | 2nd Prediction=thumb        | 2nd Confidence= 27.9%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 61.6% | 2nd Prediction=middle       | 2nd Confidence= 26.2%
# ❌ Image 9: Label=ring         | Prediction=middle       | Confidence= 59.5% | 2nd Prediction=index        | 2nd Confidence= 20.1%
# ✅ Image 10: Label=ring         | Prediction=ring         | Confidence= 60.2% | 2nd Prediction=middle       | 2nd Confidence= 24.0%
# ❌ Image 11: Label=index        | Prediction=thumb        | Confidence= 82.3% | 2nd Prediction=index        | 2nd Confidence= 11.5%
# ❌ Image 12: Label=index        | Prediction=middle       | Confidence= 41.9% | 2nd Prediction=index        | 2nd Confidence= 40.0%
# ❌ Image 13: Label=ring         | Prediction=middle       | Confidence= 48.3% | 2nd Prediction=index        | 2nd Confidence= 21.5%
# ✅ Image 14: Label=thumb        | Prediction=thumb        | Confidence= 99.5% | 2nd Prediction=index        | 2nd Confidence=  0.3%
# ✅ Image 15: Label=thumb        | Prediction=thumb        | Confidence= 98.5% | 2nd Prediction=index        | 2nd Confidence=  1.0%
# ✅ Image 16: Label=thumb        | Prediction=thumb        | Confidence= 74.6% | 2nd Prediction=index        | 2nd Confidence= 13.1%
# ✅ Image 17: Label=ring         | Prediction=ring         | Confidence= 77.3% | 2nd Prediction=middle       | 2nd Confidence= 17.8%
# ✅ Image 18: Label=ring         | Prediction=ring         | Confidence= 76.9% | 2nd Prediction=middle       | 2nd Confidence= 20.5%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 99.2% | 2nd Prediction=index        | 2nd Confidence=  0.6%
# ❌ Image 20: Label=thumb        | Prediction=index        | Confidence= 75.4% | 2nd Prediction=thumb        | 2nd Confidence= 11.6%
#
# ======================================================================================================================================================
# 2026-03-25 22:29:26.177520: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of frozen model using test dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using test dataset...
#
# Results :
#   - Loss                : 0.8802
#   - Accuracy            : 67.19%
#   - Top-2 Accuracy      : 89.26%
