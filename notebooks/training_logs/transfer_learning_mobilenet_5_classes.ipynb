# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring', 'little']

num_classes = len(class_names)
print(f"\n👁️ {num_classes} fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ 5 fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Fingerprint model name : MobileNetV2_FingerPrint_Model_5_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def traverse_dataset_dir(dataset_dir, class_names):

    # List to store file information
    imgdata = []

    # Traverse the input directory to get all image files
    for dirname, _, filenames in os.walk(dataset_dir):

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        for filename in filenames:
         
            if filename == ".DS_Store":  # Skip macOS system files
                continue

            if filename.find("Zcut") != -1:
                feature = 'zcut'
            elif filename.find('CR') != -1:
                feature = 'cr'
            elif filename.find('Obl') != -1:
                feature = 'obl'
            else:
                feature = 'unaltered'

            if filename.find("thumb") != -1:
                finger = "thumb"
            elif filename.find("index") != -1:
                finger = "index"
            elif filename.find("middle") != -1:
                finger = "middle"
            elif filename.find("ring") != -1:
                finger = "ring"
            elif filename.find("little") != -1:
                finger = "little"
            else:
                finger = None

            # image is to be considered given the current class names 
            file_path = os.path.join(dirname, filename)

            # extract the image features
            img = Image.open(file_path)
    
            try:
                img.verify()  # Verify that the file is a valid image
            except:
                print(f"Invalid image file: {file_path}")
                continue

            imgdata.append([file_path, img.format, img.size, img.mode, feature, finger])

    # Create a DataFrame
    imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Feature", "Finger"])

    # Add an index column
    imgdf.index.name = "ID"

    return imgdf

# %%
# train dataset
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
imgdf = traverse_dataset_dir(dataset_train_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15954 entries, 0 to 15953
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    15954 non-null  str
#  1   ImageFormat  15954 non-null  str
#  2   ImageSize    15954 non-null  object
#  3   ImageMode    15954 non-null  str
#  4   Feature      15954 non-null  str
#  5   Finger       15954 non-null  str
# dtypes: object(1), str(5)
# memory usage: 748.0+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    4000
# obl          3990
# zcut         3986
# cr           3978
# Name: count, dtype: int64
# Finger
# middle    3193
# index     3192
# ring      3191
# thumb     3190
# little    3188
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 19.98%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 25.07%
# Percentage of Zcut: 24.98%
# Percentage of CR: 24.93%
# Percentage of Obl: 25.01%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/train/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/train/

# %%
# validation/test dataset
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
imgdf = traverse_dataset_dir(dataset_val_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    2000 non-null   str
#  1   ImageFormat  2000 non-null   str
#  2   ImageSize    2000 non-null   object
#  3   ImageMode    2000 non-null   str
#  4   Feature      2000 non-null   str
#  5   Finger       2000 non-null   str
# dtypes: object(1), str(5)
# memory usage: 93.9+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    2000
# Name: count, dtype: int64
# Finger
# little    400
# middle    400
# thumb     400
# index     400
# ring      400
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 100.00%
# Percentage of Zcut: 0.00%
# Percentage of CR: 0.00%
# Percentage of Obl: 0.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/validation/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/validation/

# %% [markdown]
# ## Split dataset for training / validation / test

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 15954 files belonging to 5 classes.
# Found 2000 files belonging to 5 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 250
#   - Validation batches  : 22
#   - Test batches        : 10
#   - Batch size          : 64
#   - Training samples    : ~16000
#   - Validation samples  : ~1408
#   - Test samples        : ~640
# 2026-03-25 21:48:09.338089: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-25 21:48:09.338117: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-25 21:48:09.338126: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-25 21:48:09.338144: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-25 21:48:09.338158: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("  - Test dataset       : Normalisation")

print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#   - Test dataset       : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

MobileNet_basename = MobileNet_version + "_FingerPrint_BaseModel"
if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x17b630680>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x17b630680>) → Dropout(0.3) → Dense(5,softmax)
#
#   - Trainable parameters     : 344,709
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,693
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,693 (9.93 MB)
#  Trainable params: 344,709 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 20
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 20 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-25 21:48:11.382213: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3758 - loss: 4.2981 - top2_accuracy: 0.6008
# Epoch 1: val_accuracy improved from None to 0.56912, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 74ms/step - accuracy: 0.4423 - loss: 3.0162 - top2_accuracy: 0.6697 - val_accuracy: 0.5691 - val_loss: 1.6775 - val_top2_accuracy: 0.7779 - learning_rate: 0.0010
# Epoch 2/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5139 - loss: 1.6443 - top2_accuracy: 0.7474
# Epoch 2: val_accuracy improved from 0.56912 to 0.57500, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 62ms/step - accuracy: 0.5179 - loss: 1.5430 - top2_accuracy: 0.7512 - val_accuracy: 0.5750 - val_loss: 1.2784 - val_top2_accuracy: 0.8066 - learning_rate: 0.0010
# Epoch 3/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5372 - loss: 1.3612 - top2_accuracy: 0.7670
# Epoch 3: val_accuracy improved from 0.57500 to 0.58897, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - accuracy: 0.5393 - loss: 1.3317 - top2_accuracy: 0.7653 - val_accuracy: 0.5890 - val_loss: 1.1823 - val_top2_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 4/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5431 - loss: 1.2763 - top2_accuracy: 0.7711
# Epoch 4: val_accuracy did not improve from 0.58897
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5464 - loss: 1.2599 - top2_accuracy: 0.7714 - val_accuracy: 0.5860 - val_loss: 1.1735 - val_top2_accuracy: 0.8015 - learning_rate: 0.0010
# Epoch 5/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5517 - loss: 1.2460 - top2_accuracy: 0.7740
# Epoch 5: val_accuracy improved from 0.58897 to 0.60221, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 62ms/step - accuracy: 0.5484 - loss: 1.2417 - top2_accuracy: 0.7742 - val_accuracy: 0.6022 - val_loss: 1.1251 - val_top2_accuracy: 0.8096 - learning_rate: 0.0010
# Epoch 6/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5509 - loss: 1.2252 - top2_accuracy: 0.7762
# Epoch 6: val_accuracy improved from 0.60221 to 0.60441, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.5530 - loss: 1.2209 - top2_accuracy: 0.7763 - val_accuracy: 0.6044 - val_loss: 1.1256 - val_top2_accuracy: 0.8147 - learning_rate: 0.0010
# Epoch 7/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5566 - loss: 1.2207 - top2_accuracy: 0.7774
# Epoch 7: val_accuracy did not improve from 0.60441
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 62ms/step - accuracy: 0.5553 - loss: 1.2180 - top2_accuracy: 0.7770 - val_accuracy: 0.5728 - val_loss: 1.1432 - val_top2_accuracy: 0.8044 - learning_rate: 0.0010
# Epoch 8/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5487 - loss: 1.2259 - top2_accuracy: 0.7734
# Epoch 8: val_accuracy did not improve from 0.60441
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5500 - loss: 1.2174 - top2_accuracy: 0.7760 - val_accuracy: 0.5978 - val_loss: 1.1190 - val_top2_accuracy: 0.8140 - learning_rate: 0.0010
# Epoch 9/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5641 - loss: 1.2118 - top2_accuracy: 0.7774
# Epoch 9: val_accuracy improved from 0.60441 to 0.60515, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.5614 - loss: 1.2093 - top2_accuracy: 0.7776 - val_accuracy: 0.6051 - val_loss: 1.1234 - val_top2_accuracy: 0.8118 - learning_rate: 0.0010
# Epoch 10/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5564 - loss: 1.2143 - top2_accuracy: 0.7741
# Epoch 10: val_accuracy did not improve from 0.60515
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5593 - loss: 1.2051 - top2_accuracy: 0.7752 - val_accuracy: 0.5985 - val_loss: 1.1229 - val_top2_accuracy: 0.8206 - learning_rate: 0.0010
# Epoch 11/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5531 - loss: 1.2058 - top2_accuracy: 0.7812
# Epoch 11: val_accuracy did not improve from 0.60515
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5555 - loss: 1.2019 - top2_accuracy: 0.7829 - val_accuracy: 0.6037 - val_loss: 1.1113 - val_top2_accuracy: 0.8147 - learning_rate: 0.0010
# Epoch 12/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5626 - loss: 1.2054 - top2_accuracy: 0.7845
# Epoch 12: val_accuracy improved from 0.60515 to 0.61324, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - accuracy: 0.5609 - loss: 1.2008 - top2_accuracy: 0.7826 - val_accuracy: 0.6132 - val_loss: 1.0941 - val_top2_accuracy: 0.8235 - learning_rate: 0.0010
# Epoch 13/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5597 - loss: 1.1962 - top2_accuracy: 0.7779
# Epoch 13: val_accuracy did not improve from 0.61324
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.5597 - loss: 1.1990 - top2_accuracy: 0.7766 - val_accuracy: 0.5993 - val_loss: 1.1186 - val_top2_accuracy: 0.8074 - learning_rate: 0.0010
# Epoch 14/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5536 - loss: 1.1964 - top2_accuracy: 0.7836
# Epoch 14: val_accuracy did not improve from 0.61324
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.5598 - loss: 1.1932 - top2_accuracy: 0.7812 - val_accuracy: 0.5963 - val_loss: 1.1103 - val_top2_accuracy: 0.8118 - learning_rate: 0.0010
# Epoch 15/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5621 - loss: 1.1897 - top2_accuracy: 0.7850
# Epoch 15: val_accuracy did not improve from 0.61324
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.5625 - loss: 1.1909 - top2_accuracy: 0.7841 - val_accuracy: 0.5912 - val_loss: 1.1261 - val_top2_accuracy: 0.8088 - learning_rate: 0.0010
# Epoch 16/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5661 - loss: 1.1927 - top2_accuracy: 0.7864
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_accuracy did not improve from 0.61324
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.5666 - loss: 1.1895 - top2_accuracy: 0.7853 - val_accuracy: 0.6015 - val_loss: 1.1159 - val_top2_accuracy: 0.8140 - learning_rate: 0.0010
# Epoch 17/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5714 - loss: 1.1638 - top2_accuracy: 0.7863
# Epoch 17: val_accuracy improved from 0.61324 to 0.61765, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 17: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.5789 - loss: 1.1513 - top2_accuracy: 0.7927 - val_accuracy: 0.6176 - val_loss: 1.0666 - val_top2_accuracy: 0.8235 - learning_rate: 5.0000e-04
# Epoch 18/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5820 - loss: 1.1371 - top2_accuracy: 0.7990
# Epoch 18: val_accuracy did not improve from 0.61765
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.5848 - loss: 1.1319 - top2_accuracy: 0.8009 - val_accuracy: 0.6154 - val_loss: 1.0570 - val_top2_accuracy: 0.8287 - learning_rate: 5.0000e-04
# Epoch 19/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5818 - loss: 1.1216 - top2_accuracy: 0.8063
# Epoch 19: val_accuracy improved from 0.61765 to 0.61838, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.5780 - loss: 1.1266 - top2_accuracy: 0.8031 - val_accuracy: 0.6184 - val_loss: 1.0558 - val_top2_accuracy: 0.8301 - learning_rate: 5.0000e-04
# Epoch 20/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5870 - loss: 1.1166 - top2_accuracy: 0.8048
# Epoch 20: val_accuracy did not improve from 0.61838
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.5878 - loss: 1.1173 - top2_accuracy: 0.8044 - val_accuracy: 0.6110 - val_loss: 1.0611 - val_top2_accuracy: 0.8265 - learning_rate: 5.0000e-04
# Epoch 21/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5881 - loss: 1.1253 - top2_accuracy: 0.8003
# Epoch 21: val_accuracy did not improve from 0.61838
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.5883 - loss: 1.1181 - top2_accuracy: 0.8061 - val_accuracy: 0.6118 - val_loss: 1.0492 - val_top2_accuracy: 0.8368 - learning_rate: 5.0000e-04
# Epoch 22/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5823 - loss: 1.1259 - top2_accuracy: 0.7988
# Epoch 22: val_accuracy improved from 0.61838 to 0.62059, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.5865 - loss: 1.1190 - top2_accuracy: 0.8014 - val_accuracy: 0.6206 - val_loss: 1.0490 - val_top2_accuracy: 0.8353 - learning_rate: 5.0000e-04
# Epoch 23/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5847 - loss: 1.1210 - top2_accuracy: 0.8026
# Epoch 23: val_accuracy did not improve from 0.62059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.5898 - loss: 1.1135 - top2_accuracy: 0.8057 - val_accuracy: 0.6184 - val_loss: 1.0490 - val_top2_accuracy: 0.8353 - learning_rate: 5.0000e-04
# Epoch 24/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5891 - loss: 1.1119 - top2_accuracy: 0.8090
# Epoch 24: val_accuracy did not improve from 0.62059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.5928 - loss: 1.1101 - top2_accuracy: 0.8102 - val_accuracy: 0.6206 - val_loss: 1.0482 - val_top2_accuracy: 0.8301 - learning_rate: 5.0000e-04
# Epoch 25/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5982 - loss: 1.1104 - top2_accuracy: 0.8053
# Epoch 25: val_accuracy did not improve from 0.62059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.5915 - loss: 1.1140 - top2_accuracy: 0.8029 - val_accuracy: 0.6184 - val_loss: 1.0549 - val_top2_accuracy: 0.8338 - learning_rate: 5.0000e-04
# Epoch 26/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5979 - loss: 1.1112 - top2_accuracy: 0.8056
# Epoch 26: val_accuracy did not improve from 0.62059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.5934 - loss: 1.1129 - top2_accuracy: 0.8068 - val_accuracy: 0.6074 - val_loss: 1.0677 - val_top2_accuracy: 0.8331 - learning_rate: 5.0000e-04
# Epoch 27/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5993 - loss: 1.1005 - top2_accuracy: 0.8082
# Epoch 27: val_accuracy improved from 0.62059 to 0.62574, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.5964 - loss: 1.1086 - top2_accuracy: 0.8084 - val_accuracy: 0.6257 - val_loss: 1.0482 - val_top2_accuracy: 0.8382 - learning_rate: 5.0000e-04
# Epoch 28/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5952 - loss: 1.1040 - top2_accuracy: 0.8120
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 28: val_accuracy did not improve from 0.62574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.5928 - loss: 1.1101 - top2_accuracy: 0.8095 - val_accuracy: 0.6221 - val_loss: 1.0545 - val_top2_accuracy: 0.8346 - learning_rate: 5.0000e-04
# Epoch 29/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6051 - loss: 1.0832 - top2_accuracy: 0.8169
# Epoch 29: val_accuracy did not improve from 0.62574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.6086 - loss: 1.0771 - top2_accuracy: 0.8204 - val_accuracy: 0.6228 - val_loss: 1.0417 - val_top2_accuracy: 0.8353 - learning_rate: 2.5000e-04
# Epoch 30/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6048 - loss: 1.0724 - top2_accuracy: 0.8213
# Epoch 30: val_accuracy did not improve from 0.62574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.6058 - loss: 1.0676 - top2_accuracy: 0.8234 - val_accuracy: 0.6169 - val_loss: 1.0421 - val_top2_accuracy: 0.8397 - learning_rate: 2.5000e-04
# Epoch 31/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6120 - loss: 1.0587 - top2_accuracy: 0.8261
# Epoch 31: val_accuracy did not improve from 0.62574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 65ms/step - accuracy: 0.6165 - loss: 1.0567 - top2_accuracy: 0.8280 - val_accuracy: 0.6257 - val_loss: 1.0340 - val_top2_accuracy: 0.8360 - learning_rate: 2.5000e-04
# Epoch 32/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6118 - loss: 1.0570 - top2_accuracy: 0.8233
# Epoch 32: val_accuracy improved from 0.62574 to 0.63235, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 32: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.6104 - loss: 1.0561 - top2_accuracy: 0.8264 - val_accuracy: 0.6324 - val_loss: 1.0232 - val_top2_accuracy: 0.8426 - learning_rate: 2.5000e-04
# Epoch 33/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6129 - loss: 1.0541 - top2_accuracy: 0.8222
# Epoch 33: val_accuracy improved from 0.63235 to 0.63309, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 33: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.6136 - loss: 1.0548 - top2_accuracy: 0.8233 - val_accuracy: 0.6331 - val_loss: 1.0242 - val_top2_accuracy: 0.8346 - learning_rate: 2.5000e-04
# Epoch 34/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6173 - loss: 1.0483 - top2_accuracy: 0.8275
# Epoch 34: val_accuracy improved from 0.63309 to 0.63456, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 34: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.6198 - loss: 1.0466 - top2_accuracy: 0.8282 - val_accuracy: 0.6346 - val_loss: 1.0216 - val_top2_accuracy: 0.8412 - learning_rate: 2.5000e-04
# Epoch 35/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6151 - loss: 1.0512 - top2_accuracy: 0.8207
# Epoch 35: val_accuracy improved from 0.63456 to 0.63824, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 35: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6158 - loss: 1.0469 - top2_accuracy: 0.8242 - val_accuracy: 0.6382 - val_loss: 1.0160 - val_top2_accuracy: 0.8426 - learning_rate: 2.5000e-04
# Epoch 36/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6189 - loss: 1.0457 - top2_accuracy: 0.8305
# Epoch 36: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.6170 - loss: 1.0461 - top2_accuracy: 0.8298 - val_accuracy: 0.6346 - val_loss: 1.0193 - val_top2_accuracy: 0.8485 - learning_rate: 2.5000e-04
# Epoch 37/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6240 - loss: 1.0382 - top2_accuracy: 0.8323
# Epoch 37: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.6215 - loss: 1.0391 - top2_accuracy: 0.8308 - val_accuracy: 0.6265 - val_loss: 1.0179 - val_top2_accuracy: 0.8456 - learning_rate: 2.5000e-04
# Epoch 38/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6180 - loss: 1.0432 - top2_accuracy: 0.8279
# Epoch 38: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.6185 - loss: 1.0428 - top2_accuracy: 0.8291 - val_accuracy: 0.6287 - val_loss: 1.0263 - val_top2_accuracy: 0.8382 - learning_rate: 2.5000e-04
# Epoch 39/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6196 - loss: 1.0318 - top2_accuracy: 0.8369
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 39: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.6236 - loss: 1.0347 - top2_accuracy: 0.8357 - val_accuracy: 0.6243 - val_loss: 1.0309 - val_top2_accuracy: 0.8390 - learning_rate: 2.5000e-04
# Epoch 40/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6218 - loss: 1.0327 - top2_accuracy: 0.8358
# Epoch 40: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.6238 - loss: 1.0255 - top2_accuracy: 0.8382 - val_accuracy: 0.6338 - val_loss: 1.0158 - val_top2_accuracy: 0.8493 - learning_rate: 1.2500e-04
# Epoch 41/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6356 - loss: 1.0094 - top2_accuracy: 0.8401
# Epoch 41: val_accuracy did not improve from 0.63824
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6364 - loss: 1.0076 - top2_accuracy: 0.8441 - val_accuracy: 0.6368 - val_loss: 1.0118 - val_top2_accuracy: 0.8471 - learning_rate: 1.2500e-04
# Epoch 42/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6375 - loss: 1.0133 - top2_accuracy: 0.8399
# Epoch 42: val_accuracy improved from 0.63824 to 0.63897, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 42: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6356 - loss: 1.0142 - top2_accuracy: 0.8394 - val_accuracy: 0.6390 - val_loss: 1.0104 - val_top2_accuracy: 0.8485 - learning_rate: 1.2500e-04
# Epoch 43/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6291 - loss: 1.0168 - top2_accuracy: 0.8363
# Epoch 43: val_accuracy improved from 0.63897 to 0.64632, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 43: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6305 - loss: 1.0107 - top2_accuracy: 0.8400 - val_accuracy: 0.6463 - val_loss: 1.0017 - val_top2_accuracy: 0.8456 - learning_rate: 1.2500e-04
# Epoch 44/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6419 - loss: 1.0027 - top2_accuracy: 0.8421
# Epoch 44: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6410 - loss: 1.0039 - top2_accuracy: 0.8444 - val_accuracy: 0.6404 - val_loss: 1.0087 - val_top2_accuracy: 0.8441 - learning_rate: 1.2500e-04
# Epoch 45/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6296 - loss: 1.0072 - top2_accuracy: 0.8455
# Epoch 45: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6329 - loss: 1.0030 - top2_accuracy: 0.8440 - val_accuracy: 0.6360 - val_loss: 1.0140 - val_top2_accuracy: 0.8449 - learning_rate: 1.2500e-04
# Epoch 46/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6360 - loss: 1.0047 - top2_accuracy: 0.8448
# Epoch 46: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6358 - loss: 1.0024 - top2_accuracy: 0.8474 - val_accuracy: 0.6390 - val_loss: 1.0021 - val_top2_accuracy: 0.8566 - learning_rate: 1.2500e-04
# Epoch 47/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6359 - loss: 0.9974 - top2_accuracy: 0.8472
# Epoch 47: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6365 - loss: 0.9926 - top2_accuracy: 0.8472 - val_accuracy: 0.6434 - val_loss: 1.0012 - val_top2_accuracy: 0.8478 - learning_rate: 1.2500e-04
# Epoch 48/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6395 - loss: 1.0001 - top2_accuracy: 0.8436
# Epoch 48: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6393 - loss: 0.9978 - top2_accuracy: 0.8440 - val_accuracy: 0.6382 - val_loss: 1.0000 - val_top2_accuracy: 0.8515 - learning_rate: 1.2500e-04
# Epoch 49/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6449 - loss: 0.9903 - top2_accuracy: 0.8432
# Epoch 49: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6396 - loss: 0.9952 - top2_accuracy: 0.8441 - val_accuracy: 0.6331 - val_loss: 1.0065 - val_top2_accuracy: 0.8478 - learning_rate: 1.2500e-04
# Epoch 50/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6427 - loss: 1.0006 - top2_accuracy: 0.8437
# Epoch 50: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6445 - loss: 0.9939 - top2_accuracy: 0.8496 - val_accuracy: 0.6412 - val_loss: 1.0000 - val_top2_accuracy: 0.8529 - learning_rate: 1.2500e-04
# Epoch 51/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6363 - loss: 1.0041 - top2_accuracy: 0.8441
# Epoch 51: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6404 - loss: 0.9980 - top2_accuracy: 0.8453 - val_accuracy: 0.6353 - val_loss: 1.0012 - val_top2_accuracy: 0.8478 - learning_rate: 1.2500e-04
# Epoch 52/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6416 - loss: 0.9945 - top2_accuracy: 0.8484
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 52: val_accuracy did not improve from 0.64632
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.6410 - loss: 0.9984 - top2_accuracy: 0.8448 - val_accuracy: 0.6375 - val_loss: 1.0088 - val_top2_accuracy: 0.8522 - learning_rate: 1.2500e-04
# Epoch 53/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6445 - loss: 0.9854 - top2_accuracy: 0.8479
# Epoch 53: val_accuracy improved from 0.64632 to 0.65221, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
#
# Epoch 53: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes_Transfer_Learning.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6486 - loss: 0.9797 - top2_accuracy: 0.8519 - val_accuracy: 0.6522 - val_loss: 0.9959 - val_top2_accuracy: 0.8449 - learning_rate: 6.2500e-05
# Epoch 54/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6514 - loss: 0.9822 - top2_accuracy: 0.8511
# Epoch 54: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6496 - loss: 0.9768 - top2_accuracy: 0.8530 - val_accuracy: 0.6449 - val_loss: 0.9950 - val_top2_accuracy: 0.8449 - learning_rate: 6.2500e-05
# Epoch 55/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6520 - loss: 0.9736 - top2_accuracy: 0.8480
# Epoch 55: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6496 - loss: 0.9765 - top2_accuracy: 0.8506 - val_accuracy: 0.6478 - val_loss: 0.9953 - val_top2_accuracy: 0.8463 - learning_rate: 6.2500e-05
# Epoch 56/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6477 - loss: 0.9774 - top2_accuracy: 0.8545
# Epoch 56: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6500 - loss: 0.9744 - top2_accuracy: 0.8545 - val_accuracy: 0.6434 - val_loss: 0.9989 - val_top2_accuracy: 0.8478 - learning_rate: 6.2500e-05
# Epoch 57/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6566 - loss: 0.9708 - top2_accuracy: 0.8538
# Epoch 57: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6502 - loss: 0.9735 - top2_accuracy: 0.8519 - val_accuracy: 0.6412 - val_loss: 1.0006 - val_top2_accuracy: 0.8463 - learning_rate: 6.2500e-05
# Epoch 58/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6455 - loss: 0.9726 - top2_accuracy: 0.8530
# Epoch 58: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6479 - loss: 0.9719 - top2_accuracy: 0.8531 - val_accuracy: 0.6456 - val_loss: 0.9939 - val_top2_accuracy: 0.8515 - learning_rate: 6.2500e-05
# Epoch 59/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6483 - loss: 0.9713 - top2_accuracy: 0.8550
# Epoch 59: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6499 - loss: 0.9716 - top2_accuracy: 0.8561 - val_accuracy: 0.6441 - val_loss: 0.9929 - val_top2_accuracy: 0.8485 - learning_rate: 6.2500e-05
# Epoch 60/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6490 - loss: 0.9643 - top2_accuracy: 0.8558
# Epoch 60: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6520 - loss: 0.9659 - top2_accuracy: 0.8553 - val_accuracy: 0.6382 - val_loss: 1.0025 - val_top2_accuracy: 0.8449 - learning_rate: 6.2500e-05
# Epoch 61/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6463 - loss: 0.9747 - top2_accuracy: 0.8521
# Epoch 61: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.6479 - loss: 0.9732 - top2_accuracy: 0.8529 - val_accuracy: 0.6500 - val_loss: 0.9987 - val_top2_accuracy: 0.8515 - learning_rate: 6.2500e-05
# Epoch 62/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6525 - loss: 0.9755 - top2_accuracy: 0.8466
# Epoch 62: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6523 - loss: 0.9741 - top2_accuracy: 0.8499 - val_accuracy: 0.6412 - val_loss: 0.9957 - val_top2_accuracy: 0.8485 - learning_rate: 6.2500e-05
# Epoch 63/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6553 - loss: 0.9697 - top2_accuracy: 0.8559
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 63: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6516 - loss: 0.9733 - top2_accuracy: 0.8538 - val_accuracy: 0.6426 - val_loss: 1.0030 - val_top2_accuracy: 0.8456 - learning_rate: 6.2500e-05
# Epoch 64/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6509 - loss: 0.9688 - top2_accuracy: 0.8530
# Epoch 64: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6541 - loss: 0.9656 - top2_accuracy: 0.8542 - val_accuracy: 0.6456 - val_loss: 0.9941 - val_top2_accuracy: 0.8426 - learning_rate: 3.1250e-05
# Epoch 65/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6592 - loss: 0.9556 - top2_accuracy: 0.8573
# Epoch 65: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6577 - loss: 0.9577 - top2_accuracy: 0.8573 - val_accuracy: 0.6500 - val_loss: 0.9921 - val_top2_accuracy: 0.8456 - learning_rate: 3.1250e-05
# Epoch 66/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6501 - loss: 0.9693 - top2_accuracy: 0.8533
# Epoch 66: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6546 - loss: 0.9622 - top2_accuracy: 0.8553 - val_accuracy: 0.6404 - val_loss: 0.9928 - val_top2_accuracy: 0.8500 - learning_rate: 3.1250e-05
# Epoch 67/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6536 - loss: 0.9612 - top2_accuracy: 0.8569
# Epoch 67: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6523 - loss: 0.9629 - top2_accuracy: 0.8549 - val_accuracy: 0.6463 - val_loss: 0.9972 - val_top2_accuracy: 0.8404 - learning_rate: 3.1250e-05
# Epoch 68/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6575 - loss: 0.9609 - top2_accuracy: 0.8570
# Epoch 68: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6562 - loss: 0.9570 - top2_accuracy: 0.8580 - val_accuracy: 0.6522 - val_loss: 0.9918 - val_top2_accuracy: 0.8493 - learning_rate: 3.1250e-05
# Epoch 69/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6556 - loss: 0.9575 - top2_accuracy: 0.8577
# Epoch 69: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6500 - loss: 0.9665 - top2_accuracy: 0.8547 - val_accuracy: 0.6515 - val_loss: 0.9945 - val_top2_accuracy: 0.8441 - learning_rate: 3.1250e-05
# Epoch 70/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6606 - loss: 0.9595 - top2_accuracy: 0.8565
# Epoch 70: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.6571 - loss: 0.9612 - top2_accuracy: 0.8561 - val_accuracy: 0.6471 - val_loss: 0.9912 - val_top2_accuracy: 0.8456 - learning_rate: 3.1250e-05
# Epoch 71/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6588 - loss: 0.9574 - top2_accuracy: 0.8516
# Epoch 71: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6561 - loss: 0.9571 - top2_accuracy: 0.8561 - val_accuracy: 0.6456 - val_loss: 0.9918 - val_top2_accuracy: 0.8471 - learning_rate: 3.1250e-05
# Epoch 72/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6585 - loss: 0.9582 - top2_accuracy: 0.8582
# Epoch 72: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6576 - loss: 0.9561 - top2_accuracy: 0.8565 - val_accuracy: 0.6441 - val_loss: 0.9902 - val_top2_accuracy: 0.8515 - learning_rate: 3.1250e-05
# Epoch 73/90
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6541 - loss: 0.9584 - top2_accuracy: 0.8565
# Epoch 73: val_accuracy did not improve from 0.65221
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.6514 - loss: 0.9575 - top2_accuracy: 0.8577 - val_accuracy: 0.6441 - val_loss: 0.9921 - val_top2_accuracy: 0.8493 - learning_rate: 3.1250e-05
# Epoch 73: early stopping
# Restoring model weights from the end of the best epoch: 53.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 73
#    Best val_accuracy : 65.22% (epoch 53)
#
# ⚠️  Accuracy of 65.2% is below 70%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
# 2026-03-25 22:08:18.029971: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 96.7% | 2nd Prediction=index        | 2nd Confidence=  2.7%
# ❌ Image 2: Label=middle       | Prediction=index        | Confidence= 36.1% | 2nd Prediction=middle       | 2nd Confidence= 29.6%
# ✅ Image 3: Label=little       | Prediction=little       | Confidence= 45.0% | 2nd Prediction=ring         | 2nd Confidence= 31.5%
# ✅ Image 4: Label=index        | Prediction=index        | Confidence= 73.5% | 2nd Prediction=middle       | 2nd Confidence= 14.0%
# ✅ Image 5: Label=middle       | Prediction=middle       | Confidence= 53.9% | 2nd Prediction=index        | 2nd Confidence= 28.4%
# ❌ Image 6: Label=ring         | Prediction=middle       | Confidence= 62.8% | 2nd Prediction=ring         | 2nd Confidence= 30.3%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 98.7% | 2nd Prediction=index        | 2nd Confidence=  0.6%
# ❌ Image 8: Label=ring         | Prediction=middle       | Confidence= 51.2% | 2nd Prediction=ring         | 2nd Confidence= 31.9%
# ❌ Image 9: Label=ring         | Prediction=little       | Confidence= 56.4% | 2nd Prediction=ring         | 2nd Confidence= 25.2%
# ✅ Image 10: Label=ring         | Prediction=ring         | Confidence= 80.0% | 2nd Prediction=little       | 2nd Confidence= 14.5%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence= 60.3% | 2nd Prediction=little       | 2nd Confidence= 22.9%
# ❌ Image 12: Label=middle       | Prediction=ring         | Confidence= 54.6% | 2nd Prediction=little       | 2nd Confidence= 20.5%
# ✅ Image 13: Label=little       | Prediction=little       | Confidence= 83.5% | 2nd Prediction=ring         | 2nd Confidence=  7.3%
# ✅ Image 14: Label=thumb        | Prediction=thumb        | Confidence= 48.5% | 2nd Prediction=middle       | 2nd Confidence= 24.5%
# ❌ Image 15: Label=middle       | Prediction=little       | Confidence= 57.1% | 2nd Prediction=ring         | 2nd Confidence= 15.5%
# ❌ Image 16: Label=little       | Prediction=ring         | Confidence= 56.9% | 2nd Prediction=little       | 2nd Confidence= 29.3%
# ❌ Image 17: Label=ring         | Prediction=little       | Confidence= 58.7% | 2nd Prediction=ring         | 2nd Confidence= 28.3%
# ✅ Image 18: Label=little       | Prediction=little       | Confidence= 44.1% | 2nd Prediction=index        | 2nd Confidence= 31.3%
# ✅ Image 19: Label=little       | Prediction=little       | Confidence= 87.6% | 2nd Prediction=ring         | 2nd Confidence=  8.2%
# ❌ Image 20: Label=ring         | Prediction=middle       | Confidence= 55.5% | 2nd Prediction=ring         | 2nd Confidence= 31.8%
#
# ======================================================================================================================================================
# 2026-03-25 22:08:19.952905: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of frozen model using test dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using test dataset...
#
# Results :
#   - Loss                : 1.0157
#   - Accuracy            : 62.50%
#   - Top-2 Accuracy      : 83.28%
