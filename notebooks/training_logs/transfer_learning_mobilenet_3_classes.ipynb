# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle']

num_classes = len(class_names)
print(f"\n👁️ {num_classes} fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ 3 fingerprints classes : ['thumb', 'index', 'middle']
# Fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def traverse_dataset_dir(dataset_dir, class_names):

    # List to store file information
    imgdata = []

    # Traverse the input directory to get all image files
    for dirname, _, filenames in os.walk(dataset_dir):

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        for filename in filenames:
         
            if filename == ".DS_Store":  # Skip macOS system files
                continue

            if filename.find("Zcut") != -1:
                feature = 'zcut'
            elif filename.find('CR') != -1:
                feature = 'cr'
            elif filename.find('Obl') != -1:
                feature = 'obl'
            else:
                feature = 'unaltered'

            if filename.find("thumb") != -1:
                finger = "thumb"
            elif filename.find("index") != -1:
                finger = "index"
            elif filename.find("middle") != -1:
                finger = "middle"
            elif filename.find("ring") != -1:
                finger = "ring"
            elif filename.find("little") != -1:
                finger = "little"
            else:
                finger = None

            # image is to be considered given the current class names 
            file_path = os.path.join(dirname, filename)

            # extract the image features
            img = Image.open(file_path)
    
            try:
                img.verify()  # Verify that the file is a valid image
            except:
                print(f"Invalid image file: {file_path}")
                continue

            imgdata.append([file_path, img.format, img.size, img.mode, feature, finger])

    # Create a DataFrame
    imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Feature", "Finger"])

    # Add an index column
    imgdf.index.name = "ID"

    return imgdf

# %%
# train dataset
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
imgdf = traverse_dataset_dir(dataset_train_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9575 entries, 0 to 9574
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    9575 non-null   str
#  1   ImageFormat  9575 non-null   str
#  2   ImageSize    9575 non-null   object
#  3   ImageMode    9575 non-null   str
#  4   Feature      9575 non-null   str
#  5   Finger       9575 non-null   str
# dtypes: object(1), str(5)
# memory usage: 449.0+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    2400
# obl          2395
# zcut         2394
# cr           2386
# Name: count, dtype: int64
# Finger
# middle    3193
# index     3192
# thumb     3190
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 33.32%
# Percentage of Index fingers: 33.34%
# Percentage of Middle fingers: 33.35%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 25.07%
# Percentage of Zcut: 25.00%
# Percentage of CR: 24.92%
# Percentage of Obl: 25.01%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/train/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/train/

# %%
# validation/test dataset
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
imgdf = traverse_dataset_dir(dataset_val_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    1200 non-null   str
#  1   ImageFormat  1200 non-null   str
#  2   ImageSize    1200 non-null   object
#  3   ImageMode    1200 non-null   str
#  4   Feature      1200 non-null   str
#  5   Finger       1200 non-null   str
# dtypes: object(1), str(5)
# memory usage: 56.4+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    1200
# Name: count, dtype: int64
# Finger
# middle    400
# thumb     400
# index     400
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 33.33%
# Percentage of Index fingers: 33.33%
# Percentage of Middle fingers: 33.33%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 100.00%
# Percentage of Zcut: 0.00%
# Percentage of CR: 0.00%
# Percentage of Obl: 0.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/validation/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/validation/

# %% [markdown]
# ## Split dataset for training / validation / test

# %%
print("🔧 Datasets creation for training and validation/test ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_test_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

# split validation dataset into 2 using 2/3 validation and 1/3 test ratio
val_batches = tf.data.experimental.cardinality(val_test_ds)
test_ds_cardinality = int(val_batches * 33 / 100)

test_ds = val_test_ds.take(test_ds_cardinality)
test_ds.class_names = class_names
val_ds = val_test_ds.skip(test_ds_cardinality)
val_ds.class_names = class_names

print(f"✅ Datasets created !\n")

print(f"📊 Training, validation and datasets information:")
print(f"  - Training Dataset Classes        : {train_ds.class_names}")
print(f"  - Validation Dataset Classes      : {val_ds.class_names}")
print(f"  - Test Dataset Classes            : {test_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} in training dataset !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_test_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_test_ds.class_names)} classes found instead of {num_classes} in validation dataset !")
    print(f"   Classes found : {val_test_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches  : {len(val_ds)}")
print(f"  - Test batches        : {len(test_ds)}")
print(f"  - Batch size          : {BATCH_SIZE}")
print(f"  - Training samples    : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples  : ~{len(val_ds) * BATCH_SIZE}")
print(f"  - Test samples        : ~{len(test_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation/test ...
#
# Found 9575 files belonging to 3 classes.
# Found 1200 files belonging to 3 classes.
# ✅ Datasets created !
#
# 📊 Training, validation and datasets information:
#   - Training Dataset Classes        : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes      : ['thumb', 'index', 'middle']
#   - Test Dataset Classes            : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 150
#   - Validation batches  : 13
#   - Test batches        : 6
#   - Batch size          : 64
#   - Training samples    : ~9600
#   - Validation samples  : ~832
#   - Test samples        : ~384
# 2026-03-25 22:32:29.960571: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-25 22:32:29.960601: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-25 22:32:29.960609: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-25 22:32:29.960628: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-25 22:32:29.960639: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)
test_ds_prepared = prepare_dataset(test_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("  - Test dataset       : Normalisation")

print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#   - Test dataset       : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

MobileNet_basename = MobileNet_version + "_FingerPrint_BaseModel"
if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        name=MobileNet_basename,
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x303e34720>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x303e34720>) → Dropout(0.3) → Dense(3,softmax)
#
#   - Trainable parameters     : 344,579
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,563
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,563 (9.93 MB)
#  Trainable params: 344,579 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 15
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 15 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-25 22:32:32.218096: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5544 - loss: 4.2696 - top2_accuracy: 0.8535
# Epoch 1: val_accuracy improved from None to 0.69608, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.6093 - loss: 3.0317 - top2_accuracy: 0.8911 - val_accuracy: 0.6961 - val_loss: 1.5940 - val_top2_accuracy: 0.9289 - learning_rate: 0.0010
# Epoch 2/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6860 - loss: 1.4600 - top2_accuracy: 0.9267
# Epoch 2: val_accuracy improved from 0.69608 to 0.71078, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.6852 - loss: 1.3217 - top2_accuracy: 0.9295 - val_accuracy: 0.7108 - val_loss: 1.0575 - val_top2_accuracy: 0.9412 - learning_rate: 0.0010
# Epoch 3/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6942 - loss: 1.0411 - top2_accuracy: 0.9281
# Epoch 3: val_accuracy did not improve from 0.71078
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.6921 - loss: 0.9943 - top2_accuracy: 0.9298 - val_accuracy: 0.7071 - val_loss: 0.9018 - val_top2_accuracy: 0.9314 - learning_rate: 0.0010
# Epoch 4/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7049 - loss: 0.8847 - top2_accuracy: 0.9312
# Epoch 4: val_accuracy improved from 0.71078 to 0.71201, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.6999 - loss: 0.8641 - top2_accuracy: 0.9337 - val_accuracy: 0.7120 - val_loss: 0.7845 - val_top2_accuracy: 0.9363 - learning_rate: 0.0010
# Epoch 5/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7059 - loss: 0.8136 - top2_accuracy: 0.9293
# Epoch 5: val_accuracy improved from 0.71201 to 0.72549, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7026 - loss: 0.8081 - top2_accuracy: 0.9346 - val_accuracy: 0.7255 - val_loss: 0.7404 - val_top2_accuracy: 0.9387 - learning_rate: 0.0010
# Epoch 6/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7105 - loss: 0.7833 - top2_accuracy: 0.9369
# Epoch 6: val_accuracy did not improve from 0.72549
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7069 - loss: 0.7831 - top2_accuracy: 0.9382 - val_accuracy: 0.7243 - val_loss: 0.7502 - val_top2_accuracy: 0.9400 - learning_rate: 0.0010
# Epoch 7/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7118 - loss: 0.7637 - top2_accuracy: 0.9372
# Epoch 7: val_accuracy improved from 0.72549 to 0.72794, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 7: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.7064 - loss: 0.7659 - top2_accuracy: 0.9406 - val_accuracy: 0.7279 - val_loss: 0.7278 - val_top2_accuracy: 0.9412 - learning_rate: 0.0010
# Epoch 8/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7226 - loss: 0.7435 - top2_accuracy: 0.9351
# Epoch 8: val_accuracy improved from 0.72794 to 0.72917, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7159 - loss: 0.7528 - top2_accuracy: 0.9384 - val_accuracy: 0.7292 - val_loss: 0.7132 - val_top2_accuracy: 0.9412 - learning_rate: 0.0010
# Epoch 9/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7158 - loss: 0.7440 - top2_accuracy: 0.9396
# Epoch 9: val_accuracy did not improve from 0.72917
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7114 - loss: 0.7460 - top2_accuracy: 0.9390 - val_accuracy: 0.7267 - val_loss: 0.6945 - val_top2_accuracy: 0.9412 - learning_rate: 0.0010
# Epoch 10/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7163 - loss: 0.7413 - top2_accuracy: 0.9415
# Epoch 10: val_accuracy did not improve from 0.72917
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7107 - loss: 0.7442 - top2_accuracy: 0.9421 - val_accuracy: 0.7047 - val_loss: 0.7251 - val_top2_accuracy: 0.9424 - learning_rate: 0.0010
# Epoch 11/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7144 - loss: 0.7299 - top2_accuracy: 0.9395
# Epoch 11: val_accuracy did not improve from 0.72917
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7104 - loss: 0.7339 - top2_accuracy: 0.9421 - val_accuracy: 0.7169 - val_loss: 0.7259 - val_top2_accuracy: 0.9363 - learning_rate: 0.0010
# Epoch 12/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7182 - loss: 0.7233 - top2_accuracy: 0.9412
# Epoch 12: val_accuracy improved from 0.72917 to 0.73529, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.7170 - loss: 0.7301 - top2_accuracy: 0.9418 - val_accuracy: 0.7353 - val_loss: 0.7045 - val_top2_accuracy: 0.9387 - learning_rate: 0.0010
# Epoch 13/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7208 - loss: 0.7270 - top2_accuracy: 0.9369
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 13: val_accuracy did not improve from 0.73529
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7184 - loss: 0.7292 - top2_accuracy: 0.9398 - val_accuracy: 0.7194 - val_loss: 0.7104 - val_top2_accuracy: 0.9473 - learning_rate: 0.0010
# Epoch 14/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7344 - loss: 0.7009 - top2_accuracy: 0.9445
# Epoch 14: val_accuracy improved from 0.73529 to 0.74265, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 14: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.7322 - loss: 0.6967 - top2_accuracy: 0.9485 - val_accuracy: 0.7426 - val_loss: 0.6777 - val_top2_accuracy: 0.9473 - learning_rate: 5.0000e-04
# Epoch 15/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7348 - loss: 0.6855 - top2_accuracy: 0.9501
# Epoch 15: val_accuracy improved from 0.74265 to 0.74510, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.7318 - loss: 0.6896 - top2_accuracy: 0.9496 - val_accuracy: 0.7451 - val_loss: 0.6659 - val_top2_accuracy: 0.9498 - learning_rate: 5.0000e-04
# Epoch 16/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7411 - loss: 0.6754 - top2_accuracy: 0.9487
# Epoch 16: val_accuracy did not improve from 0.74510
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7348 - loss: 0.6761 - top2_accuracy: 0.9514 - val_accuracy: 0.7439 - val_loss: 0.6725 - val_top2_accuracy: 0.9424 - learning_rate: 5.0000e-04
# Epoch 17/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7440 - loss: 0.6650 - top2_accuracy: 0.9501
# Epoch 17: val_accuracy did not improve from 0.74510
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7391 - loss: 0.6753 - top2_accuracy: 0.9511 - val_accuracy: 0.7353 - val_loss: 0.6751 - val_top2_accuracy: 0.9461 - learning_rate: 5.0000e-04
# Epoch 18/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7404 - loss: 0.6741 - top2_accuracy: 0.9465
# Epoch 18: val_accuracy did not improve from 0.74510
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.7409 - loss: 0.6713 - top2_accuracy: 0.9500 - val_accuracy: 0.7402 - val_loss: 0.6751 - val_top2_accuracy: 0.9498 - learning_rate: 5.0000e-04
# Epoch 19/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7463 - loss: 0.6743 - top2_accuracy: 0.9461
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_accuracy did not improve from 0.74510
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7481 - loss: 0.6664 - top2_accuracy: 0.9508 - val_accuracy: 0.7390 - val_loss: 0.6658 - val_top2_accuracy: 0.9522 - learning_rate: 5.0000e-04
# Epoch 20/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7513 - loss: 0.6503 - top2_accuracy: 0.9546
# Epoch 20: val_accuracy did not improve from 0.74510
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.7534 - loss: 0.6426 - top2_accuracy: 0.9563 - val_accuracy: 0.7414 - val_loss: 0.6566 - val_top2_accuracy: 0.9534 - learning_rate: 2.5000e-04
# Epoch 21/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7643 - loss: 0.6330 - top2_accuracy: 0.9568
# Epoch 21: val_accuracy improved from 0.74510 to 0.75613, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 21: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.7638 - loss: 0.6349 - top2_accuracy: 0.9580 - val_accuracy: 0.7561 - val_loss: 0.6500 - val_top2_accuracy: 0.9485 - learning_rate: 2.5000e-04
# Epoch 22/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7567 - loss: 0.6340 - top2_accuracy: 0.9623
# Epoch 22: val_accuracy did not improve from 0.75613
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - accuracy: 0.7579 - loss: 0.6299 - top2_accuracy: 0.9609 - val_accuracy: 0.7488 - val_loss: 0.6359 - val_top2_accuracy: 0.9547 - learning_rate: 2.5000e-04
# Epoch 23/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7643 - loss: 0.6277 - top2_accuracy: 0.9584
# Epoch 23: val_accuracy did not improve from 0.75613
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - accuracy: 0.7624 - loss: 0.6280 - top2_accuracy: 0.9601 - val_accuracy: 0.7537 - val_loss: 0.6410 - val_top2_accuracy: 0.9522 - learning_rate: 2.5000e-04
# Epoch 24/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7747 - loss: 0.6182 - top2_accuracy: 0.9615
# Epoch 24: val_accuracy did not improve from 0.75613
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.7678 - loss: 0.6203 - top2_accuracy: 0.9616 - val_accuracy: 0.7549 - val_loss: 0.6370 - val_top2_accuracy: 0.9534 - learning_rate: 2.5000e-04
# Epoch 25/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7648 - loss: 0.6254 - top2_accuracy: 0.9586
# Epoch 25: val_accuracy did not improve from 0.75613
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7663 - loss: 0.6196 - top2_accuracy: 0.9609 - val_accuracy: 0.7451 - val_loss: 0.6489 - val_top2_accuracy: 0.9510 - learning_rate: 2.5000e-04
# Epoch 26/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7726 - loss: 0.6173 - top2_accuracy: 0.9583
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 26: val_accuracy did not improve from 0.75613
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.7702 - loss: 0.6189 - top2_accuracy: 0.9615 - val_accuracy: 0.7426 - val_loss: 0.6488 - val_top2_accuracy: 0.9571 - learning_rate: 2.5000e-04
# Epoch 27/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7760 - loss: 0.6063 - top2_accuracy: 0.9578
# Epoch 27: val_accuracy improved from 0.75613 to 0.76716, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - accuracy: 0.7775 - loss: 0.6017 - top2_accuracy: 0.9623 - val_accuracy: 0.7672 - val_loss: 0.6353 - val_top2_accuracy: 0.9583 - learning_rate: 1.2500e-04
# Epoch 28/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7709 - loss: 0.6113 - top2_accuracy: 0.9581
# Epoch 28: val_accuracy improved from 0.76716 to 0.77451, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 28: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7711 - loss: 0.6083 - top2_accuracy: 0.9614 - val_accuracy: 0.7745 - val_loss: 0.6360 - val_top2_accuracy: 0.9559 - learning_rate: 1.2500e-04
# Epoch 29/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7804 - loss: 0.5962 - top2_accuracy: 0.9655
# Epoch 29: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7797 - loss: 0.5942 - top2_accuracy: 0.9661 - val_accuracy: 0.7623 - val_loss: 0.6310 - val_top2_accuracy: 0.9620 - learning_rate: 1.2500e-04
# Epoch 30/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7774 - loss: 0.5850 - top2_accuracy: 0.9646
# Epoch 30: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.7799 - loss: 0.5893 - top2_accuracy: 0.9651 - val_accuracy: 0.7684 - val_loss: 0.6344 - val_top2_accuracy: 0.9571 - learning_rate: 1.2500e-04
# Epoch 31/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7750 - loss: 0.5962 - top2_accuracy: 0.9606
# Epoch 31: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7779 - loss: 0.5930 - top2_accuracy: 0.9630 - val_accuracy: 0.7647 - val_loss: 0.6337 - val_top2_accuracy: 0.9547 - learning_rate: 1.2500e-04
# Epoch 32/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7906 - loss: 0.5841 - top2_accuracy: 0.9613
# Epoch 32: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7857 - loss: 0.5847 - top2_accuracy: 0.9634 - val_accuracy: 0.7574 - val_loss: 0.6357 - val_top2_accuracy: 0.9608 - learning_rate: 1.2500e-04
# Epoch 33/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7789 - loss: 0.5870 - top2_accuracy: 0.9628
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 33: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7804 - loss: 0.5874 - top2_accuracy: 0.9655 - val_accuracy: 0.7574 - val_loss: 0.6413 - val_top2_accuracy: 0.9583 - learning_rate: 1.2500e-04
# Epoch 34/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7879 - loss: 0.5770 - top2_accuracy: 0.9627
# Epoch 34: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.7892 - loss: 0.5767 - top2_accuracy: 0.9657 - val_accuracy: 0.7659 - val_loss: 0.6337 - val_top2_accuracy: 0.9608 - learning_rate: 6.2500e-05
# Epoch 35/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7949 - loss: 0.5754 - top2_accuracy: 0.9687
# Epoch 35: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.7931 - loss: 0.5710 - top2_accuracy: 0.9698 - val_accuracy: 0.7733 - val_loss: 0.6325 - val_top2_accuracy: 0.9608 - learning_rate: 6.2500e-05
# Epoch 36/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7910 - loss: 0.5777 - top2_accuracy: 0.9659
# Epoch 36: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.7907 - loss: 0.5763 - top2_accuracy: 0.9664 - val_accuracy: 0.7635 - val_loss: 0.6338 - val_top2_accuracy: 0.9596 - learning_rate: 6.2500e-05
# Epoch 37/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7894 - loss: 0.5675 - top2_accuracy: 0.9645
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 37: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.7903 - loss: 0.5659 - top2_accuracy: 0.9683 - val_accuracy: 0.7561 - val_loss: 0.6377 - val_top2_accuracy: 0.9596 - learning_rate: 6.2500e-05
# Epoch 38/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7956 - loss: 0.5683 - top2_accuracy: 0.9663
# Epoch 38: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7978 - loss: 0.5679 - top2_accuracy: 0.9686 - val_accuracy: 0.7623 - val_loss: 0.6370 - val_top2_accuracy: 0.9583 - learning_rate: 3.1250e-05
# Epoch 39/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7961 - loss: 0.5670 - top2_accuracy: 0.9668
# Epoch 39: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7951 - loss: 0.5638 - top2_accuracy: 0.9679 - val_accuracy: 0.7684 - val_loss: 0.6372 - val_top2_accuracy: 0.9596 - learning_rate: 3.1250e-05
# Epoch 40/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7950 - loss: 0.5716 - top2_accuracy: 0.9680
# Epoch 40: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7911 - loss: 0.5708 - top2_accuracy: 0.9689 - val_accuracy: 0.7745 - val_loss: 0.6333 - val_top2_accuracy: 0.9608 - learning_rate: 3.1250e-05
# Epoch 41/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7955 - loss: 0.5604 - top2_accuracy: 0.9725
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 41: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7949 - loss: 0.5549 - top2_accuracy: 0.9722 - val_accuracy: 0.7672 - val_loss: 0.6348 - val_top2_accuracy: 0.9608 - learning_rate: 3.1250e-05
# Epoch 42/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7986 - loss: 0.5610 - top2_accuracy: 0.9670
# Epoch 42: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.8009 - loss: 0.5570 - top2_accuracy: 0.9686 - val_accuracy: 0.7684 - val_loss: 0.6344 - val_top2_accuracy: 0.9596 - learning_rate: 1.5625e-05
# Epoch 43/90
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7896 - loss: 0.5679 - top2_accuracy: 0.9650
# Epoch 43: val_accuracy did not improve from 0.77451
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7916 - loss: 0.5632 - top2_accuracy: 0.9669 - val_accuracy: 0.7684 - val_loss: 0.6330 - val_top2_accuracy: 0.9608 - learning_rate: 1.5625e-05
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 28.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 43
#    Best val_accuracy : 77.45% (epoch 28)
#
# ✅ Good result : 77.5%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using test dataset
num_examples_predictions = 20
for images, labels in test_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
# 2026-03-25 22:40:34.306143: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 99.9% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 2: Label=index        | Prediction=index        | Confidence= 54.0% | 2nd Prediction=middle       | 2nd Confidence= 44.2%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence= 91.9% | 2nd Prediction=index        | 2nd Confidence=  5.0%
# ❌ Image 4: Label=index        | Prediction=middle       | Confidence= 45.2% | 2nd Prediction=index        | 2nd Confidence= 36.3%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence= 99.7% | 2nd Prediction=middle       | 2nd Confidence=  0.2%
# ✅ Image 6: Label=index        | Prediction=index        | Confidence= 78.2% | 2nd Prediction=middle       | 2nd Confidence= 19.9%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 57.3% | 2nd Prediction=middle       | 2nd Confidence= 28.5%
# ✅ Image 8: Label=middle       | Prediction=middle       | Confidence= 91.2% | 2nd Prediction=index        | 2nd Confidence=  7.8%
# ✅ Image 9: Label=index        | Prediction=index        | Confidence= 70.3% | 2nd Prediction=middle       | 2nd Confidence= 21.6%
# ✅ Image 10: Label=index        | Prediction=index        | Confidence= 72.6% | 2nd Prediction=middle       | 2nd Confidence= 25.0%
# ❌ Image 11: Label=index        | Prediction=middle       | Confidence= 76.8% | 2nd Prediction=index        | 2nd Confidence= 18.6%
# ✅ Image 12: Label=thumb        | Prediction=thumb        | Confidence= 98.4% | 2nd Prediction=index        | 2nd Confidence=  1.2%
# ✅ Image 13: Label=index        | Prediction=index        | Confidence= 60.6% | 2nd Prediction=middle       | 2nd Confidence= 35.9%
# ✅ Image 14: Label=thumb        | Prediction=thumb        | Confidence= 99.2% | 2nd Prediction=index        | 2nd Confidence=  0.6%
# ❌ Image 15: Label=index        | Prediction=middle       | Confidence= 85.2% | 2nd Prediction=index        | 2nd Confidence= 12.5%
# ❌ Image 16: Label=middle       | Prediction=index        | Confidence= 61.9% | 2nd Prediction=middle       | 2nd Confidence= 37.7%
# ✅ Image 17: Label=middle       | Prediction=middle       | Confidence= 79.8% | 2nd Prediction=index        | 2nd Confidence= 17.8%
# ✅ Image 18: Label=thumb        | Prediction=thumb        | Confidence= 73.8% | 2nd Prediction=middle       | 2nd Confidence= 17.1%
# ✅ Image 19: Label=middle       | Prediction=middle       | Confidence= 77.1% | 2nd Prediction=index        | 2nd Confidence= 22.4%
# ✅ Image 20: Label=middle       | Prediction=middle       | Confidence= 83.8% | 2nd Prediction=index        | 2nd Confidence= 14.7%
#
# ======================================================================================================================================================
# 2026-03-25 22:40:36.801722: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using test dataset
print("📊 Evaluation of frozen model using test dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(test_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using test dataset...
#
# Results :
#   - Loss                : 0.5234
#   - Accuracy            : 82.29%
#   - Top-2 Accuracy      : 96.61%
