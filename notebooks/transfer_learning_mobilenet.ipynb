# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV3Large
# Fingerprint model name : MobileNetV3Large_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration
# True : consider both "Real" and "Altered" subdirectories
# False : consider only "Real" subdirectory (smaller dataset, faster processing)
CONSIDER_FULL_DATASET = False

if CONSIDER_FULL_DATASET:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")
else:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
class_names = ['thumb', 'index', 'middle', 'ring', 'little']
num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Adjusted fingerprint model name : MobileNetV3Large_FingerPrint_Model5_classes

# %% [markdown]
# ## Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         6000 non-null   int64
#  1   ImagePath  6000 non-null   str
#  2   Finger     6000 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 140.8 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    6000 non-null   str
#  1   ImageFormat  6000 non-null   str
#  2   ImageSize    6000 non-null   object
#  3   ImageMode    6000 non-null   str
# dtypes: object(1), str(3)
# memory usage: 187.6+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    6000
# Name: count, dtype: int64
# ImageSize
# (96, 96)    6000
# Name: count, dtype: int64
# ImageMode
# RGB    6000
# Name: count, dtype: int64

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Define datasets for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 32
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.3
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 6000 files belonging to 5 classes.
# Using 4200 files for training.
# Found 6000 files belonging to 5 classes.
# Using 1800 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 132
#   - Validation batches    : 57
#   - Batch size            : 32
#   - Image size            : (96, 96)
#
#   - Training samples      : ~4224
#   - Validation samples    : ~1824

# %% [markdown]
# ## Dataset preparation : no augmentation, normalisation and shuffling (training only)

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset normalisation required for MobileNet

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # Normalisation MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Construct FingerPrint Model : Pre-trained MobileNetV2 + finger classifier

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 256

DROPOUT_RATE = 0.3
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV3Large ...
# /Users/laurent/Projects/projet-fingerprint-validator/notebooks/.venv/lib/python3.12/site-packages/keras/src/applications/mobilenet_v3.py:519: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# ✅ MobileNetV3Large model loaded !
#
# 📋 Model Structure - MobileNetV3Large :
#   - Architecture   : MobileNetV3Large
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 960)
#   - Number of layers : 188
#
#   - Total number of parameters : 2,996,352
#   - Memory size (approx.) : 11.4 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},softmax)\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    188 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV3Large based FingerPrint:
#   Input(96, 96, 3) → MobileNetV3Large → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(5,softmax)
#
#   - Trainable parameters     : 247,301
#   - Non-trainable parameters : 2,996,352
#   - Total                    : 3,243,653
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV3Large pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. rescaling                                | Output: (None, 96, 96, 3)              | Trainable: False
#     3. conv                                     | Output: (None, 48, 48, 16)             | Trainable: False
#     4. conv_bn                                  | Output: (None, 48, 48, 16)             | Trainable: False
#     5. activation                               | Output: (None, 48, 48, 16)             | Trainable: False
#     6. expanded_conv_depthwise                  | Output: (None, 48, 48, 16)             | Trainable: False
#     7. expanded_conv_depthwise_bn               | Output: (None, 48, 48, 16)             | Trainable: False
#     8. re_lu                                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#    10. expanded_conv_project_bn                 | Output: (None, 48, 48, 16)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   179. expanded_conv_14_squeeze_excite_conv_1   | Output: (None, 1, 1, 960)              | Trainable: False
#   180. re_lu_18                                 | Output: (None, 1, 1, 960)              | Trainable: False
#   181. expanded_conv_14_squeeze_excite_mul      | Output: (None, 3, 3, 960)              | Trainable: False
#   182. expanded_conv_14_project                 | Output: (None, 3, 3, 160)              | Trainable: False
#   183. expanded_conv_14_project_bn              | Output: (None, 3, 3, 160)              | Trainable: False
#   184. expanded_conv_14_add                     | Output: (None, 3, 3, 160)              | Trainable: False
#   185. conv_1                                   | Output: (None, 3, 3, 960)              | Trainable: False
#   186. conv_1_bn                                | Output: (None, 3, 3, 960)              | Trainable: False
#   187. activation_19                            | Output: (None, 3, 3, 960)              | Trainable: False
#   188. avg_pool                                 | Output: (None, 960)                    | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV3Large FingerPrint model architecture
# ============================================================
# Model: "MobileNetV3Large_FingerPrint_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV3Large (Functional)   │ (None, 960)            │     2,996,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 960)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       246,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,243,653 (12.37 MB)
#  Trainable params: 247,301 (966.02 KB)
#  Non-trainable params: 2,996,352 (11.43 MB)

# %% [markdown]
# ## Training FingerPrint model

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 150
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen model training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 150
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/150
# 2026-03-18 14:56:47.114521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3333 - loss: 4.5011 - top2_accuracy: 0.5359
# Epoch 1: val_accuracy improved from None to 0.52667, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.3876 - loss: 3.3482 - top2_accuracy: 0.6014 - val_accuracy: 0.5267 - val_loss: 1.8361 - val_top2_accuracy: 0.7733 - learning_rate: 0.0010
# Epoch 2/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4602 - loss: 2.0612 - top2_accuracy: 0.6785
# Epoch 2: val_accuracy did not improve from 0.52667
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.4512 - loss: 1.9725 - top2_accuracy: 0.6752 - val_accuracy: 0.5183 - val_loss: 1.5072 - val_top2_accuracy: 0.7550 - learning_rate: 0.0010
# Epoch 3/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4591 - loss: 1.7243 - top2_accuracy: 0.6803
# Epoch 3: val_accuracy improved from 0.52667 to 0.55000, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.4581 - loss: 1.6877 - top2_accuracy: 0.6817 - val_accuracy: 0.5500 - val_loss: 1.3667 - val_top2_accuracy: 0.7739 - learning_rate: 0.0010
# Epoch 4/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4543 - loss: 1.5732 - top2_accuracy: 0.7020
# Epoch 4: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.4640 - loss: 1.5394 - top2_accuracy: 0.6976 - val_accuracy: 0.5444 - val_loss: 1.2984 - val_top2_accuracy: 0.7706 - learning_rate: 0.0010
# Epoch 5/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4826 - loss: 1.4692 - top2_accuracy: 0.6904
# Epoch 5: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.4831 - loss: 1.4438 - top2_accuracy: 0.7043 - val_accuracy: 0.5283 - val_loss: 1.2719 - val_top2_accuracy: 0.7639 - learning_rate: 0.0010
# Epoch 6/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4886 - loss: 1.3987 - top2_accuracy: 0.7096
# Epoch 6: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.4771 - loss: 1.3973 - top2_accuracy: 0.7029 - val_accuracy: 0.5378 - val_loss: 1.2468 - val_top2_accuracy: 0.7644 - learning_rate: 0.0010
# Epoch 7/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4869 - loss: 1.3592 - top2_accuracy: 0.7172
# Epoch 7: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.4812 - loss: 1.3648 - top2_accuracy: 0.7140 - val_accuracy: 0.5311 - val_loss: 1.2449 - val_top2_accuracy: 0.7483 - learning_rate: 0.0010
# Epoch 8/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4693 - loss: 1.3738 - top2_accuracy: 0.7054
# Epoch 8: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.4724 - loss: 1.3564 - top2_accuracy: 0.7102 - val_accuracy: 0.5406 - val_loss: 1.2166 - val_top2_accuracy: 0.7711 - learning_rate: 0.0010
# Epoch 9/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4938 - loss: 1.3216 - top2_accuracy: 0.7054
# Epoch 9: val_accuracy did not improve from 0.55000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.4862 - loss: 1.3224 - top2_accuracy: 0.7112 - val_accuracy: 0.5489 - val_loss: 1.2034 - val_top2_accuracy: 0.7744 - learning_rate: 0.0010
# Epoch 10/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4992 - loss: 1.2979 - top2_accuracy: 0.7253
# Epoch 10: val_accuracy improved from 0.55000 to 0.55333, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.4905 - loss: 1.3012 - top2_accuracy: 0.7183 - val_accuracy: 0.5533 - val_loss: 1.2041 - val_top2_accuracy: 0.7694 - learning_rate: 0.0010
# Epoch 11/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4988 - loss: 1.2804 - top2_accuracy: 0.7214
# Epoch 11: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.4931 - loss: 1.2918 - top2_accuracy: 0.7217 - val_accuracy: 0.5444 - val_loss: 1.1838 - val_top2_accuracy: 0.7728 - learning_rate: 0.0010
# Epoch 12/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4902 - loss: 1.2846 - top2_accuracy: 0.7228
# Epoch 12: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.4931 - loss: 1.2795 - top2_accuracy: 0.7248 - val_accuracy: 0.5394 - val_loss: 1.1895 - val_top2_accuracy: 0.7739 - learning_rate: 0.0010
# Epoch 13/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5009 - loss: 1.2878 - top2_accuracy: 0.7111
# Epoch 13: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.4962 - loss: 1.2864 - top2_accuracy: 0.7190 - val_accuracy: 0.5389 - val_loss: 1.1831 - val_top2_accuracy: 0.7661 - learning_rate: 0.0010
# Epoch 14/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5064 - loss: 1.2635 - top2_accuracy: 0.7325
# Epoch 14: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5021 - loss: 1.2695 - top2_accuracy: 0.7338 - val_accuracy: 0.5400 - val_loss: 1.1852 - val_top2_accuracy: 0.7683 - learning_rate: 0.0010
# Epoch 15/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5011 - loss: 1.2618 - top2_accuracy: 0.7280
# Epoch 15: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.4990 - loss: 1.2707 - top2_accuracy: 0.7269 - val_accuracy: 0.5444 - val_loss: 1.2014 - val_top2_accuracy: 0.7617 - learning_rate: 0.0010
# Epoch 16/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5101 - loss: 1.2588 - top2_accuracy: 0.7235
# Epoch 16: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5043 - loss: 1.2679 - top2_accuracy: 0.7240 - val_accuracy: 0.5383 - val_loss: 1.1965 - val_top2_accuracy: 0.7589 - learning_rate: 0.0010
# Epoch 17/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5152 - loss: 1.2448 - top2_accuracy: 0.7344
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 17: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5100 - loss: 1.2537 - top2_accuracy: 0.7324 - val_accuracy: 0.5394 - val_loss: 1.1880 - val_top2_accuracy: 0.7622 - learning_rate: 0.0010
# Epoch 18/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5191 - loss: 1.2311 - top2_accuracy: 0.7481
# Epoch 18: val_accuracy did not improve from 0.55333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.5236 - loss: 1.2227 - top2_accuracy: 0.7540 - val_accuracy: 0.5533 - val_loss: 1.1674 - val_top2_accuracy: 0.7778 - learning_rate: 5.0000e-04
# Epoch 19/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5146 - loss: 1.2115 - top2_accuracy: 0.7416
# Epoch 19: val_accuracy improved from 0.55333 to 0.56167, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.5110 - loss: 1.2131 - top2_accuracy: 0.7486 - val_accuracy: 0.5617 - val_loss: 1.1699 - val_top2_accuracy: 0.7772 - learning_rate: 5.0000e-04
# Epoch 20/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5172 - loss: 1.2144 - top2_accuracy: 0.7396
# Epoch 20: val_accuracy did not improve from 0.56167
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.5198 - loss: 1.2183 - top2_accuracy: 0.7440 - val_accuracy: 0.5617 - val_loss: 1.1557 - val_top2_accuracy: 0.7778 - learning_rate: 5.0000e-04
# Epoch 21/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5297 - loss: 1.2208 - top2_accuracy: 0.7476
# Epoch 21: val_accuracy did not improve from 0.56167
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.5290 - loss: 1.2185 - top2_accuracy: 0.7507 - val_accuracy: 0.5572 - val_loss: 1.1552 - val_top2_accuracy: 0.7800 - learning_rate: 5.0000e-04
# Epoch 22/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5375 - loss: 1.2090 - top2_accuracy: 0.7488
# Epoch 22: val_accuracy improved from 0.56167 to 0.56278, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.5329 - loss: 1.2097 - top2_accuracy: 0.7500 - val_accuracy: 0.5628 - val_loss: 1.1574 - val_top2_accuracy: 0.7844 - learning_rate: 5.0000e-04
# Epoch 23/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5267 - loss: 1.2143 - top2_accuracy: 0.7457
# Epoch 23: val_accuracy improved from 0.56278 to 0.56556, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 23: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5207 - loss: 1.2149 - top2_accuracy: 0.7474 - val_accuracy: 0.5656 - val_loss: 1.1497 - val_top2_accuracy: 0.7789 - learning_rate: 5.0000e-04
# Epoch 24/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5293 - loss: 1.2084 - top2_accuracy: 0.7519
# Epoch 24: val_accuracy improved from 0.56556 to 0.56667, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5293 - loss: 1.2107 - top2_accuracy: 0.7567 - val_accuracy: 0.5667 - val_loss: 1.1453 - val_top2_accuracy: 0.7839 - learning_rate: 5.0000e-04
# Epoch 25/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5215 - loss: 1.2081 - top2_accuracy: 0.7417
# Epoch 25: val_accuracy did not improve from 0.56667
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5236 - loss: 1.2096 - top2_accuracy: 0.7512 - val_accuracy: 0.5639 - val_loss: 1.1525 - val_top2_accuracy: 0.7800 - learning_rate: 5.0000e-04
# Epoch 26/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5427 - loss: 1.2027 - top2_accuracy: 0.7581
# Epoch 26: val_accuracy improved from 0.56667 to 0.57056, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 26: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.5355 - loss: 1.2071 - top2_accuracy: 0.7557 - val_accuracy: 0.5706 - val_loss: 1.1433 - val_top2_accuracy: 0.7772 - learning_rate: 5.0000e-04
# Epoch 27/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5368 - loss: 1.2044 - top2_accuracy: 0.7488
# Epoch 27: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.5319 - loss: 1.2027 - top2_accuracy: 0.7498 - val_accuracy: 0.5667 - val_loss: 1.1535 - val_top2_accuracy: 0.7878 - learning_rate: 5.0000e-04
# Epoch 28/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5402 - loss: 1.1935 - top2_accuracy: 0.7669
# Epoch 28: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5305 - loss: 1.2107 - top2_accuracy: 0.7624 - val_accuracy: 0.5639 - val_loss: 1.1566 - val_top2_accuracy: 0.7744 - learning_rate: 5.0000e-04
# Epoch 29/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5422 - loss: 1.1927 - top2_accuracy: 0.7539
# Epoch 29: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5331 - loss: 1.2028 - top2_accuracy: 0.7581 - val_accuracy: 0.5578 - val_loss: 1.1506 - val_top2_accuracy: 0.7761 - learning_rate: 5.0000e-04
# Epoch 30/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5374 - loss: 1.1887 - top2_accuracy: 0.7582
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 30: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5262 - loss: 1.2066 - top2_accuracy: 0.7524 - val_accuracy: 0.5644 - val_loss: 1.1479 - val_top2_accuracy: 0.7833 - learning_rate: 5.0000e-04
# Epoch 31/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5378 - loss: 1.1849 - top2_accuracy: 0.7491
# Epoch 31: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.5352 - loss: 1.1872 - top2_accuracy: 0.7514 - val_accuracy: 0.5706 - val_loss: 1.1327 - val_top2_accuracy: 0.7878 - learning_rate: 2.5000e-04
# Epoch 32/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5446 - loss: 1.1879 - top2_accuracy: 0.7467
# Epoch 32: val_accuracy did not improve from 0.57056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.5364 - loss: 1.1876 - top2_accuracy: 0.7536 - val_accuracy: 0.5611 - val_loss: 1.1344 - val_top2_accuracy: 0.7894 - learning_rate: 2.5000e-04
# Epoch 33/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5455 - loss: 1.1810 - top2_accuracy: 0.7511
# Epoch 33: val_accuracy improved from 0.57056 to 0.57222, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
#
# Epoch 33: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/best_mobilenet_fingerprint_model.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5407 - loss: 1.1818 - top2_accuracy: 0.7502 - val_accuracy: 0.5722 - val_loss: 1.1289 - val_top2_accuracy: 0.7844 - learning_rate: 2.5000e-04
# Epoch 34/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5489 - loss: 1.1863 - top2_accuracy: 0.7488
# Epoch 34: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.5433 - loss: 1.1839 - top2_accuracy: 0.7581 - val_accuracy: 0.5633 - val_loss: 1.1346 - val_top2_accuracy: 0.7844 - learning_rate: 2.5000e-04
# Epoch 35/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5393 - loss: 1.1695 - top2_accuracy: 0.7596
# Epoch 35: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5336 - loss: 1.1807 - top2_accuracy: 0.7540 - val_accuracy: 0.5683 - val_loss: 1.1279 - val_top2_accuracy: 0.7861 - learning_rate: 2.5000e-04
# Epoch 36/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5421 - loss: 1.1720 - top2_accuracy: 0.7602
# Epoch 36: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5371 - loss: 1.1773 - top2_accuracy: 0.7590 - val_accuracy: 0.5611 - val_loss: 1.1261 - val_top2_accuracy: 0.7861 - learning_rate: 2.5000e-04
# Epoch 37/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5505 - loss: 1.1754 - top2_accuracy: 0.7687
# Epoch 37: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5488 - loss: 1.1787 - top2_accuracy: 0.7710 - val_accuracy: 0.5656 - val_loss: 1.1240 - val_top2_accuracy: 0.7889 - learning_rate: 2.5000e-04
# Epoch 38/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5316 - loss: 1.1795 - top2_accuracy: 0.7484
# Epoch 38: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5283 - loss: 1.1843 - top2_accuracy: 0.7550 - val_accuracy: 0.5661 - val_loss: 1.1230 - val_top2_accuracy: 0.7856 - learning_rate: 2.5000e-04
# Epoch 39/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5493 - loss: 1.1753 - top2_accuracy: 0.7625
# Epoch 39: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5374 - loss: 1.1782 - top2_accuracy: 0.7617 - val_accuracy: 0.5661 - val_loss: 1.1274 - val_top2_accuracy: 0.7833 - learning_rate: 2.5000e-04
# Epoch 40/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5404 - loss: 1.1731 - top2_accuracy: 0.7557
# Epoch 40: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5314 - loss: 1.1833 - top2_accuracy: 0.7586 - val_accuracy: 0.5678 - val_loss: 1.1284 - val_top2_accuracy: 0.7872 - learning_rate: 2.5000e-04
# Epoch 41/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5409 - loss: 1.1713 - top2_accuracy: 0.7651
# Epoch 41: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.5402 - loss: 1.1737 - top2_accuracy: 0.7662 - val_accuracy: 0.5622 - val_loss: 1.1267 - val_top2_accuracy: 0.7756 - learning_rate: 2.5000e-04
# Epoch 42/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5402 - loss: 1.1751 - top2_accuracy: 0.7570
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 42: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.5288 - loss: 1.1851 - top2_accuracy: 0.7498 - val_accuracy: 0.5678 - val_loss: 1.1251 - val_top2_accuracy: 0.7800 - learning_rate: 2.5000e-04
# Epoch 43/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5634 - loss: 1.1557 - top2_accuracy: 0.7774
# Epoch 43: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.5538 - loss: 1.1636 - top2_accuracy: 0.7757 - val_accuracy: 0.5661 - val_loss: 1.1209 - val_top2_accuracy: 0.7839 - learning_rate: 1.2500e-04
# Epoch 44/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5477 - loss: 1.1514 - top2_accuracy: 0.7701
# Epoch 44: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5414 - loss: 1.1606 - top2_accuracy: 0.7660 - val_accuracy: 0.5689 - val_loss: 1.1181 - val_top2_accuracy: 0.7833 - learning_rate: 1.2500e-04
# Epoch 45/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5460 - loss: 1.1582 - top2_accuracy: 0.7690
# Epoch 45: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.5405 - loss: 1.1731 - top2_accuracy: 0.7671 - val_accuracy: 0.5650 - val_loss: 1.1166 - val_top2_accuracy: 0.7867 - learning_rate: 1.2500e-04
# Epoch 46/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5675 - loss: 1.1420 - top2_accuracy: 0.7777
# Epoch 46: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.5598 - loss: 1.1476 - top2_accuracy: 0.7779 - val_accuracy: 0.5661 - val_loss: 1.1177 - val_top2_accuracy: 0.7856 - learning_rate: 1.2500e-04
# Epoch 47/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5455 - loss: 1.1613 - top2_accuracy: 0.7629
# Epoch 47: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5510 - loss: 1.1584 - top2_accuracy: 0.7669 - val_accuracy: 0.5672 - val_loss: 1.1173 - val_top2_accuracy: 0.7883 - learning_rate: 1.2500e-04
# Epoch 48/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5534 - loss: 1.1645 - top2_accuracy: 0.7608
# Epoch 48: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5524 - loss: 1.1685 - top2_accuracy: 0.7686 - val_accuracy: 0.5678 - val_loss: 1.1145 - val_top2_accuracy: 0.7878 - learning_rate: 1.2500e-04
# Epoch 49/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5390 - loss: 1.1572 - top2_accuracy: 0.7630
# Epoch 49: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5374 - loss: 1.1632 - top2_accuracy: 0.7657 - val_accuracy: 0.5644 - val_loss: 1.1160 - val_top2_accuracy: 0.7861 - learning_rate: 1.2500e-04
# Epoch 50/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5547 - loss: 1.1571 - top2_accuracy: 0.7706
# Epoch 50: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5474 - loss: 1.1652 - top2_accuracy: 0.7748 - val_accuracy: 0.5639 - val_loss: 1.1155 - val_top2_accuracy: 0.7911 - learning_rate: 1.2500e-04
# Epoch 51/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5591 - loss: 1.1405 - top2_accuracy: 0.7772
# Epoch 51: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5514 - loss: 1.1507 - top2_accuracy: 0.7750 - val_accuracy: 0.5683 - val_loss: 1.1161 - val_top2_accuracy: 0.7906 - learning_rate: 1.2500e-04
# Epoch 52/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5543 - loss: 1.1545 - top2_accuracy: 0.7661
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 52: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.5545 - loss: 1.1558 - top2_accuracy: 0.7738 - val_accuracy: 0.5661 - val_loss: 1.1157 - val_top2_accuracy: 0.7889 - learning_rate: 1.2500e-04
# Epoch 53/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5537 - loss: 1.1484 - top2_accuracy: 0.7727
# Epoch 53: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5445 - loss: 1.1593 - top2_accuracy: 0.7655 - val_accuracy: 0.5678 - val_loss: 1.1140 - val_top2_accuracy: 0.7906 - learning_rate: 6.2500e-05
# Epoch 54/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5461 - loss: 1.1466 - top2_accuracy: 0.7703
# Epoch 54: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5450 - loss: 1.1548 - top2_accuracy: 0.7724 - val_accuracy: 0.5678 - val_loss: 1.1127 - val_top2_accuracy: 0.7911 - learning_rate: 6.2500e-05
# Epoch 55/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5491 - loss: 1.1620 - top2_accuracy: 0.7666
# Epoch 55: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5500 - loss: 1.1630 - top2_accuracy: 0.7662 - val_accuracy: 0.5661 - val_loss: 1.1121 - val_top2_accuracy: 0.7911 - learning_rate: 6.2500e-05
# Epoch 56/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5636 - loss: 1.1394 - top2_accuracy: 0.7698
# Epoch 56: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5519 - loss: 1.1571 - top2_accuracy: 0.7655 - val_accuracy: 0.5617 - val_loss: 1.1134 - val_top2_accuracy: 0.7878 - learning_rate: 6.2500e-05
# Epoch 57/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5568 - loss: 1.1440 - top2_accuracy: 0.7732
# Epoch 57: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5538 - loss: 1.1527 - top2_accuracy: 0.7743 - val_accuracy: 0.5656 - val_loss: 1.1121 - val_top2_accuracy: 0.7922 - learning_rate: 6.2500e-05
# Epoch 58/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5589 - loss: 1.1547 - top2_accuracy: 0.7727
# Epoch 58: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.5593 - loss: 1.1553 - top2_accuracy: 0.7762 - val_accuracy: 0.5694 - val_loss: 1.1121 - val_top2_accuracy: 0.7917 - learning_rate: 6.2500e-05
# Epoch 59/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5712 - loss: 1.1562 - top2_accuracy: 0.7667
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 59: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5567 - loss: 1.1550 - top2_accuracy: 0.7688 - val_accuracy: 0.5700 - val_loss: 1.1123 - val_top2_accuracy: 0.7900 - learning_rate: 6.2500e-05
# Epoch 60/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5542 - loss: 1.1353 - top2_accuracy: 0.7855
# Epoch 60: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5464 - loss: 1.1457 - top2_accuracy: 0.7752 - val_accuracy: 0.5678 - val_loss: 1.1101 - val_top2_accuracy: 0.7917 - learning_rate: 3.1250e-05
# Epoch 61/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5623 - loss: 1.1362 - top2_accuracy: 0.7839
# Epoch 61: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.5562 - loss: 1.1482 - top2_accuracy: 0.7795 - val_accuracy: 0.5678 - val_loss: 1.1098 - val_top2_accuracy: 0.7911 - learning_rate: 3.1250e-05
# Epoch 62/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5719 - loss: 1.1357 - top2_accuracy: 0.7751
# Epoch 62: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.5619 - loss: 1.1448 - top2_accuracy: 0.7786 - val_accuracy: 0.5672 - val_loss: 1.1093 - val_top2_accuracy: 0.7911 - learning_rate: 3.1250e-05
# Epoch 63/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5712 - loss: 1.1288 - top2_accuracy: 0.7789
# Epoch 63: val_accuracy did not improve from 0.57222
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5652 - loss: 1.1350 - top2_accuracy: 0.7795 - val_accuracy: 0.5689 - val_loss: 1.1087 - val_top2_accuracy: 0.7894 - learning_rate: 3.1250e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 63
#    Best val_accuracy : 57.22% (epoch 33)
#
# ⚠️  Accuracy of 57.2% is below 70%

# %% [markdown]
# ## Frozen Model evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 96.3% | 2nd Prediction=index        | 2nd Confidence=  1.7%
# ❌ Image 2: Label=ring         | Prediction=middle       | Confidence= 37.4% | 2nd Prediction=index        | 2nd Confidence= 32.1%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence= 66.4% | 2nd Prediction=index        | 2nd Confidence= 15.2%
# ✅ Image 4: Label=thumb        | Prediction=thumb        | Confidence= 50.7% | 2nd Prediction=middle       | 2nd Confidence= 25.4%
# ✅ Image 5: Label=little       | Prediction=little       | Confidence= 94.8% | 2nd Prediction=ring         | 2nd Confidence=  2.8%
# ✅ Image 6: Label=little       | Prediction=little       | Confidence= 75.0% | 2nd Prediction=index        | 2nd Confidence= 12.5%
# ❌ Image 7: Label=middle       | Prediction=index        | Confidence= 47.0% | 2nd Prediction=middle       | 2nd Confidence= 25.7%
# ❌ Image 8: Label=index        | Prediction=thumb        | Confidence= 48.7% | 2nd Prediction=middle       | 2nd Confidence= 18.7%
# ❌ Image 9: Label=thumb        | Prediction=ring         | Confidence= 36.0% | 2nd Prediction=thumb        | 2nd Confidence= 33.7%
# ✅ Image 10: Label=ring         | Prediction=ring         | Confidence= 52.3% | 2nd Prediction=middle       | 2nd Confidence= 25.9%
# ✅ Image 11: Label=ring         | Prediction=ring         | Confidence= 43.8% | 2nd Prediction=little       | 2nd Confidence= 27.0%
# ✅ Image 12: Label=index        | Prediction=index        | Confidence= 50.9% | 2nd Prediction=little       | 2nd Confidence= 25.4%
# ❌ Image 13: Label=little       | Prediction=ring         | Confidence= 46.0% | 2nd Prediction=middle       | 2nd Confidence= 36.9%
# ✅ Image 14: Label=little       | Prediction=little       | Confidence= 75.6% | 2nd Prediction=ring         | 2nd Confidence= 11.3%
# ✅ Image 15: Label=thumb        | Prediction=thumb        | Confidence= 87.2% | 2nd Prediction=index        | 2nd Confidence=  7.1%
# ❌ Image 16: Label=ring         | Prediction=middle       | Confidence= 46.3% | 2nd Prediction=ring         | 2nd Confidence= 33.1%
# ❌ Image 17: Label=ring         | Prediction=middle       | Confidence= 45.8% | 2nd Prediction=index        | 2nd Confidence= 24.4%
# ❌ Image 18: Label=index        | Prediction=thumb        | Confidence= 34.3% | 2nd Prediction=middle       | 2nd Confidence= 32.2%
# ❌ Image 19: Label=thumb        | Prediction=middle       | Confidence= 48.1% | 2nd Prediction=index        | 2nd Confidence= 17.5%
# ❌ Image 20: Label=index        | Prediction=ring         | Confidence= 43.5% | 2nd Prediction=little       | 2nd Confidence= 22.4%
#
# ======================================================================================================================================================
# 2026-03-18 15:07:08.996346: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 1.1289
#   - Accuracy            : 57.22%
#   - Top-2 Accuracy      : 78.44%
