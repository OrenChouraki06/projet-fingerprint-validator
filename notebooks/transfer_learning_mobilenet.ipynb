# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration
# True : consider both "Real" and "Altered" subdirectories
# False : consider only "Real" subdirectory (smaller dataset, faster processing)
CONSIDER_FULL_DATASET = False

if CONSIDER_FULL_DATASET:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")
else:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %% [markdown]
# ## Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         6000 non-null   int64
#  1   ImagePath  6000 non-null   str
#  2   Finger     6000 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 140.8 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3600 entries, 0 to 3599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    3600 non-null   str
#  1   ImageFormat  3600 non-null   str
#  2   ImageSize    3600 non-null   object
#  3   ImageMode    3600 non-null   str
#  4   Finger       3600 non-null   str
# dtypes: object(1), str(4)
# memory usage: 140.8+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    3600
# Name: count, dtype: int64
# ImageSize
# (96, 96)    3600
# Name: count, dtype: int64
# ImageMode
# RGB    3600
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 33.33%
# Percentage of Index fingers: 33.33%
# Percentage of Middle fingers: 33.33%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Define datasets for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 32
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.3
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 3600 files belonging to 3 classes.
# Using 2520 files for training.
# Found 3600 files belonging to 3 classes.
# Using 1080 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 79
#   - Validation batches    : 34
#   - Batch size            : 32
#   - Image size            : (96, 96)
#
#   - Training samples      : ~2528
#   - Validation samples    : ~1088
# 2026-03-18 15:56:14.974535: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-18 15:56:14.974561: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-18 15:56:14.974569: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-18 15:56:14.974584: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-18 15:56:14.974597: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : no augmentation, normalisation and shuffling (training only)

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset normalisation required for MobileNet

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # Normalisation MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Construct FingerPrint Model : Pre-trained MobileNetV2 + finger classifier

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 256

DROPOUT_RATE = 0.3
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'
print(f"Classification activation function for {num_classes} classes : {classification_activation}")

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},softmax)\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# Classification activation function for 3 classes : softmax
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(3,softmax)
#
#   - Trainable parameters     : 328,707
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,586,691
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,691 (9.87 MB)
#  Trainable params: 328,707 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## Training FingerPrint model

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 150
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen model training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 150
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/150
# 2026-03-18 15:56:16.873570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5434 - loss: 4.6567 - top2_accuracy: 0.8290
# Epoch 1: val_accuracy improved from None to 0.70463, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - accuracy: 0.5929 - loss: 3.7252 - top2_accuracy: 0.8754 - val_accuracy: 0.7046 - val_loss: 2.1204 - val_top2_accuracy: 0.9194 - learning_rate: 0.0010
# Epoch 2/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6235 - loss: 2.2841 - top2_accuracy: 0.9033
# Epoch 2: val_accuracy did not improve from 0.70463
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.6313 - loss: 2.1468 - top2_accuracy: 0.9063 - val_accuracy: 0.6556 - val_loss: 1.6835 - val_top2_accuracy: 0.9269 - learning_rate: 0.0010
# Epoch 3/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6472 - loss: 1.7139 - top2_accuracy: 0.9212
# Epoch 3: val_accuracy improved from 0.70463 to 0.71667, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.6504 - loss: 1.6198 - top2_accuracy: 0.9139 - val_accuracy: 0.7167 - val_loss: 1.2156 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 4/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6694 - loss: 1.3414 - top2_accuracy: 0.9189
# Epoch 4: val_accuracy did not improve from 0.71667
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6548 - loss: 1.3122 - top2_accuracy: 0.9262 - val_accuracy: 0.6731 - val_loss: 1.1165 - val_top2_accuracy: 0.9296 - learning_rate: 0.0010
# Epoch 5/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6764 - loss: 1.1313 - top2_accuracy: 0.9227
# Epoch 5: val_accuracy did not improve from 0.71667
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6813 - loss: 1.1225 - top2_accuracy: 0.9246 - val_accuracy: 0.7130 - val_loss: 0.9656 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 6/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6810 - loss: 1.0191 - top2_accuracy: 0.9249
# Epoch 6: val_accuracy did not improve from 0.71667
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.6738 - loss: 1.0101 - top2_accuracy: 0.9310 - val_accuracy: 0.7130 - val_loss: 0.8664 - val_top2_accuracy: 0.9361 - learning_rate: 0.0010
# Epoch 7/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6972 - loss: 0.9215 - top2_accuracy: 0.9291
# Epoch 7: val_accuracy did not improve from 0.71667
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.6837 - loss: 0.9265 - top2_accuracy: 0.9286 - val_accuracy: 0.7000 - val_loss: 0.8598 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 8/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6775 - loss: 0.9146 - top2_accuracy: 0.9266
# Epoch 8: val_accuracy did not improve from 0.71667
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6841 - loss: 0.8897 - top2_accuracy: 0.9306 - val_accuracy: 0.6796 - val_loss: 0.8351 - val_top2_accuracy: 0.9222 - learning_rate: 0.0010
# Epoch 9/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6948 - loss: 0.8132 - top2_accuracy: 0.9367
# Epoch 9: val_accuracy improved from 0.71667 to 0.72685, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7020 - loss: 0.8051 - top2_accuracy: 0.9361 - val_accuracy: 0.7269 - val_loss: 0.7614 - val_top2_accuracy: 0.9343 - learning_rate: 0.0010
# Epoch 10/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7029 - loss: 0.8155 - top2_accuracy: 0.9329
# Epoch 10: val_accuracy improved from 0.72685 to 0.73148, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.6944 - loss: 0.8131 - top2_accuracy: 0.9373 - val_accuracy: 0.7315 - val_loss: 0.7469 - val_top2_accuracy: 0.9343 - learning_rate: 0.0010
# Epoch 11/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7026 - loss: 0.7651 - top2_accuracy: 0.9465
# Epoch 11: val_accuracy did not improve from 0.73148
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.6873 - loss: 0.7784 - top2_accuracy: 0.9452 - val_accuracy: 0.6954 - val_loss: 0.7551 - val_top2_accuracy: 0.9398 - learning_rate: 0.0010
# Epoch 12/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7128 - loss: 0.7432 - top2_accuracy: 0.9401
# Epoch 12: val_accuracy did not improve from 0.73148
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7111 - loss: 0.7487 - top2_accuracy: 0.9437 - val_accuracy: 0.7009 - val_loss: 0.7581 - val_top2_accuracy: 0.9241 - learning_rate: 0.0010
# Epoch 13/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7130 - loss: 0.7522 - top2_accuracy: 0.9429
# Epoch 13: val_accuracy did not improve from 0.73148
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.7111 - loss: 0.7536 - top2_accuracy: 0.9437 - val_accuracy: 0.7185 - val_loss: 0.7234 - val_top2_accuracy: 0.9352 - learning_rate: 0.0010
# Epoch 14/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7076 - loss: 0.7515 - top2_accuracy: 0.9315
# Epoch 14: val_accuracy did not improve from 0.73148
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.7036 - loss: 0.7432 - top2_accuracy: 0.9389 - val_accuracy: 0.7287 - val_loss: 0.7169 - val_top2_accuracy: 0.9333 - learning_rate: 0.0010
# Epoch 15/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7012 - loss: 0.7457 - top2_accuracy: 0.9392
# Epoch 15: val_accuracy improved from 0.73148 to 0.74074, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7131 - loss: 0.7328 - top2_accuracy: 0.9397 - val_accuracy: 0.7407 - val_loss: 0.7081 - val_top2_accuracy: 0.9333 - learning_rate: 0.0010
# Epoch 16/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7316 - loss: 0.7109 - top2_accuracy: 0.9465
# Epoch 16: val_accuracy improved from 0.74074 to 0.74167, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7175 - loss: 0.7262 - top2_accuracy: 0.9421 - val_accuracy: 0.7417 - val_loss: 0.7033 - val_top2_accuracy: 0.9333 - learning_rate: 0.0010
# Epoch 17/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7116 - loss: 0.7197 - top2_accuracy: 0.9389
# Epoch 17: val_accuracy did not improve from 0.74167
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7103 - loss: 0.7240 - top2_accuracy: 0.9401 - val_accuracy: 0.7250 - val_loss: 0.7078 - val_top2_accuracy: 0.9370 - learning_rate: 0.0010
# Epoch 18/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7037 - loss: 0.7308 - top2_accuracy: 0.9361
# Epoch 18: val_accuracy did not improve from 0.74167
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7091 - loss: 0.7285 - top2_accuracy: 0.9409 - val_accuracy: 0.7417 - val_loss: 0.6958 - val_top2_accuracy: 0.9333 - learning_rate: 0.0010
# Epoch 19/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7081 - loss: 0.7018 - top2_accuracy: 0.9398
# Epoch 19: val_accuracy improved from 0.74167 to 0.74444, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7079 - loss: 0.7157 - top2_accuracy: 0.9425 - val_accuracy: 0.7444 - val_loss: 0.6999 - val_top2_accuracy: 0.9361 - learning_rate: 0.0010
# Epoch 20/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7315 - loss: 0.7070 - top2_accuracy: 0.9404
# Epoch 20: val_accuracy did not improve from 0.74444
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.7210 - loss: 0.7170 - top2_accuracy: 0.9377 - val_accuracy: 0.7278 - val_loss: 0.6984 - val_top2_accuracy: 0.9343 - learning_rate: 0.0010
# Epoch 21/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7073 - loss: 0.7245 - top2_accuracy: 0.9354
# Epoch 21: val_accuracy did not improve from 0.74444
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7063 - loss: 0.7158 - top2_accuracy: 0.9417 - val_accuracy: 0.7417 - val_loss: 0.6910 - val_top2_accuracy: 0.9343 - learning_rate: 0.0010
# Epoch 22/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7221 - loss: 0.6888 - top2_accuracy: 0.9397
# Epoch 22: val_accuracy improved from 0.74444 to 0.74537, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7206 - loss: 0.6907 - top2_accuracy: 0.9429 - val_accuracy: 0.7454 - val_loss: 0.6974 - val_top2_accuracy: 0.9306 - learning_rate: 0.0010
# Epoch 23/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7119 - loss: 0.7155 - top2_accuracy: 0.9319
# Epoch 23: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.7127 - loss: 0.6996 - top2_accuracy: 0.9421 - val_accuracy: 0.7361 - val_loss: 0.6931 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 24/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7155 - loss: 0.7129 - top2_accuracy: 0.9394
# Epoch 24: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.7079 - loss: 0.7234 - top2_accuracy: 0.9409 - val_accuracy: 0.7370 - val_loss: 0.6940 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 25/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7057 - loss: 0.7045 - top2_accuracy: 0.9371
# Epoch 25: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7111 - loss: 0.7175 - top2_accuracy: 0.9389 - val_accuracy: 0.7343 - val_loss: 0.6901 - val_top2_accuracy: 0.9287 - learning_rate: 0.0010
# Epoch 26/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7233 - loss: 0.6990 - top2_accuracy: 0.9467
# Epoch 26: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.7151 - loss: 0.7034 - top2_accuracy: 0.9440 - val_accuracy: 0.7435 - val_loss: 0.6942 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 27/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7114 - loss: 0.6984 - top2_accuracy: 0.9377
# Epoch 27: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.7060 - loss: 0.7015 - top2_accuracy: 0.9341 - val_accuracy: 0.7435 - val_loss: 0.6928 - val_top2_accuracy: 0.9315 - learning_rate: 0.0010
# Epoch 28/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7042 - loss: 0.7140 - top2_accuracy: 0.9422
# Epoch 28: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.6996 - loss: 0.7123 - top2_accuracy: 0.9433 - val_accuracy: 0.7278 - val_loss: 0.6929 - val_top2_accuracy: 0.9333 - learning_rate: 0.0010
# Epoch 29/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7229 - loss: 0.6929 - top2_accuracy: 0.9526
# Epoch 29: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7242 - loss: 0.6939 - top2_accuracy: 0.9520 - val_accuracy: 0.7435 - val_loss: 0.6870 - val_top2_accuracy: 0.9296 - learning_rate: 0.0010
# Epoch 30/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7287 - loss: 0.6834 - top2_accuracy: 0.9449
# Epoch 30: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7127 - loss: 0.7015 - top2_accuracy: 0.9437 - val_accuracy: 0.7389 - val_loss: 0.6854 - val_top2_accuracy: 0.9343 - learning_rate: 0.0010
# Epoch 31/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7174 - loss: 0.6970 - top2_accuracy: 0.9456
# Epoch 31: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7067 - loss: 0.7085 - top2_accuracy: 0.9448 - val_accuracy: 0.7389 - val_loss: 0.6933 - val_top2_accuracy: 0.9324 - learning_rate: 0.0010
# Epoch 32/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7174 - loss: 0.6812 - top2_accuracy: 0.9501
# Epoch 32: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.7115 - loss: 0.6955 - top2_accuracy: 0.9472 - val_accuracy: 0.7426 - val_loss: 0.7033 - val_top2_accuracy: 0.9287 - learning_rate: 0.0010
# Epoch 33/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7022 - loss: 0.7166 - top2_accuracy: 0.9409
# Epoch 33: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7044 - loss: 0.7102 - top2_accuracy: 0.9468 - val_accuracy: 0.7231 - val_loss: 0.6999 - val_top2_accuracy: 0.9324 - learning_rate: 0.0010
# Epoch 34/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7143 - loss: 0.7040 - top2_accuracy: 0.9464
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 34: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7060 - loss: 0.7139 - top2_accuracy: 0.9468 - val_accuracy: 0.7426 - val_loss: 0.6904 - val_top2_accuracy: 0.9324 - learning_rate: 0.0010
# Epoch 35/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7101 - loss: 0.6805 - top2_accuracy: 0.9421
# Epoch 35: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7171 - loss: 0.6796 - top2_accuracy: 0.9472 - val_accuracy: 0.7139 - val_loss: 0.6934 - val_top2_accuracy: 0.9306 - learning_rate: 5.0000e-04
# Epoch 36/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7200 - loss: 0.6686 - top2_accuracy: 0.9465
# Epoch 36: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7190 - loss: 0.6822 - top2_accuracy: 0.9472 - val_accuracy: 0.7343 - val_loss: 0.6774 - val_top2_accuracy: 0.9361 - learning_rate: 5.0000e-04
# Epoch 37/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7232 - loss: 0.6548 - top2_accuracy: 0.9513
# Epoch 37: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7171 - loss: 0.6719 - top2_accuracy: 0.9496 - val_accuracy: 0.7065 - val_loss: 0.6890 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 38/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7314 - loss: 0.6647 - top2_accuracy: 0.9546
# Epoch 38: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7321 - loss: 0.6686 - top2_accuracy: 0.9496 - val_accuracy: 0.7269 - val_loss: 0.6852 - val_top2_accuracy: 0.9306 - learning_rate: 5.0000e-04
# Epoch 39/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7185 - loss: 0.6743 - top2_accuracy: 0.9456
# Epoch 39: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.7242 - loss: 0.6765 - top2_accuracy: 0.9460 - val_accuracy: 0.7250 - val_loss: 0.6806 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 40/150
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7314 - loss: 0.6604 - top2_accuracy: 0.9515
# Epoch 40: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7234 - loss: 0.6801 - top2_accuracy: 0.9440 - val_accuracy: 0.7241 - val_loss: 0.6760 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 41/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7227 - loss: 0.6647 - top2_accuracy: 0.9524
# Epoch 41: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.7218 - loss: 0.6729 - top2_accuracy: 0.9508 - val_accuracy: 0.7194 - val_loss: 0.6786 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 42/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7296 - loss: 0.6458 - top2_accuracy: 0.9439
# Epoch 42: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7190 - loss: 0.6667 - top2_accuracy: 0.9425 - val_accuracy: 0.7213 - val_loss: 0.6789 - val_top2_accuracy: 0.9352 - learning_rate: 5.0000e-04
# Epoch 43/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7345 - loss: 0.6414 - top2_accuracy: 0.9551
# Epoch 43: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7278 - loss: 0.6575 - top2_accuracy: 0.9500 - val_accuracy: 0.7231 - val_loss: 0.6753 - val_top2_accuracy: 0.9361 - learning_rate: 5.0000e-04
# Epoch 44/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7138 - loss: 0.6744 - top2_accuracy: 0.9479
# Epoch 44: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7131 - loss: 0.6831 - top2_accuracy: 0.9496 - val_accuracy: 0.7157 - val_loss: 0.6847 - val_top2_accuracy: 0.9333 - learning_rate: 5.0000e-04
# Epoch 45/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7273 - loss: 0.6459 - top2_accuracy: 0.9552
# Epoch 45: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.7313 - loss: 0.6560 - top2_accuracy: 0.9563 - val_accuracy: 0.7269 - val_loss: 0.6740 - val_top2_accuracy: 0.9407 - learning_rate: 5.0000e-04
# Epoch 46/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7403 - loss: 0.6402 - top2_accuracy: 0.9547
# Epoch 46: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - accuracy: 0.7274 - loss: 0.6675 - top2_accuracy: 0.9504 - val_accuracy: 0.7176 - val_loss: 0.6803 - val_top2_accuracy: 0.9324 - learning_rate: 5.0000e-04
# Epoch 47/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7145 - loss: 0.6637 - top2_accuracy: 0.9441
# Epoch 47: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.7131 - loss: 0.6774 - top2_accuracy: 0.9464 - val_accuracy: 0.7278 - val_loss: 0.6773 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 48/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7197 - loss: 0.6877 - top2_accuracy: 0.9384
# Epoch 48: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - accuracy: 0.7214 - loss: 0.6792 - top2_accuracy: 0.9429 - val_accuracy: 0.7296 - val_loss: 0.6710 - val_top2_accuracy: 0.9352 - learning_rate: 5.0000e-04
# Epoch 49/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7284 - loss: 0.6581 - top2_accuracy: 0.9504
# Epoch 49: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.7254 - loss: 0.6740 - top2_accuracy: 0.9488 - val_accuracy: 0.7352 - val_loss: 0.6735 - val_top2_accuracy: 0.9343 - learning_rate: 5.0000e-04
# Epoch 50/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7233 - loss: 0.6638 - top2_accuracy: 0.9453
# Epoch 50: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.7298 - loss: 0.6664 - top2_accuracy: 0.9488 - val_accuracy: 0.7231 - val_loss: 0.6780 - val_top2_accuracy: 0.9389 - learning_rate: 5.0000e-04
# Epoch 51/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7331 - loss: 0.6395 - top2_accuracy: 0.9528
# Epoch 51: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.7202 - loss: 0.6641 - top2_accuracy: 0.9512 - val_accuracy: 0.7306 - val_loss: 0.6756 - val_top2_accuracy: 0.9380 - learning_rate: 5.0000e-04
# Epoch 52/150
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7425 - loss: 0.6453 - top2_accuracy: 0.9554
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 52: val_accuracy did not improve from 0.74537
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7329 - loss: 0.6575 - top2_accuracy: 0.9532 - val_accuracy: 0.7333 - val_loss: 0.6738 - val_top2_accuracy: 0.9389 - learning_rate: 5.0000e-04
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 22.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 52
#    Best val_accuracy : 74.54% (epoch 22)
#
# ✅ Good result : 74.5%

# %% [markdown]
# ## Frozen Model evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=middle       | Prediction=middle       | Confidence= 78.9% | 2nd Prediction=index        | 2nd Confidence= 20.8%
# ❌ Image 2: Label=middle       | Prediction=thumb        | Confidence= 92.5% | 2nd Prediction=middle       | 2nd Confidence=  3.9%
# ✅ Image 3: Label=middle       | Prediction=middle       | Confidence= 44.4% | 2nd Prediction=index        | 2nd Confidence= 44.4%
# ❌ Image 4: Label=index        | Prediction=middle       | Confidence= 50.7% | 2nd Prediction=index        | 2nd Confidence= 48.3%
# ❌ Image 5: Label=thumb        | Prediction=index        | Confidence= 51.8% | 2nd Prediction=thumb        | 2nd Confidence= 28.9%
# ✅ Image 6: Label=middle       | Prediction=middle       | Confidence= 58.4% | 2nd Prediction=index        | 2nd Confidence= 39.9%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 99.4% | 2nd Prediction=middle       | 2nd Confidence=  0.3%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 65.3% | 2nd Prediction=middle       | 2nd Confidence= 30.8%
# ✅ Image 9: Label=middle       | Prediction=middle       | Confidence= 67.1% | 2nd Prediction=thumb        | 2nd Confidence= 21.9%
# ✅ Image 10: Label=thumb        | Prediction=thumb        | Confidence= 36.9% | 2nd Prediction=middle       | 2nd Confidence= 33.2%
# ✅ Image 11: Label=thumb        | Prediction=thumb        | Confidence= 65.5% | 2nd Prediction=index        | 2nd Confidence= 25.0%
# ✅ Image 12: Label=index        | Prediction=index        | Confidence= 42.0% | 2nd Prediction=middle       | 2nd Confidence= 37.1%
# ❌ Image 13: Label=index        | Prediction=middle       | Confidence= 65.7% | 2nd Prediction=index        | 2nd Confidence= 33.8%
# ❌ Image 14: Label=thumb        | Prediction=middle       | Confidence= 47.7% | 2nd Prediction=thumb        | 2nd Confidence= 28.6%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 56.6% | 2nd Prediction=middle       | 2nd Confidence= 43.1%
# ✅ Image 16: Label=thumb        | Prediction=thumb        | Confidence= 52.9% | 2nd Prediction=index        | 2nd Confidence= 24.5%
# ✅ Image 17: Label=thumb        | Prediction=thumb        | Confidence= 99.9% | 2nd Prediction=index        | 2nd Confidence=  0.1%
# ✅ Image 18: Label=middle       | Prediction=middle       | Confidence= 54.9% | 2nd Prediction=index        | 2nd Confidence= 44.6%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 98.5% | 2nd Prediction=index        | 2nd Confidence=  0.9%
# ✅ Image 20: Label=middle       | Prediction=middle       | Confidence= 75.7% | 2nd Prediction=index        | 2nd Confidence= 21.2%
#
# ======================================================================================================================================================
# 2026-03-18 16:00:45.181364: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
# Results :
#   - Loss                : 0.6974
#   - Accuracy            : 74.54%
#   - Top-2 Accuracy      : 93.06%
