# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

DATASET_CSV_PATH = DATASET_ROOTDIR_PATH + "_with_labels.csv"
print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring', 'little']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_5_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         23931 non-null  int64
#  1   ImagePath  23931 non-null  str
#  2   Finger     23931 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 561.0 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.98%
# Percentage of Little fingers: 20.01%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    23931 non-null  str
#  1   ImageFormat  23931 non-null  str
#  2   ImageSize    23931 non-null  object
#  3   ImageMode    23931 non-null  str
#  4   Finger       23931 non-null  str
# dtypes: object(1), str(4)
# memory usage: 934.9+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    23931
# Name: count, dtype: int64
# ImageSize
# (96, 96)    23931
# Name: count, dtype: int64
# ImageMode
# RGB    23931
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.98%
# Percentage of Little fingers: 20.01%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Split dataset for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 23931 files belonging to 5 classes.
# Using 19145 files for training.
# 2026-03-19 07:59:40.389898: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-19 07:59:40.389936: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-19 07:59:40.389948: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-19 07:59:40.389985: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-19 07:59:40.389996: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Found 23931 files belonging to 5 classes.
# Using 4786 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 300
#   - Validation batches    : 75
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~19200
#   - Validation samples    : ~4800

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 256

DROPOUT_RATE = 0.3 # medium 
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001 # standard

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES}, {classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(5, softmax)
#
#   - Trainable parameters     : 329,221
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,587,205
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,205 (9.87 MB)
#  Trainable params: 329,221 (1.26 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 120
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/120
# 2026-03-19 07:59:42.861091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4121 - loss: 4.0742 - top2_accuracy: 0.6466
# Epoch 1: val_accuracy improved from None to 0.55453, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - accuracy: 0.4461 - loss: 2.9107 - top2_accuracy: 0.6802 - val_accuracy: 0.5545 - val_loss: 1.4733 - val_top2_accuracy: 0.7727 - learning_rate: 0.0010
# Epoch 2/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4922 - loss: 1.5724 - top2_accuracy: 0.7205
# Epoch 2: val_accuracy improved from 0.55453 to 0.55767, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 70ms/step - accuracy: 0.4974 - loss: 1.4695 - top2_accuracy: 0.7279 - val_accuracy: 0.5577 - val_loss: 1.2163 - val_top2_accuracy: 0.7741 - learning_rate: 0.0010
# Epoch 3/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5113 - loss: 1.2964 - top2_accuracy: 0.7553
# Epoch 3: val_accuracy did not improve from 0.55767
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.5240 - loss: 1.2624 - top2_accuracy: 0.7563 - val_accuracy: 0.5568 - val_loss: 1.1615 - val_top2_accuracy: 0.7737 - learning_rate: 0.0010
# Epoch 4/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5377 - loss: 1.1927 - top2_accuracy: 0.7695
# Epoch 4: val_accuracy did not improve from 0.55767
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.5389 - loss: 1.1922 - top2_accuracy: 0.7654 - val_accuracy: 0.5510 - val_loss: 1.1546 - val_top2_accuracy: 0.7714 - learning_rate: 0.0010
# Epoch 5/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5400 - loss: 1.1798 - top2_accuracy: 0.7689
# Epoch 5: val_accuracy did not improve from 0.55767
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 23s 76ms/step - accuracy: 0.5410 - loss: 1.1829 - top2_accuracy: 0.7642 - val_accuracy: 0.5453 - val_loss: 1.1701 - val_top2_accuracy: 0.7677 - learning_rate: 0.0010
# Epoch 6/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5419 - loss: 1.1785 - top2_accuracy: 0.7735
# Epoch 6: val_accuracy improved from 0.55767 to 0.57731, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 70ms/step - accuracy: 0.5441 - loss: 1.1781 - top2_accuracy: 0.7714 - val_accuracy: 0.5773 - val_loss: 1.1168 - val_top2_accuracy: 0.7927 - learning_rate: 0.0010
# Epoch 7/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5392 - loss: 1.1768 - top2_accuracy: 0.7715
# Epoch 7: val_accuracy did not improve from 0.57731
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.5383 - loss: 1.1791 - top2_accuracy: 0.7688 - val_accuracy: 0.5683 - val_loss: 1.1396 - val_top2_accuracy: 0.7879 - learning_rate: 0.0010
# Epoch 8/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5446 - loss: 1.1731 - top2_accuracy: 0.7733
# Epoch 8: val_accuracy improved from 0.57731 to 0.58776, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 74ms/step - accuracy: 0.5427 - loss: 1.1778 - top2_accuracy: 0.7678 - val_accuracy: 0.5878 - val_loss: 1.1030 - val_top2_accuracy: 0.7977 - learning_rate: 0.0010
# Epoch 9/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5496 - loss: 1.1652 - top2_accuracy: 0.7773
# Epoch 9: val_accuracy did not improve from 0.58776
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - accuracy: 0
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.5584 - loss: 1.1330 - top2_accuracy: 0.7841 - val_accuracy: 0.6028 - val_loss: 1.0565 - val_top2_accuracy: 0.8115 - learning_rate: 5.0000e-04
# Epoch 20/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5682 - loss: 1.1245 - top2_accuracy: 0.7884
# Epoch 20: val_accuracy did not improve from 0.61283
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5630 - loss: 1.1318 - top2_accuracy: 0.7851 - val_accuracy: 0.6032 - val_loss: 1.0544 - val_top2_accuracy: 0.8136 - learning_rate: 5.0000e-04
# Epoch 21/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5614 - loss: 1.1196 - top2_accuracy: 0.7879
# Epoch 21: val_accuracy did not improve from 0.61283
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5588 - loss: 1.1316 - top2_accuracy: 0.7813 - val_accuracy: 0.6038 - val_loss: 1.0632 - val_top2_accuracy: 0.8113 - learning_rate: 5.0000e-04
# Epoch 22/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5634 - loss: 1.1254 - top2_accuracy: 0.7877
# Epoch 22: val_accuracy did not improve from 0.61283
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.5616 - loss: 1.1325 - top2_accuracy: 0.7804 - val_accuracy: 0.6053 - val_loss: 1.0570 - val_top2_accuracy: 0.8109 - learning_rate: 5.0000e-04
# Epoch 23/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5538 - loss: 1.1392 - top2_accuracy: 0.7865
# Epoch 23: val_accuracy did not improve from 0.61283
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 455s 2s/step - accuracy: 0.5562 - loss: 1.1403 - top2_accuracy: 0.7832 - val_accuracy: 0.6049 - val_loss: 1.0618 - val_top2_accuracy: 0.8086 - learning_rate: 5.0000e-04
# Epoch 24/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5659 - loss: 1.1336 - top2_accuracy: 0.7865
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_accuracy did not improve from 0.61283
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - accuracy: 0.5612 - loss: 1.1389 - top2_accuracy: 0.7812 - val_accuracy: 0.6038 - val_loss: 1.0615 - val_top2_accuracy: 0.8067 - learning_rate: 5.0000e-04
# Epoch 25/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5701 - loss: 1.1213 - top2_accuracy: 0.7882
# Epoch 25: val_accuracy improved from 0.61283 to 0.61763, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 25: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5677 - loss: 1.1213 - top2_accuracy: 0.7882 - val_accuracy: 0.6176 - val_loss: 1.0465 - val_top2_accuracy: 0.8163 - learning_rate: 2.5000e-04
# Epoch 26/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5703 - loss: 1.1118 - top2_accuracy: 0.7945
# Epoch 26: val_accuracy did not improve from 0.61763
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5687 - loss: 1.1140 - top2_accuracy: 0.7910 - val_accuracy: 0.6118 - val_loss: 1.0474 - val_top2_accuracy: 0.8193 - learning_rate: 2.5000e-04
# Epoch 27/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5650 - loss: 1.1067 - top2_accuracy: 0.7929
# Epoch 27: val_accuracy did not improve from 0.61763
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - accuracy: 0.5657 - loss: 1.1091 - top2_accuracy: 0.7890 - val_accuracy: 0.6055 - val_loss: 1.0468 - val_top2_accuracy: 0.8149 - learning_rate: 2.5000e-04
# Epoch 28/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5727 - loss: 1.1008 - top2_accuracy: 0.7945
# Epoch 28: val_accuracy did not improve from 0.61763
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - accuracy: 0.5690 - loss: 1.1049 - top2_accuracy: 0.7896 - val_accuracy: 0.6087 - val_loss: 1.0449 - val_top2_accuracy: 0.8172 - learning_rate: 2.5000e-04
# Epoch 29/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5691 - loss: 1.1024 - top2_accuracy: 0.7954
# Epoch 29: val_accuracy did not improve from 0.61763
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step
120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5790 - loss: 1.0899 - top2_accuracy: 0.7987
# Epoch 39: val_accuracy did not improve from 0.62453
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 75ms/step - accuracy: 0.5788 - loss: 1.0932 - top2_accuracy: 0.7957 - val_accuracy: 0.6233 - val_loss: 1.0188 - val_top2_accuracy: 0.8257 - learning_rate: 1.2500e-04
# Epoch 40/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5844 - loss: 1.0814 - top2_accuracy: 0.7971
# Epoch 40: val_accuracy did not improve from 0.62453
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.5802 - loss: 1.0901 - top2_accuracy: 0.7945 - val_accuracy: 0.6241 - val_loss: 1.0201 - val_top2_accuracy: 0.8255 - learning_rate: 1.2500e-04
# Epoch 41/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5783 - loss: 1.0855 - top2_accuracy: 0.8005
# Epoch 41: val_accuracy improved from 0.62453 to 0.62641, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 75ms/step - accuracy: 0.5779 - loss: 1.0919 - top2_accuracy: 0.7949 - val_accuracy: 0.6264 - val_loss: 1.0195 - val_top2_accuracy: 0.8245 - learning_rate: 1.2500e-04
# Epoch 42/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5845 - loss: 1.0799 - top2_accuracy: 0.8024
# Epoch 42: val_accuracy improved from 0.62641 to 0.62662, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 42: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 74ms/step - accuracy: 0.5777 - loss: 1.0904 - top2_accuracy: 0.7984 - val_accuracy: 0.6266 - val_loss: 1.0186 - val_top2_accuracy: 0.8241 - learning_rate: 1.2500e-04
# Epoch 43/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5836 - loss: 1.0788 - top2_accuracy: 0.8053
# Epoch 43: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5814 - loss: 1.0854 - top2_accuracy: 0.7997 - val_accuracy: 0.6260 - val_loss: 1.0165 - val_top2_accuracy: 0.8249 - learning_rate: 1.2500e-04
# Epoch 44/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5828 - loss: 1.0802 - top2_accuracy: 0.7950
# Epoch 44: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5816 - loss: 1.0885 - top2_accuracy: 0.7927 - val_accuracy: 0.6262 - val_loss: 1.0165 - val_top2_accuracy: 0.8262 - learning_rate: 1.2500e-04
# Epoch 45/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5774 - loss: 1.0787 - top2_accuracy: 0.8019
# Epoch 45: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - accuracy: 0.5763 - loss: 1.0879 - top2_accuracy: 0.7982 - val_accuracy: 0.6245 - val_loss: 1.0183 - val_top2_accuracy: 0.8249 - learning_rate: 1.2500e-04
# Epoch 46/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5853 - loss: 1.0849 - top2_accuracy: 0.8022
# Epoch 46: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.5785 - loss: 1.0882 - top2_accuracy: 0.7959 - val_accuracy: 0.6254 - val_loss: 1.0187 - val_top2_accuracy: 0.8243 - learning_rate: 1.2500e-04
# Epoch 47/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5797 - loss: 1.0805 - top2_accuracy: 0.7981
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 47: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.5798 - loss: 1.0847 - top2_accuracy: 0.7958 - val_accuracy: 0.6233 - val_loss: 1.0208 - val_top2_accuracy: 0.8257 - learning_rate: 1.2500e-04
# Epoch 48/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5852 - loss: 1.0774 - top2_accuracy: 0.8055
# Epoch 48: val_accuracy did not improve from 0.62662
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - accuracy: 0.5840 - loss: 1.0806 - top2_accuracy: 0.8016 - val_accuracy: 0.6252 - val_loss: 1.0113 - val_top2_accuracy: 0.8299 - learning_rate: 6.2500e-05
# Epoch 49/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.
val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 23s 78ms/step - accuracy: 0.5842 - loss: 1.0739 - top2_accuracy: 0.7990 - val_accuracy: 0.6277 - val_loss: 1.0039 - val_top2_accuracy: 0.8314 - learning_rate: 6.2500e-05
# Epoch 71/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5831 - loss: 1.0771 - top2_accuracy: 0.8000
# Epoch 71: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - accuracy: 0.5817 - loss: 1.0816 - top2_accuracy: 0.7971 - val_accuracy: 0.6252 - val_loss: 1.0045 - val_top2_accuracy: 0.8314 - learning_rate: 6.2500e-05
# Epoch 72/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5840 - loss: 1.0753 - top2_accuracy: 0.7978
# Epoch 72: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 22s 75ms/step - accuracy: 0.5834 - loss: 1.0801 - top2_accuracy: 0.7982 - val_accuracy: 0.6272 - val_loss: 1.0052 - val_top2_accuracy: 0.8297 - learning_rate: 6.2500e-05
# Epoch 73/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5928 - loss: 1.0662 - top2_accuracy: 0.8053
# Epoch 73: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - accuracy: 0.5835 - loss: 1.0760 - top2_accuracy: 0.7999 - val_accuracy: 0.6270 - val_loss: 1.0038 - val_top2_accuracy: 0.8293 - learning_rate: 6.2500e-05
# Epoch 74/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5864 - loss: 1.0688 - top2_accuracy: 0.8089
# Epoch 74: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 74: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - accuracy: 0.5823 - loss: 1.0765 - top2_accuracy: 0.8031 - val_accuracy: 0.6275 - val_loss: 1.0040 - val_top2_accuracy: 0.8310 - learning_rate: 6.2500e-05
# Epoch 75/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5828 - loss: 1.0739 - top2_accuracy: 0.8039
# Epoch 75: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - accuracy: 0.5819 - loss: 1.0750 - top2_accuracy: 0.8028 - val_accuracy: 0.6258 - val_loss: 1.0040 - val_top2_accuracy: 0.8285 - learning_rate: 3.1250e-05
# Epoch 76/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5901 - loss: 1.0692 - top2_accuracy: 0.8055
# Epoch 76: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.5876 - loss: 1.0727 - top2_accuracy: 0.8008 - val_accuracy: 0.6249 - val_loss: 1.0034 - val_top2_accuracy: 0.8301 - learning_rate: 3.1250e-05
# Epoch 77/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5917 - loss: 1.0637 - top2_accuracy: 0.8066
# Epoch 77: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 24s 80ms/step - accuracy: 0.5873 - loss: 1.0681 - top2_accuracy: 0.8053 - val_accuracy: 0.6260 - val_loss: 1.0029 - val_top2_accuracy: 0.8312 - learning_rate: 3.1250e-05
# Epoch 78/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5971 - loss: 1.0653 - top2_accuracy: 0.8049
# Epoch 78: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 24s 80ms/step - accuracy: 0.5900 - loss: 1.0686 - top2_accuracy: 0.8046 - val_accuracy: 0.6256 - val_loss: 1.0022 - val_top2_accuracy: 0.8295 - learning_rate: 3.1250e-05
# Epoch 79/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5892 - loss: 1.0667 - top2_accuracy: 0.8074
# Epoch 79: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 23s 78ms/step - accuracy: 0.5847 - loss: 1.0738 - top2_accuracy: 0.8057 - val_accuracy: 0.6268 - val_loss: 1.0021 - val_top2_accuracy: 0.8293 - learning_rate: 3.1250e-05
# Epoch 80/120
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5884 - loss: 1.0660 - top2_accuracy: 0.8048
# Epoch 80: val_accuracy did not improve from 0.62871
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 23s 78ms/step - accuracy: 0.5838 - loss: 1.0758 - top2_accuracy: 0.8013 - val_accuracy: 0.6272 - val_loss: 1.0041 - val_top2_accuracy: 0.8276 - learning_rate: 3.1250e-05
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 50.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 80
#    Best val_accuracy : 62.87% (epoch 50)
#
# ⚠️  Accuracy of 62.9% is below 70%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=middle       | Prediction=middle       | Confidence= 52.1% | 2nd Prediction=ring         | 2nd Confidence= 28.9%
# ❌ Image 2: Label=middle       | Prediction=index        | Confidence= 64.2% | 2nd Prediction=middle       | 2nd Confidence= 19.7%
# ✅ Image 3: Label=little       | Prediction=little       | Confidence= 58.4% | 2nd Prediction=ring         | 2nd Confidence= 23.9%
# ❌ Image 4: Label=middle       | Prediction=index        | Confidence= 61.5% | 2nd Prediction=thumb        | 2nd Confidence= 17.3%
# ❌ Image 5: Label=thumb        | Prediction=middle       | Confidence= 41.1% | 2nd Prediction=thumb        | 2nd Confidence= 24.2%
# ✅ Image 6: Label=ring         | Prediction=ring         | Confidence= 49.5% | 2nd Prediction=middle       | 2nd Confidence= 29.9%
# ❌ Image 7: Label=little       | Prediction=ring         | Confidence= 36.0% | 2nd Prediction=middle       | 2nd Confidence= 24.5%
# ✅ Image 8: Label=thumb        | Prediction=thumb        | Confidence= 90.3% | 2nd Prediction=middle       | 2nd Confidence=  3.6%
# ✅ Image 9: Label=little       | Prediction=little       | Confidence= 61.7% | 2nd Prediction=ring         | 2nd Confidence= 16.8%
# ✅ Image 10: Label=middle       | Prediction=middle       | Confidence= 32.7% | 2nd Prediction=index        | 2nd Confidence= 26.0%
# ✅ Image 11: Label=thumb        | Prediction=thumb        | Confidence= 80.3% | 2nd Prediction=index        | 2nd Confidence= 16.0%
# ✅ Image 12: Label=middle       | Prediction=middle       | Confidence= 43.6% | 2nd Prediction=index        | 2nd Confidence= 39.2%
# ✅ Image 13: Label=little       | Prediction=little       | Confidence= 65.7% | 2nd Prediction=index        | 2nd Confidence= 13.6%
# ✅ Image 14: Label=little       | Prediction=little       | Confidence= 34.4% | 2nd Prediction=index        | 2nd Confidence= 31.6%
# ✅ Image 15: Label=little       | Prediction=little       | Confidence= 51.1% | 2nd Prediction=ring         | 2nd Confidence= 22.2%
# ✅ Image 16: Label=little       | Prediction=little       | Confidence= 38.1% | 2nd Prediction=ring         | 2nd Confidence= 22.0%
# ✅ Image 17: Label=index        | Prediction=index        | Confidence= 34.3% | 2nd Prediction=little       | 2nd Confidence= 31.7%
# ✅ Image 18: Label=ring         | Prediction=ring         | Confidence= 54.9% | 2nd Prediction=little       | 2nd Confidence= 25.8%
# ✅ Image 19: Label=little       | Prediction=little       | Confidence= 75.2% | 2nd Prediction=index        | 2nd Confidence= 12.9%
# ❌ Image 20: Label=little       | Prediction=middle       | Confidence= 38.2% | 2nd Prediction=index        | 2nd Confidence= 29.1%
#
# ======================================================================================================================================================
# 2026-03-19 08:36:38.271302: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 1.0097
#   - Accuracy            : 62.87%
#   - Top-2 Accuracy      : 83.08%
