# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "ResNet50V2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "ResNet50V2":
    from tensorflow.keras.applications import ResNet50V2
elif MobileNet_version == "ResNet101V2":
    from tensorflow.keras.applications import ResNet101V2
elif MobileNet_version == "ResNet152V2":
    from tensorflow.keras.applications import ResNet152V2
else:
    print("Unknown MobileNet version name")
    exit(0)
from tensorflow.keras.applications.resnet_v2 import preprocess_input

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : ResNet50V2
# Fingerprint model name : ResNet50V2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration
# True : consider both "Real" and "Altered" subdirectories
# False : consider only "Real" subdirectory (smaller dataset, faster processing)
CONSIDER_FULL_DATASET = False

if CONSIDER_FULL_DATASET:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")
else:
    DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized" 
    print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

    DATASET_CSV_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv"
    print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Real_Sanitized_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index']
# Adjusted fingerprint model name : ResNet50V2_FingerPrint_Model_2_classes

# %% [markdown]
# ## Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         6000 non-null   int64
#  1   ImagePath  6000 non-null   str
#  2   Finger     6000 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 140.8 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    2400 non-null   str
#  1   ImageFormat  2400 non-null   str
#  2   ImageSize    2400 non-null   object
#  3   ImageMode    2400 non-null   str
#  4   Finger       2400 non-null   str
# dtypes: object(1), str(4)
# memory usage: 93.9+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    2400
# Name: count, dtype: int64
# ImageSize
# (96, 96)    2400
# Name: count, dtype: int64
# ImageMode
# RGB    2400
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 50.00%
# Percentage of Index fingers: 50.00%
# Percentage of Middle fingers: 0.00%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Define datasets for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 32
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.3
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 2400 files belonging to 2 classes.
# Using 1680 files for training.
# Found 2400 files belonging to 2 classes.
# Using 720 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index']
#   - Validation Dataset Classes           : ['thumb', 'index']
#   - ✅ Number of correct classes : 2
#
#   - Training batches    : 53
#   - Validation batches    : 23
#   - Batch size            : 32
#   - Image size            : (96, 96)
#
#   - Training samples      : ~1696
#   - Validation samples    : ~736
# 2026-03-18 17:37:05.625141: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-18 17:37:05.625352: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-18 17:37:05.625377: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-18 17:37:05.625641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-18 17:37:05.625661: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : no augmentation, normalisation and shuffling (training only)

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset normalisation required for MobileNet

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # Normalisation MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Construct FingerPrint Model : Pre-trained MobileNetV2 + finger classifier

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 512

DROPOUT_RATE = 0.3
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "ResNet50V2":
    base_model = ResNet50V2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "ResNet101V2":
    base_model = ResNet101V2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "ResNet152V2":
    base_model = ResNet152V2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading ResNet50V2 ...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# ✅ ResNet50V2 model loaded !
#
# 📋 Model Structure - ResNet50V2 :
#   - Architecture   : ResNet50V2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 2048)
#   - Number of layers : 191
#
#   - Total number of parameters : 23,564,800
#   - Memory size (approx.) : 89.9 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES}, {classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    191 layers not trainable
#
# Classification activation function for 2 classes : sigmoid
# ✅ Model compiled !
#
# 📊 Architecture ResNet50V2 based FingerPrint:
#   Input(96, 96, 3) → ResNet50V2 → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(2, sigmoid)
#
#   - Trainable parameters     : 525,058
#   - Non-trainable parameters : 23,564,800
#   - Total                    : 24,089,858
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 ResNet50V2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. conv1_pad                                | Output: (None, 102, 102, 3)            | Trainable: False
#     3. conv1_conv                               | Output: (None, 48, 48, 64)             | Trainable: False
#     4. pool1_pad                                | Output: (None, 50, 50, 64)             | Trainable: False
#     5. pool1_pool                               | Output: (None, 24, 24, 64)             | Trainable: False
#     6. conv2_block1_preact_bn                   | Output: (None, 24, 24, 64)             | Trainable: False
#     7. conv2_block1_preact_relu                 | Output: (None, 24, 24, 64)             | Trainable: False
#     8. conv2_block1_1_conv                      | Output: (None, 24, 24, 64)             | Trainable: False
#     9. conv2_block1_1_bn                        | Output: (None, 24, 24, 64)             | Trainable: False
#    10. conv2_block1_1_relu                      | Output: (None, 24, 24, 64)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   182. conv5_block3_1_relu                      | Output: (None, 3, 3, 512)              | Trainable: False
#   183. conv5_block3_2_pad                       | Output: (None, 5, 5, 512)              | Trainable: False
#   184. conv5_block3_2_conv                      | Output: (None, 3, 3, 512)              | Trainable: False
#   185. conv5_block3_2_bn                        | Output: (None, 3, 3, 512)              | Trainable: False
#   186. conv5_block3_2_relu                      | Output: (None, 3, 3, 512)              | Trainable: False
#   187. conv5_block3_3_conv                      | Output: (None, 3, 3, 2048)             | Trainable: False
#   188. conv5_block3_out                         | Output: (None, 3, 3, 2048)             | Trainable: False
#   189. post_bn                                  | Output: (None, 3, 3, 2048)             | Trainable: False
#   190. post_relu                                | Output: (None, 3, 3, 2048)             | Trainable: False
#   191. avg_pool                                 | Output: (None, 2048)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing ResNet50V2 FingerPrint model architecture
# ============================================================
# Model: "ResNet50V2_FingerPrint_Model_2_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50v2 (Functional)         │ (None, 2048)           │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,089,858 (91.90 MB)
#  Trainable params: 525,058 (2.00 MB)
#  Non-trainable params: 23,564,800 (89.89 MB)

# %% [markdown]
# ## Training FingerPrint model

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 150
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen model training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 150
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/150
# 2026-03-18 16:46:56.931439: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3610 - loss: 5.2838 - top2_accuracy: 0.5823
# Epoch 1: val_accuracy improved from None to 0.55167, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.4129 - loss: 4.2409 - top2_accuracy: 0.6319 - val_accuracy: 0.5517 - val_loss: 2.3238 - val_top2_accuracy: 0.7617 - learning_rate: 0.0010
# Epoch 2/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4759 - loss: 2.6172 - top2_accuracy: 0.7144
# Epoch 2: val_accuracy improved from 0.55167 to 0.57000, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.4724 - loss: 2.4811 - top2_accuracy: 0.7024 - val_accuracy: 0.5700 - val_loss: 1.6968 - val_top2_accuracy: 0.8039 - learning_rate: 0.0010
# Epoch 3/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4782 - loss: 2.0505 - top2_accuracy: 0.6996
# Epoch 3: val_accuracy did not improve from 0.57000
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.4764 - loss: 1.9579 - top2_accuracy: 0.7060 - val_accuracy: 0.5639 - val_loss: 1.4921 - val_top2_accuracy: 0.7739 - learning_rate: 0.0010
# Epoch 4/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4907 - loss: 1.7175 - top2_accuracy: 0.7194
# Epoch 4: val_accuracy improved from 0.57000 to 0.58889, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.4905 - loss: 1.6657 - top2_accuracy: 0.7179 - val_accuracy: 0.5889 - val_loss: 1.2943 - val_top2_accuracy: 0.7972 - learning_rate: 0.0010
# Epoch 5/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5090 - loss: 1.5030 - top2_accuracy: 0.7351
# Epoch 5: val_accuracy improved from 0.58889 to 0.59556, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5079 - loss: 1.4839 - top2_accuracy: 0.7336 - val_accuracy: 0.5956 - val_loss: 1.2084 - val_top2_accuracy: 0.8122 - learning_rate: 0.0010
# Epoch 6/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5233 - loss: 1.3796 - top2_accuracy: 0.7364
# Epoch 6: val_accuracy improved from 0.59556 to 0.59667, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.5138 - loss: 1.3738 - top2_accuracy: 0.7364 - val_accuracy: 0.5967 - val_loss: 1.1738 - val_top2_accuracy: 0.8078 - learning_rate: 0.0010
# Epoch 7/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5139 - loss: 1.3470 - top2_accuracy: 0.7317
# Epoch 7: val_accuracy did not improve from 0.59667
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5171 - loss: 1.3301 - top2_accuracy: 0.7402 - val_accuracy: 0.5883 - val_loss: 1.1433 - val_top2_accuracy: 0.8056 - learning_rate: 0.0010
# Epoch 8/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5371 - loss: 1.2766 - top2_accuracy: 0.7553
# Epoch 8: val_accuracy improved from 0.59667 to 0.59722, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - accuracy: 0.5295 - loss: 1.2735 - top2_accuracy: 0.7548 - val_accuracy: 0.5972 - val_loss: 1.1195 - val_top2_accuracy: 0.8072 - learning_rate: 0.0010
# Epoch 9/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5561 - loss: 1.2219 - top2_accuracy: 0.7667
# Epoch 9: val_accuracy did not improve from 0.59722
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.5498 - loss: 1.2226 - top2_accuracy: 0.7655 - val_accuracy: 0.5889 - val_loss: 1.1187 - val_top2_accuracy: 0.7994 - learning_rate: 0.0010
# Epoch 10/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5402 - loss: 1.2210 - top2_accuracy: 0.7699
# Epoch 10: val_accuracy did not improve from 0.59722
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.5410 - loss: 1.2168 - top2_accuracy: 0.7710 - val_accuracy: 0.5911 - val_loss: 1.1138 - val_top2_accuracy: 0.7994 - learning_rate: 0.0010
# Epoch 11/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5426 - loss: 1.1963 - top2_accuracy: 0.7596
# Epoch 11: val_accuracy did not improve from 0.59722
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.5390 - loss: 1.1972 - top2_accuracy: 0.7633 - val_accuracy: 0.5917 - val_loss: 1.0975 - val_top2_accuracy: 0.8128 - learning_rate: 0.0010
# Epoch 12/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5511 - loss: 1.1792 - top2_accuracy: 0.7634
# Epoch 12: val_accuracy improved from 0.59722 to 0.59778, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - accuracy: 0.5483 - loss: 1.1894 - top2_accuracy: 0.7645 - val_accuracy: 0.5978 - val_loss: 1.0973 - val_top2_accuracy: 0.8083 - learning_rate: 0.0010
# Epoch 13/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5417 - loss: 1.1800 - top2_accuracy: 0.7726
# Epoch 13: val_accuracy improved from 0.59778 to 0.60333, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 13: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.5386 - loss: 1.1869 - top2_accuracy: 0.7719 - val_accuracy: 0.6033 - val_loss: 1.0990 - val_top2_accuracy: 0.8061 - learning_rate: 0.0010
# Epoch 14/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5567 - loss: 1.1732 - top2_accuracy: 0.7699
# Epoch 14: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.5474 - loss: 1.1855 - top2_accuracy: 0.7648 - val_accuracy: 0.6033 - val_loss: 1.0871 - val_top2_accuracy: 0.8150 - learning_rate: 0.0010
# Epoch 15/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5551 - loss: 1.1493 - top2_accuracy: 0.7809
# Epoch 15: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.5476 - loss: 1.1600 - top2_accuracy: 0.7731 - val_accuracy: 0.5922 - val_loss: 1.1218 - val_top2_accuracy: 0.8028 - learning_rate: 0.0010
# Epoch 16/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5566 - loss: 1.1783 - top2_accuracy: 0.7571
# Epoch 16: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5500 - loss: 1.1705 - top2_accuracy: 0.7650 - val_accuracy: 0.5944 - val_loss: 1.0911 - val_top2_accuracy: 0.8061 - learning_rate: 0.0010
# Epoch 17/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5635 - loss: 1.1417 - top2_accuracy: 0.7834
# Epoch 17: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.5590 - loss: 1.1477 - top2_accuracy: 0.7790 - val_accuracy: 0.5911 - val_loss: 1.1025 - val_top2_accuracy: 0.8072 - learning_rate: 0.0010
# Epoch 18/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5594 - loss: 1.1627 - top2_accuracy: 0.7840
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 18: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.5510 - loss: 1.1658 - top2_accuracy: 0.7783 - val_accuracy: 0.5967 - val_loss: 1.0923 - val_top2_accuracy: 0.8028 - learning_rate: 0.0010
# Epoch 19/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5553 - loss: 1.1346 - top2_accuracy: 0.7867
# Epoch 19: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5557 - loss: 1.1338 - top2_accuracy: 0.7855 - val_accuracy: 0.6017 - val_loss: 1.0916 - val_top2_accuracy: 0.8083 - learning_rate: 5.0000e-04
# Epoch 20/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5674 - loss: 1.1176 - top2_accuracy: 0.7927
# Epoch 20: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5626 - loss: 1.1258 - top2_accuracy: 0.7931 - val_accuracy: 0.6033 - val_loss: 1.0737 - val_top2_accuracy: 0.8161 - learning_rate: 5.0000e-04
# Epoch 21/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5642 - loss: 1.1221 - top2_accuracy: 0.7848
# Epoch 21: val_accuracy did not improve from 0.60333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5564 - loss: 1.1257 - top2_accuracy: 0.7879 - val_accuracy: 0.5961 - val_loss: 1.0839 - val_top2_accuracy: 0.8100 - learning_rate: 5.0000e-04
# Epoch 22/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5712 - loss: 1.1113 - top2_accuracy: 0.7920
# Epoch 22: val_accuracy improved from 0.60333 to 0.60444, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.5729 - loss: 1.1088 - top2_accuracy: 0.7933 - val_accuracy: 0.6044 - val_loss: 1.0665 - val_top2_accuracy: 0.8222 - learning_rate: 5.0000e-04
# Epoch 23/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5904 - loss: 1.0980 - top2_accuracy: 0.8001
# Epoch 23: val_accuracy did not improve from 0.60444
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5840 - loss: 1.1064 - top2_accuracy: 0.7979 - val_accuracy: 0.6017 - val_loss: 1.0671 - val_top2_accuracy: 0.8156 - learning_rate: 5.0000e-04
# Epoch 24/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5788 - loss: 1.1064 - top2_accuracy: 0.7913
# Epoch 24: val_accuracy did not improve from 0.60444
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.5719 - loss: 1.1178 - top2_accuracy: 0.7902 - val_accuracy: 0.6039 - val_loss: 1.0743 - val_top2_accuracy: 0.8117 - learning_rate: 5.0000e-04
# Epoch 25/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5681 - loss: 1.1024 - top2_accuracy: 0.7879
# Epoch 25: val_accuracy did not improve from 0.60444
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.5650 - loss: 1.1145 - top2_accuracy: 0.7893 - val_accuracy: 0.5922 - val_loss: 1.0782 - val_top2_accuracy: 0.8156 - learning_rate: 5.0000e-04
# Epoch 26/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5775 - loss: 1.1171 - top2_accuracy: 0.7846
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 26: val_accuracy did not improve from 0.60444
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5764 - loss: 1.1083 - top2_accuracy: 0.7938 - val_accuracy: 0.6011 - val_loss: 1.0670 - val_top2_accuracy: 0.8183 - learning_rate: 5.0000e-04
# Epoch 27/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5807 - loss: 1.0997 - top2_accuracy: 0.7986
# Epoch 27: val_accuracy improved from 0.60444 to 0.61222, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.5821 - loss: 1.0922 - top2_accuracy: 0.8005 - val_accuracy: 0.6122 - val_loss: 1.0501 - val_top2_accuracy: 0.8250 - learning_rate: 2.5000e-04
# Epoch 28/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5832 - loss: 1.0880 - top2_accuracy: 0.7976
# Epoch 28: val_accuracy improved from 0.61222 to 0.61667, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 28: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.5864 - loss: 1.0897 - top2_accuracy: 0.8036 - val_accuracy: 0.6167 - val_loss: 1.0535 - val_top2_accuracy: 0.8194 - learning_rate: 2.5000e-04
# Epoch 29/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 1.0743 - top2_accuracy: 0.8049
# Epoch 29: val_accuracy did not improve from 0.61667
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.5955 - loss: 1.0815 - top2_accuracy: 0.8043 - val_accuracy: 0.6133 - val_loss: 1.0473 - val_top2_accuracy: 0.8217 - learning_rate: 2.5000e-04
# Epoch 30/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5677 - loss: 1.0861 - top2_accuracy: 0.7945
# Epoch 30: val_accuracy improved from 0.61667 to 0.61722, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5743 - loss: 1.0905 - top2_accuracy: 0.7990 - val_accuracy: 0.6172 - val_loss: 1.0425 - val_top2_accuracy: 0.8178 - learning_rate: 2.5000e-04
# Epoch 31/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 1.0697 - top2_accuracy: 0.8071
# Epoch 31: val_accuracy did not improve from 0.61722
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.5888 - loss: 1.0742 - top2_accuracy: 0.8043 - val_accuracy: 0.6078 - val_loss: 1.0466 - val_top2_accuracy: 0.8189 - learning_rate: 2.5000e-04
# Epoch 32/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5820 - loss: 1.0771 - top2_accuracy: 0.7916
# Epoch 32: val_accuracy improved from 0.61722 to 0.62056, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 32: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5805 - loss: 1.0791 - top2_accuracy: 0.7960 - val_accuracy: 0.6206 - val_loss: 1.0393 - val_top2_accuracy: 0.8244 - learning_rate: 2.5000e-04
# Epoch 33/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5836 - loss: 1.0677 - top2_accuracy: 0.8036
# Epoch 33: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.5879 - loss: 1.0759 - top2_accuracy: 0.7974 - val_accuracy: 0.6011 - val_loss: 1.0519 - val_top2_accuracy: 0.8167 - learning_rate: 2.5000e-04
# Epoch 34/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5912 - loss: 1.0680 - top2_accuracy: 0.8012
# Epoch 34: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.5974 - loss: 1.0717 - top2_accuracy: 0.8026 - val_accuracy: 0.6100 - val_loss: 1.0454 - val_top2_accuracy: 0.8144 - learning_rate: 2.5000e-04
# Epoch 35/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5867 - loss: 1.0782 - top2_accuracy: 0.7936
# Epoch 35: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5862 - loss: 1.0778 - top2_accuracy: 0.7988 - val_accuracy: 0.6128 - val_loss: 1.0395 - val_top2_accuracy: 0.8289 - learning_rate: 2.5000e-04
# Epoch 36/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5962 - loss: 1.0647 - top2_accuracy: 0.8022
# Epoch 36: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5950 - loss: 1.0676 - top2_accuracy: 0.8055 - val_accuracy: 0.6100 - val_loss: 1.0336 - val_top2_accuracy: 0.8239 - learning_rate: 2.5000e-04
# Epoch 37/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5819 - loss: 1.0825 - top2_accuracy: 0.8091
# Epoch 37: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5895 - loss: 1.0832 - top2_accuracy: 0.8064 - val_accuracy: 0.6122 - val_loss: 1.0374 - val_top2_accuracy: 0.8194 - learning_rate: 2.5000e-04
# Epoch 38/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5920 - loss: 1.0777 - top2_accuracy: 0.8063
# Epoch 38: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5886 - loss: 1.0767 - top2_accuracy: 0.8052 - val_accuracy: 0.6172 - val_loss: 1.0370 - val_top2_accuracy: 0.8228 - learning_rate: 2.5000e-04
# Epoch 39/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5966 - loss: 1.0744 - top2_accuracy: 0.7986
# Epoch 39: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5979 - loss: 1.0736 - top2_accuracy: 0.8005 - val_accuracy: 0.6167 - val_loss: 1.0323 - val_top2_accuracy: 0.8283 - learning_rate: 2.5000e-04
# Epoch 40/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5868 - loss: 1.0690 - top2_accuracy: 0.7973
# Epoch 40: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.5876 - loss: 1.0734 - top2_accuracy: 0.8031 - val_accuracy: 0.6106 - val_loss: 1.0411 - val_top2_accuracy: 0.8200 - learning_rate: 2.5000e-04
# Epoch 41/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5887 - loss: 1.0664 - top2_accuracy: 0.7979
# Epoch 41: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5955 - loss: 1.0636 - top2_accuracy: 0.8038 - val_accuracy: 0.6100 - val_loss: 1.0434 - val_top2_accuracy: 0.8206 - learning_rate: 2.5000e-04
# Epoch 42/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5885 - loss: 1.0714 - top2_accuracy: 0.8018
# Epoch 42: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5883 - loss: 1.0762 - top2_accuracy: 0.8002 - val_accuracy: 0.6167 - val_loss: 1.0310 - val_top2_accuracy: 0.8211 - learning_rate: 2.5000e-04
# Epoch 43/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6002 - loss: 1.0607 - top2_accuracy: 0.8044
# Epoch 43: val_accuracy did not improve from 0.62056
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5936 - loss: 1.0711 - top2_accuracy: 0.7988 - val_accuracy: 0.6161 - val_loss: 1.0385 - val_top2_accuracy: 0.8172 - learning_rate: 2.5000e-04
# Epoch 44/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5847 - loss: 1.0837 - top2_accuracy: 0.8036
# Epoch 44: val_accuracy improved from 0.62056 to 0.62333, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 44: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.5874 - loss: 1.0732 - top2_accuracy: 0.8095 - val_accuracy: 0.6233 - val_loss: 1.0324 - val_top2_accuracy: 0.8283 - learning_rate: 2.5000e-04
# Epoch 45/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5862 - loss: 1.0741 - top2_accuracy: 0.7951
# Epoch 45: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5898 - loss: 1.0649 - top2_accuracy: 0.8029 - val_accuracy: 0.6089 - val_loss: 1.0270 - val_top2_accuracy: 0.8272 - learning_rate: 2.5000e-04
# Epoch 46/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6028 - loss: 1.0520 - top2_accuracy: 0.8132
# Epoch 46: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.5914 - loss: 1.0672 - top2_accuracy: 0.8048 - val_accuracy: 0.6144 - val_loss: 1.0319 - val_top2_accuracy: 0.8200 - learning_rate: 2.5000e-04
# Epoch 47/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5844 - loss: 1.0715 - top2_accuracy: 0.8025
# Epoch 47: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.5898 - loss: 1.0693 - top2_accuracy: 0.7998 - val_accuracy: 0.6106 - val_loss: 1.0283 - val_top2_accuracy: 0.8233 - learning_rate: 2.5000e-04
# Epoch 48/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5961 - loss: 1.0664 - top2_accuracy: 0.8133
# Epoch 48: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.5960 - loss: 1.0656 - top2_accuracy: 0.8107 - val_accuracy: 0.6156 - val_loss: 1.0334 - val_top2_accuracy: 0.8233 - learning_rate: 2.5000e-04
# Epoch 49/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6066 - loss: 1.0556 - top2_accuracy: 0.8091
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 49: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.5974 - loss: 1.0674 - top2_accuracy: 0.8057 - val_accuracy: 0.6083 - val_loss: 1.0381 - val_top2_accuracy: 0.8239 - learning_rate: 2.5000e-04
# Epoch 50/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6043 - loss: 1.0599 - top2_accuracy: 0.8047
# Epoch 50: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.5988 - loss: 1.0609 - top2_accuracy: 0.8048 - val_accuracy: 0.6172 - val_loss: 1.0270 - val_top2_accuracy: 0.8222 - learning_rate: 1.2500e-04
# Epoch 51/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6033 - loss: 1.0518 - top2_accuracy: 0.8044
# Epoch 51: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.6024 - loss: 1.0526 - top2_accuracy: 0.8033 - val_accuracy: 0.6150 - val_loss: 1.0289 - val_top2_accuracy: 0.8194 - learning_rate: 1.2500e-04
# Epoch 52/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6094 - loss: 1.0443 - top2_accuracy: 0.8161
# Epoch 52: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.6048 - loss: 1.0477 - top2_accuracy: 0.8169 - val_accuracy: 0.6200 - val_loss: 1.0184 - val_top2_accuracy: 0.8239 - learning_rate: 1.2500e-04
# Epoch 53/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6154 - loss: 1.0375 - top2_accuracy: 0.8232
# Epoch 53: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6048 - loss: 1.0518 - top2_accuracy: 0.8126 - val_accuracy: 0.6211 - val_loss: 1.0180 - val_top2_accuracy: 0.8239 - learning_rate: 1.2500e-04
# Epoch 54/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6020 - loss: 1.0496 - top2_accuracy: 0.8084
# Epoch 54: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6064 - loss: 1.0525 - top2_accuracy: 0.8069 - val_accuracy: 0.6189 - val_loss: 1.0172 - val_top2_accuracy: 0.8250 - learning_rate: 1.2500e-04
# Epoch 55/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6069 - loss: 1.0409 - top2_accuracy: 0.8150
# Epoch 55: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.6007 - loss: 1.0529 - top2_accuracy: 0.8081 - val_accuracy: 0.6156 - val_loss: 1.0233 - val_top2_accuracy: 0.8228 - learning_rate: 1.2500e-04
# Epoch 56/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6011 - loss: 1.0439 - top2_accuracy: 0.8144
# Epoch 56: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.6019 - loss: 1.0522 - top2_accuracy: 0.8090 - val_accuracy: 0.6228 - val_loss: 1.0176 - val_top2_accuracy: 0.8267 - learning_rate: 1.2500e-04
# Epoch 57/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6066 - loss: 1.0409 - top2_accuracy: 0.8086
# Epoch 57: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5986 - loss: 1.0467 - top2_accuracy: 0.8086 - val_accuracy: 0.6139 - val_loss: 1.0268 - val_top2_accuracy: 0.8178 - learning_rate: 1.2500e-04
# Epoch 58/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6003 - loss: 1.0347 - top2_accuracy: 0.8166
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 58: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.5981 - loss: 1.0456 - top2_accuracy: 0.8129 - val_accuracy: 0.6183 - val_loss: 1.0193 - val_top2_accuracy: 0.8256 - learning_rate: 1.2500e-04
# Epoch 59/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6129 - loss: 1.0412 - top2_accuracy: 0.8212
# Epoch 59: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.6031 - loss: 1.0444 - top2_accuracy: 0.8193 - val_accuracy: 0.6161 - val_loss: 1.0179 - val_top2_accuracy: 0.8283 - learning_rate: 6.2500e-05
# Epoch 60/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6149 - loss: 1.0226 - top2_accuracy: 0.8229
# Epoch 60: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6114 - loss: 1.0397 - top2_accuracy: 0.8124 - val_accuracy: 0.6211 - val_loss: 1.0167 - val_top2_accuracy: 0.8278 - learning_rate: 6.2500e-05
# Epoch 61/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6177 - loss: 1.0344 - top2_accuracy: 0.8167
# Epoch 61: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.6157 - loss: 1.0374 - top2_accuracy: 0.8124 - val_accuracy: 0.6228 - val_loss: 1.0165 - val_top2_accuracy: 0.8283 - learning_rate: 6.2500e-05
# Epoch 62/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6030 - loss: 1.0246 - top2_accuracy: 0.8203
# Epoch 62: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.6036 - loss: 1.0325 - top2_accuracy: 0.8171 - val_accuracy: 0.6233 - val_loss: 1.0153 - val_top2_accuracy: 0.8311 - learning_rate: 6.2500e-05
# Epoch 63/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6133 - loss: 1.0235 - top2_accuracy: 0.8178
# Epoch 63: val_accuracy did not improve from 0.62333
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6112 - loss: 1.0343 - top2_accuracy: 0.8171 - val_accuracy: 0.6211 - val_loss: 1.0159 - val_top2_accuracy: 0.8261 - learning_rate: 6.2500e-05
# Epoch 64/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6204 - loss: 1.0302 - top2_accuracy: 0.8230
# Epoch 64: val_accuracy improved from 0.62333 to 0.62833, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 64: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.6112 - loss: 1.0379 - top2_accuracy: 0.8167 - val_accuracy: 0.6283 - val_loss: 1.0118 - val_top2_accuracy: 0.8322 - learning_rate: 6.2500e-05
# Epoch 65/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6172 - loss: 1.0198 - top2_accuracy: 0.8184
# Epoch 65: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.6050 - loss: 1.0354 - top2_accuracy: 0.8157 - val_accuracy: 0.6228 - val_loss: 1.0157 - val_top2_accuracy: 0.8300 - learning_rate: 6.2500e-05
# Epoch 66/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6108 - loss: 1.0345 - top2_accuracy: 0.8197
# Epoch 66: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.6071 - loss: 1.0385 - top2_accuracy: 0.8183 - val_accuracy: 0.6239 - val_loss: 1.0132 - val_top2_accuracy: 0.8289 - learning_rate: 6.2500e-05
# Epoch 67/150
# 131/132 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6071 - loss: 1.0274 - top2_accuracy: 0.8148
# Epoch 67: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.6076 - loss: 1.0345 - top2_accuracy: 0.8143 - val_accuracy: 0.6233 - val_loss: 1.0114 - val_top2_accuracy: 0.8283 - learning_rate: 6.2500e-05
# Epoch 68/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6089 - loss: 1.0234 - top2_accuracy: 0.8201
# Epoch 68: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.6114 - loss: 1.0275 - top2_accuracy: 0.8169 - val_accuracy: 0.6228 - val_loss: 1.0112 - val_top2_accuracy: 0.8283 - learning_rate: 6.2500e-05
# Epoch 69/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5920 - loss: 1.0421 - top2_accuracy: 0.8042
# Epoch 69: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.5971 - loss: 1.0448 - top2_accuracy: 0.8083 - val_accuracy: 0.6250 - val_loss: 1.0125 - val_top2_accuracy: 0.8272 - learning_rate: 6.2500e-05
# Epoch 70/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6121 - loss: 1.0167 - top2_accuracy: 0.8264
# Epoch 70: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - accuracy: 0.6031 - loss: 1.0313 - top2_accuracy: 0.8167 - val_accuracy: 0.6228 - val_loss: 1.0107 - val_top2_accuracy: 0.8289 - learning_rate: 6.2500e-05
# Epoch 71/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6049 - loss: 1.0321 - top2_accuracy: 0.8133
# Epoch 71: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6069 - loss: 1.0349 - top2_accuracy: 0.8162 - val_accuracy: 0.6217 - val_loss: 1.0113 - val_top2_accuracy: 0.8278 - learning_rate: 6.2500e-05
# Epoch 72/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6152 - loss: 1.0198 - top2_accuracy: 0.8261
# Epoch 72: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - accuracy: 0.6098 - loss: 1.0329 - top2_accuracy: 0.8219 - val_accuracy: 0.6239 - val_loss: 1.0114 - val_top2_accuracy: 0.8300 - learning_rate: 6.2500e-05
# Epoch 73/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6103 - loss: 1.0186 - top2_accuracy: 0.8167
# Epoch 73: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6095 - loss: 1.0335 - top2_accuracy: 0.8117 - val_accuracy: 0.6233 - val_loss: 1.0098 - val_top2_accuracy: 0.8289 - learning_rate: 6.2500e-05
# Epoch 74/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6019 - loss: 1.0294 - top2_accuracy: 0.8173
# Epoch 74: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6017 - loss: 1.0293 - top2_accuracy: 0.8219 - val_accuracy: 0.6217 - val_loss: 1.0105 - val_top2_accuracy: 0.8317 - learning_rate: 6.2500e-05
# Epoch 75/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6157 - loss: 1.0234 - top2_accuracy: 0.8235
# Epoch 75: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6079 - loss: 1.0329 - top2_accuracy: 0.8188 - val_accuracy: 0.6228 - val_loss: 1.0101 - val_top2_accuracy: 0.8294 - learning_rate: 6.2500e-05
# Epoch 76/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6082 - loss: 1.0237 - top2_accuracy: 0.8148
# Epoch 76: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6083 - loss: 1.0316 - top2_accuracy: 0.8152 - val_accuracy: 0.6233 - val_loss: 1.0102 - val_top2_accuracy: 0.8317 - learning_rate: 6.2500e-05
# Epoch 77/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6290 - loss: 1.0090 - top2_accuracy: 0.8264
# Epoch 77: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 77: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6164 - loss: 1.0249 - top2_accuracy: 0.8207 - val_accuracy: 0.6272 - val_loss: 1.0115 - val_top2_accuracy: 0.8317 - learning_rate: 6.2500e-05
# Epoch 78/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6023 - loss: 1.0354 - top2_accuracy: 0.8124
# Epoch 78: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.6038 - loss: 1.0386 - top2_accuracy: 0.8112 - val_accuracy: 0.6267 - val_loss: 1.0075 - val_top2_accuracy: 0.8328 - learning_rate: 3.1250e-05
# Epoch 79/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6005 - loss: 1.0386 - top2_accuracy: 0.8200
# Epoch 79: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.5993 - loss: 1.0431 - top2_accuracy: 0.8129 - val_accuracy: 0.6256 - val_loss: 1.0077 - val_top2_accuracy: 0.8300 - learning_rate: 3.1250e-05
# Epoch 80/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6192 - loss: 1.0323 - top2_accuracy: 0.8179
# Epoch 80: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6043 - loss: 1.0416 - top2_accuracy: 0.8088 - val_accuracy: 0.6244 - val_loss: 1.0068 - val_top2_accuracy: 0.8311 - learning_rate: 3.1250e-05
# Epoch 81/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6265 - loss: 1.0112 - top2_accuracy: 0.8200
# Epoch 81: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.6193 - loss: 1.0236 - top2_accuracy: 0.8145 - val_accuracy: 0.6228 - val_loss: 1.0068 - val_top2_accuracy: 0.8317 - learning_rate: 3.1250e-05
# Epoch 82/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6028 - loss: 1.0126 - top2_accuracy: 0.8285
# Epoch 82: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6012 - loss: 1.0293 - top2_accuracy: 0.8207 - val_accuracy: 0.6244 - val_loss: 1.0064 - val_top2_accuracy: 0.8328 - learning_rate: 3.1250e-05
# Epoch 83/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6140 - loss: 1.0317 - top2_accuracy: 0.8202
# Epoch 83: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6098 - loss: 1.0339 - top2_accuracy: 0.8198 - val_accuracy: 0.6233 - val_loss: 1.0056 - val_top2_accuracy: 0.8322 - learning_rate: 3.1250e-05
# Epoch 84/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6119 - loss: 1.0193 - top2_accuracy: 0.8220
# Epoch 84: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6040 - loss: 1.0320 - top2_accuracy: 0.8181 - val_accuracy: 0.6239 - val_loss: 1.0058 - val_top2_accuracy: 0.8328 - learning_rate: 3.1250e-05
# Epoch 85/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6104 - loss: 1.0209 - top2_accuracy: 0.8187
# Epoch 85: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.6081 - loss: 1.0277 - top2_accuracy: 0.8205 - val_accuracy: 0.6250 - val_loss: 1.0060 - val_top2_accuracy: 0.8317 - learning_rate: 3.1250e-05
# Epoch 86/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6157 - loss: 1.0190 - top2_accuracy: 0.8189
# Epoch 86: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6160 - loss: 1.0259 - top2_accuracy: 0.8195 - val_accuracy: 0.6261 - val_loss: 1.0061 - val_top2_accuracy: 0.8317 - learning_rate: 3.1250e-05
# Epoch 87/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6126 - loss: 1.0260 - top2_accuracy: 0.8199
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 87: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6083 - loss: 1.0373 - top2_accuracy: 0.8152 - val_accuracy: 0.6261 - val_loss: 1.0066 - val_top2_accuracy: 0.8311 - learning_rate: 3.1250e-05
# Epoch 88/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6155 - loss: 1.0147 - top2_accuracy: 0.8183
# Epoch 88: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6083 - loss: 1.0264 - top2_accuracy: 0.8181 - val_accuracy: 0.6256 - val_loss: 1.0057 - val_top2_accuracy: 0.8294 - learning_rate: 1.5625e-05
# Epoch 89/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6170 - loss: 1.0160 - top2_accuracy: 0.8215
# Epoch 89: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6183 - loss: 1.0237 - top2_accuracy: 0.8186 - val_accuracy: 0.6256 - val_loss: 1.0059 - val_top2_accuracy: 0.8311 - learning_rate: 1.5625e-05
# Epoch 90/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6059 - loss: 1.0271 - top2_accuracy: 0.8121
# Epoch 90: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6083 - loss: 1.0323 - top2_accuracy: 0.8102 - val_accuracy: 0.6244 - val_loss: 1.0065 - val_top2_accuracy: 0.8294 - learning_rate: 1.5625e-05
# Epoch 91/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6201 - loss: 1.0063 - top2_accuracy: 0.8379
# Epoch 91: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 91: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6114 - loss: 1.0178 - top2_accuracy: 0.8326 - val_accuracy: 0.6244 - val_loss: 1.0064 - val_top2_accuracy: 0.8306 - learning_rate: 1.5625e-05
# Epoch 92/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6155 - loss: 1.0127 - top2_accuracy: 0.8253
# Epoch 92: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6074 - loss: 1.0347 - top2_accuracy: 0.8131 - val_accuracy: 0.6278 - val_loss: 1.0052 - val_top2_accuracy: 0.8344 - learning_rate: 7.8125e-06
# Epoch 93/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6169 - loss: 1.0011 - top2_accuracy: 0.8251
# Epoch 93: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.6090 - loss: 1.0234 - top2_accuracy: 0.8176 - val_accuracy: 0.6261 - val_loss: 1.0056 - val_top2_accuracy: 0.8333 - learning_rate: 7.8125e-06
# Epoch 94/150
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6186 - loss: 1.0195 - top2_accuracy: 0.8180
# Epoch 94: val_accuracy did not improve from 0.62833
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6057 - loss: 1.0303 - top2_accuracy: 0.8112 - val_accuracy: 0.6283 - val_loss: 1.0058 - val_top2_accuracy: 0.8333 - learning_rate: 7.8125e-06
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 64.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 94
#    Best val_accuracy : 62.83% (epoch 64)
#
# ⚠️  Accuracy of 62.8% is below 70%

# %% [markdown]
# ## Frozen Model evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 98.4% | 2nd Prediction=index        | 2nd Confidence=  0.8%
# ❌ Image 2: Label=ring         | Prediction=index        | Confidence= 32.8% | 2nd Prediction=ring         | 2nd Confidence= 25.2%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence= 97.0% | 2nd Prediction=index        | 2nd Confidence=  2.8%
# ✅ Image 4: Label=thumb        | Prediction=thumb        | Confidence= 37.8% | 2nd Prediction=middle       | 2nd Confidence= 37.6%
# ✅ Image 5: Label=little       | Prediction=little       | Confidence= 75.4% | 2nd Prediction=ring         | 2nd Confidence= 12.5%
# ✅ Image 6: Label=little       | Prediction=little       | Confidence= 64.2% | 2nd Prediction=ring         | 2nd Confidence= 14.7%
# ❌ Image 7: Label=middle       | Prediction=thumb        | Confidence= 31.8% | 2nd Prediction=middle       | 2nd Confidence= 30.5%
# ❌ Image 8: Label=index        | Prediction=thumb        | Confidence= 50.1% | 2nd Prediction=index        | 2nd Confidence= 28.6%
# ✅ Image 9: Label=thumb        | Prediction=thumb        | Confidence= 81.5% | 2nd Prediction=ring         | 2nd Confidence=  8.8%
# ✅ Image 10: Label=ring         | Prediction=ring         | Confidence= 62.3% | 2nd Prediction=middle       | 2nd Confidence= 20.6%
# ✅ Image 11: Label=ring         | Prediction=ring         | Confidence= 50.0% | 2nd Prediction=little       | 2nd Confidence= 25.3%
# ✅ Image 12: Label=index        | Prediction=index        | Confidence= 45.2% | 2nd Prediction=little       | 2nd Confidence= 21.1%
# ❌ Image 13: Label=little       | Prediction=ring         | Confidence= 36.6% | 2nd Prediction=little       | 2nd Confidence= 24.3%
# ❌ Image 14: Label=little       | Prediction=ring         | Confidence= 47.6% | 2nd Prediction=little       | 2nd Confidence= 28.1%
# ✅ Image 15: Label=thumb        | Prediction=thumb        | Confidence= 92.5% | 2nd Prediction=index        | 2nd Confidence=  5.9%
# ❌ Image 16: Label=ring         | Prediction=middle       | Confidence= 51.4% | 2nd Prediction=ring         | 2nd Confidence= 35.1%
# ❌ Image 17: Label=ring         | Prediction=middle       | Confidence= 56.8% | 2nd Prediction=ring         | 2nd Confidence= 26.3%
# ✅ Image 18: Label=index        | Prediction=index        | Confidence= 40.8% | 2nd Prediction=middle       | 2nd Confidence= 35.3%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 52.6% | 2nd Prediction=middle       | 2nd Confidence= 24.7%
# ✅ Image 20: Label=index        | Prediction=index        | Confidence= 46.8% | 2nd Prediction=thumb        | 2nd Confidence= 28.8%
#
# ======================================================================================================================================================
# 2026-03-18 17:02:35.941406: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 1.0118
#   - Accuracy            : 62.83%
#   - Top-2 Accuracy      : 83.22%
