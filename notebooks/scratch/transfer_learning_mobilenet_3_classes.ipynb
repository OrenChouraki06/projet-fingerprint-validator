# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

DATASET_CSV_PATH = DATASET_ROOTDIR_PATH + "_with_labels.csv"
print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         23931 non-null  int64
#  1   ImagePath  23931 non-null  str
#  2   Finger     23931 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 561.0 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.98%
# Percentage of Little fingers: 20.01%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14361 entries, 0 to 14360
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    14361 non-null  str
#  1   ImageFormat  14361 non-null  str
#  2   ImageSize    14361 non-null  object
#  3   ImageMode    14361 non-null  str
#  4   Finger       14361 non-null  str
# dtypes: object(1), str(4)
# memory usage: 561.1+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    14361
# Name: count, dtype: int64
# ImageSize
# (96, 96)    14361
# Name: count, dtype: int64
# ImageMode
# RGB    14361
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 33.32%
# Percentage of Index fingers: 33.34%
# Percentage of Middle fingers: 33.34%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Split dataset for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 14361 files belonging to 3 classes.
# Using 11489 files for training.
# Found 14361 files belonging to 3 classes.
# Using 2872 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 180
#   - Validation batches    : 45
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~11520
#   - Validation samples    : ~2880
# 2026-03-22 21:51:37.919420: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-22 21:51:37.919447: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-22 21:51:37.919455: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-22 21:51:37.919470: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-22 21:51:37.919481: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x174c25ee0>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x174c25ee0>) → Dropout(0.3) → Dense(3,softmax)
#
#   - Trainable parameters     : 344,579
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,563
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,563 (9.93 MB)
#  Trainable params: 344,579 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 15
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 15 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-22 21:51:39.859549: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5540 - loss: 4.0614 - top2_accuracy: 0.8510
# Epoch 1: val_accuracy improved from None to 0.67967, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 18s 84ms/step - accuracy: 0.6159 - loss: 2.7949 - top2_accuracy: 0.8942 - val_accuracy: 0.6797 - val_loss: 1.5029 - val_top2_accuracy: 0.9164 - learning_rate: 0.0010
# Epoch 2/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6756 - loss: 1.3278 - top2_accuracy: 0.9232
# Epoch 2: val_accuracy improved from 0.67967 to 0.68733, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - accuracy: 0.6838 - loss: 1.2021 - top2_accuracy: 0.9241 - val_accuracy: 0.6873 - val_loss: 1.0314 - val_top2_accuracy: 0.9150 - learning_rate: 0.0010
# Epoch 3/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6929 - loss: 0.9716 - top2_accuracy: 0.9298
# Epoch 3: val_accuracy improved from 0.68733 to 0.72319, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - accuracy: 0.6958 - loss: 0.9274 - top2_accuracy: 0.9336 - val_accuracy: 0.7232 - val_loss: 0.8174 - val_top2_accuracy: 0.9443 - learning_rate: 0.0010
# Epoch 4/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6930 - loss: 0.8557 - top2_accuracy: 0.9356
# Epoch 4: val_accuracy improved from 0.72319 to 0.72632, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.6994 - loss: 0.8369 - top2_accuracy: 0.9352 - val_accuracy: 0.7263 - val_loss: 0.7619 - val_top2_accuracy: 0.9429 - learning_rate: 0.0010
# Epoch 5/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6992 - loss: 0.8010 - top2_accuracy: 0.9364
# Epoch 5: val_accuracy did not improve from 0.72632
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.7048 - loss: 0.7919 - top2_accuracy: 0.9365 - val_accuracy: 0.7176 - val_loss: 0.7743 - val_top2_accuracy: 0.9269 - learning_rate: 0.0010
# Epoch 6/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7094 - loss: 0.7777 - top2_accuracy: 0.9329
# Epoch 6: val_accuracy improved from 0.72632 to 0.72980, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - accuracy: 0.7082 - loss: 0.7740 - top2_accuracy: 0.9349 - val_accuracy: 0.7298 - val_loss: 0.7205 - val_top2_accuracy: 0.9485 - learning_rate: 0.0010
# Epoch 7/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7107 - loss: 0.7590 - top2_accuracy: 0.9346
# Epoch 7: val_accuracy did not improve from 0.72980
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - accuracy: 0.7082 - loss: 0.7543 - top2_accuracy: 0.9345 - val_accuracy: 0.7214 - val_loss: 0.7488 - val_top2_accuracy: 0.9286 - learning_rate: 0.0010
# Epoch 8/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7090 - loss: 0.7564 - top2_accuracy: 0.9317
# Epoch 8: val_accuracy did not improve from 0.72980
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step
90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7711 - loss: 0.6074 - top2_accuracy: 0.9587
# Epoch 39: val_accuracy did not improve from 0.78517
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.7737 - loss: 0.6010 - top2_accuracy: 0.9601 - val_accuracy: 0.7838 - val_loss: 0.5829 - val_top2_accuracy: 0.9690 - learning_rate: 2.5000e-04
# Epoch 40/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7739 - loss: 0.6044 - top2_accuracy: 0.9621
# Epoch 40: val_accuracy did not improve from 0.78517
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.7727 - loss: 0.6040 - top2_accuracy: 0.9622 - val_accuracy: 0.7827 - val_loss: 0.5803 - val_top2_accuracy: 0.9725 - learning_rate: 2.5000e-04
# Epoch 41/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7802 - loss: 0.5952 - top2_accuracy: 0.9622
# Epoch 41: val_accuracy improved from 0.78517 to 0.78795, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 75ms/step - accuracy: 0.7792 - loss: 0.5952 - top2_accuracy: 0.9620 - val_accuracy: 0.7880 - val_loss: 0.5793 - val_top2_accuracy: 0.9652 - learning_rate: 2.5000e-04
# Epoch 42/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7726 - loss: 0.6047 - top2_accuracy: 0.9647
# Epoch 42: val_accuracy improved from 0.78795 to 0.79387, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 42: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.7741 - loss: 0.6067 - top2_accuracy: 0.9626 - val_accuracy: 0.7939 - val_loss: 0.5758 - val_top2_accuracy: 0.9673 - learning_rate: 2.5000e-04
# Epoch 43/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7729 - loss: 0.6049 - top2_accuracy: 0.9609
# Epoch 43: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7759 - loss: 0.5987 - top2_accuracy: 0.9614 - val_accuracy: 0.7900 - val_loss: 0.5778 - val_top2_accuracy: 0.9669 - learning_rate: 2.5000e-04
# Epoch 44/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7745 - loss: 0.5946 - top2_accuracy: 0.9619
# Epoch 44: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7741 - loss: 0.5928 - top2_accuracy: 0.9632 - val_accuracy: 0.7921 - val_loss: 0.5724 - val_top2_accuracy: 0.9669 - learning_rate: 2.5000e-04
# Epoch 45/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7730 - loss: 0.6027 - top2_accuracy: 0.9634
# Epoch 45: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7728 - loss: 0.6022 - top2_accuracy: 0.9609 - val_accuracy: 0.7928 - val_loss: 0.5729 - val_top2_accuracy: 0.9683 - learning_rate: 2.5000e-04
# Epoch 46/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7728 - loss: 0.6070 - top2_accuracy: 0.9583
# Epoch 46: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7754 - loss: 0.6047 - top2_accuracy: 0.9596 - val_accuracy: 0.7831 - val_loss: 0.5728 - val_top2_accuracy: 0.9721 - learning_rate: 2.5000e-04
# Epoch 47/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7744 - loss: 0.6062 - top2_accuracy: 0.9615
# Epoch 47: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7761 - loss: 0.5992 - top2_accuracy: 0.9626 - val_accuracy: 0.7911 - val_loss: 0.5780 - val_top2_accuracy: 0.9652 - learning_rate: 2.5000e-04
# Epoch 48/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7816 - loss: 0.5942 - top2_accuracy: 0.9625
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 48: val_accuracy did not improve from 0.79387
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.7780 - loss: 0.5978 - top2_accuracy: 0.9624 - val_accuracy: 0.7866 - val_loss: 0.5851 - val_top2_accuracy: 0.9641 - learning_rate: 2.5000e-04
# Epoch 49/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7779 - loss: 0.5906 - top2_accuracy: 0.9638
# Epoch 49: val_accuracy improved from 0.79387 to 0.79457, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 49: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7801 - loss: 0.5819 - top2_accuracy: 0.9634 - val_accuracy: 0.7946 - val_loss: 0.5612 - val_top2_accuracy: 0.9725 - learning_rate: 1.2500e-04
# Epoch 50/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7875 - loss: 0.5786 - top2_accuracy: 0.9608
# Epoch 50: val_accuracy did not improve from 0.79457
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7886 - loss: 0.5743 - top2_accuracy: 0.9633 - val_accuracy: 0.7911 - val_loss: 0.5604 - val_top2_accuracy: 0.9735 - learning_rate: 1.2500e-04
# Epoch 51/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7790 - loss: 0.5958 - top2_accuracy: 0.9615
# Epoch 51: val_accuracy did not improve from 0.79457
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.7845 - loss: 0.5796 - top2_accuracy: 0.9638 - val_accuracy: 0.7942 - val_loss: 0.5576 - val_top2_accuracy: 0.9704 - learning_rate: 1.2500e-04
# Epoch 52/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7850 - loss: 0.5811 - top2_accuracy: 0.9640
# Epoch 52: val_accuracy improved from 0.79457 to 0.80049, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 52: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7844 - loss: 0.5767 - top2_accuracy: 0.9652 - val_accuracy: 0.8005 - val_loss: 0.5511 - val_top2_accuracy: 0.9739 - learning_rate: 1.2500e-04
# Epoch 53/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7855 - loss: 0.5749 - top2_accuracy: 0.9701
# Epoch 53: val_accuracy did not improve from 0.80049
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7894 - loss: 0.5704 - top2_accuracy: 0.9680 - val_accuracy: 0.8005 - val_loss: 0.5530 - val_top2_accuracy: 0.9725 - learning_rate: 1.2500e-04
# Epoch 54/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7908 - loss: 0.5713 - top2_accuracy: 0.9674
# Epoch 54: val_accuracy did not improve from 0.80049
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7913 - loss: 0.5669 - top2_accuracy: 0.9661 - val_accuracy: 0.7984 - val_loss: 0.5525 - val_top2_accuracy: 0.9721 - learning_rate: 1.2500e-04
# Epoch 55/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7916 - loss: 0.5726 - top2_accuracy: 0.9650
# Epoch 55: val_accuracy did not improve from 0.80049
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7934 - loss: 0.5603 - top2_accuracy: 0.9678 - val_accuracy: 0.7991 - val_loss: 0.5512 - val_top2_accuracy: 0.9739 - learning_rate: 1.2500e-04
# Epoch 56/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7864 - loss: 0.5628 - top2_accuracy: 0.9698
# Epoch 56: val_accuracy improved from 0.80049 to 0.80675, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 56: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.7893 - loss: 0.5669 - top2_accuracy: 0.9662 - val_accuracy: 0.8068 - val_loss: 0.5492 - val_top2_accuracy: 0.9732 - learning_rate: 1.2500e-04
# Epoch 57/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7904 - loss: 0.5674 - top2_accuracy: 0.9655
# Epoch 57: val_accuracy did not improve from 0.80675
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7911 - loss: 0.5650 - top2_accuracy: 0.9671 - val_accuracy: 0.8022 - val_loss: 0.5512 - val_top2_accuracy: 0.9721 - learning_rate: 1.2500e-04
# Epoch 58/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7877 - loss: 0.5683 - top2_accuracy: 0.9702
# Epoch 58: val_accuracy improved from 0.80675 to 0.80745, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 58: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7889 - loss: 0.5638 - top2_accuracy: 0.9687 - val_accuracy: 0.8075 - val_loss: 0.5424 - val_top2_accuracy: 0.9725 - learning_rate: 1.2500e-04
# Epoch 59/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7963 - loss: 0.5586 - top2_accuracy: 0.9678
# Epoch 59: val_accuracy did not improve from 0.80745
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7938 - loss: 0.5617 - top2_accuracy: 0.9667 - val_accuracy: 0.7956 - val_loss: 0.5513 - val_top2_accuracy: 0.9725 - learning_rate: 1.2500e-04
# Epoch 60/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7851 - loss: 0.5694 - top2_accuracy: 0.9653
# Epoch 60: val_accuracy did not improve from 0.80745
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7876 - loss: 0.5647 - top2_accuracy: 0.9661 - val_accuracy: 0.8057 - val_loss: 0.5521 - val_top2_accuracy: 0.9735 - learning_rate: 1.2500e-04
# Epoch 61/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7879 - loss: 0.5701 - top2_accuracy: 0.9686
# Epoch 61: val_accuracy did not improve from 0.80745
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7920 - loss: 0.5598 - top2_accuracy: 0.9697 - val_accuracy: 0.8064 - val_loss: 0.5483 - val_top2_accuracy: 0.9721 - learning_rate: 1.2500e-04
# Epoch 62/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7901 - loss: 0.5677 - top2_accuracy: 0.9674
# Epoch 62: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 62: val_accuracy did not improve from 0.80745
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7914 - loss: 0.5635 - top2_accuracy: 0.9672 - val_accuracy: 0.8050 - val_loss: 0.5437 - val_top2_accuracy: 0.9714 - learning_rate: 1.2500e-04
# Epoch 63/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7940 - loss: 0.5611 - top2_accuracy: 0.9687
# Epoch 63: val_accuracy improved from 0.80745 to 0.81198, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 63: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7990 - loss: 0.5490 - top2_accuracy: 0.9701 - val_accuracy: 0.8120 - val_loss: 0.5369 - val_top2_accuracy: 0.9728 - learning_rate: 6.2500e-05
# Epoch 64/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8048 - loss: 0.5436 - top2_accuracy: 0.9739
# Epoch 64: val_accuracy did not improve from 0.81198
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.7997 - loss: 0.5468 - top2_accuracy: 0.9705 - val_accuracy: 0.8106 - val_loss: 0.5345 - val_top2_accuracy: 0.9728 - learning_rate: 6.2500e-05
# Epoch 65/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7972 - loss: 0.5482 - top2_accuracy: 0.9678
# Epoch 65: val_accuracy improved from 0.81198 to 0.81546, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 65: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.8015 - loss: 0.5454 - top2_accuracy: 0.9683 - val_accuracy: 0.8155 - val_loss: 0.5327 - val_top2_accuracy: 0.9746 - learning_rate: 6.2500e-05
# Epoch 66/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7990 - loss: 0.5430 - top2_accuracy: 0.9673
# Epoch 66: val_accuracy did not improve from 0.81546
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8030 - loss: 0.5373 - top2_accuracy: 0.9687 - val_accuracy: 0.8134 - val_loss: 0.5317 - val_top2_accuracy: 0.9721 - learning_rate: 6.2500e-05
# Epoch 67/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7984 - loss: 0.5498 - top2_accuracy: 0.9701
# Epoch 67: val_accuracy improved from 0.81546 to 0.81581, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 67: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.8042 - loss: 0.5390 - top2_accuracy: 0.9720 - val_accuracy: 0.8158 - val_loss: 0.5246 - val_top2_accuracy: 0.9732 - learning_rate: 6.2500e-05
# Epoch 68/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7941 - loss: 0.5595 - top2_accuracy: 0.9710
# Epoch 68: val_accuracy did not improve from 0.81581
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8010 - loss: 0.5491 - top2_accuracy: 0.9694 - val_accuracy: 0.8148 - val_loss: 0.5277 - val_top2_accuracy: 0.9739 - learning_rate: 6.2500e-05
# Epoch 69/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7965 - loss: 0.5433 - top2_accuracy: 0.9711
# Epoch 69: val_accuracy improved from 0.81581 to 0.81650, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 69: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.7989 - loss: 0.5397 - top2_accuracy: 0.9713 - val_accuracy: 0.8165 - val_loss: 0.5271 - val_top2_accuracy: 0.9739 - learning_rate: 6.2500e-05
# Epoch 70/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 80: val_accuracy did not improve from 0.82208
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8044 - loss: 0.5367 - top2_accuracy: 0.9710 - val_accuracy: 0.8221 - val_loss: 0.5194 - val_top2_accuracy: 0.9749 - learning_rate: 3.1250e-05
# Epoch 81/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8063 - loss: 0.5334 - top2_accuracy: 0.9694
# Epoch 81: val_accuracy did not improve from 0.82208
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8113 - loss: 0.5268 - top2_accuracy: 0.9696 - val_accuracy: 0.8221 - val_loss: 0.5150 - val_top2_accuracy: 0.9742 - learning_rate: 1.5625e-05
# Epoch 82/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8106 - loss: 0.5273 - top2_accuracy: 0.9711
# Epoch 82: val_accuracy improved from 0.82208 to 0.82416, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 82: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.8110 - loss: 0.5257 - top2_accuracy: 0.9731 - val_accuracy: 0.8242 - val_loss: 0.5140 - val_top2_accuracy: 0.9763 - learning_rate: 1.5625e-05
# Epoch 83/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8073 - loss: 0.5317 - top2_accuracy: 0.9707
# Epoch 83: val_accuracy did not improve from 0.82416
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8077 - loss: 0.5276 - top2_accuracy: 0.9720 - val_accuracy: 0.8214 - val_loss: 0.5145 - val_top2_accuracy: 0.9749 - learning_rate: 1.5625e-05
# Epoch 84/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8063 - loss: 0.5342 - top2_accuracy: 0.9695
# Epoch 84: val_accuracy improved from 0.82416 to 0.82556, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
#
# Epoch 84: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.8074 - loss: 0.5322 - top2_accuracy: 0.9708 - val_accuracy: 0.8256 - val_loss: 0.5149 - val_top2_accuracy: 0.9767 - learning_rate: 1.5625e-05
# Epoch 85/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8097 - loss: 0.5304 - top2_accuracy: 0.9697
# Epoch 85: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8095 - loss: 0.5275 - top2_accuracy: 0.9711 - val_accuracy: 0.8231 - val_loss: 0.5159 - val_top2_accuracy: 0.9760 - learning_rate: 1.5625e-05
# Epoch 86/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8164 - loss: 0.5263 - top2_accuracy: 0.9729
# Epoch 86: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 86: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8116 - loss: 0.5292 - top2_accuracy: 0.9733 - val_accuracy: 0.8238 - val_loss: 0.5156 - val_top2_accuracy: 0.9763 - learning_rate: 1.5625e-05
# Epoch 87/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8068 - loss: 0.5258 - top2_accuracy: 0.9691
# Epoch 87: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8104 - loss: 0.5222 - top2_accuracy: 0.9708 - val_accuracy: 0.8214 - val_loss: 0.5140 - val_top2_accuracy: 0.9767 - learning_rate: 7.8125e-06
# Epoch 88/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8065 - loss: 0.5296 - top2_accuracy: 0.9690
# Epoch 88: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8099 - loss: 0.5262 - top2_accuracy: 0.9691 - val_accuracy: 0.8228 - val_loss: 0.5128 - val_top2_accuracy: 0.9774 - learning_rate: 7.8125e-06
# Epoch 89/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8162 - loss: 0.5215 - top2_accuracy: 0.9751
# Epoch 89: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8135 - loss: 0.5203 - top2_accuracy: 0.9749 - val_accuracy: 0.8231 - val_loss: 0.5128 - val_top2_accuracy: 0.9770 - learning_rate: 7.8125e-06
# Epoch 90/90
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8032 - loss: 0.5299 - top2_accuracy: 0.9727
# Epoch 90: val_accuracy did not improve from 0.82556
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8067 - loss: 0.5257 - top2_accuracy: 0.9723 - val_accuracy: 0.8224 - val_loss: 0.5122 - val_top2_accuracy: 0.9756 - learning_rate: 7.8125e-06
# Restoring model weights from the end of the best epoch: 84.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 90
#    Best val_accuracy : 82.56% (epoch 84)
#
# 🎯 Excellent ! Accuracy of 82.6%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=index        | Prediction=index        | Confidence= 77.8% | 2nd Prediction=middle       | 2nd Confidence= 21.7%
# ✅ Image 2: Label=middle       | Prediction=middle       | Confidence= 53.5% | 2nd Prediction=index        | 2nd Confidence= 39.9%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence= 99.2% | 2nd Prediction=index        | 2nd Confidence=  0.5%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence= 80.8% | 2nd Prediction=index        | 2nd Confidence= 18.5%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence= 99.8% | 2nd Prediction=middle       | 2nd Confidence=  0.1%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence= 99.9% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence= 99.8% | 2nd Prediction=index        | 2nd Confidence=  0.1%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 70.0% | 2nd Prediction=middle       | 2nd Confidence= 19.3%
# ✅ Image 9: Label=middle       | Prediction=middle       | Confidence= 74.5% | 2nd Prediction=index        | 2nd Confidence= 25.2%
# ✅ Image 10: Label=thumb        | Prediction=thumb        | Confidence= 95.6% | 2nd Prediction=middle       | 2nd Confidence=  2.3%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence= 90.6% | 2nd Prediction=middle       | 2nd Confidence=  9.0%
# ✅ Image 12: Label=middle       | Prediction=middle       | Confidence= 77.0% | 2nd Prediction=index        | 2nd Confidence= 22.2%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence= 46.2% | 2nd Prediction=index        | 2nd Confidence= 40.8%
# ✅ Image 14: Label=middle       | Prediction=middle       | Confidence= 62.7% | 2nd Prediction=index        | 2nd Confidence= 36.8%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 62.5% | 2nd Prediction=middle       | 2nd Confidence= 21.1%
# ✅ Image 16: Label=middle       | Prediction=middle       | Confidence= 75.9% | 2nd Prediction=index        | 2nd Confidence= 23.9%
# ❌ Image 17: Label=middle       | Prediction=index        | Confidence= 53.9% | 2nd Prediction=middle       | 2nd Confidence= 45.3%
# ✅ Image 18: Label=middle       | Prediction=middle       | Confidence= 48.9% | 2nd Prediction=index        | 2nd Confidence= 48.3%
# ✅ Image 19: Label=index        | Prediction=index        | Confidence= 96.9% | 2nd Prediction=middle       | 2nd Confidence=  1.7%
# ✅ Image 20: Label=middle       | Prediction=middle       | Confidence= 77.4% | 2nd Prediction=index        | 2nd Confidence= 22.5%
#
# ======================================================================================================================================================
# 2026-03-22 22:11:57.802377: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 0.5149
#   - Accuracy            : 82.56%
#   - Top-2 Accuracy      : 97.67%
