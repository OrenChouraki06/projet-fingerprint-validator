# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_4_classes

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 19143 files belonging to 4 classes.
# Using 15315 files for training.
# 2026-03-23 21:50:48.500551: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-23 21:50:48.500584: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-23 21:50:48.500595: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-23 21:50:48.500617: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-23 21:50:48.500630: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Found 19143 files belonging to 4 classes.
# Using 3828 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle', 'ring']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle', 'ring']
#   - ✅ Number of correct classes : 4
#
#   - Training batches    : 240
#   - Validation batches    : 60
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~15360
#   - Validation samples    : ~3840

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 4)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,628
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_4_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 4)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_4_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,291,918 (12.56 MB)
#  Trainable params: 344,644 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,290 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-23 21:50:50.504795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 71.11%
#   - Loss     : 0.7856

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants
FINE_TUNING_UNFREEZE_LAYERS = 100

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Freeze only the first FINE_TUNING_UNFREEZE_LAYERS-th layers
for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFREEZE_LAYERS:
        layer.trainable = False
    else:
        layer.trainable = True

print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {FINE_TUNING_UNFREEZE_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# 📊 Unfreeze configuration :
#   - Frozen layers   : 100
#   - Unfrozen layers : 55
#   - Trainable params : 1,861,440 (82.4%)
#   - Frozen params    : 396,544
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_4_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_4_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,628 (9.93 MB)
#  Trainable params: 2,206,084 (8.42 MB)
#  Non-trainable params: 396,544 (1.51 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_after_compile[1]*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 71.11%
#   - Loss     : 0.7856
#
#   ✅ Transfer-learning weigths have been preserved (71.1%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
# These values are taken from transfer learning trainings
accuracies = [0.951, 0.826, 0.726, 0.68]

frozen_best = accuracies[num_classes - 2]
improvement = (best_val_acc - frozen_best) * 100
print(f"\n📊 Improvement vs Frozen : {improvement:+.1f} %")
print(f"   - Frozen    : {frozen_best*100:.1f}%")
print(f"   - Fine-tuned: {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.4931 - loss: 1.4090 - top2_accuracy: 0.7407
# Epoch 1: val_accuracy improved from None to 0.64028, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 64s 219ms/step - accuracy: 0.5245 - loss: 1.2427 - top2_accuracy: 0.7726 - val_accuracy: 0.6403 - val_loss: 1.0429 - val_top2_accuracy: 0.8373 - learning_rate: 1.0000e-05
# Epoch 2/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6078 - loss: 0.9795 - top2_accuracy: 0.8428
# Epoch 2: val_accuracy did not improve from 0.64028
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.6123 - loss: 0.9708 - top2_accuracy: 0.8442 - val_accuracy: 0.6306 - val_loss: 1.0315 - val_top2_accuracy: 0.8388 - learning_rate: 1.0000e-05
# Epoch 3/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6591 - loss: 0.8716 - top2_accuracy: 0.8793
# Epoch 3: val_accuracy improved from 0.64028 to 0.65308, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 202ms/step - accuracy: 0.6576 - loss: 0.8675 - top2_accuracy: 0.8817 - val_accuracy: 0.6531 - val_loss: 0.9734 - val_top2_accuracy: 0.8550 - learning_rate: 1.0000e-05
# Epoch 4/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6945 - loss: 0.7988 - top2_accuracy: 0.8947
# Epoch 4: val_accuracy improved from 0.65308 to 0.67241, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.6931 - loss: 0.7972 - top2_accuracy: 0.8972 - val_accuracy: 0.6724 - val_loss: 0.9212 - val_top2_accuracy: 0.8746 - learning_rate: 1.0000e-05
# Epoch 5/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7225 - loss: 0.7371 - top2_accuracy: 0.9196
# Epoch 5: val_accuracy improved from 0.67241 to 0.67921, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.7225 - loss: 0.7306 - top2_accuracy: 0.9194 - val_accuracy: 0.6792 - val_loss: 0.8804 - val_top2_accuracy: 0.8858 - learning_rate: 1.0000e-05
# Epoch 6/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7493 - loss: 0.6794 - top2_accuracy: 0.9321
# Epoch 6: val_accuracy improved from 0.67921 to 0.68730, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.7491 - loss: 0.6733 - top2_accuracy: 0.9331 - val_accuracy: 0.6873 - val_loss: 0.8681 - val_top2_accuracy: 0.8900 - learning_rate: 1.0000e-05
# Epoch 7/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7765 - loss: 0.6179 - top2_accuracy: 0.9470
# Epoch 7: val_accuracy improved from 0.68730 to 0.70193, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 7: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 195ms/step - accuracy: 0.7754 - loss: 0.6150 - top2_accuracy: 0.9489 - val_accuracy: 0.7019 - val_loss: 0.8227 - val_top2_accuracy: 0.9031 - learning_rate: 1.0000e-05
# Epoch 8/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7970 - loss: 0.5691 - top2_accuracy: 0.9586
# Epoch 8: val_accuracy improved from 0.70193 to 0.71944, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 196ms/step - accuracy: 0.7973 - loss: 0.5652 - top2_accuracy: 0.9570 - val_accuracy: 0.7194 - val_loss: 0.7806 - val_top2_accuracy: 0.9151 - learning_rate: 1.0000e-05
# Epoch 9/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8198 - loss: 0.5245 - top2_accuracy: 0.9647
# Epoch 9: val_accuracy improved from 0.71944 to 0.73642, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 204ms/step - accuracy: 0.8227 - loss: 0.5156 - top2_accuracy: 0.9672 - val_accuracy: 0.7364 - val_loss: 0.7528 - val_top2_accuracy: 0.9141 - learning_rate: 1.0000e-05
# Epoch 10/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8378 - loss: 0.4805 - top2_accuracy: 0.9738
# Epoch 10: val_accuracy improved from 0.73642 to 0.75862, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.8415 - loss: 0.4726 - top2_accuracy: 0.9751 - val_accuracy: 0.7586 - val_loss: 0.7099 - val_top2_accuracy: 0.9242 - learning_rate: 1.0000e-05
# Epoch 11/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8611 - loss: 0.4301 - top2_accuracy: 0.9801
# Epoch 11: val_accuracy improved from 0.75862 to 0.77194, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 11: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.8592 - loss: 0.4287 - top2_accuracy: 0.9799 - val_accuracy: 0.7719 - val_loss: 0.6762 - val_top2_accuracy: 0.9342 - learning_rate: 1.0000e-05
# Epoch 12/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8748 - loss: 0.3936 - top2_accuracy: 0.9847
# Epoch 12: val_accuracy improved from 0.77194 to 0.78527, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.8784 - loss: 0.3885 - top2_accuracy: 0.9850 - val_accuracy: 0.7853 - val_loss: 0.6529 - val_top2_accuracy: 0.9394 - learning_rate: 1.0000e-05
# Epoch 13/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8949 - loss: 0.3517 - top2_accuracy: 0.9904
# Epoch 13: val_accuracy improved from 0.78527 to 0.79650, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 13: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 196ms/step - accuracy: 0.8972 - loss: 0.3490 - top2_accuracy: 0.9900 - val_accuracy: 0.7965 - val_loss: 0.6321 - val_top2_accuracy: 0.9472 - learning_rate: 1.0000e-05
# Epoch 14/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9131 - loss: 0.3184 - top2_accuracy: 0.9927
# Epoch 14: val_accuracy improved from 0.79650 to 0.79833, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 14: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 196ms/step - accuracy: 0.9139 - loss: 0.3143 - top2_accuracy: 0.9931 - val_accuracy: 0.7983 - val_loss: 0.6490 - val_top2_accuracy: 0.9459 - learning_rate: 1.0000e-05
# Epoch 15/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9270 - loss: 0.2820 - top2_accuracy: 0.9956
# Epoch 15: val_accuracy improved from 0.79833 to 0.81296, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9268 - loss: 0.2820 - top2_accuracy: 0.9959 - val_accuracy: 0.8130 - val_loss: 0.6150 - val_top2_accuracy: 0.9522 - learning_rate: 1.0000e-05
# Epoch 16/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9365 - loss: 0.2565 - top2_accuracy: 0.9962
# Epoch 16: val_accuracy improved from 0.81296 to 0.81792, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9389 - loss: 0.2540 - top2_accuracy: 0.9960 - val_accuracy: 0.8179 - val_loss: 0.6045 - val_top2_accuracy: 0.9532 - learning_rate: 1.0000e-05
# Epoch 17/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9491 - loss: 0.2290 - top2_accuracy: 0.9972
# Epoch 17: val_accuracy improved from 0.81792 to 0.82079, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 17: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.9510 - loss: 0.2275 - top2_accuracy: 0.9970 - val_accuracy: 0.8208 - val_loss: 0.6093 - val_top2_accuracy: 0.9509 - learning_rate: 1.0000e-05
# Epoch 18/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9624 - loss: 0.2043 - top2_accuracy: 0.9980
# Epoch 18: val_accuracy improved from 0.82079 to 0.82367, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 18: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 197ms/step - accuracy: 0.9629 - loss: 0.2008 - top2_accuracy: 0.9981 - val_accuracy: 0.8237 - val_loss: 0.6076 - val_top2_accuracy: 0.9543 - learning_rate: 1.0000e-05
# Epoch 19/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9688 - loss: 0.1831 - top2_accuracy: 0.9983
# Epoch 19: val_accuracy improved from 0.82367 to 0.83359, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 197ms/step - accuracy: 0.9691 - loss: 0.1820 - top2_accuracy: 0.9984 - val_accuracy: 0.8336 - val_loss: 0.6142 - val_top2_accuracy: 0.9587 - learning_rate: 1.0000e-05
# Epoch 20/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9729 - loss: 0.1697 - top2_accuracy: 0.9990
# Epoch 20: val_accuracy did not improve from 0.83359
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 196ms/step - accuracy: 0.9741 - loss: 0.1666 - top2_accuracy: 0.9989 - val_accuracy: 0.8278 - val_loss: 0.6194 - val_top2_accuracy: 0.9587 - learning_rate: 1.0000e-05
# Epoch 21/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9814 - loss: 0.1544 - top2_accuracy: 0.9996
# Epoch 21: val_accuracy improved from 0.83359 to 0.83464, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 21: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 198ms/step - accuracy: 0.9823 - loss: 0.1508 - top2_accuracy: 0.9993 - val_accuracy: 0.8346 - val_loss: 0.6200 - val_top2_accuracy: 0.9585 - learning_rate: 1.0000e-05
# Epoch 22/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9858 - loss: 0.1382 - top2_accuracy: 0.9996
# Epoch 22: val_accuracy did not improve from 0.83464
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9864 - loss: 0.1357 - top2_accuracy: 0.9995 - val_accuracy: 0.8328 - val_loss: 0.6394 - val_top2_accuracy: 0.9582 - learning_rate: 1.0000e-05
# Epoch 23/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9874 - loss: 0.1303 - top2_accuracy: 0.9996
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 23: val_accuracy improved from 0.83464 to 0.83804, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 23: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9895 - loss: 0.1268 - top2_accuracy: 0.9999 - val_accuracy: 0.8380 - val_loss: 0.6381 - val_top2_accuracy: 0.9606 - learning_rate: 1.0000e-05
# Epoch 24/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9914 - loss: 0.1188 - top2_accuracy: 0.9999
# Epoch 24: val_accuracy improved from 0.83804 to 0.84195, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 198ms/step - accuracy: 0.9920 - loss: 0.1192 - top2_accuracy: 0.9999 - val_accuracy: 0.8420 - val_loss: 0.6247 - val_top2_accuracy: 0.9616 - learning_rate: 5.0000e-06
# Epoch 25/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9933 - loss: 0.1163 - top2_accuracy: 1.0000
# Epoch 25: val_accuracy improved from 0.84195 to 0.84744, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 25: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9939 - loss: 0.1154 - top2_accuracy: 1.0000 - val_accuracy: 0.8474 - val_loss: 0.6262 - val_top2_accuracy: 0.9611 - learning_rate: 5.0000e-06
# Epoch 26/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9939 - loss: 0.1117 - top2_accuracy: 0.9999
# Epoch 26: val_accuracy did not improve from 0.84744
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 196ms/step - accuracy: 0.9942 - loss: 0.1118 - top2_accuracy: 0.9998 - val_accuracy: 0.8467 - val_loss: 0.6263 - val_top2_accuracy: 0.9632 - learning_rate: 5.0000e-06
# Epoch 27/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9949 - loss: 0.1093 - top2_accuracy: 0.9998
# Epoch 27: val_accuracy improved from 0.84744 to 0.84901, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9946 - loss: 0.1089 - top2_accuracy: 0.9999 - val_accuracy: 0.8490 - val_loss: 0.6283 - val_top2_accuracy: 0.9613 - learning_rate: 5.0000e-06
# Epoch 28/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9954 - loss: 0.1058 - top2_accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.84901 to 0.84953, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 28: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9954 - loss: 0.1054 - top2_accuracy: 1.0000 - val_accuracy: 0.8495 - val_loss: 0.6342 - val_top2_accuracy: 0.9616 - learning_rate: 5.0000e-06
# Epoch 29/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9959 - loss: 0.1038 - top2_accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.84953 to 0.85084, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 29: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9954 - loss: 0.1041 - top2_accuracy: 0.9999 - val_accuracy: 0.8508 - val_loss: 0.6344 - val_top2_accuracy: 0.9624 - learning_rate: 5.0000e-06
# Epoch 30/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9963 - loss: 0.1019 - top2_accuracy: 1.0000
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 30: val_accuracy improved from 0.85084 to 0.85240, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9964 - loss: 0.1013 - top2_accuracy: 1.0000 - val_accuracy: 0.8524 - val_loss: 0.6341 - val_top2_accuracy: 0.9624 - learning_rate: 5.0000e-06
# Epoch 31/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9970 - loss: 0.0990 - top2_accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.85240
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.9967 - loss: 0.0995 - top2_accuracy: 1.0000 - val_accuracy: 0.8508 - val_loss: 0.6337 - val_top2_accuracy: 0.9632 - learning_rate: 2.5000e-06
# Epoch 32/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9968 - loss: 0.0994 - top2_accuracy: 0.9999
# Epoch 32: val_accuracy improved from 0.85240 to 0.85266, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 32: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9971 - loss: 0.0988 - top2_accuracy: 0.9999 - val_accuracy: 0.8527 - val_loss: 0.6386 - val_top2_accuracy: 0.9634 - learning_rate: 2.5000e-06
# Epoch 33/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9982 - loss: 0.0960 - top2_accuracy: 1.0000
# Epoch 33: val_accuracy improved from 0.85266 to 0.85345, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 33: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 202ms/step - accuracy: 0.9980 - loss: 0.0959 - top2_accuracy: 0.9999 - val_accuracy: 0.8534 - val_loss: 0.6346 - val_top2_accuracy: 0.9634 - learning_rate: 2.5000e-06
# Epoch 34/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9972 - loss: 0.0966 - top2_accuracy: 0.9998
# Epoch 34: val_accuracy did not improve from 0.85345
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9973 - loss: 0.0965 - top2_accuracy: 0.9999 - val_accuracy: 0.8532 - val_loss: 0.6373 - val_top2_accuracy: 0.9645 - learning_rate: 2.5000e-06
# Epoch 35/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9982 - loss: 0.0945 - top2_accuracy: 1.0000
# Epoch 35: val_accuracy improved from 0.85345 to 0.85423, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 35: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9982 - loss: 0.0945 - top2_accuracy: 1.0000 - val_accuracy: 0.8542 - val_loss: 0.6399 - val_top2_accuracy: 0.9642 - learning_rate: 2.5000e-06
# Epoch 36/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9972 - loss: 0.0946 - top2_accuracy: 1.0000
# Epoch 36: val_accuracy improved from 0.85423 to 0.85475, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 36: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 202ms/step - accuracy: 0.9976 - loss: 0.0943 - top2_accuracy: 0.9999 - val_accuracy: 0.8548 - val_loss: 0.6395 - val_top2_accuracy: 0.9647 - learning_rate: 2.5000e-06
# Epoch 37/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9981 - loss: 0.0926 - top2_accuracy: 1.0000
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 37: val_accuracy improved from 0.85475 to 0.85737, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 37: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 202ms/step - accuracy: 0.9977 - loss: 0.0933 - top2_accuracy: 1.0000 - val_accuracy: 0.8574 - val_loss: 0.6366 - val_top2_accuracy: 0.9658 - learning_rate: 2.5000e-06
# Epoch 38/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9987 - loss: 0.0910 - top2_accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9984 - loss: 0.0916 - top2_accuracy: 1.0000 - val_accuracy: 0.8563 - val_loss: 0.6373 - val_top2_accuracy: 0.9658 - learning_rate: 1.2500e-06
# Epoch 39/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9974 - loss: 0.0923 - top2_accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9976 - loss: 0.0921 - top2_accuracy: 1.0000 - val_accuracy: 0.8568 - val_loss: 0.6359 - val_top2_accuracy: 0.9650 - learning_rate: 1.2500e-06
# Epoch 40/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9976 - loss: 0.0920 - top2_accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9979 - loss: 0.0918 - top2_accuracy: 0.9999 - val_accuracy: 0.8553 - val_loss: 0.6351 - val_top2_accuracy: 0.9650 - learning_rate: 1.2500e-06
# Epoch 41/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9986 - loss: 0.0897 - top2_accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 204ms/step - accuracy: 0.9984 - loss: 0.0904 - top2_accuracy: 1.0000 - val_accuracy: 0.8558 - val_loss: 0.6348 - val_top2_accuracy: 0.9650 - learning_rate: 1.2500e-06
# Epoch 42/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9977 - loss: 0.0907 - top2_accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 197ms/step - accuracy: 0.9982 - loss: 0.0898 - top2_accuracy: 1.0000 - val_accuracy: 0.8561 - val_loss: 0.6358 - val_top2_accuracy: 0.9645 - learning_rate: 1.2500e-06
# Epoch 43/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9982 - loss: 0.0897 - top2_accuracy: 0.9999
# Epoch 43: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 47s 197ms/step - accuracy: 0.9983 - loss: 0.0898 - top2_accuracy: 0.9999 - val_accuracy: 0.8553 - val_loss: 0.6371 - val_top2_accuracy: 0.9653 - learning_rate: 1.2500e-06
# Epoch 44/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9983 - loss: 0.0879 - top2_accuracy: 1.0000
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 44: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.9984 - loss: 0.0883 - top2_accuracy: 1.0000 - val_accuracy: 0.8566 - val_loss: 0.6366 - val_top2_accuracy: 0.9647 - learning_rate: 1.2500e-06
# Epoch 45/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9991 - loss: 0.0877 - top2_accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.85737
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9988 - loss: 0.0881 - top2_accuracy: 1.0000 - val_accuracy: 0.8563 - val_loss: 0.6369 - val_top2_accuracy: 0.9645 - learning_rate: 6.2500e-07
# Epoch 46/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9984 - loss: 0.0882 - top2_accuracy: 1.0000
# Epoch 46: val_accuracy improved from 0.85737 to 0.85789, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 46: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9985 - loss: 0.0881 - top2_accuracy: 1.0000 - val_accuracy: 0.8579 - val_loss: 0.6352 - val_top2_accuracy: 0.9647 - learning_rate: 6.2500e-07
# Epoch 47/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9991 - loss: 0.0866 - top2_accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.85789
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9990 - loss: 0.0869 - top2_accuracy: 1.0000 - val_accuracy: 0.8574 - val_loss: 0.6354 - val_top2_accuracy: 0.9650 - learning_rate: 6.2500e-07
# Epoch 48/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9992 - loss: 0.0865 - top2_accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.85789
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 198ms/step - accuracy: 0.9988 - loss: 0.0871 - top2_accuracy: 0.9999 - val_accuracy: 0.8571 - val_loss: 0.6354 - val_top2_accuracy: 0.9645 - learning_rate: 6.2500e-07
# Epoch 49/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9990 - loss: 0.0862 - top2_accuracy: 0.9999
# Epoch 49: val_accuracy improved from 0.85789 to 0.85867, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 49: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9988 - loss: 0.0866 - top2_accuracy: 0.9999 - val_accuracy: 0.8587 - val_loss: 0.6347 - val_top2_accuracy: 0.9647 - learning_rate: 6.2500e-07
# Epoch 50/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9986 - loss: 0.0864 - top2_accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.85867
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9984 - loss: 0.0871 - top2_accuracy: 0.9999 - val_accuracy: 0.8582 - val_loss: 0.6351 - val_top2_accuracy: 0.9647 - learning_rate: 6.2500e-07
# Epoch 51/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9991 - loss: 0.0861 - top2_accuracy: 1.0000
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 51: val_accuracy did not improve from 0.85867
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9986 - loss: 0.0864 - top2_accuracy: 1.0000 - val_accuracy: 0.8587 - val_loss: 0.6351 - val_top2_accuracy: 0.9653 - learning_rate: 6.2500e-07
# Epoch 52/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9988 - loss: 0.0863 - top2_accuracy: 1.0000
# Epoch 52: val_accuracy improved from 0.85867 to 0.85920, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 52: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9986 - loss: 0.0864 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6349 - val_top2_accuracy: 0.9647 - learning_rate: 3.1250e-07
# Epoch 53/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9988 - loss: 0.0863 - top2_accuracy: 0.9999
# Epoch 53: val_accuracy did not improve from 0.85920
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9987 - loss: 0.0867 - top2_accuracy: 0.9999 - val_accuracy: 0.8579 - val_loss: 0.6352 - val_top2_accuracy: 0.9653 - learning_rate: 3.1250e-07
# Epoch 54/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9987 - loss: 0.0859 - top2_accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.85920
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9985 - loss: 0.0858 - top2_accuracy: 1.0000 - val_accuracy: 0.8582 - val_loss: 0.6354 - val_top2_accuracy: 0.9653 - learning_rate: 3.1250e-07
# Epoch 55/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9989 - loss: 0.0863 - top2_accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.85920
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9990 - loss: 0.0862 - top2_accuracy: 1.0000 - val_accuracy: 0.8579 - val_loss: 0.6356 - val_top2_accuracy: 0.9650 - learning_rate: 3.1250e-07
# Epoch 56/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9987 - loss: 0.0857 - top2_accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.85920
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9984 - loss: 0.0864 - top2_accuracy: 0.9999 - val_accuracy: 0.8584 - val_loss: 0.6359 - val_top2_accuracy: 0.9650 - learning_rate: 3.1250e-07
# Epoch 57/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9986 - loss: 0.0865 - top2_accuracy: 0.9997
# Epoch 57: val_accuracy improved from 0.85920 to 0.85946, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 57: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9990 - loss: 0.0858 - top2_accuracy: 0.9999 - val_accuracy: 0.8595 - val_loss: 0.6357 - val_top2_accuracy: 0.9653 - learning_rate: 3.1250e-07
# Epoch 58/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9994 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 58: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 204ms/step - accuracy: 0.9990 - loss: 0.0850 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6360 - val_top2_accuracy: 0.9655 - learning_rate: 3.1250e-07
# Epoch 59/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9984 - loss: 0.0864 - top2_accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9986 - loss: 0.0860 - top2_accuracy: 1.0000 - val_accuracy: 0.8587 - val_loss: 0.6359 - val_top2_accuracy: 0.9653 - learning_rate: 1.5625e-07
# Epoch 60/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9989 - loss: 0.0854 - top2_accuracy: 0.9998
# Epoch 60: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 207ms/step - accuracy: 0.9990 - loss: 0.0854 - top2_accuracy: 0.9999 - val_accuracy: 0.8589 - val_loss: 0.6359 - val_top2_accuracy: 0.9653 - learning_rate: 1.5625e-07
# Epoch 61/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9988 - loss: 0.0857 - top2_accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 52s 217ms/step - accuracy: 0.9987 - loss: 0.0854 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6359 - val_top2_accuracy: 0.9650 - learning_rate: 1.5625e-07
# Epoch 62/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9994 - loss: 0.0849 - top2_accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 51s 213ms/step - accuracy: 0.9988 - loss: 0.0854 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6361 - val_top2_accuracy: 0.9653 - learning_rate: 1.5625e-07
# Epoch 63/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9988 - loss: 0.0854 - top2_accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.85946
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 204ms/step - accuracy: 0.9990 - loss: 0.0854 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6362 - val_top2_accuracy: 0.9650 - learning_rate: 1.5625e-07
# Epoch 64/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9992 - loss: 0.0853 - top2_accuracy: 1.0000
# Epoch 64: val_accuracy improved from 0.85946 to 0.85972, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
#
# Epoch 64: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_4_classes_Fine_Tuning.keras
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9987 - loss: 0.0857 - top2_accuracy: 1.0000 - val_accuracy: 0.8597 - val_loss: 0.6360 - val_top2_accuracy: 0.9653 - learning_rate: 1.5625e-07
# Epoch 65/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9987 - loss: 0.0849 - top2_accuracy: 1.0000
# Epoch 65: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 65: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9990 - loss: 0.0846 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6360 - val_top2_accuracy: 0.9653 - learning_rate: 1.5625e-07
# Epoch 66/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9988 - loss: 0.0845 - top2_accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 206ms/step - accuracy: 0.9990 - loss: 0.0847 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6361 - val_top2_accuracy: 0.9653 - learning_rate: 7.8125e-08
# Epoch 67/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9996 - loss: 0.0846 - top2_accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 207ms/step - accuracy: 0.9993 - loss: 0.0849 - top2_accuracy: 0.9999 - val_accuracy: 0.8592 - val_loss: 0.6363 - val_top2_accuracy: 0.9653 - learning_rate: 7.8125e-08
# Epoch 68/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9993 - loss: 0.0850 - top2_accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 204ms/step - accuracy: 0.9992 - loss: 0.0848 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6364 - val_top2_accuracy: 0.9653 - learning_rate: 7.8125e-08
# Epoch 69/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9989 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9987 - loss: 0.0849 - top2_accuracy: 0.9999 - val_accuracy: 0.8584 - val_loss: 0.6365 - val_top2_accuracy: 0.9650 - learning_rate: 7.8125e-08
# Epoch 70/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9981 - loss: 0.0859 - top2_accuracy: 0.9999
# Epoch 70: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 209ms/step - accuracy: 0.9984 - loss: 0.0856 - top2_accuracy: 0.9999 - val_accuracy: 0.8584 - val_loss: 0.6365 - val_top2_accuracy: 0.9653 - learning_rate: 7.8125e-08
# Epoch 71/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9984 - loss: 0.0844 - top2_accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 51s 211ms/step - accuracy: 0.9985 - loss: 0.0848 - top2_accuracy: 1.0000 - val_accuracy: 0.8584 - val_loss: 0.6366 - val_top2_accuracy: 0.9650 - learning_rate: 7.8125e-08
# Epoch 72/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9990 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 72: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 72: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 59s 244ms/step - accuracy: 0.9993 - loss: 0.0841 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6365 - val_top2_accuracy: 0.9653 - learning_rate: 7.8125e-08
# Epoch 73/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9993 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 60s 249ms/step - accuracy: 0.9990 - loss: 0.0847 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 74/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9995 - loss: 0.0838 - top2_accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 57s 237ms/step - accuracy: 0.9994 - loss: 0.0841 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 75/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9987 - loss: 0.0851 - top2_accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 58s 241ms/step - accuracy: 0.9990 - loss: 0.0845 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6365 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 76/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9983 - loss: 0.0857 - top2_accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 56s 235ms/step - accuracy: 0.9986 - loss: 0.0853 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 77/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9995 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 53s 222ms/step - accuracy: 0.9995 - loss: 0.0842 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 78/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9987 - loss: 0.0853 - top2_accuracy: 0.9999
# Epoch 78: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 210ms/step - accuracy: 0.9987 - loss: 0.0857 - top2_accuracy: 0.9999 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9653 - learning_rate: 3.9062e-08
# Epoch 79/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9993 - loss: 0.0838 - top2_accuracy: 1.0000
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-08.
#
# Epoch 79: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 208ms/step - accuracy: 0.9991 - loss: 0.0843 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 3.9062e-08
# Epoch 80/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9989 - loss: 0.0845 - top2_accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 206ms/step - accuracy: 0.9989 - loss: 0.0845 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 81/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9987 - loss: 0.0851 - top2_accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9989 - loss: 0.0849 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 82/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9991 - loss: 0.0849 - top2_accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9992 - loss: 0.0847 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 83/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9984 - loss: 0.0848 - top2_accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9986 - loss: 0.0849 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 84/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9991 - loss: 0.0839 - top2_accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9992 - loss: 0.0838 - top2_accuracy: 1.0000 - val_accuracy: 0.8595 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 85/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9988 - loss: 0.0838 - top2_accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 207ms/step - accuracy: 0.9989 - loss: 0.0843 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 86/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9986 - loss: 0.0838 - top2_accuracy: 0.9999
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1e-08.
#
# Epoch 86: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 50s 206ms/step - accuracy: 0.9986 - loss: 0.0845 - top2_accuracy: 0.9999 - val_accuracy: 0.8592 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.9531e-08
# Epoch 87/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9985 - loss: 0.0843 - top2_accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 201ms/step - accuracy: 0.9990 - loss: 0.0840 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 88/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9981 - loss: 0.0851 - top2_accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9983 - loss: 0.0853 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 89/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9990 - loss: 0.0840 - top2_accuracy: 0.9999
# Epoch 89: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 203ms/step - accuracy: 0.9986 - loss: 0.0846 - top2_accuracy: 0.9999 - val_accuracy: 0.8589 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 90/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9984 - loss: 0.0849 - top2_accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.9986 - loss: 0.0848 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 91/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9991 - loss: 0.0845 - top2_accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 53s 219ms/step - accuracy: 0.9990 - loss: 0.0846 - top2_accuracy: 1.0000 - val_accuracy: 0.8589 - val_loss: 0.6367 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 92/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9986 - loss: 0.0845 - top2_accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 54s 224ms/step - accuracy: 0.9986 - loss: 0.0847 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 93/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9996 - loss: 0.0832 - top2_accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 199ms/step - accuracy: 0.9995 - loss: 0.0837 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 94/120
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9993 - loss: 0.0850 - top2_accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.85972
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 48s 200ms/step - accuracy: 0.9994 - loss: 0.0843 - top2_accuracy: 1.0000 - val_accuracy: 0.8592 - val_loss: 0.6366 - val_top2_accuracy: 0.9655 - learning_rate: 1.0000e-08
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 64.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 94
#    Meilleure val_accuracy : 85.97% (epoch 64)
#
# 📊 Improvement vs Frozen : +13.4 %
#    - Frozen    : 72.6%
#    - Fine-tuned: 86.0%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=index        | Prediction=index        | Confidence= 99.9% | 2nd Prediction=middle       | 2nd Confidence=  0.1%
# ✅ Image 2: Label=ring         | Prediction=ring         | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence= 95.7% | 2nd Prediction=ring         | 2nd Confidence=  4.3%
# ✅ Image 4: Label=ring         | Prediction=ring         | Confidence= 79.4% | 2nd Prediction=thumb        | 2nd Confidence= 11.3%
# ❌ Image 5: Label=middle       | Prediction=index        | Confidence= 98.8% | 2nd Prediction=middle       | 2nd Confidence=  1.2%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 7: Label=ring         | Prediction=ring         | Confidence= 94.1% | 2nd Prediction=middle       | 2nd Confidence=  5.9%
# ✅ Image 8: Label=middle       | Prediction=middle       | Confidence= 53.4% | 2nd Prediction=index        | 2nd Confidence= 46.4%
# ✅ Image 9: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 10: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=ring         | 2nd Confidence=  0.0%
# ✅ Image 11: Label=middle       | Prediction=middle       | Confidence= 98.3% | 2nd Prediction=index        | 2nd Confidence=  1.3%
# ✅ Image 12: Label=ring         | Prediction=ring         | Confidence= 83.6% | 2nd Prediction=middle       | 2nd Confidence= 16.4%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence= 86.6% | 2nd Prediction=ring         | 2nd Confidence= 12.7%
# ✅ Image 14: Label=middle       | Prediction=middle       | Confidence= 99.1% | 2nd Prediction=index        | 2nd Confidence=  0.5%
# ✅ Image 15: Label=ring         | Prediction=ring         | Confidence= 81.9% | 2nd Prediction=index        | 2nd Confidence= 15.3%
# ❌ Image 16: Label=ring         | Prediction=index        | Confidence= 85.7% | 2nd Prediction=thumb        | 2nd Confidence= 13.9%
# ✅ Image 17: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 18: Label=thumb        | Prediction=thumb        | Confidence= 96.0% | 2nd Prediction=index        | 2nd Confidence=  3.3%
# ❌ Image 19: Label=ring         | Prediction=middle       | Confidence= 94.5% | 2nd Prediction=ring         | 2nd Confidence=  4.6%
# ✅ Image 20: Label=ring         | Prediction=ring         | Confidence= 99.8% | 2nd Prediction=middle       | 2nd Confidence=  0.2%
#
# ======================================================================================================================================================
# 2026-03-23 23:08:18.678452: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of fine-tuned model using validation dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using validation dataset...
#
# Results :
#   - Loss                : 0.6360
#   - Accuracy            : 85.97%
#   - Top-2 Accuracy      : 96.53%
