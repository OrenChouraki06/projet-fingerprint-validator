# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

DATASET_CSV_PATH = DATASET_ROOTDIR_PATH + "_with_labels.csv"
print(f"📁 Fingerprints dataset CSV path : {DATASET_CSV_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
# 📁 Fingerprints dataset CSV path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training_with_labels.csv
#
# 👁️ fingerprints classes : ['thumb', 'index']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_2_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# load csv
df = pd.read_csv(DATASET_CSV_PATH)

print(f"\n📊 Fingerprints dataset basic stats :")
df.info()
# Out:
# 📊 Fingerprints dataset basic stats :
# <class 'pandas.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         23931 non-null  int64
#  1   ImagePath  23931 non-null  str
#  2   Finger     23931 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 561.0 KB

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# show distribution of columns
plotPerColumnDistribution(df, 10, 5)

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {df['Finger'].value_counts().get('thumb', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Index fingers: {df['Finger'].value_counts().get('index', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Middle fingers: {df['Finger'].value_counts().get('middle', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Ring fingers: {df['Finger'].value_counts().get('ring', 0) / len(df) * 100:.2f}%")
print(f"Percentage of Little fingers: {df['Finger'].value_counts().get('little', 0) / len(df) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.98%
# Percentage of Little fingers: 20.01%

# %%
# List to store file information
imgdata = []

# Traverse the input directory to get all image files
for dirname, _, filenames in os.walk(DATASET_ROOTDIR_PATH):
    for filename in filenames:
         
        if filename == ".DS_Store":  # Skip macOS system files
            continue

        if filename.find("thumb") != -1:
           finger = "thumb"
        elif filename.find("index") != -1:
            finger = "index"
        elif filename.find("middle") != -1:
            finger = "middle"
        elif filename.find("ring") != -1:
            finger = "ring"
        elif filename.find("little") != -1:
            finger = "little"
        else:
            finger = None

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        # image is to be considered given the current class names 
        file_path = os.path.join(dirname, filename)

        # extract the image features
        img = Image.open(file_path)
    
        try:
            img.verify()  # Verify that the file is a valid image
        except:
            print(f"Invalid image file: {file_path}")
            continue

        imgdata.append([file_path, img.format, img.size, img.mode, finger])

# Create a DataFrame
imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Finger"])

# Add an index column
imgdf.index.name = "ID"

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9573 entries, 0 to 9572
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    9573 non-null   str
#  1   ImageFormat  9573 non-null   str
#  2   ImageSize    9573 non-null   object
#  3   ImageMode    9573 non-null   str
#  4   Finger       9573 non-null   str
# dtypes: object(1), str(4)
# memory usage: 374.1+ KB

# %%
# Display the distribution of ImageFormat, ImageSize, ImageMode
print(imgdf["ImageFormat"].value_counts())
print(imgdf["ImageSize"].value_counts())
print(imgdf["ImageMode"].value_counts())
# Out:
# ImageFormat
# JPEG    9573
# Name: count, dtype: int64
# ImageSize
# (96, 96)    9573
# Name: count, dtype: int64
# ImageMode
# RGB    9573
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 49.98%
# Percentage of Index fingers: 50.02%
# Percentage of Middle fingers: 0.00%
# Percentage of Ring fingers: 0.00%
# Percentage of Little fingers: 0.00%

# %%
# visualisation of some images
print("FingerPrint Examples from dataset\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(DATASET_ROOTDIR_PATH, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset

# %% [markdown]
# ## Split dataset for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 9573 files belonging to 2 classes.
# Using 7659 files for training.
# Found 9573 files belonging to 2 classes.
# Using 1914 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index']
#   - Validation Dataset Classes           : ['thumb', 'index']
#   - ✅ Number of correct classes : 2
#
#   - Training batches    : 120
#   - Validation batches    : 30
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~7680
#   - Validation samples    : ~1920
# 2026-03-22 22:15:26.736249: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-22 22:15:26.736276: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-22 22:15:26.736286: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-22 22:15:26.736301: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-22 22:15:26.736313: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

# Size of intermediate dense layers between base-model and classifier stage
HIDDEN_DENSE_LAYERS_SIZE = [256, 64]

def leaky_relu(x):
    return keras.activations.relu(x, negative_slope=0.01)

ACTIVATION_FUNCTION = leaky_relu

# Regularization setting
L2_REGULARIZATION = 0.01
DROPOUT_RATE = 0.3

# Learning Rate Standard for Transfer Learning of frozen model 
LEARNING_RATE = 0.001

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothened out hidden layers with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[0], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYERS_SIZE[1], 
                 activation=ACTIVATION_FUNCTION, 
                 kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

# Smootened out classification layer
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compile the model with Adam optimizer and standard LR  
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[0]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYERS_SIZE[1]},{ACTIVATION_FUNCTION}) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES},{classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 FringerPrint Model configuration:")
print(f"  - Learning rate           : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate            : {DROPOUT_RATE} (medium)")
print(f"  - 1rst Hidden dense layer : {HIDDEN_DENSE_LAYERS_SIZE[0]} neurons")
print(f"  - 2nd Hidden dense layer  : {HIDDEN_DENSE_LAYERS_SIZE[1]} neurons")
print(f"  - L2 regularization       : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,<function leaky_relu at 0x174ee87c0>) → Dropout(0.3) → Dense(64,<function leaky_relu at 0x174ee87c0>) → Dropout(0.3) → Dense(2,sigmoid)
#
#   - Trainable parameters     : 344,514
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,602,498
#
# 💡 FringerPrint Model configuration:
#   - Learning rate           : 0.001 (standard)
#   - Dropout rate            : 0.3 (medium)
#   - 1rst Hidden dense layer : 256 neurons
#   - 2nd Hidden dense layer  : 64 neurons
#   - L2 regularization       : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_2_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,498 (9.93 MB)
#  Trainable params: 344,514 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 15
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + "_Transfer_Learning.keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 90
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 90
#   - EarlyStopping Patience   : 15 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/90
# 2026-03-22 22:15:28.951322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7616 - loss: 4.0229 - top2_accuracy: 1.0000
# Epoch 1: val_accuracy improved from None to 0.87147, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - accuracy: 0.8193 - loss: 2.8149 - top2_accuracy: 1.0000 - val_accuracy: 0.8715 - val_loss: 1.4022 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 2/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8602 - loss: 1.2157 - top2_accuracy: 1.0000
# Epoch 2: val_accuracy improved from 0.87147 to 0.90021, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.8672 - loss: 1.0480 - top2_accuracy: 1.0000 - val_accuracy: 0.9002 - val_loss: 0.7478 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 3/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8703 - loss: 0.7329 - top2_accuracy: 1.0000
# Epoch 3: val_accuracy did not improve from 0.90021
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8745 - loss: 0.6728 - top2_accuracy: 1.0000 - val_accuracy: 0.8746 - val_loss: 0.5804 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 4/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8680 - loss: 0.5599 - top2_accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 0.90021
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8754 - loss: 0.5190 - top2_accuracy: 1.0000 - val_accuracy: 0.8783 - val_loss: 0.4716 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 5/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8683 - loss: 0.4784 - top2_accuracy: 1.0000
# Epoch 5: val_accuracy improved from 0.90021 to 0.90491, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.8795 - loss: 0.4506 - top2_accuracy: 1.0000 - val_accuracy: 0.9049 - val_loss: 0.3827 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 6/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8913 - loss: 0.4039 - top2_accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.90491
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8873 - loss: 0.3986 - top2_accuracy: 1.0000 - val_accuracy: 0.9023 - val_loss: 0.3486 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 7/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8882 - loss: 0.3855 - top2_accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.90491
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8890 - loss: 0.3756 - top2_accuracy: 1.0000 - val_accuracy: 0.8950 - val_loss: 0.3563 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 8/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8853 - loss: 0.3780 - top2_accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.90491
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8863 - loss: 0.3753 - top2_accuracy: 1.0000 - val_accuracy: 0.9018 - val_loss: 0.3456 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 9/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8843 - loss: 0.3648 - top2_accuracy: 1.0000
# Epoch 9: val_accuracy improved from 0.90491 to 0.90752, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.8854 - loss: 0.3569 - top2_accuracy: 1.0000 - val_accuracy: 0.9075 - val_loss: 0.3294 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 10/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8821 - loss: 0.3644 - top2_accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8848 - loss: 0.3603 - top2_accuracy: 1.0000 - val_accuracy: 0.8918 - val_loss: 0.3602 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 11/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8873 - loss: 0.3579 - top2_accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8867 - loss: 0.3522 - top2_accuracy: 1.0000 - val_accuracy: 0.9075 - val_loss: 0.3282 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 12/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8834 - loss: 0.3643 - top2_accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8868 - loss: 0.3531 - top2_accuracy: 1.0000 - val_accuracy: 0.9018 - val_loss: 0.3209 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 13/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8884 - loss: 0.3543 - top2_accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8892 - loss: 0.3497 - top2_accuracy: 1.0000 - val_accuracy: 0.9065 - val_loss: 0.3292 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 14/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8826 - loss: 0.3603 - top2_accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8911 - loss: 0.3459 - top2_accuracy: 1.0000 - val_accuracy: 0.8971 - val_loss: 0.3193 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 15/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8842 - loss: 0.3485 - top2_accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8880 - loss: 0.3424 - top2_accuracy: 1.0000 - val_accuracy: 0.9065 - val_loss: 0.3228 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 16/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8869 - loss: 0.3435 - top2_accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.90752
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8912 - loss: 0.3379 - top2_accuracy: 1.0000 - val_accuracy: 0.9049 - val_loss: 0.3160 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 17/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8836 - loss: 0.3551 - top2_accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.90752 to 0.91484, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 17: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.8936 - loss: 0.3401 - top2_accuracy: 1.0000 - val_accuracy: 0.9148 - val_loss: 0.2899 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 18/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8940 - loss: 0.3363 - top2_accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.91484
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8920 - loss: 0.3382 - top2_accuracy: 1.0000 - val_accuracy: 0.9039 - val_loss: 0.3226 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 19/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8900 - loss: 0.3430 - top2_accuracy: 1.0000
# Epoch 19: val_accuracy improved from 0.91484 to 0.91850, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.8933 - loss: 0.3350 - top2_accuracy: 1.0000 - val_accuracy: 0.9185 - val_loss: 0.2948 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 20/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8902 - loss: 0.3420 - top2_accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.91850
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8933 - loss: 0.3351 - top2_accuracy: 1.0000 - val_accuracy: 0.9054 - val_loss: 0.2967 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 21/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8922 - loss: 0.3297 - top2_accuracy: 1.0000
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_accuracy did not improve from 0.91850
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8932 - loss: 0.3262 - top2_accuracy: 1.0000 - val_accuracy: 0.9033 - val_loss: 0.3180 - val_top2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 22/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8893 - loss: 0.3380 - top2_accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.91850
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8988 - loss: 0.3213 - top2_accuracy: 1.0000 - val_accuracy: 0.9159 - val_loss: 0.2832 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 23/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9030 - loss: 0.3018 - top2_accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.91850
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.9066 - loss: 0.2941 - top2_accuracy: 1.0000 - val_accuracy: 0.9164 - val_loss: 0.2756 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 24/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8985 - loss: 0.3049 - top2_accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.91850 to 0.92111, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9019 - loss: 0.2989 - top2_accuracy: 1.0000 - val_accuracy: 0.9211 - val_loss: 0.2749 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 25/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9055 - loss: 0.2934 - top2_accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.92111
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.9070 - loss: 0.2895 - top2_accuracy: 1.0000 - val_accuracy: 0.9175 - val_loss: 0.2711 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 26/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9031 - loss: 0.2910 - top2_accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.92111
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9064 - loss: 0.2894 - top2_accuracy: 1.0000 - val_accuracy: 0.9154 - val_loss: 0.2697 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 27/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9075 - loss: 0.2838 - top2_accuracy: 1.0000
# Epoch 27: val_accuracy improved from 0.92111 to 0.92163, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9095 - loss: 0.2841 - top2_accuracy: 1.0000 - val_accuracy: 0.9216 - val_loss: 0.2671 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 28/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9117 - loss: 0.2913 - top2_accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.92163
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9090 - loss: 0.2878 - top2_accuracy: 1.0000 - val_accuracy: 0.9138 - val_loss: 0.2890 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 29/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9046 - loss: 0.2984 - top2_accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.92163 to 0.92529, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 29: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.9090 - loss: 0.2881 - top2_accuracy: 1.0000 - val_accuracy: 0.9253 - val_loss: 0.2585 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 30/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9064 - loss: 0.2805 - top2_accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.92529
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9057 - loss: 0.2815 - top2_accuracy: 1.0000 - val_accuracy: 0.9216 - val_loss: 0.2593 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 31/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9089 - loss: 0.2918 - top2_accuracy: 1.0000
# Epoch 31: val_accuracy improved from 0.92529 to 0.92633, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 31: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.9093 - loss: 0.2859 - top2_accuracy: 1.0000 - val_accuracy: 0.9263 - val_loss: 0.2559 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 32/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9136 - loss: 0.2807 - top2_accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.92633
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.9124 - loss: 0.2801 - top2_accuracy: 1.0000 - val_accuracy: 0.9258 - val_loss: 0.2599 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 33/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9145 - loss: 0.2782 - top2_accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.92633
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.9127 - loss: 0.2803 - top2_accuracy: 1.0000 - val_accuracy: 0.9237 - val_loss: 0.2555 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 34/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9184 - loss: 0.2736 - top2_accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.92633
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.9170 - loss: 0.2722 - top2_accuracy: 1.0000 - val_accuracy: 0.9222 - val_loss: 0.2627 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 35/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9111 - loss: 0.2818 - top2_accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.92633
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.9113 - loss: 0.2814 - top2_accuracy: 1.0000 - val_accuracy: 0.9216 - val_loss: 0.2506 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 36/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9153 - loss: 0.2791 - top2_accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.92633
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.9162 - loss: 0.2737 - top2_accuracy: 1.0000 - val_accuracy: 0.9232 - val_loss: 0.2441 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 37/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9120 - loss: 0.2723 - top2_accuracy: 1.0000
# Epoch 37: val_accuracy improved from 0.92633 to 0.92947, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 37: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.9170 - loss: 0.2658 - top2_accuracy: 1.0000 - val_accuracy: 0.9295 - val_loss: 0.2534 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 38/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9095 - loss: 0.2783 - top2_accuracy: 1.0000
# Epoch 38: val_accuracy improved from 0.92947 to 0.93574, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 38: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9133 - loss: 0.2722 - top2_accuracy: 1.0000 - val_accuracy: 0.9357 - val_loss: 0.2458 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 39/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9175 - loss: 0.2669 - top2_accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9133 - loss: 0.2728 - top2_accuracy: 1.0000 - val_accuracy: 0.9295 - val_loss: 0.2537 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 40/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9124 - loss: 0.2809 - top2_accuracy: 1.0000
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 40: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9127 - loss: 0.2759 - top2_accuracy: 1.0000 - val_accuracy: 0.9232 - val_loss: 0.2533 - val_top2_accuracy: 1.0000 - learning_rate: 5.0000e-04
# Epoch 41/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9157 - loss: 0.2696 - top2_accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9164 - loss: 0.2635 - top2_accuracy: 1.0000 - val_accuracy: 0.9284 - val_loss: 0.2353 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 42/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9213 - loss: 0.2569 - top2_accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9213 - loss: 0.2560 - top2_accuracy: 1.0000 - val_accuracy: 0.9284 - val_loss: 0.2374 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 43/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9165 - loss: 0.2612 - top2_accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9211 - loss: 0.2522 - top2_accuracy: 1.0000 - val_accuracy: 0.9295 - val_loss: 0.2292 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 44/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9251 - loss: 0.2460 - top2_accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9261 - loss: 0.2439 - top2_accuracy: 1.0000 - val_accuracy: 0.9357 - val_loss: 0.2255 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 45/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9255 - loss: 0.2509 - top2_accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9262 - loss: 0.2457 - top2_accuracy: 1.0000 - val_accuracy: 0.9321 - val_loss: 0.2253 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 46/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9252 - loss: 0.2444 - top2_accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.93574
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.9257 - loss: 0.2427 - top2_accuracy: 1.0000 - val_accuracy: 0.9295 - val_loss: 0.2363 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 47/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9248 - loss: 0.2420 - top2_accuracy: 1.0000
# Epoch 47: val_accuracy improved from 0.93574 to 0.93626, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 47: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.9243 - loss: 0.2409 - top2_accuracy: 1.0000 - val_accuracy: 0.9363 - val_loss: 0.2252 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 48/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9272 - loss: 0.2452 - top2_accuracy: 1.0000
# Epoch 48: val_accuracy improved from 0.93626 to 0.93887, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 48: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.9248 - loss: 0.2473 - top2_accuracy: 1.0000 - val_accuracy: 0.9389 - val_loss: 0.2217 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 49/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9254 - loss: 0.2430 - top2_accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.93887
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.9309 - loss: 0.2357 - top2_accuracy: 1.0000 - val_accuracy: 0.9378 - val_loss: 0.2213 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 50/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9233 - loss: 0.2449 - top2_accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.93887
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 116ms/step - accuracy: 0.9247 - loss: 0.2438 - top2_accuracy: 1.0000 - val_accuracy: 0.9347 - val_loss: 0.2206 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 51/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9241 - loss: 0.2449 - top2_accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.93887
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.9258 - loss: 0.2414 - top2_accuracy: 1.0000 - val_accuracy: 0.9378 - val_loss: 0.2217 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 52/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9250 - loss: 0.2485 - top2_accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.93887
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - accuracy: 0.9266 - loss: 0.2418 - top2_accuracy: 1.0000 - val_accuracy: 0.9373 - val_loss: 0.2167 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 53/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9292 - loss: 0.2389 - top2_accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.93887
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - accuracy: 0.9271 - loss: 0.2407 - top2_accuracy: 1.0000 - val_accuracy: 0.9378 - val_loss: 0.2213 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 54/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9278 - loss: 0.2425 - top2_accuracy: 1.0000
# Epoch 54: val_accuracy improved from 0.93887 to 0.93992, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 54: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 15s 122ms/step - accuracy: 0.9270 - loss: 0.2428 - top2_accuracy: 1.0000 - val_accuracy: 0.9399 - val_loss: 0.2225 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 55/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9223 - loss: 0.2461 - top2_accuracy: 1.0000
# Epoch 55: val_accuracy improved from 0.93992 to 0.94305, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 55: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - accuracy: 0.9266 - loss: 0.2406 - top2_accuracy: 1.0000 - val_accuracy: 0.9431 - val_loss: 0.2158 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 56/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9269 - loss: 0.2350 - top2_accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.94305
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - accuracy: 0.9271 - loss: 0.2345 - top2_accuracy: 1.0000 - val_accuracy: 0.9410 - val_loss: 0.2172 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 57/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9262 - loss: 0.2391 - top2_accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.94305
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - accuracy: 0.9248 - loss: 0.2386 - top2_accuracy: 1.0000 - val_accuracy: 0.9404 - val_loss: 0.2187 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 58/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9342 - loss: 0.2300 - top2_accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.94305
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step - accuracy: 0.9332 - loss: 0.2328 - top2_accuracy: 1.0000 - val_accuracy: 0.9389 - val_loss: 0.2148 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 59/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9266 - loss: 0.2387 - top2_accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.94305
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 114ms/step - accuracy: 0.9307 - loss: 0.2311 - top2_accuracy: 1.0000 - val_accuracy: 0.9415 - val_loss: 0.2136 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 60/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9272 - loss: 0.2381 - top2_accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.94305
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - accuracy: 0.9296 - loss: 0.2306 - top2_accuracy: 1.0000 - val_accuracy: 0.9420 - val_loss: 0.2094 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 61/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9339 - loss: 0.2320 - top2_accuracy: 1.0000
# Epoch 61: val_accuracy improved from 0.94305 to 0.94462, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 61: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - accuracy: 0.9312 - loss: 0.2308 - top2_accuracy: 1.0000 - val_accuracy: 0.9446 - val_loss: 0.2123 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 62/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9307 - loss: 0.2294 - top2_accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.94462
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - accuracy: 0.9318 - loss: 0.2328 - top2_accuracy: 1.0000 - val_accuracy: 0.9410 - val_loss: 0.2233 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 63/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9332 - loss: 0.2295 - top2_accuracy: 1.0000
# Epoch 63: val_accuracy improved from 0.94462 to 0.94671, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 63: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 115ms/step - accuracy: 0.9298 - loss: 0.2326 - top2_accuracy: 1.0000 - val_accuracy: 0.9467 - val_loss: 0.2101 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 64/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9374 - loss: 0.2259 - top2_accuracy: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 64: val_accuracy did not improve from 0.94671
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - accuracy: 0.9342 - loss: 0.2313 - top2_accuracy: 1.0000 - val_accuracy: 0.9383 - val_loss: 0.2207 - val_top2_accuracy: 1.0000 - learning_rate: 2.5000e-04
# Epoch 65/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9374 - loss: 0.2192 - top2_accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.94671
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.9385 - loss: 0.2142 - top2_accuracy: 1.0000 - val_accuracy: 0.9431 - val_loss: 0.2066 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 66/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9414 - loss: 0.2099 - top2_accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.94671
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.9407 - loss: 0.2108 - top2_accuracy: 1.0000 - val_accuracy: 0.9420 - val_loss: 0.2063 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 67/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9380 - loss: 0.2142 - top2_accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.94671
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.9410 - loss: 0.2074 - top2_accuracy: 1.0000 - val_accuracy: 0.9404 - val_loss: 0.2080 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 68/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9405 - loss: 0.2093 - top2_accuracy: 1.0000
# Epoch 68: val_accuracy improved from 0.94671 to 0.94828, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 68: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.9405 - loss: 0.2068 - top2_accuracy: 1.0000 - val_accuracy: 0.9483 - val_loss: 0.2024 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 69/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9381 - loss: 0.2166 - top2_accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.9399 - loss: 0.2115 - top2_accuracy: 1.0000 - val_accuracy: 0.9478 - val_loss: 0.2001 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 70/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9428 - loss: 0.2067 - top2_accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.9401 - loss: 0.2092 - top2_accuracy: 1.0000 - val_accuracy: 0.9472 - val_loss: 0.1993 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 71/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9374 - loss: 0.2095 - top2_accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - accuracy: 0.9412 - loss: 0.2054 - top2_accuracy: 1.0000 - val_accuracy: 0.9483 - val_loss: 0.1993 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 72/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9382 - loss: 0.2137 - top2_accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - accuracy: 0.9390 - loss: 0.2095 - top2_accuracy: 1.0000 - val_accuracy: 0.9446 - val_loss: 0.2012 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 73/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9338 - loss: 0.2144 - top2_accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - accuracy: 0.9352 - loss: 0.2109 - top2_accuracy: 1.0000 - val_accuracy: 0.9441 - val_loss: 0.1994 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 74/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9395 - loss: 0.2111 - top2_accuracy: 1.0000
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 74: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 16s 131ms/step - accuracy: 0.9392 - loss: 0.2094 - top2_accuracy: 1.0000 - val_accuracy: 0.9451 - val_loss: 0.2002 - val_top2_accuracy: 1.0000 - learning_rate: 1.2500e-04
# Epoch 75/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9403 - loss: 0.1964 - top2_accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 107ms/step - accuracy: 0.9407 - loss: 0.1982 - top2_accuracy: 1.0000 - val_accuracy: 0.9451 - val_loss: 0.1979 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 76/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9448 - loss: 0.1974 - top2_accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.94828
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.9433 - loss: 0.1974 - top2_accuracy: 1.0000 - val_accuracy: 0.9478 - val_loss: 0.1949 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 77/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9411 - loss: 0.1997 - top2_accuracy: 1.0000
# Epoch 77: val_accuracy improved from 0.94828 to 0.94984, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 77: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.9411 - loss: 0.1987 - top2_accuracy: 1.0000 - val_accuracy: 0.9498 - val_loss: 0.1960 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 78/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9471 - loss: 0.1977 - top2_accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.94984
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.9440 - loss: 0.1988 - top2_accuracy: 1.0000 - val_accuracy: 0.9488 - val_loss: 0.1958 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 79/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9479 - loss: 0.1963 - top2_accuracy: 1.0000
# Epoch 79: val_accuracy improved from 0.94984 to 0.95141, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 79: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.9466 - loss: 0.1972 - top2_accuracy: 1.0000 - val_accuracy: 0.9514 - val_loss: 0.1956 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 80/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9402 - loss: 0.2054 - top2_accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9439 - loss: 0.1986 - top2_accuracy: 1.0000 - val_accuracy: 0.9509 - val_loss: 0.1900 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 81/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9409 - loss: 0.2007 - top2_accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9412 - loss: 0.2005 - top2_accuracy: 1.0000 - val_accuracy: 0.9514 - val_loss: 0.1925 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 82/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9411 - loss: 0.2007 - top2_accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9411 - loss: 0.2008 - top2_accuracy: 1.0000 - val_accuracy: 0.9493 - val_loss: 0.1919 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 83/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9438 - loss: 0.2020 - top2_accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.9459 - loss: 0.1975 - top2_accuracy: 1.0000 - val_accuracy: 0.9493 - val_loss: 0.1907 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 84/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9442 - loss: 0.1957 - top2_accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.9450 - loss: 0.1946 - top2_accuracy: 1.0000 - val_accuracy: 0.9514 - val_loss: 0.1891 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 85/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9460 - loss: 0.1953 - top2_accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.9444 - loss: 0.1970 - top2_accuracy: 1.0000 - val_accuracy: 0.9504 - val_loss: 0.1907 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 86/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9469 - loss: 0.1942 - top2_accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.95141
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9463 - loss: 0.1943 - top2_accuracy: 1.0000 - val_accuracy: 0.9493 - val_loss: 0.1925 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 87/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9474 - loss: 0.1905 - top2_accuracy: 1.0000
# Epoch 87: val_accuracy improved from 0.95141 to 0.95246, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 87: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9473 - loss: 0.1907 - top2_accuracy: 1.0000 - val_accuracy: 0.9525 - val_loss: 0.1898 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 88/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9466 - loss: 0.1907 - top2_accuracy: 1.0000
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 88: val_accuracy did not improve from 0.95246
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9459 - loss: 0.1912 - top2_accuracy: 1.0000 - val_accuracy: 0.9519 - val_loss: 0.1898 - val_top2_accuracy: 1.0000 - learning_rate: 6.2500e-05
# Epoch 89/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9466 - loss: 0.1884 - top2_accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.95246
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9480 - loss: 0.1865 - top2_accuracy: 1.0000 - val_accuracy: 0.9519 - val_loss: 0.1890 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-05
# Epoch 90/90
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9467 - loss: 0.1942 - top2_accuracy: 1.0000
# Epoch 90: val_accuracy improved from 0.95246 to 0.95350, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
#
# Epoch 90: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_2_classes_Transfer_Learning.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.9462 - loss: 0.1959 - top2_accuracy: 1.0000 - val_accuracy: 0.9535 - val_loss: 0.1873 - val_top2_accuracy: 1.0000 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 90.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 90
#    Best val_accuracy : 95.35% (epoch 90)
#
# 🎯 Excellent ! Accuracy of 95.4%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=thumb        | Prediction=thumb        | Confidence= 79.6% | 2nd Prediction=index        | 2nd Confidence= 14.3%
# ✅ Image 2: Label=index        | Prediction=index        | Confidence= 96.3% | 2nd Prediction=thumb        | 2nd Confidence=  4.1%
# ✅ Image 3: Label=index        | Prediction=index        | Confidence= 93.3% | 2nd Prediction=thumb        | 2nd Confidence=  7.3%
# ✅ Image 4: Label=thumb        | Prediction=thumb        | Confidence= 93.2% | 2nd Prediction=index        | 2nd Confidence=  3.5%
# ✅ Image 5: Label=index        | Prediction=index        | Confidence= 73.9% | 2nd Prediction=thumb        | 2nd Confidence= 24.4%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence= 98.2% | 2nd Prediction=index        | 2nd Confidence=  0.7%
# ✅ Image 7: Label=index        | Prediction=index        | Confidence= 92.8% | 2nd Prediction=thumb        | 2nd Confidence=  7.8%
# ❌ Image 8: Label=index        | Prediction=thumb        | Confidence= 59.1% | 2nd Prediction=index        | 2nd Confidence= 34.1%
# ✅ Image 9: Label=index        | Prediction=index        | Confidence= 94.2% | 2nd Prediction=thumb        | 2nd Confidence=  6.4%
# ✅ Image 10: Label=index        | Prediction=index        | Confidence= 90.5% | 2nd Prediction=thumb        | 2nd Confidence= 10.0%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence= 90.7% | 2nd Prediction=thumb        | 2nd Confidence=  9.9%
# ❌ Image 12: Label=thumb        | Prediction=index        | Confidence= 66.5% | 2nd Prediction=thumb        | 2nd Confidence= 30.7%
# ✅ Image 13: Label=thumb        | Prediction=thumb        | Confidence= 60.7% | 2nd Prediction=index        | 2nd Confidence= 32.4%
# ✅ Image 14: Label=index        | Prediction=index        | Confidence= 94.1% | 2nd Prediction=thumb        | 2nd Confidence=  6.4%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 69.3% | 2nd Prediction=thumb        | 2nd Confidence= 28.4%
# ✅ Image 16: Label=index        | Prediction=index        | Confidence= 92.7% | 2nd Prediction=thumb        | 2nd Confidence=  8.0%
# ✅ Image 17: Label=index        | Prediction=index        | Confidence= 91.5% | 2nd Prediction=thumb        | 2nd Confidence=  9.1%
# ✅ Image 18: Label=index        | Prediction=index        | Confidence= 59.4% | 2nd Prediction=thumb        | 2nd Confidence= 36.6%
# ✅ Image 19: Label=thumb        | Prediction=thumb        | Confidence= 93.4% | 2nd Prediction=index        | 2nd Confidence=  3.3%
# ❌ Image 20: Label=thumb        | Prediction=index        | Confidence= 49.2% | 2nd Prediction=thumb        | 2nd Confidence= 45.6%
#
# ======================================================================================================================================================
# 2026-03-22 22:30:16.879369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 0.1873
#   - Accuracy            : 95.35%
#   - Top-2 Accuracy      : 100.00%
