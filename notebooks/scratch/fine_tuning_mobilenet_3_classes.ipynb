# %% [markdown]
# # A notebook for fine-tuning fingerprint model generated after transfer learning of mobilenet pre-trained model

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, saving

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"
fingerprint_basemodel_name = MobileNet_version + "_FingerPrint_BaseModel"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_basename = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_basename}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Training
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_3_classes

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

VALIDATION_SPLIT = 0.2
DATASET_SEED = 42

# Create traning dataset with class filtering
train_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
val_ds = image_dataset_from_directory(
    DATASET_ROOTDIR_PATH,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=DATASET_SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 14361 files belonging to 3 classes.
# Using 11489 files for training.
# Found 14361 files belonging to 3 classes.
# Using 2872 files for validation.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle']
#   - ✅ Number of correct classes : 3
#
#   - Training batches    : 180
#   - Validation batches    : 45
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~11520
#   - Validation samples    : ~2880
# 2026-03-23 20:59:09.839509: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-23 20:59:09.839547: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-23 20:59:09.839561: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-23 20:59:09.839582: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-23 20:59:09.839617: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset Preparation : normalization and shuffling (training only), no augmentation

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Loading Frozen Previously Trained model with Pre-Trained MobileNet base model

# %%
fingerprint_model_dir = "/Users/laurent/Projects/projet-fingerprint-validator/models"
fingerprint_model_name = fingerprint_model_basename + "_Transfer_Learning.keras"
fingerprint_model_path = fingerprint_model_dir + "/" + fingerprint_model_name

print(f"📥 Loading Frozen Previously Trained {fingerprint_model_name} model ...")

# Loading frozen fingerprint model
try:
    frozen_fingerprint_model = tf.keras.models.load_model(fingerprint_model_path, compile=True)
except Exception as e:
    print(f"Unable to load pre-trained model {fingerprint_model_path} : {e}")
    exit(0)

print(f"✅ {fingerprint_model_name} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {fingerprint_model_name} :")
print(f"  - Input shape    : {frozen_fingerprint_model.input_shape}")
print(f"  - Output shape   : {frozen_fingerprint_model.output_shape}")
print(f"  - Number of layers : {len(frozen_fingerprint_model.layers)}")

# Count parameters
total_params = frozen_fingerprint_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading Frozen Previously Trained MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model ...
# ✅ MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras model loaded !
#
# 📋 Model Structure - MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras :
#   - Input shape    : (None, 96, 96, 3)
#   - Output shape   : (None, 3)
#   - Number of layers : 8
#
#   - Total number of parameters : 2,602,563
#   - Memory size (approx.) : 9.9 MB

# %%
print(f"🔍 {fingerprint_model_name} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display layers
frozen_fingerprint_basemodel = None

print("\n📌 Model layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_model.layers):
    output_shape = get_output_shape(layer)
    if layer.name == fingerprint_basemodel_name:
        frozen_fingerprint_basemodel = layer

    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2_FingerPrint_Model_3_classes_Transfer_Learning.keras pre-trained model architecture
#
# ============================================================
#
# 📌 Model layers (low-level feature extraction) :
#     1. input_layer_1                            | Output: (None, 96, 96, 3)              | Trainable: True
#     2. MobileNetV2_FingerPrint_BaseModel        | Output: (None, 1280)                   | Trainable: False
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 64)                     | Trainable: True
#     7. dropout_2                                | Output: (None, 64)                     | Trainable: True
#     8. dense_2                                  | Output: (None, 3)                      | Trainable: True
#
#       ...
#
# ============================================================

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: True
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
frozen_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,291,723 (12.56 MB)
#  Trainable params: 344,579 (1.31 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 689,160 (2.63 MB)

# %% [markdown]
# ## Evaluation before Fine-Tuning

# %%
print("📈 Evaluation before fine-tuning :")

# Perform evaluation BEFORE fine-tuning
results_before = frozen_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")
# Out:
# 📈 Evaluation before fine-tuning :
# 2026-03-23 20:59:11.546635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#   - Accuracy : 79.53%
#   - Loss     : 0.5525

# %% [markdown]
# ## Fune-Tuning Preparation : unfreezing base model and recompile

# %%
# Constants
FINE_TUNING_UNFREEZE_LAYERS = 100

# Low LR for fine tuning
FINE_TUNE_LR = 1e-5

# %%
print("🔥 Fine-Tuning Preparation...\n")

# APPROCHE LA PLUS SIMPLE : Modifier le modèle frozen en place
print(f"💡 Strategy : unfreeze the {MobileNet_version} pre-trained base model and continue training\n")

# Unfreeze base model
frozen_fingerprint_basemodel.trainable = True

# Freeze only the first FINE_TUNING_UNFREEZE_LAYERS-th layers
for i, layer in enumerate(frozen_fingerprint_basemodel.layers):
    if i < FINE_TUNING_UNFREEZE_LAYERS:
        layer.trainable = False
    else:
        layer.trainable = True

print(f"📊 Unfreeze configuration :")
print(f"  - Frozen layers   : {FINE_TUNING_UNFREEZE_LAYERS}")
print(f"  - Unfrozen layers : {len(frozen_fingerprint_basemodel.layers) - FINE_TUNING_UNFREEZE_LAYERS}")

# Model params counting 
trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in frozen_fingerprint_basemodel.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Trainable params : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Frozen params    : {non_trainable_count:,}\n")

# Recompile model 
frozen_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Fine-tuned model with partial frozen base model 
finetuned_fingerprint_model = frozen_fingerprint_model

print(f"✅ Fingerprint model {finetuned_fingerprint_model.name} recompiled with low LR = {FINE_TUNE_LR}")
# Out:
# 🔥 Fine-Tuning Preparation...
#
# 💡 Strategy : unfreeze the MobileNetV2 pre-trained base model and continue training
#
# 📊 Unfreeze configuration :
#   - Frozen layers   : 100
#   - Unfrozen layers : 55
#   - Trainable params : 1,861,440 (82.4%)
#   - Frozen params    : 396,544
#
# ✅ Fingerprint model MobileNetV2_FingerPrint_Model_3_classes recompiled with low LR = 1e-05

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

# Display the first 10 and last 10 layers of the base model to verify unfreezing
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(frozen_fingerprint_basemodel.layers[-10:], start=len(frozen_fingerprint_basemodel.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#
# ============================================================

# %%
finetuned_fingerprint_model.summary()
# Out:
# Model: "MobileNetV2_FingerPrint_Model_3_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV2_FingerPrint_BaseMo… │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,602,563 (9.93 MB)
#  Trainable params: 2,206,019 (8.42 MB)
#  Non-trainable params: 396,544 (1.51 MB)

# %%
# failsafe checking
print("\n🔍 Weigths failsafe checking :")
results_after_compile = finetuned_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print(f"  - Accuracy : {results_after_compile[1]*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Transfer-learning weigths have been preserved ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Transfer-learning weigths have been affected after compile")
# Out:
# 🔍 Weigths failsafe checking :
#   - Accuracy : 79.53%
#   - Loss     : 0.5525
#
#   ✅ Transfer-learning weigths have been preserved (79.5%)

# %% [markdown]
# ## Fine-Tuning Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 7
REDUCELRONPLATEAU_MIN_LR = 1e-8
REDUCELRONPLATEAU_VERBOSE = 1

fingerprint_model_name = MobileNet_version + "_FingerPrint_Model_" + str(num_classes) + "_classes_Fine_Tuning.keras"
MODELCHECKPOINT_PATH = fingerprint_model_dir + "/" + fingerprint_model_name
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 120
FIT_VERBOSE = 1

# %%
print("🚀 Fine-tuning FringerPrint Model...\n")

# Callbacks 
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=EARLYSTOPPING_PATIENCE,
    restore_best_weights=True,
    mode='max',
    verbose=EARLYSTOPPING_VERBOSE
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=REDUCELRONPLATEAU_FACTOR,
    patience=REDUCELRONPLATEAU_PATIENCE,
    min_lr=REDUCELRONPLATEAU_MIN_LR,
    verbose=REDUCELRONPLATEAU_VERBOSE
)

checkpoint_ft = callbacks.ModelCheckpoint(
    MODELCHECKPOINT_PATH,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=MODELCHECKPOINT_VERBOSE
)
# Out:
# 🚀 Fine-tuning FringerPrint Model...

# %%
print(f"Training for {FIT_NUM_EPOCHS} epochs maximum...\n")

history_finetuned = finetuned_fingerprint_model.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=FIT_NUM_EPOCHS,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=FIT_VERBOSE
)

print("\n✅ Fine-tuning complete !")
print(f"   Number of epochs completed : {len(history_finetuned.history['loss'])}")

# Best performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
# These values are taken from transfer learning trainings
accuracies = [0.951, 0.826, 0.726, 0.68]

frozen_best = accuracies[num_classes - 2]
improvement = (best_val_acc - frozen_best) * 100
print(f"\n📊 Improvement vs Frozen : {improvement:+.1f} %")
print(f"   - Frozen    : {frozen_best*100:.1f}%")
print(f"   - Fine-tuned: {best_val_acc*100:.1f}%")
# Out:
# Training for 120 epochs maximum...
#
# Epoch 1/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.5751 - loss: 1.2537 - top2_accuracy: 0.8659
# Epoch 1: val_accuracy improved from None to 0.72110, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 49s 216ms/step - accuracy: 0.6236 - loss: 1.0280 - top2_accuracy: 0.8914 - val_accuracy: 0.7211 - val_loss: 0.8245 - val_top2_accuracy: 0.9022 - learning_rate: 1.0000e-05
# Epoch 2/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7158 - loss: 0.7321 - top2_accuracy: 0.9354
# Epoch 2: val_accuracy did not improve from 0.72110
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - accuracy: 0.7208 - loss: 0.7148 - top2_accuracy: 0.9382 - val_accuracy: 0.7117 - val_loss: 0.8556 - val_top2_accuracy: 0.8976 - learning_rate: 1.0000e-05
# Epoch 3/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7583 - loss: 0.6263 - top2_accuracy: 0.9551
# Epoch 3: val_accuracy improved from 0.72110 to 0.73120, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 197ms/step - accuracy: 0.7608 - loss: 0.6182 - top2_accuracy: 0.9552 - val_accuracy: 0.7312 - val_loss: 0.7982 - val_top2_accuracy: 0.9119 - learning_rate: 1.0000e-05
# Epoch 4/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7881 - loss: 0.5588 - top2_accuracy: 0.9644
# Epoch 4: val_accuracy improved from 0.73120 to 0.74513, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 197ms/step - accuracy: 0.7916 - loss: 0.5563 - top2_accuracy: 0.9647 - val_accuracy: 0.7451 - val_loss: 0.7606 - val_top2_accuracy: 0.9199 - learning_rate: 1.0000e-05
# Epoch 5/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8216 - loss: 0.5023 - top2_accuracy: 0.9740
# Epoch 5: val_accuracy improved from 0.74513 to 0.75070, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 5: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 196ms/step - accuracy: 0.8224 - loss: 0.4937 - top2_accuracy: 0.9735 - val_accuracy: 0.7507 - val_loss: 0.7238 - val_top2_accuracy: 0.9338 - learning_rate: 1.0000e-05
# Epoch 6/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8505 - loss: 0.4456 - top2_accuracy: 0.9806
# Epoch 6: val_accuracy improved from 0.75070 to 0.75104, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 6: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 195ms/step - accuracy: 0.8512 - loss: 0.4405 - top2_accuracy: 0.9818 - val_accuracy: 0.7510 - val_loss: 0.7174 - val_top2_accuracy: 0.9377 - learning_rate: 1.0000e-05
# Epoch 7/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8668 - loss: 0.4019 - top2_accuracy: 0.9846
# Epoch 7: val_accuracy improved from 0.75104 to 0.76079, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 7: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 196ms/step - accuracy: 0.8724 - loss: 0.3940 - top2_accuracy: 0.9849 - val_accuracy: 0.7608 - val_loss: 0.6829 - val_top2_accuracy: 0.9453 - learning_rate: 1.0000e-05
# Epoch 8/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8864 - loss: 0.3568 - top2_accuracy: 0.9886
# Epoch 8: val_accuracy improved from 0.76079 to 0.78099, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 8: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 35s 196ms/step - accuracy: 0.8864 - loss: 0.3563 - top2_accuracy: 0.9887 - val_accuracy: 0.7810 - val_loss: 0.6230 - val_top2_accuracy: 0.9558 - learning_rate: 1.0000e-05
# Epoch 9/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9062 - loss: 0.3154 - top2_accuracy: 0.9917
# Epoch 9: val_accuracy improved from 0.78099 to 0.79318, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 9: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9095 - loss: 0.3097 - top2_accuracy: 0.9920 - val_accuracy: 0.7932 - val_loss: 0.6014 - val_top2_accuracy: 0.9645 - learning_rate: 1.0000e-05
# Epoch 10/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9259 - loss: 0.2802 - top2_accuracy: 0.9935
# Epoch 10: val_accuracy improved from 0.79318 to 0.81128, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 10: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9272 - loss: 0.2752 - top2_accuracy: 0.9930 - val_accuracy: 0.8113 - val_loss: 0.5605 - val_top2_accuracy: 0.9714 - learning_rate: 1.0000e-05
# Epoch 11/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9421 - loss: 0.2370 - top2_accuracy: 0.9953
# Epoch 11: val_accuracy improved from 0.81128 to 0.83148, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 11: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9439 - loss: 0.2345 - top2_accuracy: 0.9959 - val_accuracy: 0.8315 - val_loss: 0.5296 - val_top2_accuracy: 0.9735 - learning_rate: 1.0000e-05
# Epoch 12/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9524 - loss: 0.2073 - top2_accuracy: 0.9961
# Epoch 12: val_accuracy improved from 0.83148 to 0.84540, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 12: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9517 - loss: 0.2072 - top2_accuracy: 0.9963 - val_accuracy: 0.8454 - val_loss: 0.5116 - val_top2_accuracy: 0.9770 - learning_rate: 1.0000e-05
# Epoch 13/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9618 - loss: 0.1840 - top2_accuracy: 0.9972
# Epoch 13: val_accuracy improved from 0.84540 to 0.85585, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 13: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9636 - loss: 0.1805 - top2_accuracy: 0.9982 - val_accuracy: 0.8558 - val_loss: 0.4848 - val_top2_accuracy: 0.9791 - learning_rate: 1.0000e-05
# Epoch 14/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9658 - loss: 0.1671 - top2_accuracy: 0.9980
# Epoch 14: val_accuracy improved from 0.85585 to 0.86630, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 14: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9699 - loss: 0.1604 - top2_accuracy: 0.9984 - val_accuracy: 0.8663 - val_loss: 0.4726 - val_top2_accuracy: 0.9795 - learning_rate: 1.0000e-05
# Epoch 15/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9758 - loss: 0.1496 - top2_accuracy: 0.9988
# Epoch 15: val_accuracy improved from 0.86630 to 0.87221, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 15: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9782 - loss: 0.1430 - top2_accuracy: 0.9988 - val_accuracy: 0.8722 - val_loss: 0.4578 - val_top2_accuracy: 0.9795 - learning_rate: 1.0000e-05
# Epoch 16/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9796 - loss: 0.1340 - top2_accuracy: 0.9990
# Epoch 16: val_accuracy improved from 0.87221 to 0.88127, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9797 - loss: 0.1333 - top2_accuracy: 0.9991 - val_accuracy: 0.8813 - val_loss: 0.4453 - val_top2_accuracy: 0.9808 - learning_rate: 1.0000e-05
# Epoch 17/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9854 - loss: 0.1191 - top2_accuracy: 0.9999
# Epoch 17: val_accuracy improved from 0.88127 to 0.88440, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 17: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9865 - loss: 0.1179 - top2_accuracy: 0.9997 - val_accuracy: 0.8844 - val_loss: 0.4400 - val_top2_accuracy: 0.9826 - learning_rate: 1.0000e-05
# Epoch 18/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9894 - loss: 0.1113 - top2_accuracy: 0.9998
# Epoch 18: val_accuracy improved from 0.88440 to 0.88475, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 18: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9893 - loss: 0.1103 - top2_accuracy: 0.9997 - val_accuracy: 0.8847 - val_loss: 0.4408 - val_top2_accuracy: 0.9819 - learning_rate: 1.0000e-05
# Epoch 19/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9899 - loss: 0.1033 - top2_accuracy: 0.9999
# Epoch 19: val_accuracy improved from 0.88475 to 0.89032, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 19: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9909 - loss: 0.1029 - top2_accuracy: 0.9999 - val_accuracy: 0.8903 - val_loss: 0.4371 - val_top2_accuracy: 0.9833 - learning_rate: 1.0000e-05
# Epoch 20/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9933 - loss: 0.0981 - top2_accuracy: 0.9999
# Epoch 20: val_accuracy improved from 0.89032 to 0.89206, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 20: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9930 - loss: 0.0982 - top2_accuracy: 0.9998 - val_accuracy: 0.8921 - val_loss: 0.4392 - val_top2_accuracy: 0.9854 - learning_rate: 1.0000e-05
# Epoch 21/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9945 - loss: 0.0939 - top2_accuracy: 0.9998
# Epoch 21: val_accuracy did not improve from 0.89206
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9944 - loss: 0.0934 - top2_accuracy: 0.9997 - val_accuracy: 0.8914 - val_loss: 0.4451 - val_top2_accuracy: 0.9843 - learning_rate: 1.0000e-05
# Epoch 22/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9965 - loss: 0.0894 - top2_accuracy: 1.0000
# Epoch 22: val_accuracy improved from 0.89206 to 0.89415, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 22: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9966 - loss: 0.0883 - top2_accuracy: 0.9999 - val_accuracy: 0.8942 - val_loss: 0.4451 - val_top2_accuracy: 0.9861 - learning_rate: 1.0000e-05
# Epoch 23/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9950 - loss: 0.0870 - top2_accuracy: 1.0000
# Epoch 23: val_accuracy improved from 0.89415 to 0.89450, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 23: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9953 - loss: 0.0873 - top2_accuracy: 1.0000 - val_accuracy: 0.8945 - val_loss: 0.4399 - val_top2_accuracy: 0.9857 - learning_rate: 1.0000e-05
# Epoch 24/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9956 - loss: 0.0840 - top2_accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.89450 to 0.89520, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 24: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9966 - loss: 0.0833 - top2_accuracy: 1.0000 - val_accuracy: 0.8952 - val_loss: 0.4422 - val_top2_accuracy: 0.9861 - learning_rate: 1.0000e-05
# Epoch 25/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9973 - loss: 0.0817 - top2_accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.89520
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9979 - loss: 0.0799 - top2_accuracy: 1.0000 - val_accuracy: 0.8942 - val_loss: 0.4504 - val_top2_accuracy: 0.9864 - learning_rate: 1.0000e-05
# Epoch 26/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9988 - loss: 0.0777 - top2_accuracy: 1.0000
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 26: val_accuracy improved from 0.89520 to 0.89694, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 26: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9984 - loss: 0.0780 - top2_accuracy: 1.0000 - val_accuracy: 0.8969 - val_loss: 0.4481 - val_top2_accuracy: 0.9850 - learning_rate: 1.0000e-05
# Epoch 27/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9980 - loss: 0.0763 - top2_accuracy: 1.0000
# Epoch 27: val_accuracy improved from 0.89694 to 0.89972, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 27: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9980 - loss: 0.0765 - top2_accuracy: 1.0000 - val_accuracy: 0.8997 - val_loss: 0.4456 - val_top2_accuracy: 0.9854 - learning_rate: 5.0000e-06
# Epoch 28/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9975 - loss: 0.0763 - top2_accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.89972 to 0.90007, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 28: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9978 - loss: 0.0759 - top2_accuracy: 1.0000 - val_accuracy: 0.9001 - val_loss: 0.4442 - val_top2_accuracy: 0.9864 - learning_rate: 5.0000e-06
# Epoch 29/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9986 - loss: 0.0745 - top2_accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.90007 to 0.90042, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 29: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9984 - loss: 0.0744 - top2_accuracy: 1.0000 - val_accuracy: 0.9004 - val_loss: 0.4457 - val_top2_accuracy: 0.9857 - learning_rate: 5.0000e-06
# Epoch 30/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9992 - loss: 0.0723 - top2_accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.90042
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9990 - loss: 0.0727 - top2_accuracy: 0.9999 - val_accuracy: 0.8997 - val_loss: 0.4483 - val_top2_accuracy: 0.9854 - learning_rate: 5.0000e-06
# Epoch 31/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9986 - loss: 0.0722 - top2_accuracy: 1.0000
# Epoch 31: val_accuracy improved from 0.90042 to 0.90077, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 31: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9990 - loss: 0.0721 - top2_accuracy: 1.0000 - val_accuracy: 0.9008 - val_loss: 0.4505 - val_top2_accuracy: 0.9854 - learning_rate: 5.0000e-06
# Epoch 32/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9992 - loss: 0.0721 - top2_accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.90077
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9990 - loss: 0.0718 - top2_accuracy: 1.0000 - val_accuracy: 0.9008 - val_loss: 0.4565 - val_top2_accuracy: 0.9843 - learning_rate: 5.0000e-06
# Epoch 33/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9995 - loss: 0.0702 - top2_accuracy: 1.0000
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 33: val_accuracy did not improve from 0.90077
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9991 - loss: 0.0706 - top2_accuracy: 1.0000 - val_accuracy: 0.8987 - val_loss: 0.4600 - val_top2_accuracy: 0.9857 - learning_rate: 5.0000e-06
# Epoch 34/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9986 - loss: 0.0704 - top2_accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.90077
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9987 - loss: 0.0702 - top2_accuracy: 1.0000 - val_accuracy: 0.9001 - val_loss: 0.4554 - val_top2_accuracy: 0.9854 - learning_rate: 2.5000e-06
# Epoch 35/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9992 - loss: 0.0692 - top2_accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.90077
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9994 - loss: 0.0687 - top2_accuracy: 1.0000 - val_accuracy: 0.9001 - val_loss: 0.4531 - val_top2_accuracy: 0.9850 - learning_rate: 2.5000e-06
# Epoch 36/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9988 - loss: 0.0687 - top2_accuracy: 1.0000
# Epoch 36: val_accuracy improved from 0.90077 to 0.90181, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 36: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9988 - loss: 0.0690 - top2_accuracy: 1.0000 - val_accuracy: 0.9018 - val_loss: 0.4531 - val_top2_accuracy: 0.9850 - learning_rate: 2.5000e-06
# Epoch 37/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9997 - loss: 0.0680 - top2_accuracy: 0.9999
# Epoch 37: val_accuracy did not improve from 0.90181
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9992 - loss: 0.0684 - top2_accuracy: 0.9999 - val_accuracy: 0.9011 - val_loss: 0.4532 - val_top2_accuracy: 0.9861 - learning_rate: 2.5000e-06
# Epoch 38/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9997 - loss: 0.0671 - top2_accuracy: 1.0000
# Epoch 38: val_accuracy improved from 0.90181 to 0.90216, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 38: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9994 - loss: 0.0675 - top2_accuracy: 1.0000 - val_accuracy: 0.9022 - val_loss: 0.4494 - val_top2_accuracy: 0.9854 - learning_rate: 2.5000e-06
# Epoch 39/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9996 - loss: 0.0667 - top2_accuracy: 1.0000
# Epoch 39: val_accuracy improved from 0.90216 to 0.90494, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 39: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9994 - loss: 0.0670 - top2_accuracy: 1.0000 - val_accuracy: 0.9049 - val_loss: 0.4463 - val_top2_accuracy: 0.9857 - learning_rate: 2.5000e-06
# Epoch 40/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9999 - loss: 0.0659 - top2_accuracy: 1.0000
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 40: val_accuracy did not improve from 0.90494
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9997 - loss: 0.0663 - top2_accuracy: 1.0000 - val_accuracy: 0.9046 - val_loss: 0.4478 - val_top2_accuracy: 0.9854 - learning_rate: 2.5000e-06
# Epoch 41/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9996 - loss: 0.0663 - top2_accuracy: 1.0000
# Epoch 41: val_accuracy improved from 0.90494 to 0.90634, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9994 - loss: 0.0665 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4460 - val_top2_accuracy: 0.9854 - learning_rate: 1.2500e-06
# Epoch 42/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9995 - loss: 0.0654 - top2_accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.90634
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9993 - loss: 0.0658 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4455 - val_top2_accuracy: 0.9850 - learning_rate: 1.2500e-06
# Epoch 43/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9996 - loss: 0.0653 - top2_accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.90634
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9994 - loss: 0.0658 - top2_accuracy: 1.0000 - val_accuracy: 0.9053 - val_loss: 0.4452 - val_top2_accuracy: 0.9854 - learning_rate: 1.2500e-06
# Epoch 44/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9997 - loss: 0.0660 - top2_accuracy: 1.0000
# Epoch 44: val_accuracy improved from 0.90634 to 0.90669, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 44: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9995 - loss: 0.0657 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.4448 - val_top2_accuracy: 0.9854 - learning_rate: 1.2500e-06
# Epoch 45/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9992 - loss: 0.0654 - top2_accuracy: 1.0000
# Epoch 45: val_accuracy improved from 0.90669 to 0.90703, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
#
# Epoch 45: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_3_classes_Fine_Tuning.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9993 - loss: 0.0654 - top2_accuracy: 1.0000 - val_accuracy: 0.9070 - val_loss: 0.4464 - val_top2_accuracy: 0.9857 - learning_rate: 1.2500e-06
# Epoch 46/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9998 - loss: 0.0640 - top2_accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9998 - loss: 0.0642 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4471 - val_top2_accuracy: 0.9857 - learning_rate: 1.2500e-06
# Epoch 47/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9999 - loss: 0.0639 - top2_accuracy: 1.0000
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 47: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9998 - loss: 0.0639 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4451 - val_top2_accuracy: 0.9854 - learning_rate: 1.2500e-06
# Epoch 48/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9996 - loss: 0.0644 - top2_accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 222ms/step - accuracy: 0.9997 - loss: 0.0639 - top2_accuracy: 1.0000 - val_accuracy: 0.9049 - val_loss: 0.4455 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 49/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9989 - loss: 0.0648 - top2_accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9992 - loss: 0.0644 - top2_accuracy: 1.0000 - val_accuracy: 0.9046 - val_loss: 0.4452 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 50/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9993 - loss: 0.0647 - top2_accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9995 - loss: 0.0642 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4464 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 51/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9998 - loss: 0.0635 - top2_accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9995 - loss: 0.0638 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4454 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 52/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9992 - loss: 0.0645 - top2_accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9993 - loss: 0.0641 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4452 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 53/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9995 - loss: 0.0634 - top2_accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.9997 - loss: 0.0629 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4452 - val_top2_accuracy: 0.9854 - learning_rate: 6.2500e-07
# Epoch 54/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 1.0000 - loss: 0.0625 - top2_accuracy: 1.0000
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 54: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9999 - loss: 0.0628 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4446 - val_top2_accuracy: 0.9850 - learning_rate: 6.2500e-07
# Epoch 55/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.0625 - top2_accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9999 - loss: 0.0627 - top2_accuracy: 1.0000 - val_accuracy: 0.9049 - val_loss: 0.4444 - val_top2_accuracy: 0.9850 - learning_rate: 3.1250e-07
# Epoch 56/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9998 - loss: 0.0631 - top2_accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9995 - loss: 0.0634 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4442 - val_top2_accuracy: 0.9850 - learning_rate: 3.1250e-07
# Epoch 57/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9994 - loss: 0.0632 - top2_accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.9994 - loss: 0.0634 - top2_accuracy: 1.0000 - val_accuracy: 0.9070 - val_loss: 0.4432 - val_top2_accuracy: 0.9847 - learning_rate: 3.1250e-07
# Epoch 58/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9994 - loss: 0.0632 - top2_accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.9994 - loss: 0.0633 - top2_accuracy: 1.0000 - val_accuracy: 0.9056 - val_loss: 0.4433 - val_top2_accuracy: 0.9854 - learning_rate: 3.1250e-07
# Epoch 59/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9996 - loss: 0.0628 - top2_accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.9997 - loss: 0.0628 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4428 - val_top2_accuracy: 0.9854 - learning_rate: 3.1250e-07
# Epoch 60/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9996 - loss: 0.0624 - top2_accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9996 - loss: 0.0626 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4431 - val_top2_accuracy: 0.9854 - learning_rate: 3.1250e-07
# Epoch 61/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9995 - loss: 0.0631 - top2_accuracy: 1.0000
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 61: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.9992 - loss: 0.0633 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4426 - val_top2_accuracy: 0.9854 - learning_rate: 3.1250e-07
# Epoch 62/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9998 - loss: 0.0624 - top2_accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 41s 225ms/step - accuracy: 0.9997 - loss: 0.0628 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4427 - val_top2_accuracy: 0.9854 - learning_rate: 1.5625e-07
# Epoch 63/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9998 - loss: 0.0623 - top2_accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9996 - loss: 0.0631 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4427 - val_top2_accuracy: 0.9854 - learning_rate: 1.5625e-07
# Epoch 64/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9997 - loss: 0.0619 - top2_accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9997 - loss: 0.0621 - top2_accuracy: 1.0000 - val_accuracy: 0.9060 - val_loss: 0.4427 - val_top2_accuracy: 0.9854 - learning_rate: 1.5625e-07
# Epoch 65/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9999 - loss: 0.0623 - top2_accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9997 - loss: 0.0623 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4429 - val_top2_accuracy: 0.9850 - learning_rate: 1.5625e-07
# Epoch 66/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9992 - loss: 0.0632 - top2_accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9996 - loss: 0.0628 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4426 - val_top2_accuracy: 0.9850 - learning_rate: 1.5625e-07
# Epoch 67/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9996 - loss: 0.0630 - top2_accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9997 - loss: 0.0626 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4424 - val_top2_accuracy: 0.9850 - learning_rate: 1.5625e-07
# Epoch 68/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9998 - loss: 0.0620 - top2_accuracy: 1.0000
# Epoch 68: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 68: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9997 - loss: 0.0622 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4428 - val_top2_accuracy: 0.9850 - learning_rate: 1.5625e-07
# Epoch 69/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 1.0000 - loss: 0.0621 - top2_accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 1.0000 - loss: 0.0621 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4429 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 70/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9995 - loss: 0.0626 - top2_accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.9995 - loss: 0.0624 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4430 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 71/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9995 - loss: 0.0619 - top2_accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 198ms/step - accuracy: 0.9996 - loss: 0.0623 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4431 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 72/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9998 - loss: 0.0622 - top2_accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 198ms/step - accuracy: 0.9995 - loss: 0.0627 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4432 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 73/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0618 - top2_accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.9999 - loss: 0.0617 - top2_accuracy: 1.0000 - val_accuracy: 0.9063 - val_loss: 0.4432 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 74/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9995 - loss: 0.0622 - top2_accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.9996 - loss: 0.0621 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.4433 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 75/120
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9999 - loss: 0.0615 - top2_accuracy: 1.0000
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 75: val_accuracy did not improve from 0.90703
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9998 - loss: 0.0618 - top2_accuracy: 1.0000 - val_accuracy: 0.9067 - val_loss: 0.4432 - val_top2_accuracy: 0.9850 - learning_rate: 7.8125e-08
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 45.
#
# ✅ Fine-tuning complete !
#    Number of epochs completed : 75
#    Meilleure val_accuracy : 90.70% (epoch 45)
#
# 📊 Improvement vs Frozen : +8.1 %
#    - Frozen    : 82.6%
#    - Fine-tuned: 90.7%

# %% [markdown]
# ## Fine-Tuned Model Evaluation

# %%
print("🔍 Diagnostic of fine-tuned model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = finetuned_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of fine-tuned model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=index        | Prediction=index        | Confidence= 99.9% | 2nd Prediction=middle       | 2nd Confidence=  0.1%
# ✅ Image 2: Label=middle       | Prediction=middle       | Confidence= 96.3% | 2nd Prediction=index        | 2nd Confidence=  3.5%
# ✅ Image 3: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 6: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 7: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 97.2% | 2nd Prediction=middle       | 2nd Confidence=  1.9%
# ✅ Image 9: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ✅ Image 10: Label=thumb        | Prediction=thumb        | Confidence=100.0% | 2nd Prediction=middle       | 2nd Confidence=  0.0%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence=100.0% | 2nd Prediction=thumb        | 2nd Confidence=  0.0%
# ✅ Image 12: Label=middle       | Prediction=middle       | Confidence= 91.3% | 2nd Prediction=index        | 2nd Confidence=  8.7%
# ✅ Image 13: Label=middle       | Prediction=middle       | Confidence=100.0% | 2nd Prediction=index        | 2nd Confidence=  0.0%
# ❌ Image 14: Label=middle       | Prediction=index        | Confidence= 89.8% | 2nd Prediction=middle       | 2nd Confidence= 10.2%
# ✅ Image 15: Label=index        | Prediction=index        | Confidence= 99.4% | 2nd Prediction=thumb        | 2nd Confidence=  0.4%
# ✅ Image 16: Label=middle       | Prediction=middle       | Confidence= 99.9% | 2nd Prediction=index        | 2nd Confidence=  0.1%
# ✅ Image 17: Label=middle       | Prediction=middle       | Confidence= 99.6% | 2nd Prediction=index        | 2nd Confidence=  0.4%
# ❌ Image 18: Label=middle       | Prediction=index        | Confidence= 89.7% | 2nd Prediction=middle       | 2nd Confidence= 10.3%
# ✅ Image 19: Label=index        | Prediction=index        | Confidence= 98.8% | 2nd Prediction=middle       | 2nd Confidence=  1.1%
# ✅ Image 20: Label=middle       | Prediction=middle       | Confidence= 99.6% | 2nd Prediction=index        | 2nd Confidence=  0.4%
#
# ======================================================================================================================================================
# 2026-03-23 21:45:16.240251: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of fine-tuned model using validation dataset...\n")

results_model_finetuned = finetuned_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_model_finetuned[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_finetuned[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_finetuned.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_finetuned.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with fine tuning', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of fine-tuned model using validation dataset...
#
# Results :
#   - Loss                : 0.4464
#   - Accuracy            : 90.70%
#   - Top-2 Accuracy      : 98.57%
