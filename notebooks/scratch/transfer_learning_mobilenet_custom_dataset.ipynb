# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring', 'little']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_5_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def traverse_dataset_dir(dataset_dir, class_names):

    # List to store file information
    imgdata = []

    # Traverse the input directory to get all image files
    for dirname, _, filenames in os.walk(dataset_dir):

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        for filename in filenames:
         
            if filename == ".DS_Store":  # Skip macOS system files
                continue

            if filename.find("Zcut") != -1:
                feature = 'zcut'
            elif filename.find('CR') != -1:
                feature = 'cr'
            elif filename.find('Obl') != -1:
                feature = 'obl'
            else:
                feature = 'unaltered'

            if filename.find("thumb") != -1:
                finger = "thumb"
            elif filename.find("index") != -1:
                finger = "index"
            elif filename.find("middle") != -1:
                finger = "middle"
            elif filename.find("ring") != -1:
                finger = "ring"
            elif filename.find("little") != -1:
                finger = "little"
            else:
                finger = None

            # image is to be considered given the current class names 
            file_path = os.path.join(dirname, filename)

            # extract the image features
            img = Image.open(file_path)
    
            try:
                img.verify()  # Verify that the file is a valid image
            except:
                print(f"Invalid image file: {file_path}")
                continue

            imgdata.append([file_path, img.format, img.size, img.mode, feature, finger])

    # Create a DataFrame
    imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Feature", "Finger"])

    # Add an index column
    imgdf.index.name = "ID"

    return imgdf

# %%
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
imgdf = traverse_dataset_dir(dataset_train_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    15931 non-null  str
#  1   ImageFormat  15931 non-null  str
#  2   ImageSize    15931 non-null  object
#  3   ImageMode    15931 non-null  str
#  4   Feature      15931 non-null  str
#  5   Finger       15931 non-null  str
# dtypes: object(1), str(5)
# memory usage: 746.9+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    4000
# obl          3982
# zcut         3980
# cr           3969
# Name: count, dtype: int64
# Finger
# little    3188
# middle    3188
# index     3188
# thumb     3185
# ring      3182
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.97%
# Percentage of Little fingers: 20.01%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 25.11%
# Percentage of Zcut: 24.98%
# Percentage of CR: 24.91%
# Percentage of Obl: 25.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/train/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/train/

# %%
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
imgdf = traverse_dataset_dir(dataset_val_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    4000 non-null   str
#  1   ImageFormat  4000 non-null   str
#  2   ImageSize    4000 non-null   object
#  3   ImageMode    4000 non-null   str
#  4   Feature      4000 non-null   str
#  5   Finger       4000 non-null   str
# dtypes: object(1), str(5)
# memory usage: 187.6+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    2000
# zcut         2000
# Name: count, dtype: int64
# Finger
# little    800
# middle    800
# thumb     800
# index     800
# ring      800
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 50.00%
# Percentage of Zcut: 50.00%
# Percentage of CR: 0.00%
# Percentage of Obl: 0.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/validation/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/validation/

# %% [markdown]
# ## Split dataset for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 15931 files belonging to 5 classes.
# Found 4000 files belonging to 5 classes.
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 249
#   - Validation batches    : 63
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~15936
#   - Validation samples    : ~4032
# 2026-03-20 13:00:03.444127: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-20 13:00:03.444166: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-20 13:00:03.444174: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-20 13:00:03.444193: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-20 13:00:03.444207: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 256

DROPOUT_RATE = 0.3 # medium 
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001 # standard

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES}, {classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(5, softmax)
#
#   - Trainable parameters     : 329,221
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,587,205
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,205 (9.87 MB)
#  Trainable params: 329,221 (1.26 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 150
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 150
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/150
# 2026-03-20 13:00:06.215592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3910 - loss: 4.4438 - top2_accuracy: 0.6252
# Epoch 1: val_accuracy improved from None to 0.58400, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.4346 - loss: 3.2161 - top2_accuracy: 0.6671 - val_accuracy: 0.5840 - val_loss: 1.5382 - val_top2_accuracy: 0.7975 - learning_rate: 0.0010
# Epoch 2/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4802 - loss: 1.7728 - top2_accuracy: 0.7132
# Epoch 2: val_accuracy improved from 0.58400 to 0.59475, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.4853 - loss: 1.6389 - top2_accuracy: 0.7138 - val_accuracy: 0.5947 - val_loss: 1.2061 - val_top2_accuracy: 0.7952 - learning_rate: 0.0010
# Epoch 3/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4998 - loss: 1.3966 - top2_accuracy: 0.7313
# Epoch 3: val_accuracy improved from 0.59475 to 0.59925, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 3: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - accuracy: 0.5035 - loss: 1.3592 - top2_accuracy: 0.7354 - val_accuracy: 0.5993 - val_loss: 1.1187 - val_top2_accuracy: 0.8008 - learning_rate: 0.0010
# Epoch 4/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5144 - loss: 1.2838 - top2_accuracy: 0.7494
# Epoch 4: val_accuracy did not improve from 0.59925
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5212 - loss: 1.2582 - top2_accuracy: 0.7495 - val_accuracy: 0.5870 - val_loss: 1.0976 - val_top2_accuracy: 0.8150 - learning_rate: 0.0010
# Epoch 5/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.
150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5553 - loss: 1.1414 - top2_accuracy: 0.7752
# Epoch 15: val_accuracy did not improve from 0.60900
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5573 - loss: 1.1364 - top2_accuracy: 0.7789 - val_accuracy: 0.6010 - val_loss: 1.0409 - val_top2_accuracy: 0.8155 - learning_rate: 5.0000e-04
# Epoch 16/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5489 - loss: 1.1397 - top2_accuracy: 0.7805
# Epoch 16: val_accuracy improved from 0.60900 to 0.61575, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 16: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5547 - loss: 1.1362 - top2_accuracy: 0.7805 - val_accuracy: 0.6158 - val_loss: 1.0289 - val_top2_accuracy: 0.8215 - learning_rate: 5.0000e-04
# Epoch 17/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5561 - loss: 1.1389 - top2_accuracy: 0.7830
# Epoch 17: val_accuracy improved from 0.61575 to 0.62275, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 17: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5573 - loss: 1.1378 - top2_accuracy: 0.7847 - val_accuracy: 0.6227 - val_loss: 1.0251 - val_top2_accuracy: 0.8198 - learning_rate: 5.0000e-04
# Epoch 18/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5652 - loss: 1.1307 - top2_accuracy: 0.7860
# Epoch 18: val_accuracy did not improve from 0.62275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5654 - loss: 1.1306 - top2_accuracy: 0.7827 - val_accuracy: 0.6085 - val_loss: 1.0335 - val_top2_accuracy: 0.8200 - learning_rate: 5.0000e-04
# Epoch 19/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5596 - loss: 1.1378 - top2_accuracy: 0.7830
# Epoch 19: val_accuracy did not improve from 0.62275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5612 - loss: 1.1349 - top2_accuracy: 0.7846 - val_accuracy: 0.6145 - val_loss: 1.0319 - val_top2_accuracy: 0.8190 - learning_rate: 5.0000e-04
# Epoch 20/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5580 - loss: 1.1441 - top2_accuracy: 0.7839
# Epoch 20: val_accuracy did not improve from 0.62275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5591 - loss: 1.1411 - top2_accuracy: 0.7820 - val_accuracy: 0.6102 - val_loss: 1.0315 - val_top2_accuracy: 0.8207 - learning_rate: 5.0000e-04
# Epoch 21/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5678 - loss: 1.1344 - top2_accuracy: 0.7815
# Epoch 21: val_accuracy improved from 0.62275 to 0.62550, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 21: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5605 - loss: 1.1379 - top2_accuracy: 0.7785 - val_accuracy: 0.6255 - val_loss: 1.0222 - val_top2_accuracy: 0.8205 - learning_rate: 5.0000e-04
# Epoch 22/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5593 - loss: 1.1341 - top2_accuracy: 0.7834
# Epoch 22: val_accuracy did not improve from 0.62550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5585 - loss: 1.1352 - top2_accuracy: 0.7831 - val_accuracy: 0.6237 - val_loss: 1.0232 - val_top2_accuracy: 0.8240 - learning_rate: 5.0000e-04
# Epoch 23/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5592 - loss: 1.1312 - top2_accuracy: 0.7876
# Epoch 23: val_accuracy did not improve from 0.62550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.5606 - loss: 1.1325 - top2_accuracy: 0.7839 - val_accuracy: 0.6085 - val_loss: 1.0304 - val_top2_accuracy: 0.8202 - learning_rate: 5.0000e-04
# Epoch 24/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5522 - loss: 1.1450 - top2_accuracy: 0.7823
# Epoch 24: val_accuracy did not improve from 0.62550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5579 - loss: 1.1394 - top2_accuracy: 0.7820 - val_accuracy: 0.6155 - val_loss: 1.0268 - val_top2_accuracy: 0.8227 - learning_rate: 5.0000e-04
# Epoch 25/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5677 - loss: 1.1350 - top2_accuracy: 0.7851
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 25: val_accuracy did not improve from 0.62550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5647 - loss: 1.1365 - top2_accuracy: 0.7854 - val_accuracy: 0.6210 - val_loss: 1.0256 - val_top2_accuracy: 0.8213 - learning_rate: 5.0000e-04
# Epoch 26/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5717 - loss: 1.1216 - top2_accuracy: 0.7852
# Epoch 26: val_accuracy improved from 0.62550 to 0.62575, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 26: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5676 - loss: 1.1179 - top2_accuracy: 0.7870 - val_accuracy: 0.6258 - val_loss: 1.0159 - val_top2_accuracy: 0.8255 - learning_rate: 2.5000e-04
# Epoch 27/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5653 - loss: 1.1185 - top2_accuracy: 0.7904
# Epoch 27: val_accuracy did not improve from 0.62575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5693 - loss: 1.1157 - top2_accuracy: 0.7892 - val_accuracy: 0.6242 - val_loss: 1.0143 - val_top2_accuracy: 0.8245 - learning_rate: 2.5000e-04
# Epoch 28/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5709 - loss: 1.1131 - top2_accuracy: 0.7894
# Epoch 28: val_accuracy did not improve from 0.62575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5722 - loss: 1.1129 - top2_accuracy: 0.7876 - val_accuracy: 0.6177 - val_loss: 1.0151 - val_top2_accuracy: 0.8213 - learning_rate: 2.5000e-04
# Epoch 29/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5697 - loss: 1.1148 - top2_accuracy: 0.7848
# Epoch 29: val_accuracy did not improve from 0.62575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5705 - loss: 1.1165 - top2_accuracy: 0.7870 - val_accuracy: 0.6248 - val_loss: 1.0111 - val_top2_accuracy: 0.8245 - learning_rate: 2.5000e-04
# Epoch 30/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5696 - loss: 1.1044 - top2_accuracy: 0.7924
# Epoch 30: val_accuracy improved from 0.62575 to 0.62750, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5757 - loss: 1.1007 - top2_accuracy: 0.7947 - val_accuracy: 0.6275 - val_loss: 1.0072 - val_top2_accuracy: 0.8253 - learning_rate: 2.5000e-04
# Epoch 31/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5757 - loss: 1.1130 - top2_accuracy: 0.7916
# Epoch 31: val_accuracy improved from 0.62750 to 0.62775, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 31: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5769 - loss: 1.1097 - top2_accuracy: 0.7942 - val_accuracy: 0.6277 - val_loss: 1.0066 - val_top2_accuracy: 0.8257 - learning_rate: 2.5000e-04
# Epoch 32/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5759 - loss: 1.1033 - top2_accuracy: 0.7922
# Epoch 32: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5744 - loss: 1.1070 - top2_accuracy: 0.7900 - val_accuracy: 0.6177 - val_loss: 1.0103 - val_top2_accuracy: 0.8265 - learning_rate: 2.5000e-04
# Epoch 33/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5752 - loss: 1.1068 - top2_accuracy: 0.7906
# Epoch 33: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5750 - loss: 1.1051 - top2_accuracy: 0.7910 - val_accuracy: 0.6155 - val_loss: 1.0095 - val_top2_accuracy: 0.8242 - learning_rate: 2.5000e-04
# Epoch 34/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5751 - loss: 1.1050 - top2_accuracy: 0.7925
# Epoch 34: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0
150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5698 - loss: 1.1108 - top2_accuracy: 0.7932
# Epoch 44: val_accuracy improved from 0.63175 to 0.63525, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 44: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.5717 - loss: 1.1081 - top2_accuracy: 0.7943 - val_accuracy: 0.6352 - val_loss: 0.9980 - val_top2_accuracy: 0.8295 - learning_rate: 2.5000e-04
# Epoch 45/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5710 - loss: 1.1020 - top2_accuracy: 0.7931
# Epoch 45: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5760 - loss: 1.1020 - top2_accuracy: 0.7934 - val_accuracy: 0.6298 - val_loss: 0.9994 - val_top2_accuracy: 0.8285 - learning_rate: 2.5000e-04
# Epoch 46/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5700 - loss: 1.1107 - top2_accuracy: 0.7971
# Epoch 46: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5738 - loss: 1.1085 - top2_accuracy: 0.7956 - val_accuracy: 0.6273 - val_loss: 1.0008 - val_top2_accuracy: 0.8290 - learning_rate: 2.5000e-04
# Epoch 47/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5703 - loss: 1.1098 - top2_accuracy: 0.7883
# Epoch 47: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5720 - loss: 1.1088 - top2_accuracy: 0.7883 - val_accuracy: 0.6290 - val_loss: 0.9995 - val_top2_accuracy: 0.8290 - learning_rate: 2.5000e-04
# Epoch 48/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5779 - loss: 1.1006 - top2_accuracy: 0.7972
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 48: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.5765 - loss: 1.1050 - top2_accuracy: 0.7938 - val_accuracy: 0.6285 - val_loss: 1.0001 - val_top2_accuracy: 0.8282 - learning_rate: 2.5000e-04
# Epoch 49/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5757 - loss: 1.1006 - top2_accuracy: 0.7992
# Epoch 49: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5764 - loss: 1.1006 - top2_accuracy: 0.7984 - val_accuracy: 0.6263 - val_loss: 0.9982 - val_top2_accuracy: 0.8273 - learning_rate: 1.2500e-04
# Epoch 50/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5750 - loss: 1.0997 - top2_accuracy: 0.7967
# Epoch 50: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5785 - loss: 1.0959 - top2_accuracy: 0.7976 - val_accuracy: 0.6335 - val_loss: 0.9913 - val_top2_accuracy: 0.8295 - learning_rate: 1.2500e-04
# Epoch 51/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5741 - loss: 1.1024 - top2_accuracy: 0.7956
# Epoch 51: val_accuracy did not improve from 0.63525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5793 - loss: 1.0981 - top2_accuracy: 0.7944 - val_accuracy: 0.6350 - val_loss: 0.9909 - val_top2_accuracy: 0.8313 - learning_rate: 1.2500e-04
# Epoch 52/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5739 - loss: 1.0991 - top2_accuracy: 0.7999
# Epoch 52: val_accuracy improved from 0.63525 to 0.63650, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 52: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5768 - loss: 1.0967 - top2_accuracy: 0.7982 - val_accuracy: 0.6365 - val_loss: 0.9888 - val_top2_accuracy: 0.8322 - learning_rate: 1.2500e-04
# Epoch 53/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5787 - loss: 1.0866 - top2_accuracy: 0.8009
# Epoch 53: val_accuracy did not improve from 0.63650
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5809 - loss: 1.0892 - top2_accuracy: 0.8011 - val_accuracy: 0.6300 - val_loss: 0.9918 - val_top2_accuracy: 0.8315 - learning_rate: 1.2500e-04
# Epoch 54/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.
150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5975 - loss: 1.0667 - top2_accuracy: 0.8074
# Epoch 117: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 117: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 24s 95ms/step - accuracy: 0.5907 - loss: 1.0706 - top2_accuracy: 0.8066 - val_accuracy: 0.6373 - val_loss: 0.9760 - val_top2_accuracy: 0.8347 - learning_rate: 9.7656e-07
# Epoch 118/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5840 - loss: 1.0670 - top2_accuracy: 0.8081
# Epoch 118: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5851 - loss: 1.0724 - top2_accuracy: 0.8029 - val_accuracy: 0.6370 - val_loss: 0.9760 - val_top2_accuracy: 0.8345 - learning_rate: 4.8828e-07
# Epoch 119/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5914 - loss: 1.0674 - top2_accuracy: 0.8058
# Epoch 119: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5863 - loss: 1.0719 - top2_accuracy: 0.8040 - val_accuracy: 0.6367 - val_loss: 0.9760 - val_top2_accuracy: 0.8347 - learning_rate: 4.8828e-07
# Epoch 120/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5851 - loss: 1.0759 - top2_accuracy: 0.8024
# Epoch 120: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.5841 - loss: 1.0747 - top2_accuracy: 0.8046 - val_accuracy: 0.6363 - val_loss: 0.9760 - val_top2_accuracy: 0.8350 - learning_rate: 4.8828e-07
# Epoch 121/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5779 - loss: 1.0794 - top2_accuracy: 0.8016
# Epoch 121: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 121: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.5828 - loss: 1.0813 - top2_accuracy: 0.8001 - val_accuracy: 0.6363 - val_loss: 0.9760 - val_top2_accuracy: 0.8347 - learning_rate: 4.8828e-07
# Epoch 122/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5889 - loss: 1.0709 - top2_accuracy: 0.8110
# Epoch 122: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5848 - loss: 1.0751 - top2_accuracy: 0.8070 - val_accuracy: 0.6363 - val_loss: 0.9760 - val_top2_accuracy: 0.8347 - learning_rate: 2.4414e-07
# Epoch 123/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5872 - loss: 1.0722 - top2_accuracy: 0.8029
# Epoch 123: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5845 - loss: 1.0771 - top2_accuracy: 0.8026 - val_accuracy: 0.6360 - val_loss: 0.9760 - val_top2_accuracy: 0.8350 - learning_rate: 2.4414e-07
# Epoch 124/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5810 - loss: 1.0829 - top2_accuracy: 0.8033
# Epoch 124: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5842 - loss: 1.0801 - top2_accuracy: 0.8036 - val_accuracy: 0.6357 - val_loss: 0.9760 - val_top2_accuracy: 0.8350 - learning_rate: 2.4414e-07
# Epoch 125/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5775 - loss: 1.0733 - top2_accuracy: 0.8054
# Epoch 125: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 125: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5840 - loss: 1.0741 - top2_accuracy: 0.8038 - val_accuracy: 0.6360 - val_loss: 0.9760 - val_top2_accuracy: 0.8350 - learning_rate: 2.4414e-07
# Epoch 126/150
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5926 - loss: 1.0711 - top2_accuracy: 0.8103
# Epoch 126: val_accuracy did not improve from 0.64350
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.5907 - loss: 1.0701 - top2_accuracy: 0.8085 - val_accuracy: 0.6363 - val_loss: 0.9760 - val_top2_accuracy: 0.8350 - learning_rate: 1.2207e-07
# Epoch 126: early stopping
# Restoring model weights from the end of the best epoch: 96.
#
# ✅ Fingerprint (frozen) model training completed !
#    Epochs completed : 126
#    Best val_accuracy : 64.35% (epoch 96)
#
# ⚠️  Accuracy of 64.3% is below 70%

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)
# Out:
# 🔍 Diagnostic of frozen model
#
# ======================================================================================================================================================
#
# 📊 Prediction samples :
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ✅ Image 1: Label=index        | Prediction=index        | Confidence= 53.8% | 2nd Prediction=middle       | 2nd Confidence= 24.5%
# ❌ Image 2: Label=index        | Prediction=little       | Confidence= 25.9% | 2nd Prediction=middle       | 2nd Confidence= 25.0%
# ❌ Image 3: Label=index        | Prediction=thumb        | Confidence= 50.5% | 2nd Prediction=index        | 2nd Confidence= 33.4%
# ✅ Image 4: Label=middle       | Prediction=middle       | Confidence= 37.1% | 2nd Prediction=index        | 2nd Confidence= 29.3%
# ✅ Image 5: Label=thumb        | Prediction=thumb        | Confidence= 99.6% | 2nd Prediction=index        | 2nd Confidence=  0.2%
# ✅ Image 6: Label=little       | Prediction=little       | Confidence= 68.7% | 2nd Prediction=index        | 2nd Confidence= 12.3%
# ✅ Image 7: Label=middle       | Prediction=middle       | Confidence= 47.6% | 2nd Prediction=ring         | 2nd Confidence= 31.0%
# ✅ Image 8: Label=index        | Prediction=index        | Confidence= 67.6% | 2nd Prediction=middle       | 2nd Confidence= 20.6%
# ✅ Image 9: Label=index        | Prediction=index        | Confidence= 56.0% | 2nd Prediction=middle       | 2nd Confidence= 21.1%
# ❌ Image 10: Label=index        | Prediction=middle       | Confidence= 29.1% | 2nd Prediction=ring         | 2nd Confidence= 27.6%
# ✅ Image 11: Label=index        | Prediction=index        | Confidence= 56.7% | 2nd Prediction=middle       | 2nd Confidence= 31.3%
# ✅ Image 12: Label=thumb        | Prediction=thumb        | Confidence= 95.8% | 2nd Prediction=index        | 2nd Confidence=  3.5%
# ✅ Image 13: Label=ring         | Prediction=ring         | Confidence= 47.0% | 2nd Prediction=middle       | 2nd Confidence= 19.9%
# ✅ Image 14: Label=middle       | Prediction=middle       | Confidence= 62.3% | 2nd Prediction=ring         | 2nd Confidence= 20.2%
# ❌ Image 15: Label=thumb        | Prediction=index        | Confidence= 38.5% | 2nd Prediction=thumb        | 2nd Confidence= 26.6%
# ❌ Image 16: Label=middle       | Prediction=little       | Confidence= 40.9% | 2nd Prediction=ring         | 2nd Confidence= 27.8%
# ✅ Image 17: Label=middle       | Prediction=middle       | Confidence= 52.8% | 2nd Prediction=index        | 2nd Confidence= 19.3%
# ✅ Image 18: Label=ring         | Prediction=ring         | Confidence= 44.1% | 2nd Prediction=middle       | 2nd Confidence= 35.0%
# ✅ Image 19: Label=little       | Prediction=little       | Confidence= 75.9% | 2nd Prediction=ring         | 2nd Confidence= 10.3%
# ✅ Image 20: Label=index        | Prediction=index        | Confidence= 54.8% | 2nd Prediction=middle       | 2nd Confidence= 20.4%
#
# ======================================================================================================================================================
# 2026-03-20 13:47:18.312426: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluation of frozen model using validation dataset...
#
# Results :
#   - Loss                : 0.9767
#   - Accuracy            : 64.35%
#   - Top-2 Accuracy      : 83.60%
