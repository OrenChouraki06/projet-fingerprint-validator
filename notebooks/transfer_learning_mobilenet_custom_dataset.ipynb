# %% [markdown]
# # Transfer learning notebook for fingerprintvalidator project

# %% [markdown]
# ## Project Pre-requisites

# %%
# Import libraries
import os
from pathlib import Path

import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# pre-trained model selection
MobileNet_version = "MobileNetV2"
fingerprint_model_name = MobileNet_version + "_FingerPrint_Model"

if MobileNet_version == "MobileNet":
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif MobileNet_version == "MobileNetV2":
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif MobileNet_version == "MobileNetV3Small":
    from tensorflow.keras.applications import MobileNetV3Small
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
elif MobileNet_version == "MobileNetV3Large":
    from tensorflow.keras.applications import MobileNetV3Large
    from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
else:
    print("Unknown MobileNet version name")
    exit(0)

# %%
# Check selected pre-trained model
print(f"Selected pre-trained model version : {MobileNet_version}")
print(f"Fingerprint model name : {fingerprint_model_name}")
# Out:
# Selected pre-trained model version : MobileNetV2
# Fingerprint model name : MobileNetV2_FingerPrint_Model

# %%
# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")

print(f"\n🚀 Prêt pour le transfer learning en computer vision !")
# Out:
# ✅ GPU(s) détecté(s): 1 - Croissance mémoire activée
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.16.2
#   - Keras      : 3.13.2
#   - NumPy      : 1.26.4
#
# 🚀 Prêt pour le transfer learning en computer vision !

# %% [markdown]
# ## Project Constants

# %%
# Random seeding 
TENSORFLOW_SEED = 42
tf.random.set_seed(TENSORFLOW_SEED)

NUMPY_SEED = 42
np.random.seed(NUMPY_SEED)

# Dataset configuration

DATASET_ROOTDIR_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom" 
print(f"📁 Fingerprints dataset images root directory path : {DATASET_ROOTDIR_PATH}")

# labels
# class_names = ['thumb', 'index', 'middle', 'ring', 'little']
class_names = ['thumb', 'index', 'middle', 'ring', 'little']

num_classes = len(class_names)
print(f"\n👁️ fingerprints classes : {class_names}")

# model name
fingerprint_model_name = fingerprint_model_name + "_" + str(num_classes) + "_classes"
print(f"Adjusted fingerprint model name : {fingerprint_model_name}")
# Out:
# 📁 Fingerprints dataset images root directory path : /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom
#
# 👁️ fingerprints classes : ['thumb', 'index', 'middle', 'ring', 'little']
# Adjusted fingerprint model name : MobileNetV2_FingerPrint_Model_5_classes

# %% [markdown]
# ## Training Dataset Exploration

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = int((nCol + nGraphPerRow - 1) / nGraphPerRow)
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def traverse_dataset_dir(dataset_dir, class_names):

    # List to store file information
    imgdata = []

    # Traverse the input directory to get all image files
    for dirname, _, filenames in os.walk(dataset_dir):

        # check whether image is in a class which ought to be considered
        try:
            basename = os.path.basename(dirname)
            val = class_names.index(basename)
        except ValueError:
            # class not found
            continue

        for filename in filenames:
         
            if filename == ".DS_Store":  # Skip macOS system files
                continue

            if filename.find("Zcut") != -1:
                feature = 'zcut'
            elif filename.find('CR') != -1:
                feature = 'cr'
            elif filename.find('Obl') != -1:
                feature = 'obl'
            else:
                feature = 'unaltered'

            if filename.find("thumb") != -1:
                finger = "thumb"
            elif filename.find("index") != -1:
                finger = "index"
            elif filename.find("middle") != -1:
                finger = "middle"
            elif filename.find("ring") != -1:
                finger = "ring"
            elif filename.find("little") != -1:
                finger = "little"
            else:
                finger = None

            # image is to be considered given the current class names 
            file_path = os.path.join(dirname, filename)

            # extract the image features
            img = Image.open(file_path)
    
            try:
                img.verify()  # Verify that the file is a valid image
            except:
                print(f"Invalid image file: {file_path}")
                continue

            imgdata.append([file_path, img.format, img.size, img.mode, feature, finger])

    # Create a DataFrame
    imgdf = pd.DataFrame(imgdata, columns=["ImagePath", "ImageFormat", "ImageSize", "ImageMode", "Feature", "Finger"])

    # Add an index column
    imgdf.index.name = "ID"

    return imgdf

# %%
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
imgdf = traverse_dataset_dir(dataset_train_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    15931 non-null  str
#  1   ImageFormat  15931 non-null  str
#  2   ImageSize    15931 non-null  object
#  3   ImageMode    15931 non-null  str
#  4   Feature      15931 non-null  str
#  5   Finger       15931 non-null  str
# dtypes: object(1), str(5)
# memory usage: 746.9+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    4000
# obl          3982
# zcut         3980
# cr           3969
# Name: count, dtype: int64
# Finger
# little    3188
# middle    3188
# index     3188
# thumb     3185
# ring      3182
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 19.99%
# Percentage of Index fingers: 20.01%
# Percentage of Middle fingers: 20.01%
# Percentage of Ring fingers: 19.97%
# Percentage of Little fingers: 20.01%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 25.11%
# Percentage of Zcut: 24.98%
# Percentage of CR: 24.91%
# Percentage of Obl: 25.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/train/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/train/

# %%
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
imgdf = traverse_dataset_dir(dataset_val_dir, class_names)

# %%
# display the dataframe info
imgdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ImagePath    4000 non-null   str
#  1   ImageFormat  4000 non-null   str
#  2   ImageSize    4000 non-null   object
#  3   ImageMode    4000 non-null   str
#  4   Feature      4000 non-null   str
#  5   Finger       4000 non-null   str
# dtypes: object(1), str(5)
# memory usage: 187.6+ KB

# %%
# Display the distribution of Feature, Finger
print(imgdf["Feature"].value_counts())
print(imgdf["Finger"].value_counts())
# Out:
# Feature
# unaltered    2000
# zcut         2000
# Name: count, dtype: int64
# Finger
# little    800
# middle    800
# thumb     800
# index     800
# ring      800
# Name: count, dtype: int64

# %%
# Display of number of thumbs, index, middle, ring, and little fingers
print(f"Percentage of Thumbs: {imgdf['Finger'].value_counts().get('thumb', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Index fingers: {imgdf['Finger'].value_counts().get('index', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Middle fingers: {imgdf['Finger'].value_counts().get('middle', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Ring fingers: {imgdf['Finger'].value_counts().get('ring', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Little fingers: {imgdf['Finger'].value_counts().get('little', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of Thumbs: 20.00%
# Percentage of Index fingers: 20.00%
# Percentage of Middle fingers: 20.00%
# Percentage of Ring fingers: 20.00%
# Percentage of Little fingers: 20.00%

# %%
# Display of feature
print(f"Percentage of unaltered: {imgdf['Feature'].value_counts().get('unaltered', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Zcut: {imgdf['Feature'].value_counts().get('zcut', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of CR: {imgdf['Feature'].value_counts().get('cr', 0) / len(imgdf) * 100:.2f}%")
print(f"Percentage of Obl: {imgdf['Feature'].value_counts().get('obl', 0) / len(imgdf) * 100:.2f}%")
# Out:
# Percentage of unaltered: 50.00%
# Percentage of Zcut: 50.00%
# Percentage of CR: 0.00%
# Percentage of Obl: 0.00%

# %%
plotPerColumnDistribution(imgdf, 10, 5)

# %%
# visualisation of some images
dataset_target_dir = DATASET_ROOTDIR_PATH + "/validation/"
print(f"FingerPrint Examples from dataset dir {dataset_target_dir}\n")

num_examples_images = 10
fig, axes = plt.subplots(num_classes, num_examples_images, figsize=(18, 3 * num_classes))

for i, class_name in enumerate(class_names):
    class_path = Path(os.path.join(dataset_target_dir, class_name))
    image_files = list(class_path.glob('*.*'))[:num_examples_images]
    
    for j, img_path in enumerate(image_files):
        img = plt.imread(img_path)
        axes[i, j].imshow(img)
        axes[i, j].axis('on')
        if j == 0:
            axes[i, j].set_xlabel(class_name.upper(), fontsize=12, fontweight='bold', rotation=0, ha='right', va='center')

plt.suptitle("Fingerprint image example by class", fontsize=16, fontweight='bold', y=1.001)
plt.tight_layout()
plt.show()
# Out:
# FingerPrint Examples from dataset dir /Users/laurent/Projects/projet-fingerprint-validator/dataset/SOCOFing_Custom/validation/

# %% [markdown]
# ## Split dataset for training / validation

# %%
print("🔧 Datasets creation for training and validation ...\n")

# Dataset creation parameters
BATCH_SIZE = 64
IMAGE_SIZE = (96, 96)

# Create traning dataset with class filtering
dataset_train_dir = DATASET_ROOTDIR_PATH + "/train"
train_ds = image_dataset_from_directory(
    dataset_train_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',  # One-hot encoding for multi-class
    class_names=class_names  # Explicitly specify the class names to ensure correct mapping
)

# Create validation dataset with the same class names to ensure correct mapping
dataset_val_dir = DATASET_ROOTDIR_PATH + "/validation"
val_ds = image_dataset_from_directory(
    dataset_val_dir,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Same order of classes
)

print(f"✅ Datasets created !\n")

print(f"📊 Training and validation datasets information:")
print(f"  - Training Dataset Classes             : {train_ds.class_names}")
print(f"  - Validation Dataset Classes           : {val_ds.class_names}")

# Checking number of classes in both datasets
if len(train_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(train_ds.class_names)} classes found instead of {num_classes} !")
    print(f"   Classes found: {train_ds.class_names}\n")
elif len(val_ds.class_names) != num_classes:
    print(f"\n⚠️  Error : {len(val_ds.class_names)} classes found au lieu de {num_classes} !")
    print(f"   Classes found : {val_ds.class_names}")
else:
    print(f"  - ✅ Number of correct classes : {num_classes} \n")

print(f"  - Training batches    : {len(train_ds)}")
print(f"  - Validation batches    : {len(val_ds)}")
print(f"  - Batch size            : {BATCH_SIZE}")
print(f"  - Image size            : {IMAGE_SIZE}\n")
print(f"  - Training samples      : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Validation samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Datasets creation for training and validation ...
#
# Found 15931 files belonging to 5 classes.
# Found 4000 files belonging to 5 classes.
# 2026-03-19 21:35:57.673421: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2026-03-19 21:35:57.673615: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-19 21:35:57.673633: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-19 21:35:57.673841: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-19 21:35:57.673869: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ✅ Datasets created !
#
# 📊 Training and validation datasets information:
#   - Training Dataset Classes             : ['thumb', 'index', 'middle', 'ring', 'little']
#   - Validation Dataset Classes           : ['thumb', 'index', 'middle', 'ring', 'little']
#   - ✅ Number of correct classes : 5
#
#   - Training batches    : 249
#   - Validation batches    : 63
#   - Batch size            : 64
#   - Image size            : (96, 96)
#
#   - Training samples      : ~15936
#   - Validation samples    : ~4032

# %% [markdown]
# ## Dataset preparation : normalisation and shuffling (training only)
# ##                       No augmentation since altered images already embeded in dataset

# %%
print("🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...\n")

# Dataset preparation function
def prepare_dataset(ds, shuffle=True):

    # normalisation required for MobileNet
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle (training only)
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    
    # Performances optimisation
    ds = ds.cache()  # Memory caching
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch for acceleration
    
    return ds

# Apply transformations
train_ds_prepared = prepare_dataset(train_ds, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, shuffle=False)

print("✅ Dataset preparation completed !\n")

print("📝 Applied transformations :")
print("  - Training dataset   : normalisation + shuffle")
print("  - Validation dataset : Normalisation")
print("\n  - Caching et prefetch activated for performance")
# Out:
# 🎨 Fingerprint dataset preparation : normalisation and shuffling (training only) ...
#
# ✅ Dataset preparation completed !
#
# 📝 Applied transformations :
#   - Training dataset   : normalisation + shuffle
#   - Validation dataset : Normalisation
#
#   - Caching et prefetch activated for performance

# %% [markdown]
# ## Build FingerPrint Model : Pre-trained MobileNet-based model + Classifier layer

# %%
# Constants for the model
INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = num_classes

HIDDEN_DENSE_LAYER_SIZE = 256

DROPOUT_RATE = 0.3 # medium 
L2_REGULARIZATION = 0.01
LEARNING_RATE = 0.001 # standard

# %%
print(f"📥 Loading {MobileNet_version} ...")

# Loading pre-trained MobileNet without the classifier (include_top=False)
# We will add our own classifier for finger classification

if MobileNet_version == "MobileNet":
    base_model = MobileNet(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV2":
    base_model = MobileNetV2(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Small":
    base_model = MobileNetV3Small(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
elif MobileNet_version == "MobileNetV3Large":
    base_model = MobileNetV3Large(
        input_shape=INPUT_SHAPE,
        include_top=False,  # Exclure la couche de classification ImageNet
        weights='imagenet',  # Load pre-trained weights from ImageNet
        pooling='avg'  # Global Average Pooling to end model
    )
else:
    print(f"Unknown pre-trained model version : {MobileNet_version}")
    exit(0)

print(f"✅ {MobileNet_version} model loaded !\n")

# Display model structure
print(f"📋 Model Structure - {MobileNet_version} :")
print(f"  - Architecture   : {MobileNet_version}")
print(f"  - Input shape    : {INPUT_SHAPE}")
print(f"  - Weights        : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Number of layers : {len(base_model.layers)}")

# Count parameters
total_params = base_model.count_params()
print(f"\n  - Total number of parameters : {total_params:,}")
print(f"  - Memory size (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# 📥 Loading MobileNetV2 ...
# ✅ MobileNetV2 model loaded !
#
# 📋 Model Structure - MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (96, 96, 3)
#   - Weights        : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Number of layers : 155
#
#   - Total number of parameters : 2,257,984
#   - Memory size (approx.) : 8.6 MB

# %%
print("🧊 Construct FingerPrint model with classifier...\n")

# Freeze the base model to keep the pre-trained features
base_model.trainable = False

print(f"✅ Base model frozen")
print(f"   {len(base_model.layers)} layers not trainable\n")

# OPTIMAL Architecture for this dataset
inputs = keras.Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Smoothend out Classifier with regularizerization 
x = layers.Dropout(DROPOUT_RATE)(x)
x = layers.Dense(HIDDEN_DENSE_LAYER_SIZE, activation='relu', kernel_regularizer=keras.regularizers.l2(L2_REGULARIZATION))(x)

# Check number of classes
if num_classes > 2:
    classification_activation = 'softmax'
else:
    classification_activation = 'sigmoid'

x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation=classification_activation)(x)

mobilenet_fingerprint_model = keras.Model(inputs, outputs, name=fingerprint_model_name)

# Compiler avec LR optimal
mobilenet_fingerprint_model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("✅ Model compiled !\n")

print(f"📊 Architecture {MobileNet_version} based FingerPrint:")
print(f"  Input{INPUT_SHAPE} → {MobileNet_version} → Dropout({DROPOUT_RATE}) → Dense({HIDDEN_DENSE_LAYER_SIZE},relu) → Dropout({DROPOUT_RATE}) → Dense({NUM_CLASSES}, {classification_activation})\n")

trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in mobilenet_fingerprint_model.non_trainable_weights])
print(f"  - Trainable parameters     : {trainable:,}")
print(f"  - Non-trainable parameters : {non_trainable:,}")
print(f"  - Total                    : {trainable + non_trainable:,}")

print("\n💡 Model configuration :")
print(f"  - Learning rate      : {LEARNING_RATE} (standard)")
print(f"  - Dropout rate       : {DROPOUT_RATE} (medium)")
print(f"  - Hidden dense layer : {HIDDEN_DENSE_LAYER_SIZE} neurons")
print(f"  - L2 regularization  : {L2_REGULARIZATION}")
# Out:
# 🧊 Construct FingerPrint model with classifier...
#
# ✅ Base model frozen
#    155 layers not trainable
#
# ✅ Model compiled !
#
# 📊 Architecture MobileNetV2 based FingerPrint:
#   Input(96, 96, 3) → MobileNetV2 → Dropout(0.3) → Dense(256,relu) → Dropout(0.3) → Dense(5, softmax)
#
#   - Trainable parameters     : 329,221
#   - Non-trainable parameters : 2,257,984
#   - Total                    : 2,587,205
#
# 💡 Model configuration :
#   - Learning rate      : 0.001 (standard)
#   - Dropout rate       : 0.3 (medium)
#   - Hidden dense layer : 256 neurons
#   - L2 regularization  : 0.01

# %% [markdown]
# ## Display FingerPrint Model

# %%
print(f"🔍 {MobileNet_version} pre-trained model architecture\n")
print("="*60)

def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

# Display the first 10 and last 10 layers of the base model to understand the feature extraction process
print("\n📌 First layers (low-level feature extraction) :")
for i, layer in enumerate(base_model.layers[:10]):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n      ...")

print("\n📌 Last layers (high-level features) :")
for i, layer in enumerate(base_model.layers[-10:], start=len(base_model.layers)-10):
    output_shape = get_output_shape(layer)
    print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

print("\n" + "="*60)
# Out:
# 🔍 MobileNetV2 pre-trained model architecture
#
# ============================================================
#
# 📌 First layers (low-level feature extraction) :
#     1. input_layer                              | Output: (None, 96, 96, 3)              | Trainable: False
#     2. Conv1                                    | Output: (None, 48, 48, 32)             | Trainable: False
#     3. bn_Conv1                                 | Output: (None, 48, 48, 32)             | Trainable: False
#     4. Conv1_relu                               | Output: (None, 48, 48, 32)             | Trainable: False
#     5. expanded_conv_depthwise                  | Output: (None, 48, 48, 32)             | Trainable: False
#     6. expanded_conv_depthwise_BN               | Output: (None, 48, 48, 32)             | Trainable: False
#     7. expanded_conv_depthwise_relu             | Output: (None, 48, 48, 32)             | Trainable: False
#     8. expanded_conv_project                    | Output: (None, 48, 48, 16)             | Trainable: False
#     9. expanded_conv_project_BN                 | Output: (None, 48, 48, 16)             | Trainable: False
#    10. block_1_expand                           | Output: (None, 48, 48, 96)             | Trainable: False
#
#       ...
#
# 📌 Last layers (high-level features) :
#   146. block_16_expand_relu                     | Output: (None, 3, 3, 960)              | Trainable: False
#   147. block_16_depthwise                       | Output: (None, 3, 3, 960)              | Trainable: False
#   148. block_16_depthwise_BN                    | Output: (None, 3, 3, 960)              | Trainable: False
#   149. block_16_depthwise_relu                  | Output: (None, 3, 3, 960)              | Trainable: False
#   150. block_16_project                         | Output: (None, 3, 3, 320)              | Trainable: False
#   151. block_16_project_BN                      | Output: (None, 3, 3, 320)              | Trainable: False
#   152. Conv_1                                   | Output: (None, 3, 3, 1280)             | Trainable: False
#   153. Conv_1_bn                                | Output: (None, 3, 3, 1280)             | Trainable: False
#   154. out_relu                                 | Output: (None, 3, 3, 1280)             | Trainable: False
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: False
#
# ============================================================

# %%
print(f"🔍 Visualizing {MobileNet_version} FingerPrint model architecture")
print("="*60)

mobilenet_fingerprint_model.summary()
# Out:
# 🔍 Visualizing MobileNetV2 FingerPrint model architecture
# ============================================================
# Model: "MobileNetV2_FingerPrint_Model_5_classes"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,205 (9.87 MB)
#  Trainable params: 329,221 (1.26 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ##  Frozen Model Training

# %%
# Constants for training callbacks
EARLYSTOPPING_PATIENCE = 30
EARLYSTOPPING_VERBOSE = 1

REDUCELRONPLATEAU_FACTOR = 0.5
REDUCELRONPLATEAU_PATIENCE = 4
REDUCELRONPLATEAU_MIN_LR = 1e-7
REDUCELRONPLATEAU_VERBOSE = 1

MODELCHECKPOINT_PATH = "/Users/laurent/Projects/projet-fingerprint-validator/models/" + fingerprint_model_name + ".keras"
MODELCHECKPOINT_VERBOSE = 1

FIT_NUM_EPOCHS = 150
FIT_VERBOSE = 1

# %%
# Training function
def fit_fingerprint_model(model: keras.Model, train_ds: tf.data.Dataset, val_ds: tf.data.Dataset):

    print("🚀 Training (frozen) FingerPrint model ...\n")

    # Define callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=EARLYSTOPPING_PATIENCE,
        restore_best_weights=True,
        mode='max',
        verbose=EARLYSTOPPING_VERBOSE
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=REDUCELRONPLATEAU_FACTOR,
        patience=REDUCELRONPLATEAU_PATIENCE,
        min_lr=REDUCELRONPLATEAU_MIN_LR,
        verbose=REDUCELRONPLATEAU_VERBOSE
    )

    checkpoint = callbacks.ModelCheckpoint(
        MODELCHECKPOINT_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=MODELCHECKPOINT_VERBOSE
    )

    print(f"Configuration :")
    print(f"  - Maximum Number of Epochs : {FIT_NUM_EPOCHS}")
    print(f"  - EarlyStopping Patience   : {EARLYSTOPPING_PATIENCE} epochs")
    print(f"  - Reduce LR Patience       : {REDUCELRONPLATEAU_PATIENCE} epochs")
    print(f"  - LR initial               : {LEARNING_RATE}")
    print(f"  - LR min                  : {REDUCELRONPLATEAU_MIN_LR}\n")
    
    history_fit = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FIT_NUM_EPOCHS,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=FIT_VERBOSE
    )
    
    print("\n✅ Fingerprint (frozen) model training completed !")
    print(f"   Epochs completed : {len(history_fit.history['loss'])}")
    
    best_val_acc = max(history_fit.history['val_accuracy'])
    best_epoch = history_fit.history['val_accuracy'].index(best_val_acc) + 1
    print(f"   Best val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

    if best_val_acc < 0.70:
        print(f"\n⚠️  Accuracy of {best_val_acc*100:.1f}% is below 70%")
    elif best_val_acc < 0.80:
        print(f"\n✅ Good result : {best_val_acc*100:.1f}%")
    else:
        print(f"\n🎯 Excellent ! Accuracy of {best_val_acc*100:.1f}%")

    return history_fit

# %% [markdown]
# ## Frozen Model Training

# %%
# initial training with frozen base model
history_fit = fit_fingerprint_model(mobilenet_fingerprint_model, train_ds_prepared, val_ds_prepared)
# Out:
# 🚀 Training (frozen) FingerPrint model ...
#
# Configuration :
#   - Maximum Number of Epochs : 120
#   - EarlyStopping Patience   : 30 epochs
#   - Reduce LR Patience       : 4 epochs
#   - LR initial               : 0.001
#   - LR min                  : 1e-07
#
# Epoch 1/120
# 2026-03-19 21:37:23.128806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3832 - loss: 4.4553 - top2_accuracy: 0.6090
# Epoch 1: val_accuracy improved from None to 0.59200, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 1: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 24s 80ms/step - accuracy: 0.4320 - loss: 3.1787 - top2_accuracy: 0.6587 - val_accuracy: 0.5920 - val_loss: 1.4689 - val_top2_accuracy: 0.8100 - learning_rate: 0.0010
# Epoch 2/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4793 - loss: 1.7218 - top2_accuracy: 0.7123
# Epoch 2: val_accuracy improved from 0.59200 to 0.59650, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 2: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - accuracy: 0.4878 - loss: 1.5864 - top2_accuracy: 0.7189 - val_accuracy: 0.5965 - val_loss: 1.1881 - val_top2_accuracy: 0.8008 - learning_rate: 0.0010
# Epoch 3/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5074 - loss: 1.3632 - top2_accuracy: 0.7362
# Epoch 3: val_accuracy did not improve from 0.59650
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.5175 - loss: 1.3178 - top2_accuracy: 0.7414 - val_accuracy: 0.5910 - val_loss: 1.0996 - val_top2_accuracy: 0.8198 - learning_rate: 0.0010
# Epoch 4/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5157 - loss: 1.2696 - top2_accuracy: 0.7425
# Epoch 4: val_accuracy improved from 0.59650 to 0.60575, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 4: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.5245 - loss: 1.2364 - top2_accuracy: 0.7531 - val_accuracy: 0.6058 - val_loss: 1.0682 - val_top2_accuracy: 0.8207 - learning_rate: 0.0010
# Epoch 5/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5282 - loss: 1.2069 - top2_accuracy: 0.7555
# Epoch 5: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.5332 - loss: 1.1937 - top2_accuracy: 0.7578 - val_accuracy: 0.5955 - val_loss: 1.0705 - val_top2_accuracy: 0.8180 - learning_rate: 0.0010
# Epoch 6/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5233 - loss: 1.1934 - top2_accuracy: 0.7570
# Epoch 6: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.5309 - loss: 1.1845 - top2_accuracy: 0.7612 - val_accuracy: 0.5995 - val_loss: 1.0670 - val_top2_accuracy: 0.8175 - learning_rate: 0.0010
# Epoch 7/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5326 - loss: 1.1960 - top2_accuracy: 0.7571
# Epoch 7: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.5396 - loss: 1.1811 - top2_accuracy: 0.7602 - val_accuracy: 0.5895 - val_loss: 1.0663 - val_top2_accuracy: 0.8085 - learning_rate: 0.0010
# Epoch 8/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5328 - loss: 1.1894 - top2_accuracy: 0.7563
# Epoch 8: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - accuracy: 0.5368 - loss: 1.1725 - top2_accuracy: 0.7635 - val_accuracy: 0.6000 - val_loss: 1.0583 - val_top2_accuracy: 0.8163 - learning_rate: 0.0010
# Epoch 9/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5378 - loss: 1.1810 - top2_accuracy: 0.7650
# Epoch 9: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - accuracy: 0.5415 - loss: 1.1711 - top2_accuracy: 0.7670 - val_accuracy: 0.5947 - val_loss: 1.0652 - val_top2_accuracy: 0.8158 - learning_rate: 0.0010
# Epoch 10/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5334 - loss: 1.1874 - top2_accuracy: 0.7591
# Epoch 10: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.5395 - loss: 1.1760 - top2_accuracy: 0.7617 - val_accuracy: 0.6047 - val_loss: 1.0571 - val_top2_accuracy: 0.8190 - learning_rate: 0.0010
# Epoch 11/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5281 - loss: 1.1938 - top2_accuracy: 0.7569
# Epoch 11: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5369 - loss: 1.1783 - top2_accuracy: 0.7642 - val_accuracy: 0.5870 - val_loss: 1.0736 - val_top2_accuracy: 0.8075 - learning_rate: 0.0010
# Epoch 12/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5353 - loss: 1.1886 - top2_accuracy: 0.7579
# Epoch 12: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5394 - loss: 1.1738 - top2_accuracy: 0.7623 - val_accuracy: 0.5987 - val_loss: 1.0557 - val_top2_accuracy: 0.8195 - learning_rate: 0.0010
# Epoch 13/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5362 - loss: 1.1818 - top2_accuracy: 0.7574
# Epoch 13: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5407 - loss: 1.1660 - top2_accuracy: 0.7657 - val_accuracy: 0.5875 - val_loss: 1.0636 - val_top2_accuracy: 0.8108 - learning_rate: 0.0010
# Epoch 14/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5348 - loss: 1.1910 - top2_accuracy: 0.7627
# Epoch 14: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 24s 95ms/step - accuracy: 0.5394 - loss: 1.1792 - top2_accuracy: 0.7650 - val_accuracy: 0.5905 - val_loss: 1.0658 - val_top2_accuracy: 0.8135 - learning_rate: 0.0010
# Epoch 15/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5340 - loss: 1.1889 - top2_accuracy: 0.7528
# Epoch 15: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5418 - loss: 1.1725 - top2_accuracy: 0.7624 - val_accuracy: 0.5867 - val_loss: 1.0586 - val_top2_accuracy: 0.8120 - learning_rate: 0.0010
# Epoch 16/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5351 - loss: 1.1869 - top2_accuracy: 0.7580
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.5403 - loss: 1.1713 - top2_accuracy: 0.7647 - val_accuracy: 0.5893 - val_loss: 1.0635 - val_top2_accuracy: 0.8102 - learning_rate: 0.0010
# Epoch 17/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5426 - loss: 1.1585 - top2_accuracy: 0.7712
# Epoch 17: val_accuracy did not improve from 0.60575
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.5528 - loss: 1.1369 - top2_accuracy: 0.7796 - val_accuracy: 0.6033 - val_loss: 1.0354 - val_top2_accuracy: 0.8207 - learning_rate: 5.0000e-04
# Epoch 18/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5499 - loss: 1.1432 - top2_accuracy: 0.7757
# Epoch 18: val_accuracy improved from 0.60575 to 0.62000, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 18: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 25s 100ms/step - accuracy: 0.5555 - loss: 1.1317 - top2_accuracy: 0.7797 - val_accuracy: 0.6200 - val_loss: 1.0243 - val_top2_accuracy: 0.8320 - learning_rate: 5.0000e-04
# Epoch 19/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5582 - loss: 1.1384 - top2_accuracy: 0.7764
# Epoch 19: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.5583 - loss: 1.1287 - top2_accuracy: 0.7797 - val_accuracy: 0.6010 - val_loss: 1.0310 - val_top2_accuracy: 0.8250 - learning_rate: 5.0000e-04
# Epoch 20/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5494 - loss: 1.1433 - top2_accuracy: 0.7693
# Epoch 20: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.5518 - loss: 1.1327 - top2_accuracy: 0.7747 - val_accuracy: 0.6102 - val_loss: 1.0236 - val_top2_accuracy: 0.8280 - learning_rate: 5.0000e-04
# Epoch 21/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5538 - loss: 1.1350 - top2_accuracy: 0.7749
# Epoch 21: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.5572 - loss: 1.1249 - top2_accuracy: 0.7790 - val_accuracy: 0.6097 - val_loss: 1.0220 - val_top2_accuracy: 0.8292 - learning_rate: 5.0000e-04
# Epoch 22/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5515 - loss: 1.1403 - top2_accuracy: 0.7728
# Epoch 22: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5575 - loss: 1.1284 - top2_accuracy: 0.7806 - val_accuracy: 0.6112 - val_loss: 1.0221 - val_top2_accuracy: 0.8255 - learning_rate: 5.0000e-04
# Epoch 23/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5589 - loss: 1.1411 - top2_accuracy: 0.7793
# Epoch 23: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.5583 - loss: 1.1306 - top2_accuracy: 0.7800 - val_accuracy: 0.6112 - val_loss: 1.0239 - val_top2_accuracy: 0.8273 - learning_rate: 5.0000e-04
# Epoch 24/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5521 - loss: 1.1413 - top2_accuracy: 0.7744
# Epoch 24: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 25s 99ms/step - accuracy: 0.5558 - loss: 1.1259 - top2_accuracy: 0.7774 - val_accuracy: 0.6145 - val_loss: 1.0203 - val_top2_accuracy: 0.8295 - learning_rate: 5.0000e-04
# Epoch 25/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5589 - loss: 1.1299 - top2_accuracy: 0.7719
# Epoch 25: val_accuracy did not improve from 0.62000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - accuracy: 0.5607 - loss: 1.1209 - top2_accuracy: 0.7811 - val_accuracy: 0.6162 - val_loss: 1.0135 - val_top2_accuracy: 0.8345 - learning_rate: 5.0000e-04
# Epoch 26/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5516 - loss: 1.1489 - top2_accuracy: 0.7779
# Epoch 26: val_accuracy improved from 0.62000 to 0.62225, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 26: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5603 - loss: 1.1319 - top2_accuracy: 0.7831 - val_accuracy: 0.6223 - val_loss: 1.0148 - val_top2_accuracy: 0.8307 - learning_rate: 5.0000e-04
# Epoch 27/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5565 - loss: 1.1338 - top2_accuracy: 0.7795
# Epoch 27: val_accuracy did not improve from 0.62225
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5612 - loss: 1.1298 - top2_accuracy: 0.7789 - val_accuracy: 0.6118 - val_loss: 1.0203 - val_top2_accuracy: 0.8328 - learning_rate: 5.0000e-04
# Epoch 28/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5519 - loss: 1.1389 - top2_accuracy: 0.7758
# Epoch 28: val_accuracy did not improve from 0.62225
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5527 - loss: 1.1319 - top2_accuracy: 0.7799 - val_accuracy: 0.5907 - val_loss: 1.0376 - val_top2_accuracy: 0.8188 - learning_rate: 5.0000e-04
# Epoch 29/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5569 - loss: 1.1339 - top2_accuracy: 0.7758
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 29: val_accuracy did not improve from 0.62225
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.5622 - loss: 1.1252 - top2_accuracy: 0.7809 - val_accuracy: 0.6090 - val_loss: 1.0203 - val_top2_accuracy: 0.8267 - learning_rate: 5.0000e-04
# Epoch 30/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5621 - loss: 1.1216 - top2_accuracy: 0.7813
# Epoch 30: val_accuracy improved from 0.62225 to 0.62350, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 30: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.5651 - loss: 1.1116 - top2_accuracy: 0.7851 - val_accuracy: 0.6235 - val_loss: 1.0115 - val_top2_accuracy: 0.8305 - learning_rate: 2.5000e-04
# Epoch 31/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5645 - loss: 1.1174 - top2_accuracy: 0.7786
# Epoch 31: val_accuracy improved from 0.62350 to 0.62525, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 31: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5659 - loss: 1.1076 - top2_accuracy: 0.7857 - val_accuracy: 0.6252 - val_loss: 1.0041 - val_top2_accuracy: 0.8350 - learning_rate: 2.5000e-04
# Epoch 32/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5655 - loss: 1.1109 - top2_accuracy: 0.7885
# Epoch 32: val_accuracy did not improve from 0.62525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5654 - loss: 1.1058 - top2_accuracy: 0.7887 - val_accuracy: 0.6198 - val_loss: 1.0082 - val_top2_accuracy: 0.8340 - learning_rate: 2.5000e-04
# Epoch 33/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5672 - loss: 1.1104 - top2_accuracy: 0.7813
# Epoch 33: val_accuracy did not improve from 0.62525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5710 - loss: 1.1011 - top2_accuracy: 0.7881 - val_accuracy: 0.6225 - val_loss: 1.0010 - val_top2_accuracy: 0.8355 - learning_rate: 2.5000e-04
# Epoch 34/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5619 - loss: 1.1125 - top2_accuracy: 0.7819
# Epoch 34: val_accuracy did not improve from 0.62525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5671 - loss: 1.1029 - top2_accuracy: 0.7868 - val_accuracy: 0.6252 - val_loss: 0.9990 - val_top2_accuracy: 0.8390 - learning_rate: 2.5000e-04
# Epoch 35/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5649 - loss: 1.1097 - top2_accuracy: 0.7866
# Epoch 35: val_accuracy did not improve from 0.62525
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5671 - loss: 1.1008 - top2_accuracy: 0.7919 - val_accuracy: 0.6215 - val_loss: 1.0055 - val_top2_accuracy: 0.8350 - learning_rate: 2.5000e-04
# Epoch 36/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5626 - loss: 1.1093 - top2_accuracy: 0.7897
# Epoch 36: val_accuracy improved from 0.62525 to 0.62775, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 36: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5666 - loss: 1.1022 - top2_accuracy: 0.7912 - val_accuracy: 0.6277 - val_loss: 0.9958 - val_top2_accuracy: 0.8382 - learning_rate: 2.5000e-04
# Epoch 37/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5647 - loss: 1.1138 - top2_accuracy: 0.7866
# Epoch 37: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5691 - loss: 1.1011 - top2_accuracy: 0.7904 - val_accuracy: 0.6270 - val_loss: 0.9943 - val_top2_accuracy: 0.8385 - learning_rate: 2.5000e-04
# Epoch 38/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5675 - loss: 1.1138 - top2_accuracy: 0.7805
# Epoch 38: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5726 - loss: 1.1018 - top2_accuracy: 0.7862 - val_accuracy: 0.6235 - val_loss: 0.9940 - val_top2_accuracy: 0.8385 - learning_rate: 2.5000e-04
# Epoch 39/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5673 - loss: 1.1073 - top2_accuracy: 0.7889
# Epoch 39: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5698 - loss: 1.1003 - top2_accuracy: 0.7916 - val_accuracy: 0.6267 - val_loss: 0.9969 - val_top2_accuracy: 0.8353 - learning_rate: 2.5000e-04
# Epoch 40/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5653 - loss: 1.1135 - top2_accuracy: 0.7851
# Epoch 40: val_accuracy did not improve from 0.62775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5665 - loss: 1.1009 - top2_accuracy: 0.7890 - val_accuracy: 0.6270 - val_loss: 0.9926 - val_top2_accuracy: 0.8390 - learning_rate: 2.5000e-04
# Epoch 41/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5643 - loss: 1.1157 - top2_accuracy: 0.7821
# Epoch 41: val_accuracy improved from 0.62775 to 0.62850, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 41: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5656 - loss: 1.1063 - top2_accuracy: 0.7871 - val_accuracy: 0.6285 - val_loss: 0.9945 - val_top2_accuracy: 0.8385 - learning_rate: 2.5000e-04
# Epoch 42/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5586 - loss: 1.1072 - top2_accuracy: 0.7883
# Epoch 42: val_accuracy improved from 0.62850 to 0.62875, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 42: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5659 - loss: 1.0980 - top2_accuracy: 0.7940 - val_accuracy: 0.6288 - val_loss: 0.9915 - val_top2_accuracy: 0.8382 - learning_rate: 2.5000e-04
# Epoch 43/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5586 - loss: 1.1177 - top2_accuracy: 0.7794
# Epoch 43: val_accuracy did not improve from 0.62875
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5659 - loss: 1.1012 - top2_accuracy: 0.7885 - val_accuracy: 0.6260 - val_loss: 0.9969 - val_top2_accuracy: 0.8363 - learning_rate: 2.5000e-04
# Epoch 44/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5688 - loss: 1.1053 - top2_accuracy: 0.7914
# Epoch 44: val_accuracy improved from 0.62875 to 0.63000, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 44: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5721 - loss: 1.1002 - top2_accuracy: 0.7911 - val_accuracy: 0.6300 - val_loss: 0.9929 - val_top2_accuracy: 0.8407 - learning_rate: 2.5000e-04
# Epoch 45/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5722 - loss: 1.1044 - top2_accuracy: 0.7888
# Epoch 45: val_accuracy did not improve from 0.63000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5731 - loss: 1.0973 - top2_accuracy: 0.7908 - val_accuracy: 0.6215 - val_loss: 0.9973 - val_top2_accuracy: 0.8363 - learning_rate: 2.5000e-04
# Epoch 46/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5633 - loss: 1.1087 - top2_accuracy: 0.7848
# Epoch 46: val_accuracy did not improve from 0.63000
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5696 - loss: 1.0976 - top2_accuracy: 0.7890 - val_accuracy: 0.6298 - val_loss: 0.9908 - val_top2_accuracy: 0.8360 - learning_rate: 2.5000e-04
# Epoch 47/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5683 - loss: 1.1067 - top2_accuracy: 0.7832
# Epoch 47: val_accuracy improved from 0.63000 to 0.63225, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 47: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5700 - loss: 1.0992 - top2_accuracy: 0.7893 - val_accuracy: 0.6323 - val_loss: 0.9905 - val_top2_accuracy: 0.8400 - learning_rate: 2.5000e-04
# Epoch 48/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5606 - loss: 1.1042 - top2_accuracy: 0.7899
# Epoch 48: val_accuracy improved from 0.63225 to 0.63300, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 48: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5646 - loss: 1.1007 - top2_accuracy: 0.7909 - val_accuracy: 0.6330 - val_loss: 0.9898 - val_top2_accuracy: 0.8395 - learning_rate: 2.5000e-04
# Epoch 49/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5631 - loss: 1.1034 - top2_accuracy: 0.7886
# Epoch 49: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.5694 - loss: 1.0961 - top2_accuracy: 0.7903 - val_accuracy: 0.6217 - val_loss: 0.9961 - val_top2_accuracy: 0.8378 - learning_rate: 2.5000e-04
# Epoch 50/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5660 - loss: 1.1149 - top2_accuracy: 0.7874
# Epoch 50: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5732 - loss: 1.1000 - top2_accuracy: 0.7898 - val_accuracy: 0.6250 - val_loss: 0.9931 - val_top2_accuracy: 0.8380 - learning_rate: 2.5000e-04
# Epoch 51/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5661 - loss: 1.1114 - top2_accuracy: 0.7888
# Epoch 51: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.5688 - loss: 1.1039 - top2_accuracy: 0.7902 - val_accuracy: 0.6300 - val_loss: 0.9913 - val_top2_accuracy: 0.8370 - learning_rate: 2.5000e-04
# Epoch 52/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5657 - loss: 1.1160 - top2_accuracy: 0.7821
# Epoch 52: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - accuracy: 0.5691 - loss: 1.1077 - top2_accuracy: 0.7893 - val_accuracy: 0.6300 - val_loss: 0.9892 - val_top2_accuracy: 0.8370 - learning_rate: 2.5000e-04
# Epoch 53/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5670 - loss: 1.1102 - top2_accuracy: 0.7840
# Epoch 53: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5753 - loss: 1.1005 - top2_accuracy: 0.7906 - val_accuracy: 0.6288 - val_loss: 0.9909 - val_top2_accuracy: 0.8388 - learning_rate: 2.5000e-04
# Epoch 54/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5689 - loss: 1.1162 - top2_accuracy: 0.7905
# Epoch 54: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5719 - loss: 1.1047 - top2_accuracy: 0.7905 - val_accuracy: 0.6313 - val_loss: 0.9896 - val_top2_accuracy: 0.8403 - learning_rate: 2.5000e-04
# Epoch 55/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5638 - loss: 1.1186 - top2_accuracy: 0.7843
# Epoch 55: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5671 - loss: 1.1113 - top2_accuracy: 0.7859 - val_accuracy: 0.6225 - val_loss: 0.9952 - val_top2_accuracy: 0.8378 - learning_rate: 2.5000e-04
# Epoch 56/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5596 - loss: 1.1124 - top2_accuracy: 0.7803
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 56: val_accuracy did not improve from 0.63300
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5648 - loss: 1.1037 - top2_accuracy: 0.7865 - val_accuracy: 0.6270 - val_loss: 0.9921 - val_top2_accuracy: 0.8407 - learning_rate: 2.5000e-04
# Epoch 57/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5695 - loss: 1.1079 - top2_accuracy: 0.7841
# Epoch 57: val_accuracy improved from 0.63300 to 0.63475, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 57: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5765 - loss: 1.0942 - top2_accuracy: 0.7902 - val_accuracy: 0.6348 - val_loss: 0.9919 - val_top2_accuracy: 0.8388 - learning_rate: 1.2500e-04
# Epoch 58/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5702 - loss: 1.0996 - top2_accuracy: 0.7921
# Epoch 58: val_accuracy improved from 0.63475 to 0.63500, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 58: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5744 - loss: 1.0908 - top2_accuracy: 0.7945 - val_accuracy: 0.6350 - val_loss: 0.9895 - val_top2_accuracy: 0.8410 - learning_rate: 1.2500e-04
# Epoch 59/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5700 - loss: 1.1082 - top2_accuracy: 0.7908
# Epoch 59: val_accuracy improved from 0.63500 to 0.63650, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 59: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.5760 - loss: 1.0935 - top2_accuracy: 0.7950 - val_accuracy: 0.6365 - val_loss: 0.9864 - val_top2_accuracy: 0.8403 - learning_rate: 1.2500e-04
# Epoch 60/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5662 - loss: 1.1001 - top2_accuracy: 0.7869
# Epoch 60: val_accuracy improved from 0.63650 to 0.64125, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 60: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5713 - loss: 1.0919 - top2_accuracy: 0.7915 - val_accuracy: 0.6413 - val_loss: 0.9836 - val_top2_accuracy: 0.8410 - learning_rate: 1.2500e-04
# Epoch 61/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5685 - loss: 1.1014 - top2_accuracy: 0.7911
# Epoch 61: val_accuracy did not improve from 0.64125
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5743 - loss: 1.0898 - top2_accuracy: 0.7957 - val_accuracy: 0.6367 - val_loss: 0.9851 - val_top2_accuracy: 0.8415 - learning_rate: 1.2500e-04
# Epoch 62/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5579 - loss: 1.1133 - top2_accuracy: 0.7817
# Epoch 62: val_accuracy improved from 0.64125 to 0.64275, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 62: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.5685 - loss: 1.0968 - top2_accuracy: 0.7888 - val_accuracy: 0.6428 - val_loss: 0.9807 - val_top2_accuracy: 0.8430 - learning_rate: 1.2500e-04
# Epoch 63/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5725 - loss: 1.1065 - top2_accuracy: 0.7878
# Epoch 63: val_accuracy did not improve from 0.64275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5738 - loss: 1.0971 - top2_accuracy: 0.7907 - val_accuracy: 0.6380 - val_loss: 0.9838 - val_top2_accuracy: 0.8403 - learning_rate: 1.2500e-04
# Epoch 64/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5594 - loss: 1.1136 - top2_accuracy: 0.7862
# Epoch 64: val_accuracy did not improve from 0.64275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5702 - loss: 1.0954 - top2_accuracy: 0.7920 - val_accuracy: 0.6370 - val_loss: 0.9840 - val_top2_accuracy: 0.8400 - learning_rate: 1.2500e-04
# Epoch 65/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5678 - loss: 1.1070 - top2_accuracy: 0.7832
# Epoch 65: val_accuracy did not improve from 0.64275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5753 - loss: 1.0921 - top2_accuracy: 0.7920 - val_accuracy: 0.6345 - val_loss: 0.9845 - val_top2_accuracy: 0.8403 - learning_rate: 1.2500e-04
# Epoch 66/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5626 - loss: 1.1060 - top2_accuracy: 0.7824
# Epoch 66: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 66: val_accuracy did not improve from 0.64275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.5681 - loss: 1.0933 - top2_accuracy: 0.7892 - val_accuracy: 0.6390 - val_loss: 0.9820 - val_top2_accuracy: 0.8420 - learning_rate: 1.2500e-04
# Epoch 67/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5732 - loss: 1.0922 - top2_accuracy: 0.7891
# Epoch 67: val_accuracy did not improve from 0.64275
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.5759 - loss: 1.0840 - top2_accuracy: 0.7925 - val_accuracy: 0.6407 - val_loss: 0.9797 - val_top2_accuracy: 0.8410 - learning_rate: 6.2500e-05
# Epoch 68/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5747 - loss: 1.0953 - top2_accuracy: 0.7906
# Epoch 68: val_accuracy improved from 0.64275 to 0.64325, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 68: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5795 - loss: 1.0818 - top2_accuracy: 0.7989 - val_accuracy: 0.6432 - val_loss: 0.9771 - val_top2_accuracy: 0.8430 - learning_rate: 6.2500e-05
# Epoch 69/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5727 - loss: 1.0960 - top2_accuracy: 0.7932
# Epoch 69: val_accuracy did not improve from 0.64325
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.5798 - loss: 1.0792 - top2_accuracy: 0.7981 - val_accuracy: 0.6388 - val_loss: 0.9786 - val_top2_accuracy: 0.8400 - learning_rate: 6.2500e-05
# Epoch 70/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5773 - loss: 1.0931 - top2_accuracy: 0.7912
# Epoch 70: val_accuracy did not improve from 0.64325
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.5772 - loss: 1.0811 - top2_accuracy: 0.7972 - val_accuracy: 0.6410 - val_loss: 0.9773 - val_top2_accuracy: 0.8422 - learning_rate: 6.2500e-05
# Epoch 71/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5738 - loss: 1.0999 - top2_accuracy: 0.7872
# Epoch 71: val_accuracy did not improve from 0.64325
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5791 - loss: 1.0871 - top2_accuracy: 0.7914 - val_accuracy: 0.6388 - val_loss: 0.9775 - val_top2_accuracy: 0.8438 - learning_rate: 6.2500e-05
# Epoch 72/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5705 - loss: 1.0944 - top2_accuracy: 0.7883
# Epoch 72: val_accuracy improved from 0.64325 to 0.64550, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 72: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5717 - loss: 1.0872 - top2_accuracy: 0.7946 - val_accuracy: 0.6455 - val_loss: 0.9754 - val_top2_accuracy: 0.8430 - learning_rate: 6.2500e-05
# Epoch 73/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5705 - loss: 1.0979 - top2_accuracy: 0.7890
# Epoch 73: val_accuracy did not improve from 0.64550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5748 - loss: 1.0862 - top2_accuracy: 0.7939 - val_accuracy: 0.6420 - val_loss: 0.9764 - val_top2_accuracy: 0.8422 - learning_rate: 6.2500e-05
# Epoch 74/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5689 - loss: 1.0918 - top2_accuracy: 0.7878
# Epoch 74: val_accuracy did not improve from 0.64550
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5750 - loss: 1.0845 - top2_accuracy: 0.7927 - val_accuracy: 0.6415 - val_loss: 0.9758 - val_top2_accuracy: 0.8445 - learning_rate: 6.2500e-05
# Epoch 75/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5710 - loss: 1.0956 - top2_accuracy: 0.7928
# Epoch 75: val_accuracy improved from 0.64550 to 0.64625, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 75: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5769 - loss: 1.0845 - top2_accuracy: 0.7964 - val_accuracy: 0.6463 - val_loss: 0.9742 - val_top2_accuracy: 0.8432 - learning_rate: 6.2500e-05
# Epoch 76/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5734 - loss: 1.1001 - top2_accuracy: 0.7860
# Epoch 76: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5779 - loss: 1.0895 - top2_accuracy: 0.7929 - val_accuracy: 0.6420 - val_loss: 0.9752 - val_top2_accuracy: 0.8445 - learning_rate: 6.2500e-05
# Epoch 77/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5729 - loss: 1.0886 - top2_accuracy: 0.7945
# Epoch 77: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5765 - loss: 1.0773 - top2_accuracy: 0.7963 - val_accuracy: 0.6415 - val_loss: 0.9748 - val_top2_accuracy: 0.8447 - learning_rate: 6.2500e-05
# Epoch 78/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5682 - loss: 1.0932 - top2_accuracy: 0.7885
# Epoch 78: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5732 - loss: 1.0822 - top2_accuracy: 0.7934 - val_accuracy: 0.6420 - val_loss: 0.9739 - val_top2_accuracy: 0.8455 - learning_rate: 6.2500e-05
# Epoch 79/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5702 - loss: 1.0956 - top2_accuracy: 0.7918
# Epoch 79: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5764 - loss: 1.0823 - top2_accuracy: 0.7961 - val_accuracy: 0.6415 - val_loss: 0.9747 - val_top2_accuracy: 0.8438 - learning_rate: 6.2500e-05
# Epoch 80/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5708 - loss: 1.0910 - top2_accuracy: 0.7905
# Epoch 80: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5768 - loss: 1.0850 - top2_accuracy: 0.7954 - val_accuracy: 0.6435 - val_loss: 0.9743 - val_top2_accuracy: 0.8430 - learning_rate: 6.2500e-05
# Epoch 81/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5734 - loss: 1.0914 - top2_accuracy: 0.7944
# Epoch 81: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.5791 - loss: 1.0795 - top2_accuracy: 0.8005 - val_accuracy: 0.6445 - val_loss: 0.9734 - val_top2_accuracy: 0.8430 - learning_rate: 6.2500e-05
# Epoch 82/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5789 - loss: 1.0912 - top2_accuracy: 0.7916
# Epoch 82: val_accuracy did not improve from 0.64625
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5804 - loss: 1.0803 - top2_accuracy: 0.7980 - val_accuracy: 0.6428 - val_loss: 0.9738 - val_top2_accuracy: 0.8432 - learning_rate: 6.2500e-05
# Epoch 83/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5820 - loss: 1.0852 - top2_accuracy: 0.7922
# Epoch 83: val_accuracy improved from 0.64625 to 0.64675, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 83: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.5836 - loss: 1.0777 - top2_accuracy: 0.7963 - val_accuracy: 0.6467 - val_loss: 0.9731 - val_top2_accuracy: 0.8443 - learning_rate: 6.2500e-05
# Epoch 84/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5771 - loss: 1.0874 - top2_accuracy: 0.7940
# Epoch 84: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5789 - loss: 1.0803 - top2_accuracy: 0.7962 - val_accuracy: 0.6428 - val_loss: 0.9730 - val_top2_accuracy: 0.8418 - learning_rate: 6.2500e-05
# Epoch 85/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5665 - loss: 1.0936 - top2_accuracy: 0.7892
# Epoch 85: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5749 - loss: 1.0872 - top2_accuracy: 0.7925 - val_accuracy: 0.6463 - val_loss: 0.9734 - val_top2_accuracy: 0.8440 - learning_rate: 6.2500e-05
# Epoch 86/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5729 - loss: 1.0882 - top2_accuracy: 0.7978
# Epoch 86: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 91ms/step - accuracy: 0.5770 - loss: 1.0794 - top2_accuracy: 0.7992 - val_accuracy: 0.6450 - val_loss: 0.9731 - val_top2_accuracy: 0.8428 - learning_rate: 6.2500e-05
# Epoch 87/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5723 - loss: 1.0930 - top2_accuracy: 0.7939
# Epoch 87: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.5777 - loss: 1.0816 - top2_accuracy: 0.7975 - val_accuracy: 0.6438 - val_loss: 0.9737 - val_top2_accuracy: 0.8440 - learning_rate: 6.2500e-05
# Epoch 88/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5688 - loss: 1.0863 - top2_accuracy: 0.7912
# Epoch 88: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.5776 - loss: 1.0790 - top2_accuracy: 0.7951 - val_accuracy: 0.6432 - val_loss: 0.9723 - val_top2_accuracy: 0.8447 - learning_rate: 6.2500e-05
# Epoch 89/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5701 - loss: 1.0959 - top2_accuracy: 0.7926
# Epoch 89: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.5768 - loss: 1.0835 - top2_accuracy: 0.7987 - val_accuracy: 0.6465 - val_loss: 0.9712 - val_top2_accuracy: 0.8422 - learning_rate: 6.2500e-05
# Epoch 90/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5640 - loss: 1.0923 - top2_accuracy: 0.7837
# Epoch 90: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5696 - loss: 1.0876 - top2_accuracy: 0.7903 - val_accuracy: 0.6438 - val_loss: 0.9718 - val_top2_accuracy: 0.8438 - learning_rate: 6.2500e-05
# Epoch 91/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5717 - loss: 1.0914 - top2_accuracy: 0.7880
# Epoch 91: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5750 - loss: 1.0837 - top2_accuracy: 0.7924 - val_accuracy: 0.6460 - val_loss: 0.9724 - val_top2_accuracy: 0.8420 - learning_rate: 6.2500e-05
# Epoch 92/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5768 - loss: 1.0810 - top2_accuracy: 0.7973
# Epoch 92: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5750 - loss: 1.0775 - top2_accuracy: 0.7982 - val_accuracy: 0.6463 - val_loss: 0.9707 - val_top2_accuracy: 0.8445 - learning_rate: 6.2500e-05
# Epoch 93/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5696 - loss: 1.0945 - top2_accuracy: 0.7915
# Epoch 93: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5737 - loss: 1.0867 - top2_accuracy: 0.7951 - val_accuracy: 0.6440 - val_loss: 0.9711 - val_top2_accuracy: 0.8445 - learning_rate: 6.2500e-05
# Epoch 94/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5751 - loss: 1.0919 - top2_accuracy: 0.7895
# Epoch 94: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.5771 - loss: 1.0843 - top2_accuracy: 0.7932 - val_accuracy: 0.6447 - val_loss: 0.9717 - val_top2_accuracy: 0.8447 - learning_rate: 6.2500e-05
# Epoch 95/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5781 - loss: 1.0928 - top2_accuracy: 0.7943
# Epoch 95: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.5806 - loss: 1.0815 - top2_accuracy: 0.7983 - val_accuracy: 0.6417 - val_loss: 0.9724 - val_top2_accuracy: 0.8432 - learning_rate: 6.2500e-05
# Epoch 96/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5790 - loss: 1.0927 - top2_accuracy: 0.7943
# Epoch 96: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 96: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.5776 - loss: 1.0834 - top2_accuracy: 0.7981 - val_accuracy: 0.6430 - val_loss: 0.9719 - val_top2_accuracy: 0.8438 - learning_rate: 6.2500e-05
# Epoch 97/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5768 - loss: 1.0860 - top2_accuracy: 0.7925
# Epoch 97: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5824 - loss: 1.0763 - top2_accuracy: 0.7973 - val_accuracy: 0.6453 - val_loss: 0.9720 - val_top2_accuracy: 0.8455 - learning_rate: 3.1250e-05
# Epoch 98/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5805 - loss: 1.0795 - top2_accuracy: 0.7988
# Epoch 98: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5814 - loss: 1.0749 - top2_accuracy: 0.7974 - val_accuracy: 0.6438 - val_loss: 0.9708 - val_top2_accuracy: 0.8445 - learning_rate: 3.1250e-05
# Epoch 99/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5745 - loss: 1.0945 - top2_accuracy: 0.7891
# Epoch 99: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5811 - loss: 1.0818 - top2_accuracy: 0.7963 - val_accuracy: 0.6467 - val_loss: 0.9711 - val_top2_accuracy: 0.8462 - learning_rate: 3.1250e-05
# Epoch 100/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5766 - loss: 1.0952 - top2_accuracy: 0.7882
# Epoch 100: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5790 - loss: 1.0822 - top2_accuracy: 0.7947 - val_accuracy: 0.6453 - val_loss: 0.9705 - val_top2_accuracy: 0.8462 - learning_rate: 3.1250e-05
# Epoch 101/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5689 - loss: 1.0943 - top2_accuracy: 0.7922
# Epoch 101: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5745 - loss: 1.0833 - top2_accuracy: 0.7961 - val_accuracy: 0.6450 - val_loss: 0.9703 - val_top2_accuracy: 0.8455 - learning_rate: 3.1250e-05
# Epoch 102/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5741 - loss: 1.0905 - top2_accuracy: 0.7907
# Epoch 102: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5777 - loss: 1.0781 - top2_accuracy: 0.7940 - val_accuracy: 0.6447 - val_loss: 0.9707 - val_top2_accuracy: 0.8455 - learning_rate: 3.1250e-05
# Epoch 103/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5765 - loss: 1.0905 - top2_accuracy: 0.7893
# Epoch 103: val_accuracy did not improve from 0.64675
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5796 - loss: 1.0804 - top2_accuracy: 0.7948 - val_accuracy: 0.6460 - val_loss: 0.9707 - val_top2_accuracy: 0.8447 - learning_rate: 3.1250e-05
# Epoch 104/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5769 - loss: 1.0884 - top2_accuracy: 0.7962
# Epoch 104: val_accuracy improved from 0.64675 to 0.64700, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 104: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5821 - loss: 1.0751 - top2_accuracy: 0.7995 - val_accuracy: 0.6470 - val_loss: 0.9698 - val_top2_accuracy: 0.8470 - learning_rate: 3.1250e-05
# Epoch 105/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5722 - loss: 1.0942 - top2_accuracy: 0.7928
# Epoch 105: val_accuracy did not improve from 0.64700
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.5782 - loss: 1.0757 - top2_accuracy: 0.7967 - val_accuracy: 0.6465 - val_loss: 0.9692 - val_top2_accuracy: 0.8478 - learning_rate: 3.1250e-05
# Epoch 106/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5866 - loss: 1.0840 - top2_accuracy: 0.7958
# Epoch 106: val_accuracy did not improve from 0.64700
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - accuracy: 0.5819 - loss: 1.0770 - top2_accuracy: 0.7955 - val_accuracy: 0.6465 - val_loss: 0.9696 - val_top2_accuracy: 0.8438 - learning_rate: 3.1250e-05
# Epoch 107/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5762 - loss: 1.0887 - top2_accuracy: 0.7908
# Epoch 107: val_accuracy did not improve from 0.64700
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - accuracy: 0.5830 - loss: 1.0751 - top2_accuracy: 0.7967 - val_accuracy: 0.6470 - val_loss: 0.9693 - val_top2_accuracy: 0.8460 - learning_rate: 3.1250e-05
# Epoch 108/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5740 - loss: 1.0874 - top2_accuracy: 0.7956
# Epoch 108: val_accuracy improved from 0.64700 to 0.64775, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 108: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - accuracy: 0.5753 - loss: 1.0805 - top2_accuracy: 0.7981 - val_accuracy: 0.6478 - val_loss: 0.9693 - val_top2_accuracy: 0.8432 - learning_rate: 3.1250e-05
# Epoch 109/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5768 - loss: 1.0799 - top2_accuracy: 0.7972
# Epoch 109: val_accuracy did not improve from 0.64775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - accuracy: 0.5784 - loss: 1.0737 - top2_accuracy: 0.7962 - val_accuracy: 0.6467 - val_loss: 0.9689 - val_top2_accuracy: 0.8443 - learning_rate: 3.1250e-05
# Epoch 110/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5794 - loss: 1.0886 - top2_accuracy: 0.7966
# Epoch 110: val_accuracy did not improve from 0.64775
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.5811 - loss: 1.0772 - top2_accuracy: 0.7969 - val_accuracy: 0.6453 - val_loss: 0.9687 - val_top2_accuracy: 0.8447 - learning_rate: 3.1250e-05
# Epoch 111/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5711 - loss: 1.0888 - top2_accuracy: 0.7908
# Epoch 111: val_accuracy improved from 0.64775 to 0.64900, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 111: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - accuracy: 0.5779 - loss: 1.0793 - top2_accuracy: 0.7963 - val_accuracy: 0.6490 - val_loss: 0.9691 - val_top2_accuracy: 0.8447 - learning_rate: 3.1250e-05
# Epoch 112/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5815 - loss: 1.0775 - top2_accuracy: 0.7926
# Epoch 112: val_accuracy improved from 0.64900 to 0.64975, saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
#
# Epoch 112: finished saving model to /Users/laurent/Projects/projet-fingerprint-validator/models/MobileNetV2_FingerPrint_Model_5_classes.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 24s 97ms/step - accuracy: 0.5836 - loss: 1.0695 - top2_accuracy: 0.8009 - val_accuracy: 0.6497 - val_loss: 0.9681 - val_top2_accuracy: 0.8460 - learning_rate: 3.1250e-05
# Epoch 113/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5809 - loss: 1.0862 - top2_accuracy: 0.7944
# Epoch 113: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.5825 - loss: 1.0763 - top2_accuracy: 0.7981 - val_accuracy: 0.6482 - val_loss: 0.9679 - val_top2_accuracy: 0.8450 - learning_rate: 3.1250e-05
# Epoch 114/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5743 - loss: 1.0919 - top2_accuracy: 0.7935
# Epoch 114: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.5777 - loss: 1.0768 - top2_accuracy: 0.7989 - val_accuracy: 0.6485 - val_loss: 0.9683 - val_top2_accuracy: 0.8455 - learning_rate: 3.1250e-05
# Epoch 115/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5776 - loss: 1.0840 - top2_accuracy: 0.7922
# Epoch 115: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.5824 - loss: 1.0723 - top2_accuracy: 0.7989 - val_accuracy: 0.6485 - val_loss: 0.9685 - val_top2_accuracy: 0.8453 - learning_rate: 3.1250e-05
# Epoch 116/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5763 - loss: 1.0906 - top2_accuracy: 0.7932
# Epoch 116: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.5768 - loss: 1.0795 - top2_accuracy: 0.7968 - val_accuracy: 0.6492 - val_loss: 0.9676 - val_top2_accuracy: 0.8460 - learning_rate: 3.1250e-05
# Epoch 117/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5801 - loss: 1.0893 - top2_accuracy: 0.7959
# Epoch 117: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.5785 - loss: 1.0815 - top2_accuracy: 0.7969 - val_accuracy: 0.6495 - val_loss: 0.9678 - val_top2_accuracy: 0.8455 - learning_rate: 3.1250e-05
# Epoch 118/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5809 - loss: 1.0791 - top2_accuracy: 0.7968
# Epoch 118: val_accuracy did not improve from 0.64975
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.5791 - loss: 1.0727 - top2_accuracy: 0.7992 - val_accuracy: 0.6480 - val_loss: 0.9679 - val_top2_accuracy: 0.8447 - learning_rate: 3.1250e-05
# Epoch 119/120
#  52/249 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.5704 - loss: 1.0948 - top2_accuracy: 0.7949

# %% [markdown]
# ## Frozen Model Evaluation

# %%
print("🔍 Diagnostic of frozen model\n")
print("="*150)

# Make a few prédictions using validation dataset
num_examples_predictions = 20
for images, labels in val_ds_prepared.take(1):
    predictions = mobilenet_fingerprint_model.predict(images[:num_examples_predictions], verbose=0)
    
    print("\n📊 Prediction samples :")
    print("-"*150)
    
    for i in range(num_examples_predictions):

        example_predictions = np.copy(predictions[i])

        true_label = np.argmax(labels[i])
        top1_pred_label = np.argmax(example_predictions)
        top1_confidence = example_predictions[top1_pred_label]

        example_predictions[top1_pred_label] = 0
        top2_pred_label = np.argmax(example_predictions)
        top2_confidence = example_predictions[top2_pred_label]

        status = "✅" if true_label == top1_pred_label else "❌"
        print(f"{status} Image {i+1}: Label={class_names[true_label]:12s} | Prediction={class_names[top1_pred_label]:12s} | Confidence={top1_confidence*100:5.1f}% | 2nd Prediction={class_names[top2_pred_label]:12s} | 2nd Confidence={top2_confidence*100:5.1f}%")

print("\n" + "="*150)

# %%
# Evaluation using validation dataset
print("📊 Evaluation of frozen model using validation dataset...\n")

results_model_frozen = mobilenet_fingerprint_model.evaluate(val_ds_prepared, verbose=0)

print("Results :")
print(f"  - Loss                : {results_model_frozen[0]:.4f}")
print(f"  - Accuracy            : {results_model_frozen[1]*100:.2f}%")
print(f"  - Top-2 Accuracy      : {results_model_frozen[2]*100:.2f}%")

# Display training grpahs
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_fit.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_fit.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Frozen model', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_fit.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_fit.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Top2 Accuracy
axes[2].plot(history_fit.history['top2_accuracy'], label='Train Top-2Accuracy', linewidth=2)
axes[2].plot(history_fit.history['val_top2_accuracy'], label='Val Top-2Accuracy', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Top2 Accuracy', fontsize=12)
axes[2].set_title('Top2 Accuracy - Frozen model', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle(f'{MobileNet_version} model training with feature extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
